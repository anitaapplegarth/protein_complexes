# %%
"""
Check whether the same proteins end up in the very_large test set
across the 15 repeated stratified splits.
"""

import pandas as pd
from collections import Counter

# ── Load ──────────────────────────────────────────────────────────────
df = pd.read_csv("../../data/lookup_tables/cp_ess_protein_splits.csv")

# ── Filter to very_large test proteins ────────────────────────────────
vl_test = df[(df["group_bucket"] == "very_large") & (df["split"] == "test")]

# ── 1. Which group lands in test per split? ───────────────────────────
print("=" * 60)
print("1. Which very_large group is in TEST per split?")
print("=" * 60)
groups_per_split = (
    vl_test.groupby("split_index")["group_id"]
    .apply(lambda x: sorted(x.unique()))
)
for split_idx, grps in groups_per_split.items():
    print(f"  Split {split_idx:>2d}: {', '.join(grps)}")

# ── 2. Summary of all very_large groups ───────────────────────────────
print("\n" + "=" * 60)
print("2. All very_large groups and their sizes")
print("=" * 60)
vl_all = df[df["group_bucket"] == "very_large"]
for gid, sub in sorted(vl_all.groupby("group_id")):
    size = int(sub["group_size"].iloc[0])
    test_splits = sorted(
        vl_test[vl_test["group_id"] == gid]["split_index"].unique()
    )
    print(f"  {gid}: {size:>4d} proteins  |  in test for splits {test_splits}")

# ── 3. Test set sizes per split ───────────────────────────────────────
print("\n" + "=" * 60)
print("3. very_large test set size per split")
print("=" * 60)
proteins_per_split = vl_test.groupby("split_index")["UniProt_AC"].apply(set)
for split_idx, prots in proteins_per_split.items():
    print(f"  Split {split_idx:>2d}: {len(prots):>4d} proteins")

# ── 4. Overlap statistics ─────────────────────────────────────────────
print("\n" + "=" * 60)
print("4. Overlap statistics across all 15 splits")
print("=" * 60)
common = set.intersection(*proteins_per_split.values)
union = set.union(*proteins_per_split.values)
print(f"  Intersection (in ALL 15 test sets): {len(common)}")
print(f"  Union (in ANY test set):            {len(union)}")
if len(union) > 0:
    print(f"  Jaccard similarity:                 {len(common) / len(union):.3f}")

# ── 5. How many splits does each protein appear in test? ──────────────
print("\n" + "=" * 60)
print("5. Per-protein test frequency (how many splits is each protein in test?)")
print("=" * 60)
freq = vl_test.groupby("UniProt_AC")["split_index"].nunique()
print(freq.value_counts().sort_index().to_string())
# Out:
# ============================================================
# 1. Which very_large group is in TEST per split?
# ============================================================
#   Split  1: grp_1179
#   Split  2: grp_0064
#   Split  3: grp_0064
#   Split  4: grp_0222
#   Split  5: grp_0000
#   Split  6: grp_1179
#   Split  7: grp_0000
#   Split  8: grp_0222
#   Split  9: grp_0222
#   Split 10: grp_0064
#   Split 11: grp_0000
#   Split 12: grp_1179
#   Split 13: grp_0000
#   Split 14: grp_0000
#   Split 15: grp_0064
#
# ============================================================
# 2. All very_large groups and their sizes
# ============================================================
#   grp_0000:   51 proteins  |  in test for splits [np.int64(5), np.int64(7), np.int64(11), np.int64(13), np.int64(14)]
#   grp_0064:   90 proteins  |  in test for splits [np.int64(2), np.int64(3), np.int64(10), np.int64(15)]
#   grp_0222:  113 proteins  |  in test for splits [np.int64(4), np.int64(8), np.int64(9)]
#   grp_1179:   89 proteins  |  in test for splits [np.int64(1), np.int64(6), np.int64(12)]
#
# ============================================================
# 3. very_large test set size per split
# ============================================================
#   Split  1:   89 proteins
#   Split  2:   90 proteins
#   Split  3:   90 proteins
#   Split  4:  113 proteins
#   Split  5:   51 proteins
#   Split  6:   89 proteins
#   Split  7:   51 proteins
#   Split  8:  113 proteins
#   Split  9:  113 proteins
#   Split 10:   90 proteins
#   Split 11:   51 proteins
#   Split 12:   89 proteins
#   Split 13:   51 proteins
#   Split 14:   51 proteins
#   Split 15:   90 proteins
#
# ============================================================
# 4. Overlap statistics across all 15 splits
# ============================================================
#   Intersection (in ALL 15 test sets): 0
#   Union (in ANY test set):            343
#   Jaccard similarity:                 0.000
#
# ============================================================
# 5. Per-protein test frequency (how many splits is each protein in test?)
# ============================================================
# split_index
# 3    202
# 4     90
# 5     51

# %%
"""
Check whether the same proteins end up in the very_large test set
across the 15 repeated stratified splits.
"""

import pandas as pd
from collections import Counter

# ── Load ──────────────────────────────────────────────────────────────
df = pd.read_csv("../../data/lookup_tables/corum_ess_protein_splits.csv")

# ── Filter to very_large test proteins ────────────────────────────────
vl_test = df[(df["group_bucket"] == "very_large") & (df["split"] == "test")]

# ── 1. Which group lands in test per split? ───────────────────────────
print("=" * 60)
print("1. Which very_large group is in TEST per split?")
print("=" * 60)
groups_per_split = (
    vl_test.groupby("split_index")["group_id"]
    .apply(lambda x: sorted(x.unique()))
)
for split_idx, grps in groups_per_split.items():
    print(f"  Split {split_idx:>2d}: {', '.join(grps)}")

# ── 2. Summary of all very_large groups ───────────────────────────────
print("\n" + "=" * 60)
print("2. All very_large groups and their sizes")
print("=" * 60)
vl_all = df[df["group_bucket"] == "very_large"]
for gid, sub in sorted(vl_all.groupby("group_id")):
    size = int(sub["group_size"].iloc[0])
    test_splits = sorted(
        vl_test[vl_test["group_id"] == gid]["split_index"].unique()
    )
    print(f"  {gid}: {size:>4d} proteins  |  in test for splits {test_splits}")

# ── 3. Test set sizes per split ───────────────────────────────────────
print("\n" + "=" * 60)
print("3. very_large test set size per split")
print("=" * 60)
proteins_per_split = vl_test.groupby("split_index")["UniProt_AC"].apply(set)
for split_idx, prots in proteins_per_split.items():
    print(f"  Split {split_idx:>2d}: {len(prots):>4d} proteins")

# ── 4. Overlap statistics ─────────────────────────────────────────────
print("\n" + "=" * 60)
print("4. Overlap statistics across all 15 splits")
print("=" * 60)
common = set.intersection(*proteins_per_split.values)
union = set.union(*proteins_per_split.values)
print(f"  Intersection (in ALL 15 test sets): {len(common)}")
print(f"  Union (in ANY test set):            {len(union)}")
if len(union) > 0:
    print(f"  Jaccard similarity:                 {len(common) / len(union):.3f}")

# ── 5. How many splits does each protein appear in test? ──────────────
print("\n" + "=" * 60)
print("5. Per-protein test frequency (how many splits is each protein in test?)")
print("=" * 60)
freq = vl_test.groupby("UniProt_AC")["split_index"].nunique()
print(freq.value_counts().sort_index().to_string())
# Out:
# ============================================================
# 1. Which very_large group is in TEST per split?
# ============================================================
#   Split  1: grp_0514, grp_1262
#   Split  2: grp_1900, grp_1932
#   Split  3: grp_0152, grp_0761
#   Split  4: grp_1727, grp_1900
#   Split  5: grp_0152, grp_1764
#   Split  6: grp_1154, grp_1900
#   Split  7: grp_0514, grp_1764
#   Split  8: grp_1727, grp_1932
#   Split  9: grp_1900, grp_1932
#   Split 10: grp_0152, grp_1900
#   Split 11: grp_0038, grp_1154
#   Split 12: grp_0038, grp_1154
#   Split 13: grp_1727, grp_1900
#   Split 14: grp_0152, grp_1262
#   Split 15: grp_1154, grp_2065
#
# ============================================================
# 2. All very_large groups and their sizes
# ============================================================
#   grp_0038:   52 proteins  |  in test for splits [np.int64(11), np.int64(12)]
#   grp_0152:   71 proteins  |  in test for splits [np.int64(3), np.int64(5), np.int64(10), np.int64(14)]
#   grp_0514:  220 proteins  |  in test for splits [np.int64(1), np.int64(7)]
#   grp_0761:   51 proteins  |  in test for splits [np.int64(3)]
#   grp_1154:  119 proteins  |  in test for splits [np.int64(6), np.int64(11), np.int64(12), np.int64(15)]
#   grp_1184:   74 proteins  |  in test for splits []
#   grp_1262:   82 proteins  |  in test for splits [np.int64(1), np.int64(14)]
#   grp_1727:   91 proteins  |  in test for splits [np.int64(4), np.int64(8), np.int64(13)]
#   grp_1764:   59 proteins  |  in test for splits [np.int64(5), np.int64(7)]
#   grp_1900:   56 proteins  |  in test for splits [np.int64(2), np.int64(4), np.int64(6), np.int64(9), np.int64(10), np.int64(13)]
#   grp_1932:  117 proteins  |  in test for splits [np.int64(2), np.int64(8), np.int64(9)]
#   grp_2065:   53 proteins  |  in test for splits [np.int64(15)]
#
# ============================================================
# 3. very_large test set size per split
# ============================================================
#   Split  1:  302 proteins
#   Split  2:  173 proteins
#   Split  3:  122 proteins
#   Split  4:  147 proteins
#   Split  5:  130 proteins
#   Split  6:  175 proteins
#   Split  7:  279 proteins
#   Split  8:  208 proteins
#   Split  9:  173 proteins
#   Split 10:  127 proteins
#   Split 11:  171 proteins
#   Split 12:  171 proteins
#   Split 13:  147 proteins
#   Split 14:  153 proteins
#   Split 15:  172 proteins
#
# ============================================================
# 4. Overlap statistics across all 15 splits
# ============================================================
#   Intersection (in ALL 15 test sets): 0
#   Union (in ANY test set):            971
#   Jaccard similarity:                 0.000
#
# ============================================================
# 5. Per-protein test frequency (how many splits is each protein in test?)
# ============================================================
# split_index
# 1    104
# 2    413
# 3    208
# 4    190
# 6     56

# %%
"""
Check whether the same proteins end up in the very_large test set
across the 15 repeated stratified splits.
"""

import pandas as pd
from collections import Counter

# ── Load ──────────────────────────────────────────────────────────────
df = pd.read_csv("../../data/lookup_tables/corum_drug_hpa_protein_splits.csv")

# ── Filter to very_large test proteins ────────────────────────────────
vl_test = df[(df["group_bucket"] == "very_large") & (df["split"] == "test")]

# ── 1. Which group lands in test per split? ───────────────────────────
print("=" * 60)
print("1. Which very_large group is in TEST per split?")
print("=" * 60)
groups_per_split = (
    vl_test.groupby("split_index")["group_id"]
    .apply(lambda x: sorted(x.unique()))
)
for split_idx, grps in groups_per_split.items():
    print(f"  Split {split_idx:>2d}: {', '.join(grps)}")

# ── 2. Summary of all very_large groups ───────────────────────────────
print("\n" + "=" * 60)
print("2. All very_large groups and their sizes")
print("=" * 60)
vl_all = df[df["group_bucket"] == "very_large"]
for gid, sub in sorted(vl_all.groupby("group_id")):
    size = int(sub["group_size"].iloc[0])
    test_splits = sorted(
        vl_test[vl_test["group_id"] == gid]["split_index"].unique()
    )
    print(f"  {gid}: {size:>4d} proteins  |  in test for splits {test_splits}")

# ── 3. Test set sizes per split ───────────────────────────────────────
print("\n" + "=" * 60)
print("3. very_large test set size per split")
print("=" * 60)
proteins_per_split = vl_test.groupby("split_index")["UniProt_AC"].apply(set)
for split_idx, prots in proteins_per_split.items():
    print(f"  Split {split_idx:>2d}: {len(prots):>4d} proteins")

# ── 4. Overlap statistics ─────────────────────────────────────────────
print("\n" + "=" * 60)
print("4. Overlap statistics across all 15 splits")
print("=" * 60)
common = set.intersection(*proteins_per_split.values)
union = set.union(*proteins_per_split.values)
print(f"  Intersection (in ALL 15 test sets): {len(common)}")
print(f"  Union (in ANY test set):            {len(union)}")
if len(union) > 0:
    print(f"  Jaccard similarity:                 {len(common) / len(union):.3f}")

# ── 5. How many splits does each protein appear in test? ──────────────
print("\n" + "=" * 60)
print("5. Per-protein test frequency (how many splits is each protein in test?)")
print("=" * 60)
freq = vl_test.groupby("UniProt_AC")["split_index"].nunique()
print(freq.value_counts().sort_index().to_string())
# Out:
# ============================================================
# 1. Which very_large group is in TEST per split?
# ============================================================
#   Split  1: grp_0038, grp_1727
#   Split  2: grp_1900, grp_1932
#   Split  3: grp_0038, grp_1932
#   Split  4: grp_0761, grp_1727
#   Split  5: grp_0152, grp_1727
#   Split  6: grp_1154, grp_1900
#   Split  7: grp_0514, grp_1764
#   Split  8: grp_1184, grp_1262
#   Split  9: grp_1900, grp_1932
#   Split 10: grp_0152, grp_1900
#   Split 11: grp_1764, grp_1932
#   Split 12: grp_1154, grp_1184
#   Split 13: grp_0761, grp_2065
#   Split 14: grp_0152, grp_1262
#   Split 15: grp_1262, grp_1764
#
# ============================================================
# 2. All very_large groups and their sizes
# ============================================================
#   grp_0038:   52 proteins  |  in test for splits [np.int64(1), np.int64(3)]
#   grp_0152:   71 proteins  |  in test for splits [np.int64(5), np.int64(10), np.int64(14)]
#   grp_0514:  220 proteins  |  in test for splits [np.int64(7)]
#   grp_0761:   51 proteins  |  in test for splits [np.int64(4), np.int64(13)]
#   grp_1154:  119 proteins  |  in test for splits [np.int64(6), np.int64(12)]
#   grp_1184:   74 proteins  |  in test for splits [np.int64(8), np.int64(12)]
#   grp_1262:   82 proteins  |  in test for splits [np.int64(8), np.int64(14), np.int64(15)]
#   grp_1727:   91 proteins  |  in test for splits [np.int64(1), np.int64(4), np.int64(5)]
#   grp_1764:   59 proteins  |  in test for splits [np.int64(7), np.int64(11), np.int64(15)]
#   grp_1900:   56 proteins  |  in test for splits [np.int64(2), np.int64(6), np.int64(9), np.int64(10)]
#   grp_1932:  117 proteins  |  in test for splits [np.int64(2), np.int64(3), np.int64(9), np.int64(11)]
#   grp_2065:   53 proteins  |  in test for splits [np.int64(13)]
#
# ============================================================
# 3. very_large test set size per split
# ============================================================
#   Split  1:  143 proteins
#   Split  2:  173 proteins
#   Split  3:  169 proteins
#   Split  4:  142 proteins
#   Split  5:  162 proteins
#   Split  6:  175 proteins
#   Split  7:  279 proteins
#   Split  8:  156 proteins
#   Split  9:  173 proteins
#   Split 10:  127 proteins
#   Split 11:  176 proteins
#   Split 12:  193 proteins
#   Split 13:  104 proteins
#   Split 14:  153 proteins
#   Split 15:  141 proteins
#
# ============================================================
# 4. Overlap statistics across all 15 splits
# ============================================================
#   Intersection (in ALL 15 test sets): 0
#   Union (in ANY test set):            1045
#   Jaccard similarity:                 0.000
#
# ============================================================
# 5. Per-protein test frequency (how many splits is each protein in test?)
# ============================================================
# split_index
# 1    273
# 2    296
# 3    303
# 4    173

# %%
"""
Check whether the same proteins end up in the very_large test set
across the 15 repeated stratified splits.
"""

import pandas as pd
from collections import Counter

# ── Load ──────────────────────────────────────────────────────────────
df = pd.read_csv("../../data/lookup_tables/cp_drug_hpa_protein_splits.csv")

# ── Filter to very_large test proteins ────────────────────────────────
vl_test = df[(df["group_bucket"] == "very_large") & (df["split"] == "test")]

# ── 1. Which group lands in test per split? ───────────────────────────
print("=" * 60)
print("1. Which very_large group is in TEST per split?")
print("=" * 60)
groups_per_split = (
    vl_test.groupby("split_index")["group_id"]
    .apply(lambda x: sorted(x.unique()))
)
for split_idx, grps in groups_per_split.items():
    print(f"  Split {split_idx:>2d}: {', '.join(grps)}")

# ── 2. Summary of all very_large groups ───────────────────────────────
print("\n" + "=" * 60)
print("2. All very_large groups and their sizes")
print("=" * 60)
vl_all = df[df["group_bucket"] == "very_large"]
for gid, sub in sorted(vl_all.groupby("group_id")):
    size = int(sub["group_size"].iloc[0])
    test_splits = sorted(
        vl_test[vl_test["group_id"] == gid]["split_index"].unique()
    )
    print(f"  {gid}: {size:>4d} proteins  |  in test for splits {test_splits}")

# ── 3. Test set sizes per split ───────────────────────────────────────
print("\n" + "=" * 60)
print("3. very_large test set size per split")
print("=" * 60)
proteins_per_split = vl_test.groupby("split_index")["UniProt_AC"].apply(set)
for split_idx, prots in proteins_per_split.items():
    print(f"  Split {split_idx:>2d}: {len(prots):>4d} proteins")

# ── 4. Overlap statistics ─────────────────────────────────────────────
print("\n" + "=" * 60)
print("4. Overlap statistics across all 15 splits")
print("=" * 60)
common = set.intersection(*proteins_per_split.values)
union = set.union(*proteins_per_split.values)
print(f"  Intersection (in ALL 15 test sets): {len(common)}")
print(f"  Union (in ANY test set):            {len(union)}")
if len(union) > 0:
    print(f"  Jaccard similarity:                 {len(common) / len(union):.3f}")

# ── 5. How many splits does each protein appear in test? ──────────────
print("\n" + "=" * 60)
print("5. Per-protein test frequency (how many splits is each protein in test?)")
print("=" * 60)
freq = vl_test.groupby("UniProt_AC")["split_index"].nunique()
print(freq.value_counts().sort_index().to_string())
# Out:
# ============================================================
# 1. Which very_large group is in TEST per split?
# ============================================================
#   Split  1: grp_0000
#   Split  2: grp_0064
#   Split  3: grp_0000
#   Split  4: grp_0222
#   Split  5: grp_0000
#   Split  6: grp_0000
#   Split  7: grp_0000
#   Split  8: grp_1179
#   Split  9: grp_0000
#   Split 10: grp_0064
#   Split 11: grp_0000
#   Split 12: grp_0000
#   Split 13: grp_0000
#   Split 14: grp_0000
#   Split 15: grp_0000
#
# ============================================================
# 2. All very_large groups and their sizes
# ============================================================
#   grp_0000:   51 proteins  |  in test for splits [np.int64(1), np.int64(3), np.int64(5), np.int64(6), np.int64(7), np.int64(9), np.int64(11), np.int64(12), np.int64(13), np.int64(14), np.int64(15)]
#   grp_0064:   90 proteins  |  in test for splits [np.int64(2), np.int64(10)]
#   grp_0222:  113 proteins  |  in test for splits [np.int64(4)]
#   grp_1179:   89 proteins  |  in test for splits [np.int64(8)]
#
# ============================================================
# 3. very_large test set size per split
# ============================================================
#   Split  1:   51 proteins
#   Split  2:   90 proteins
#   Split  3:   51 proteins
#   Split  4:  113 proteins
#   Split  5:   51 proteins
#   Split  6:   51 proteins
#   Split  7:   51 proteins
#   Split  8:   89 proteins
#   Split  9:   51 proteins
#   Split 10:   90 proteins
#   Split 11:   51 proteins
#   Split 12:   51 proteins
#   Split 13:   51 proteins
#   Split 14:   51 proteins
#   Split 15:   51 proteins
#
# ============================================================
# 4. Overlap statistics across all 15 splits
# ============================================================
#   Intersection (in ALL 15 test sets): 0
#   Union (in ANY test set):            343
#   Jaccard similarity:                 0.000
#
# ============================================================
# 5. Per-protein test frequency (how many splits is each protein in test?)
# ============================================================
# split_index
# 1     202
# 2      90
# 11     51

# %%
"""
Check whether the same proteins end up in the very_large test set
across the 15 repeated stratified splits.
"""

import pandas as pd
from collections import Counter

# ── Load ──────────────────────────────────────────────────────────────
df = pd.read_csv("../../data/lookup_tables/cp_drug_chembl_protein_splits.csv")

# ── Filter to very_large test proteins ────────────────────────────────
vl_test = df[(df["group_bucket"] == "very_large") & (df["split"] == "test")]

# ── 1. Which group lands in test per split? ───────────────────────────
print("=" * 60)
print("1. Which very_large group is in TEST per split?")
print("=" * 60)
groups_per_split = (
    vl_test.groupby("split_index")["group_id"]
    .apply(lambda x: sorted(x.unique()))
)
for split_idx, grps in groups_per_split.items():
    print(f"  Split {split_idx:>2d}: {', '.join(grps)}")

# ── 2. Summary of all very_large groups ───────────────────────────────
print("\n" + "=" * 60)
print("2. All very_large groups and their sizes")
print("=" * 60)
vl_all = df[df["group_bucket"] == "very_large"]
for gid, sub in sorted(vl_all.groupby("group_id")):
    size = int(sub["group_size"].iloc[0])
    test_splits = sorted(
        vl_test[vl_test["group_id"] == gid]["split_index"].unique()
    )
    print(f"  {gid}: {size:>4d} proteins  |  in test for splits {test_splits}")

# ── 3. Test set sizes per split ───────────────────────────────────────
print("\n" + "=" * 60)
print("3. very_large test set size per split")
print("=" * 60)
proteins_per_split = vl_test.groupby("split_index")["UniProt_AC"].apply(set)
for split_idx, prots in proteins_per_split.items():
    print(f"  Split {split_idx:>2d}: {len(prots):>4d} proteins")

# ── 4. Overlap statistics ─────────────────────────────────────────────
print("\n" + "=" * 60)
print("4. Overlap statistics across all 15 splits")
print("=" * 60)
common = set.intersection(*proteins_per_split.values)
union = set.union(*proteins_per_split.values)
print(f"  Intersection (in ALL 15 test sets): {len(common)}")
print(f"  Union (in ANY test set):            {len(union)}")
if len(union) > 0:
    print(f"  Jaccard similarity:                 {len(common) / len(union):.3f}")

# ── 5. How many splits does each protein appear in test? ──────────────
print("\n" + "=" * 60)
print("5. Per-protein test frequency (how many splits is each protein in test?)")
print("=" * 60)
freq = vl_test.groupby("UniProt_AC")["split_index"].nunique()
print(freq.value_counts().sort_index().to_string())
# Out:
# ============================================================
# 1. Which very_large group is in TEST per split?
# ============================================================
#   Split  1: grp_1179
#   Split  2: grp_0064
#   Split  3: grp_0000
#   Split  4: grp_0222
#   Split  5: grp_0000
#   Split  6: grp_0000
#   Split  7: grp_1179
#   Split  8: grp_1179
#   Split  9: grp_0222
#   Split 10: grp_0064
#   Split 11: grp_0000
#   Split 12: grp_0000
#   Split 13: grp_0000
#   Split 14: grp_0000
#   Split 15: grp_0000
#
# ============================================================
# 2. All very_large groups and their sizes
# ============================================================
#   grp_0000:   51 proteins  |  in test for splits [np.int64(3), np.int64(5), np.int64(6), np.int64(11), np.int64(12), np.int64(13), np.int64(14), np.int64(15)]
#   grp_0064:   90 proteins  |  in test for splits [np.int64(2), np.int64(10)]
#   grp_0222:  113 proteins  |  in test for splits [np.int64(4), np.int64(9)]
#   grp_1179:   89 proteins  |  in test for splits [np.int64(1), np.int64(7), np.int64(8)]
#
# ============================================================
# 3. very_large test set size per split
# ============================================================
#   Split  1:   89 proteins
#   Split  2:   90 proteins
#   Split  3:   51 proteins
#   Split  4:  113 proteins
#   Split  5:   51 proteins
#   Split  6:   51 proteins
#   Split  7:   89 proteins
#   Split  8:   89 proteins
#   Split  9:  113 proteins
#   Split 10:   90 proteins
#   Split 11:   51 proteins
#   Split 12:   51 proteins
#   Split 13:   51 proteins
#   Split 14:   51 proteins
#   Split 15:   51 proteins
#
# ============================================================
# 4. Overlap statistics across all 15 splits
# ============================================================
#   Intersection (in ALL 15 test sets): 0
#   Union (in ANY test set):            343
#   Jaccard similarity:                 0.000
#
# ============================================================
# 5. Per-protein test frequency (how many splits is each protein in test?)
# ============================================================
# split_index
# 2    203
# 3     89
# 8     51
