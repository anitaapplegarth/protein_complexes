# %%
import pandas as pd
s = pd.read_csv('../../data/lookup_tables/protein_splits_all_strat.csv')
dt = pd.read_csv('../../data/lookup_tables/lu_drug_target_protein_chembl.csv')  # whatever your label file is

# merge and check positives per split in test
merged = s.merge(dt, left_on='UniProt_AC', right_on='ProteinId')
for idx in sorted(merged['split_index'].unique()):
    test = merged[(merged['split_index']==idx) & (merged['split']=='test')]
    n_pos = (test['target']==1).sum()
    print(f"Split {idx}: {len(test)} test proteins, {n_pos} positives ({100*n_pos/len(test):.1f}%)")
# Out:
# Split 1: 638 test proteins, 26 positives (4.1%)
# Split 2: 612 test proteins, 37 positives (6.0%)
# Split 3: 671 test proteins, 43 positives (6.4%)
# Split 4: 619 test proteins, 26 positives (4.2%)
# Split 5: 631 test proteins, 33 positives (5.2%)
# Split 6: 654 test proteins, 48 positives (7.3%)
# Split 7: 642 test proteins, 46 positives (7.2%)
# Split 8: 636 test proteins, 47 positives (7.4%)
# Split 9: 647 test proteins, 34 positives (5.3%)
# Split 10: 663 test proteins, 22 positives (3.3%)
# Split 11: 617 test proteins, 37 positives (6.0%)
# Split 12: 655 test proteins, 34 positives (5.2%)
# Split 13: 625 test proteins, 52 positives (8.3%)
# Split 14: 655 test proteins, 39 positives (6.0%)
# Split 15: 631 test proteins, 40 positives (6.3%)
