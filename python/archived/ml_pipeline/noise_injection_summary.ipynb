# %%
"""
noise_injection_summary.py
==========================
Produces ranked feature importance tables from the noise injection experiment,
showing where random features sit within each model's ranking.

Outputs
-------
  - noise_ranked_tables.txt        — plain-text ranked tables (for supervisor)
  - noise_ranked_hypergraph.csv    — full ranked hypergraph table with noise
  - noise_ranked_pairwise.csv      — full ranked pairwise table with noise
  - noise_ranked_random.csv        — pure random model noise floor
  - features_to_drop.txt           — recommended features to remove + rationale

Usage
-----
  python noise_injection_summary.py

  Expects these files in INPUT_DIR (output from cp_noise_injection.py):
    hypergraph_noise_importance.csv
    pairwise_noise_importance.csv
    random_noise_importance.csv
    noise_floor_summary.csv
"""

from pathlib import Path
import pandas as pd
import numpy as np

# =======================================================
# CONFIGURATION — update INPUT_DIR to your output folder
# =======================================================
INPUT_DIR  = Path("./randomforest/hpa_noise_injection/drug_target_family_splits")
OUTPUT_DIR = INPUT_DIR   # write summary files alongside the other outputs

MODEL_TYPE  = "RandomForest"
TASK        = "Drug Target Prediction"
N_SPLITS    = 15
N_SEEDS     = 3
N_NOISE     = 4

# Threshold rule: noise mean + 1 SD of the per-noise-feature means.
# A real feature must exceed this to be considered above the noise floor.
# Using the PURE RANDOM model's noise features as the reference, since that
# model has no real features that could influence the noise importance estimates.
THRESHOLD_RULE = "pure_random mean + 1 SD of per-feature means"


# =======================================================
# LOAD
# =======================================================

def load_tables():
    hyper = pd.read_csv(INPUT_DIR / 'hypergraph_noise_importance.csv')
    pair  = pd.read_csv(INPUT_DIR / 'pairwise_noise_importance.csv')
    rand  = pd.read_csv(INPUT_DIR / 'random_noise_importance.csv')
    floor = pd.read_csv(INPUT_DIR / 'noise_floor_summary.csv')
    return hyper, pair, rand, floor


# =======================================================
# THRESHOLD COMPUTATION
# =======================================================

def compute_threshold(rand_df: pd.DataFrame) -> tuple[float, float, float]:
    """
    Derive noise threshold from the pure-random model.

    Returns (noise_mean, noise_sd, threshold) where:
      noise_mean = mean of the per-noise-feature means
      noise_sd   = std  of the per-noise-feature means
      threshold  = noise_mean + noise_sd
    """
    noise_rows = rand_df[rand_df['feature'].str.startswith('rand_')]
    per_feature_means = noise_rows['mean'].values
    noise_mean = float(np.mean(per_feature_means))
    noise_sd   = float(np.std(per_feature_means))
    threshold  = noise_mean + noise_sd
    return noise_mean, noise_sd, threshold


# =======================================================
# BUILD RANKED TABLES
# =======================================================

def build_ranked_table(imp_df: pd.DataFrame, threshold: float) -> pd.DataFrame:
    """
    Merge real features and individual noise features into one ranked table.
    The pooled noise row ([noise × N]) is excluded — individual rows are used
    so the noise features appear at their actual rank positions.
    """
    # Real features
    real = imp_df[~imp_df['is_noise']].copy()

    # Individual noise features (exclude the pooled summary row)
    noise = imp_df[
        imp_df['feature'].str.startswith('rand_')
    ].copy()

    combined = pd.concat([real, noise], ignore_index=True)
    combined = combined.sort_values('mean', ascending=False).reset_index(drop=True)
    combined['rank'] = range(1, len(combined) + 1)
    combined['above_noise'] = combined['mean'] > threshold
    combined['type'] = combined['feature'].apply(
        lambda f: 'NOISE' if f.startswith('rand_') else 'real'
    )

    return combined[['rank', 'type', 'feature', 'mean', 'std', 'above_noise']]


# =======================================================
# PRINTING & SAVING
# =======================================================

def format_table(df: pd.DataFrame) -> str:
    lines = []
    header = f"  {'Rank':<5} {'Type':<7} {'Feature':<38} {'Mean':>9}  {'Std':>9}  {'Signal'}"
    lines.append(header)
    lines.append("  " + "-" * 80)
    for _, row in df.iterrows():
        signal = "✓ above noise" if row['above_noise'] else "– within noise"
        noise_marker = "  <-- NOISE" if row['type'] == 'NOISE' else ""
        lines.append(
            f"  {int(row['rank']):<5} {row['type']:<7} {row['feature']:<38} "
            f"{row['mean']:>9.5f}  {row['std']:>9.5f}  {signal}{noise_marker}"
        )
    return "\n".join(lines)


def write_summary(
    rand_df, pair_ranked, hyper_ranked,
    noise_mean, noise_sd, threshold,
    drop_pair, drop_hyper,
    output_path: Path,
):
    lines = []
    sep = "=" * 85

    lines += [
        sep,
        "  NOISE INJECTION — FEATURE IMPORTANCE RANKING SUMMARY",
        sep,
        f"  Task          : {TASK}",
        f"  Model         : {MODEL_TYPE}",
        f"  Splits × Seeds: {N_SPLITS} × {N_SEEDS} = {N_SPLITS * N_SEEDS} realisations per feature",
        f"  Noise features: {N_NOISE} (standard normal, i.i.d.)",
        f"  Threshold rule: {THRESHOLD_RULE}",
        "",
        f"  Noise floor (pure random model):",
        f"    Mean of per-feature means : {noise_mean:+.5f}",
        f"    SD   of per-feature means : {noise_sd:.5f}",
        f"    Threshold (mean + 1 SD)   : {threshold:+.5f}",
        "",
        "  Interpretation: a real feature must have mean importance > threshold",
        "  to be considered as carrying signal above noise.",
        "",
    ]

    # Pure random model
    lines += [
        sep,
        "  1. PURE RANDOM MODEL (noise features only)",
        sep,
        "  All importances should be near zero — confirms noise is uninformative.",
        "",
    ]
    noise_only = rand_df[rand_df['feature'].str.startswith('rand_')][
        ['feature', 'mean', 'std']
    ].copy()
    noise_only = noise_only.sort_values('mean', ascending=False).reset_index(drop=True)
    noise_only['rank'] = range(1, len(noise_only) + 1)
    hdr = f"  {'Rank':<5} {'Feature':<20} {'Mean':>9}  {'Std':>9}"
    lines.append(hdr)
    lines.append("  " + "-" * 48)
    for _, row in noise_only.iterrows():
        lines.append(f"  {int(row['rank']):<5} {row['feature']:<20} "
                     f"{row['mean']:>9.5f}  {row['std']:>9.5f}")
    lines.append("")

    # Pairwise
    lines += [
        sep,
        "  2. PAIRWISE + NOISE — Full ranked list",
        sep,
        "  Noise features (rand_*) are interleaved at their actual rank position.",
        "",
    ]
    lines.append(format_table(pair_ranked))
    lines.append("")

    # Hypergraph
    lines += [
        sep,
        "  3. HYPERGRAPH + NOISE — Full ranked list",
        sep,
        "  Noise features (rand_*) are interleaved at their actual rank position.",
        "",
    ]
    lines.append(format_table(hyper_ranked))
    lines.append("")

    # Features to drop
    lines += [
        sep,
        "  FEATURES TO DROP (at or below noise threshold)",
        sep,
        f"  Threshold: {threshold:+.5f}  ({THRESHOLD_RULE})",
        "",
    ]

    lines.append("  Pairwise features to drop:")
    if len(drop_pair) == 0:
        lines.append("    None — all pairwise features are above the noise floor.")
    else:
        for _, row in drop_pair.iterrows():
            lines.append(f"    rank {int(row['rank'])}: {row['feature']}  "
                         f"(mean={row['mean']:+.5f}, std={row['std']:.5f})")

    lines.append("")
    lines.append("  Hypergraph features to drop:")
    if len(drop_hyper) == 0:
        lines.append("    None — all hypergraph features are above the noise floor.")
    else:
        for _, row in drop_hyper.iterrows():
            lines.append(f"    rank {int(row['rank'])}: {row['feature']}  "
                         f"(mean={row['mean']:+.5f}, std={row['std']:.5f})")

    lines += [
        "",
        sep,
        "  RECOMMENDED FINAL FEATURE SETS",
        sep,
        "",
        "  Pairwise (unchanged):",
    ]
    pair_keep = pair_ranked[
        (~pair_ranked['feature'].str.startswith('rand_')) & pair_ranked['above_noise']
    ]
    for _, row in pair_keep.iterrows():
        lines.append(f"    {row['feature']}")

    lines += ["", "  Hypergraph (Range features removed):"]
    hyper_keep = hyper_ranked[
        (~hyper_ranked['feature'].str.startswith('rand_')) & hyper_ranked['above_noise']
    ]
    for _, row in hyper_keep.iterrows():
        lines.append(f"    {row['feature']}")

    lines += [
        "",
        "  NOTE: base_UniquePartners is technically above threshold but sits",
        "  interleaved with noise features and is likely redundant with base_Degree",
        "  (high correlation; permuting it doesn't hurt because base_Degree compensates).",
        "  Consider testing with and without it in the final model.",
        "",
        sep,
    ]

    text = "\n".join(lines)
    output_path.write_text(text)
    print(text)
    return text


# =======================================================
# MAIN
# =======================================================

if __name__ == '__main__':

    print(f"Reading from: {INPUT_DIR}\n")
    hyper_df, pair_df, rand_df, floor_df = load_tables()

    noise_mean, noise_sd, threshold = compute_threshold(rand_df)

    pair_ranked  = build_ranked_table(pair_df,  threshold)
    hyper_ranked = build_ranked_table(hyper_df, threshold)

    drop_pair  = pair_ranked[
        ~pair_ranked['feature'].str.startswith('rand_') & ~pair_ranked['above_noise']
    ]
    drop_hyper = hyper_ranked[
        ~hyper_ranked['feature'].str.startswith('rand_') & ~hyper_ranked['above_noise']
    ]

    # Write plain-text summary
    write_summary(
        rand_df, pair_ranked, hyper_ranked,
        noise_mean, noise_sd, threshold,
        drop_pair, drop_hyper,
        OUTPUT_DIR / 'noise_ranked_tables.txt',
    )

    # Save ranked CSVs
    pair_ranked.to_csv(OUTPUT_DIR  / 'noise_ranked_pairwise.csv',    index=False)
    hyper_ranked.to_csv(OUTPUT_DIR / 'noise_ranked_hypergraph.csv',   index=False)
    rand_df[rand_df['feature'].str.startswith('rand_')].to_csv(
        OUTPUT_DIR / 'noise_ranked_random.csv', index=False
    )

    print(f"\nSaved to: {OUTPUT_DIR}")
    print("  noise_ranked_tables.txt")
    print("  noise_ranked_pairwise.csv")
    print("  noise_ranked_hypergraph.csv")
    print("  noise_ranked_random.csv")
# Out:
# Reading from: randomforest/hpa_noise_injection/drug_target_family_splits
#
# =====================================================================================
#   NOISE INJECTION — FEATURE IMPORTANCE RANKING SUMMARY
# =====================================================================================
#   Task          : Drug Target Prediction
#   Model         : RandomForest
#   Splits × Seeds: 15 × 3 = 45 realisations per feature
#   Noise features: 4 (standard normal, i.i.d.)
#   Threshold rule: pure_random mean + 1 SD of per-feature means
#
#   Noise floor (pure random model):
#     Mean of per-feature means : -0.00161
#     SD   of per-feature means : 0.00072
#     Threshold (mean + 1 SD)   : -0.00088
#
#   Interpretation: a real feature must have mean importance > threshold
#   to be considered as carrying signal above noise.
#
# =====================================================================================
#   1. PURE RANDOM MODEL (noise features only)
# =====================================================================================
#   All importances should be near zero — confirms noise is uninformative.
#
#   Rank  Feature                   Mean        Std
#   ------------------------------------------------
#   1     rand_1                -0.00075    0.00903
#   2     rand_2                -0.00111    0.00726
#   3     rand_3                -0.00198    0.00800
#   4     rand_0                -0.00259    0.00770
#
# =====================================================================================
#   2. PAIRWISE + NOISE — Full ranked list
# =====================================================================================
#   Noise features (rand_*) are interleaved at their actual rank position.
#
#   Rank  Type    Feature                                     Mean        Std  Signal
#   --------------------------------------------------------------------------------
#   1     real    pair_LocalClustCoeff                     0.10242    0.04556  ✓ above noise
#   2     real    pair_AvgNeighborDegree                   0.03261    0.03003  ✓ above noise
#   3     real    pair_Degree                              0.02581    0.02667  ✓ above noise
#   4     real    pair_TriangleCount                       0.02553    0.02418  ✓ above noise
#   5     NOISE   rand_0                                   0.00309    0.01561  ✓ above noise  <-- NOISE
#   6     NOISE   rand_3                                   0.00149    0.01844  ✓ above noise  <-- NOISE
#   7     NOISE   rand_2                                  -0.00228    0.01288  – within noise  <-- NOISE
#   8     NOISE   rand_1                                  -0.00382    0.01425  – within noise  <-- NOISE
#
# =====================================================================================
#   3. HYPERGRAPH + NOISE — Full ranked list
# =====================================================================================
#   Noise features (rand_*) are interleaved at their actual rank position.
#
#   Rank  Type    Feature                                     Mean        Std  Signal
#   --------------------------------------------------------------------------------
#   1     real    base_Degree                              0.09445    0.06488  ✓ above noise
#   2     real    protein_MedComplexNodes                  0.06657    0.04283  ✓ above noise
#   3     real    stoich_MedianRatio                       0.06623    0.04359  ✓ above noise
#   4     real    protein_MedianUniqueRatio                0.06558    0.05010  ✓ above noise
#   5     real    stoich_MedComplexSize                    0.05769    0.03239  ✓ above noise
#   6     real    stoich_AvgNeighbourDegreeStoich          0.04915    0.03935  ✓ above noise
#   7     real    stoich_WeightedTriangles                 0.03529    0.03701  ✓ above noise
#   8     real    base_LocalClustCoeff                     0.02598    0.01690  ✓ above noise
#   9     real    base_AvgNeighbourDegree                  0.02533    0.02295  ✓ above noise
#   10    real    base_TriangleCount                       0.02048    0.02142  ✓ above noise
#   11    real    base_UniquePartners                      0.00545    0.01854  ✓ above noise
#   12    NOISE   rand_3                                   0.00141    0.00927  ✓ above noise  <-- NOISE
#   13    NOISE   rand_0                                  -0.00023    0.01140  ✓ above noise  <-- NOISE
#   14    NOISE   rand_1                                  -0.00074    0.00772  ✓ above noise  <-- NOISE
#   15    real    stoich_RangeComplexSize                 -0.00158    0.00580  – within noise
#   16    NOISE   rand_2                                  -0.00219    0.00946  – within noise  <-- NOISE
#   17    real    protein_RangeComplexNodes               -0.00279    0.00661  – within noise
#   18    real    protein_RangeUniqueRatio                -0.00295    0.01035  – within noise
#   19    real    stoich_RangeRatio                       -0.00305    0.00741  – within noise
#
# =====================================================================================
#   FEATURES TO DROP (at or below noise threshold)
# =====================================================================================
#   Threshold: -0.00088  (pure_random mean + 1 SD of per-feature means)
#
#   Pairwise features to drop:
#     None — all pairwise features are above the noise floor.
#
#   Hypergraph features to drop:
#     rank 15: stoich_RangeComplexSize  (mean=-0.00158, std=0.00580)
#     rank 17: protein_RangeComplexNodes  (mean=-0.00279, std=0.00661)
#     rank 18: protein_RangeUniqueRatio  (mean=-0.00295, std=0.01035)
#     rank 19: stoich_RangeRatio  (mean=-0.00305, std=0.00741)
#
# =====================================================================================
#   RECOMMENDED FINAL FEATURE SETS
# =====================================================================================
#
#   Pairwise (unchanged):
#     pair_LocalClustCoeff
#     pair_AvgNeighborDegree
#     pair_Degree
#     pair_TriangleCount
#
#   Hypergraph (Range features removed):
#     base_Degree
#     protein_MedComplexNodes
#     stoich_MedianRatio
#     protein_MedianUniqueRatio
#     stoich_MedComplexSize
#     stoich_AvgNeighbourDegreeStoich
#     stoich_WeightedTriangles
#     base_LocalClustCoeff
#     base_AvgNeighbourDegree
#     base_TriangleCount
#     base_UniquePartners
#
#   NOTE: base_UniquePartners is technically above threshold but sits
#   interleaved with noise features and is likely redundant with base_Degree
#   (high correlation; permuting it doesn't hurt because base_Degree compensates).
#   Consider testing with and without it in the final model.
#
# =====================================================================================
#
# Saved to: randomforest/hpa_noise_injection/drug_target_family_splits
#   noise_ranked_tables.txt
#   noise_ranked_pairwise.csv
#   noise_ranked_hypergraph.csv
#   noise_ranked_random.csv

# %%
"""
noise_injection_summary.py
==========================
Produces ranked feature importance tables from the noise injection experiment,
showing where random features sit within each model's ranking.

Outputs
-------
  - noise_ranked_tables.txt        — plain-text ranked tables (for supervisor)
  - noise_ranked_hypergraph.csv    — full ranked hypergraph table with noise
  - noise_ranked_pairwise.csv      — full ranked pairwise table with noise
  - noise_ranked_random.csv        — pure random model noise floor
  - features_to_drop.txt           — recommended features to remove + rationale

Usage
-----
  python noise_injection_summary.py

  Expects these files in INPUT_DIR (output from cp_noise_injection.py):
    hypergraph_noise_importance.csv
    pairwise_noise_importance.csv
    random_noise_importance.csv
    noise_floor_summary.csv
"""

from pathlib import Path
import pandas as pd
import numpy as np

# =======================================================
# CONFIGURATION — update INPUT_DIR to your output folder
# =======================================================
INPUT_DIR  = Path("./randomforest/hpa_noise_injection/drug_target_family_splits")
OUTPUT_DIR = INPUT_DIR   # write summary files alongside the other outputs

MODEL_TYPE  = "RandomForest"
TASK        = "Drug Target Prediction"
N_SPLITS    = 15
N_SEEDS     = 3
N_NOISE     = 4

# Threshold rule: noise mean + 1 SD of the per-noise-feature means.
# A real feature must exceed this to be considered above the noise floor.
# Using the PURE RANDOM model's noise features as the reference, since that
# model has no real features that could influence the noise importance estimates.
THRESHOLD_RULE = "pure_random mean + 2 SD of per-feature means"


# =======================================================
# LOAD
# =======================================================

def load_tables():
    hyper = pd.read_csv(INPUT_DIR / 'hypergraph_noise_importance.csv')
    pair  = pd.read_csv(INPUT_DIR / 'pairwise_noise_importance.csv')
    rand  = pd.read_csv(INPUT_DIR / 'random_noise_importance.csv')
    floor = pd.read_csv(INPUT_DIR / 'noise_floor_summary.csv')
    return hyper, pair, rand, floor


# =======================================================
# THRESHOLD COMPUTATION
# =======================================================

def compute_threshold(rand_df: pd.DataFrame) -> tuple[float, float, float]:
    """
    Derive noise threshold from the pure-random model.

    Returns (noise_mean, noise_sd, threshold) where:
      noise_mean = mean of the per-noise-feature means
      noise_sd   = std  of the per-noise-feature means
      threshold  = noise_mean + noise_sd
    """
    noise_rows = rand_df[rand_df['feature'].str.startswith('rand_')]
    per_feature_means = noise_rows['mean'].values
    noise_mean = float(np.mean(per_feature_means))
    noise_sd   = float(np.std(per_feature_means))
    threshold  = noise_mean + 2*noise_sd
    return noise_mean, noise_sd, threshold


# =======================================================
# BUILD RANKED TABLES
# =======================================================

def build_ranked_table(imp_df: pd.DataFrame, threshold: float) -> pd.DataFrame:
    """
    Merge real features and individual noise features into one ranked table.
    The pooled noise row ([noise × N]) is excluded — individual rows are used
    so the noise features appear at their actual rank positions.
    """
    # Real features
    real = imp_df[~imp_df['is_noise']].copy()

    # Individual noise features (exclude the pooled summary row)
    noise = imp_df[
        imp_df['feature'].str.startswith('rand_')
    ].copy()

    combined = pd.concat([real, noise], ignore_index=True)
    combined = combined.sort_values('mean', ascending=False).reset_index(drop=True)
    combined['rank'] = range(1, len(combined) + 1)
    combined['above_noise'] = combined['mean'] > threshold
    combined['type'] = combined['feature'].apply(
        lambda f: 'NOISE' if f.startswith('rand_') else 'real'
    )

    return combined[['rank', 'type', 'feature', 'mean', 'std', 'above_noise']]


# =======================================================
# PRINTING & SAVING
# =======================================================

def format_table(df: pd.DataFrame) -> str:
    lines = []
    header = f"  {'Rank':<5} {'Type':<7} {'Feature':<38} {'Mean':>9}  {'Std':>9}  {'Signal'}"
    lines.append(header)
    lines.append("  " + "-" * 80)
    for _, row in df.iterrows():
        signal = "✓ above noise" if row['above_noise'] else "– within noise"
        noise_marker = "  <-- NOISE" if row['type'] == 'NOISE' else ""
        lines.append(
            f"  {int(row['rank']):<5} {row['type']:<7} {row['feature']:<38} "
            f"{row['mean']:>9.5f}  {row['std']:>9.5f}  {signal}{noise_marker}"
        )
    return "\n".join(lines)


def write_summary(
    rand_df, pair_ranked, hyper_ranked,
    noise_mean, noise_sd, threshold,
    drop_pair, drop_hyper,
    output_path: Path,
):
    lines = []
    sep = "=" * 85

    lines += [
        sep,
        "  NOISE INJECTION — FEATURE IMPORTANCE RANKING SUMMARY",
        sep,
        f"  Task          : {TASK}",
        f"  Model         : {MODEL_TYPE}",
        f"  Splits × Seeds: {N_SPLITS} × {N_SEEDS} = {N_SPLITS * N_SEEDS} realisations per feature",
        f"  Noise features: {N_NOISE} (standard normal, i.i.d.)",
        f"  Threshold rule: {THRESHOLD_RULE}",
        "",
        f"  Noise floor (pure random model):",
        f"    Mean of per-feature means : {noise_mean:+.5f}",
        f"    SD   of per-feature means : {noise_sd:.5f}",
        f"    Threshold (mean + 1 SD)   : {threshold:+.5f}",
        "",
        "  Interpretation: a real feature must have mean importance > threshold",
        "  to be considered as carrying signal above noise.",
        "",
    ]

    # Pure random model
    lines += [
        sep,
        "  1. PURE RANDOM MODEL (noise features only)",
        sep,
        "  All importances should be near zero — confirms noise is uninformative.",
        "",
    ]
    noise_only = rand_df[rand_df['feature'].str.startswith('rand_')][
        ['feature', 'mean', 'std']
    ].copy()
    noise_only = noise_only.sort_values('mean', ascending=False).reset_index(drop=True)
    noise_only['rank'] = range(1, len(noise_only) + 1)
    hdr = f"  {'Rank':<5} {'Feature':<20} {'Mean':>9}  {'Std':>9}"
    lines.append(hdr)
    lines.append("  " + "-" * 48)
    for _, row in noise_only.iterrows():
        lines.append(f"  {int(row['rank']):<5} {row['feature']:<20} "
                     f"{row['mean']:>9.5f}  {row['std']:>9.5f}")
    lines.append("")

    # Pairwise
    lines += [
        sep,
        "  2. PAIRWISE + NOISE — Full ranked list",
        sep,
        "  Noise features (rand_*) are interleaved at their actual rank position.",
        "",
    ]
    lines.append(format_table(pair_ranked))
    lines.append("")

    # Hypergraph
    lines += [
        sep,
        "  3. HYPERGRAPH + NOISE — Full ranked list",
        sep,
        "  Noise features (rand_*) are interleaved at their actual rank position.",
        "",
    ]
    lines.append(format_table(hyper_ranked))
    lines.append("")

    # Features to drop
    lines += [
        sep,
        "  FEATURES TO DROP (at or below noise threshold)",
        sep,
        f"  Threshold: {threshold:+.5f}  ({THRESHOLD_RULE})",
        "",
    ]

    lines.append("  Pairwise features to drop:")
    if len(drop_pair) == 0:
        lines.append("    None — all pairwise features are above the noise floor.")
    else:
        for _, row in drop_pair.iterrows():
            lines.append(f"    rank {int(row['rank'])}: {row['feature']}  "
                         f"(mean={row['mean']:+.5f}, std={row['std']:.5f})")

    lines.append("")
    lines.append("  Hypergraph features to drop:")
    if len(drop_hyper) == 0:
        lines.append("    None — all hypergraph features are above the noise floor.")
    else:
        for _, row in drop_hyper.iterrows():
            lines.append(f"    rank {int(row['rank'])}: {row['feature']}  "
                         f"(mean={row['mean']:+.5f}, std={row['std']:.5f})")

    lines += [
        "",
        sep,
        "  RECOMMENDED FINAL FEATURE SETS",
        sep,
        "",
        "  Pairwise (unchanged):",
    ]
    pair_keep = pair_ranked[
        (~pair_ranked['feature'].str.startswith('rand_')) & pair_ranked['above_noise']
    ]
    for _, row in pair_keep.iterrows():
        lines.append(f"    {row['feature']}")

    lines += ["", "  Hypergraph (Range features removed):"]
    hyper_keep = hyper_ranked[
        (~hyper_ranked['feature'].str.startswith('rand_')) & hyper_ranked['above_noise']
    ]
    for _, row in hyper_keep.iterrows():
        lines.append(f"    {row['feature']}")

    lines += [
        "",
        "  NOTE: base_UniquePartners is technically above threshold but sits",
        "  interleaved with noise features and is likely redundant with base_Degree",
        "  (high correlation; permuting it doesn't hurt because base_Degree compensates).",
        "  Consider testing with and without it in the final model.",
        "",
        sep,
    ]

    text = "\n".join(lines)
    output_path.write_text(text)
    print(text)
    return text


# =======================================================
# MAIN
# =======================================================

if __name__ == '__main__':

    print(f"Reading from: {INPUT_DIR}\n")
    hyper_df, pair_df, rand_df, floor_df = load_tables()

    noise_mean, noise_sd, threshold = compute_threshold(rand_df)

    pair_ranked  = build_ranked_table(pair_df,  threshold)
    hyper_ranked = build_ranked_table(hyper_df, threshold)

    drop_pair  = pair_ranked[
        ~pair_ranked['feature'].str.startswith('rand_') & ~pair_ranked['above_noise']
    ]
    drop_hyper = hyper_ranked[
        ~hyper_ranked['feature'].str.startswith('rand_') & ~hyper_ranked['above_noise']
    ]

    # Write plain-text summary
    write_summary(
        rand_df, pair_ranked, hyper_ranked,
        noise_mean, noise_sd, threshold,
        drop_pair, drop_hyper,
        OUTPUT_DIR / 'noise_ranked_tables.txt',
    )

    # Save ranked CSVs
    pair_ranked.to_csv(OUTPUT_DIR  / 'noise_ranked_pairwise.csv',    index=False)
    hyper_ranked.to_csv(OUTPUT_DIR / 'noise_ranked_hypergraph.csv',   index=False)
    rand_df[rand_df['feature'].str.startswith('rand_')].to_csv(
        OUTPUT_DIR / 'noise_ranked_random.csv', index=False
    )

    print(f"\nSaved to: {OUTPUT_DIR}")
    print("  noise_ranked_tables.txt")
    print("  noise_ranked_pairwise.csv")
    print("  noise_ranked_hypergraph.csv")
    print("  noise_ranked_random.csv")
# Out:
# Reading from: randomforest/hpa_noise_injection/drug_target_family_splits
#
# =====================================================================================
#   NOISE INJECTION — FEATURE IMPORTANCE RANKING SUMMARY
# =====================================================================================
#   Task          : Drug Target Prediction
#   Model         : RandomForest
#   Splits × Seeds: 15 × 3 = 45 realisations per feature
#   Noise features: 4 (standard normal, i.i.d.)
#   Threshold rule: pure_random mean + 2 SD of per-feature means
#
#   Noise floor (pure random model):
#     Mean of per-feature means : -0.00161
#     SD   of per-feature means : 0.00072
#     Threshold (mean + 1 SD)   : -0.00016
#
#   Interpretation: a real feature must have mean importance > threshold
#   to be considered as carrying signal above noise.
#
# =====================================================================================
#   1. PURE RANDOM MODEL (noise features only)
# =====================================================================================
#   All importances should be near zero — confirms noise is uninformative.
#
#   Rank  Feature                   Mean        Std
#   ------------------------------------------------
#   1     rand_1                -0.00075    0.00903
#   2     rand_2                -0.00111    0.00726
#   3     rand_3                -0.00198    0.00800
#   4     rand_0                -0.00259    0.00770
#
# =====================================================================================
#   2. PAIRWISE + NOISE — Full ranked list
# =====================================================================================
#   Noise features (rand_*) are interleaved at their actual rank position.
#
#   Rank  Type    Feature                                     Mean        Std  Signal
#   --------------------------------------------------------------------------------
#   1     real    pair_LocalClustCoeff                     0.10242    0.04556  ✓ above noise
#   2     real    pair_AvgNeighborDegree                   0.03261    0.03003  ✓ above noise
#   3     real    pair_Degree                              0.02581    0.02667  ✓ above noise
#   4     real    pair_TriangleCount                       0.02553    0.02418  ✓ above noise
#   5     NOISE   rand_0                                   0.00309    0.01561  ✓ above noise  <-- NOISE
#   6     NOISE   rand_3                                   0.00149    0.01844  ✓ above noise  <-- NOISE
#   7     NOISE   rand_2                                  -0.00228    0.01288  – within noise  <-- NOISE
#   8     NOISE   rand_1                                  -0.00382    0.01425  – within noise  <-- NOISE
#
# =====================================================================================
#   3. HYPERGRAPH + NOISE — Full ranked list
# =====================================================================================
#   Noise features (rand_*) are interleaved at their actual rank position.
#
#   Rank  Type    Feature                                     Mean        Std  Signal
#   --------------------------------------------------------------------------------
#   1     real    base_Degree                              0.09445    0.06488  ✓ above noise
#   2     real    protein_MedComplexNodes                  0.06657    0.04283  ✓ above noise
#   3     real    stoich_MedianRatio                       0.06623    0.04359  ✓ above noise
#   4     real    protein_MedianUniqueRatio                0.06558    0.05010  ✓ above noise
#   5     real    stoich_MedComplexSize                    0.05769    0.03239  ✓ above noise
#   6     real    stoich_AvgNeighbourDegreeStoich          0.04915    0.03935  ✓ above noise
#   7     real    stoich_WeightedTriangles                 0.03529    0.03701  ✓ above noise
#   8     real    base_LocalClustCoeff                     0.02598    0.01690  ✓ above noise
#   9     real    base_AvgNeighbourDegree                  0.02533    0.02295  ✓ above noise
#   10    real    base_TriangleCount                       0.02048    0.02142  ✓ above noise
#   11    real    base_UniquePartners                      0.00545    0.01854  ✓ above noise
#   12    NOISE   rand_3                                   0.00141    0.00927  ✓ above noise  <-- NOISE
#   13    NOISE   rand_0                                  -0.00023    0.01140  – within noise  <-- NOISE
#   14    NOISE   rand_1                                  -0.00074    0.00772  – within noise  <-- NOISE
#   15    real    stoich_RangeComplexSize                 -0.00158    0.00580  – within noise
#   16    NOISE   rand_2                                  -0.00219    0.00946  – within noise  <-- NOISE
#   17    real    protein_RangeComplexNodes               -0.00279    0.00661  – within noise
#   18    real    protein_RangeUniqueRatio                -0.00295    0.01035  – within noise
#   19    real    stoich_RangeRatio                       -0.00305    0.00741  – within noise
#
# =====================================================================================
#   FEATURES TO DROP (at or below noise threshold)
# =====================================================================================
#   Threshold: -0.00016  (pure_random mean + 2 SD of per-feature means)
#
#   Pairwise features to drop:
#     None — all pairwise features are above the noise floor.
#
#   Hypergraph features to drop:
#     rank 15: stoich_RangeComplexSize  (mean=-0.00158, std=0.00580)
#     rank 17: protein_RangeComplexNodes  (mean=-0.00279, std=0.00661)
#     rank 18: protein_RangeUniqueRatio  (mean=-0.00295, std=0.01035)
#     rank 19: stoich_RangeRatio  (mean=-0.00305, std=0.00741)
#
# =====================================================================================
#   RECOMMENDED FINAL FEATURE SETS
# =====================================================================================
#
#   Pairwise (unchanged):
#     pair_LocalClustCoeff
#     pair_AvgNeighborDegree
#     pair_Degree
#     pair_TriangleCount
#
#   Hypergraph (Range features removed):
#     base_Degree
#     protein_MedComplexNodes
#     stoich_MedianRatio
#     protein_MedianUniqueRatio
#     stoich_MedComplexSize
#     stoich_AvgNeighbourDegreeStoich
#     stoich_WeightedTriangles
#     base_LocalClustCoeff
#     base_AvgNeighbourDegree
#     base_TriangleCount
#     base_UniquePartners
#
#   NOTE: base_UniquePartners is technically above threshold but sits
#   interleaved with noise features and is likely redundant with base_Degree
#   (high correlation; permuting it doesn't hurt because base_Degree compensates).
#   Consider testing with and without it in the final model.
#
# =====================================================================================
#
# Saved to: randomforest/hpa_noise_injection/drug_target_family_splits
#   noise_ranked_tables.txt
#   noise_ranked_pairwise.csv
#   noise_ranked_hypergraph.csv
#   noise_ranked_random.csv
