# %%
"""
=======================================================================
LOGISTIC REGRESSION BASELINE — REPRESENTATION COMPARISON (Complex Portal)
=======================================================================

Runs the same four-tier representation comparison as the tree-ensemble
scripts (cp_ess_second.py / cp_hpa_second.py / cp_chembl_second.py), but
with an L2-penalised logistic regression, across ALL THREE tasks in one
run:

    gene essentiality  |  HPA drug targets  |  ChEMBL drug targets

Tiers (identical to the tree scripts, nested pairwise ⊂ hypergraph ⊂ hb_graph):
    pairwise   — dyadic PPI features
    hypergraph — set-based higher-order features (no stoichiometry)
    hyper_flag — hypergraph + binary annotation-presence flag   [TEST A]
    hyper_recip— hypergraph + 1/(1+complex size)                [TEST C]
    hb_graph   — hypergraph + stoichiometry (multiset hyperedges)

TEST C — the reciprocal-of-size control
    Among curated CP proteins stoich_MedianRatio correlates with
    protein_MedComplexNodes at Spearman -0.918 (CORUM -0.659), and
    stoich_WeightedTriangles at +0.942. The mechanism is arithmetic: for a
    complex of n roughly equimolar subunits, one protein's share of total
    stoichiometry is about 1/n, so stoich_MedianRatio ~= 1/MedComplexNodes.

    A reciprocal is monotone but strongly NONLINEAR. L2 logistic regression
    on x cannot represent 1/x, so supplying stoich_MedianRatio hands it a
    basis function it structurally lacked; a random forest already
    approximates 1/x by splitting repeatedly on x. That is exactly the
    observed pattern (large LR stoichiometry gains, RF null, one feature
    carrying the whole effect), so the two must be told apart.

    The hyper_recip tier adds recip_MedComplexNodes = 1/(1 + MedComplexNodes),
    a deterministic transform of a feature the hypergraph tier ALREADY has
    and which contains NO stoichiometry information. The contrast that
    matters is then hb_graph - hyper_recip: if it collapses to zero, the
    apparent stoichiometric gain was a size recoding.

WHAT DIFFERS FROM THE TREE SCRIPTS
    1. The estimator is a Pipeline: StandardScaler -> LogisticRegression.
       Scaling is MANDATORY here (unlike for trees) because the features span
       orders of magnitude — base_Degree is an unbounded count, stoich_MedianRatio
       is bounded in (0, 1] — and an L2 penalty applied to unscaled features
       penalises them by an arbitrary amount that depends only on their units.
       The scaler sits INSIDE the pipeline, so it is refitted on each inner CV
       training fold and never sees the test split.
    2. The hyperparameter grid is over C (inverse regularisation strength) only.
    3. Feature importance is permutation importance (PR-AUC drop), exactly as
       in the tree scripts, so the numbers are directly comparable. Coefficients
       are deliberately NOT reported: with correlated features they are not a
       reliable importance ranking.

EVERYTHING ELSE IS HELD FIXED so the comparison is like-for-like:
    same splits files, same frozen feature sets, same fillna(0) encoding,
    same average_precision scorer, same 5-fold inner CV, same PR-AUC / F1
    metrics, same one-sided sign tests, same output file names.

USAGE
    Set DATA_DIR and BASE_OUTPUT_DIR below, then:  python lr_cp_all_tasks.py
    Outputs land in BASE_OUTPUT_DIR/<task_key>/ , one directory per task,
    plus a cross-task summary at BASE_OUTPUT_DIR/all_tasks_summary.csv.
"""

import os
import time
import warnings
from pathlib import Path
from typing import List, Dict, Optional

import numpy as np
import pandas as pd
import matplotlib
matplotlib.use("Agg")
import matplotlib.pyplot as plt

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report, average_precision_score
from sklearn.inspection import permutation_importance
from sklearn.exceptions import ConvergenceWarning
from scipy.stats import binomtest, spearmanr

# =======================================================
# Plotting Style Configuration
# =======================================================
plt.rcParams.update({
    'font.size': 16,
    'axes.titlesize': 18,
    'axes.labelsize': 16,
    'xtick.labelsize': 14,
    'ytick.labelsize': 14,
    'legend.fontsize': 14,
    'figure.titlesize': 20
})

# =======================================================
# CONFIGURATION
# =======================================================
CONFIG = {
    # --- Database identity (used in printouts and output filenames) ---
    "DATABASE": "CP",

    # --- Paths ---
    "DATA_DIR": Path("/Users/anitaapplegarth/github/dphil/protein_complexes/data/lookup_tables/cp/"),
    "BASE_OUTPUT_DIR": Path("./logistic/cp_second_testA"),

    "PROTEIN_FEATURES_FILE":  "hypergraph_features.csv",
    "PAIRWISE_FEATURES_FILE": "pairwise_features.csv",

    # Optional sanity check of the annotation flag against the raw incidence file.
    # Must sit in the SAME subdirectory as DATA_DIR. Set to None to skip.
    "RAW_STOICH_FILE": Path("/Users/anitaapplegarth/github/dphil/protein_complexes/data/lookup_tables/cp/stoich_protein.csv"),

    # --- TASKS ---------------------------------------------------------------
    # All three tasks run in a single invocation. Each writes to its own
    # subdirectory of BASE_OUTPUT_DIR. To run only a subset, comment one out.
    #
    # 'label_map' must match the protein_label strings in that task's splits
    # file; anything not in the map is treated as Unknown (NaN) and excluded
    # by label_mask, exactly as in the tree scripts.
    "TASKS": {
        "ess": {
            "name":        "Gene Essentiality",
            "splits_file": "ess_protein_splits.csv",
            "label_map":   {'Essential': 1, 'Non-essential': 0},
            "pos_name":    "Essential",
            "neg_name":    "Non-Essential",
        },
        "hpa": {
            "name":        "Drug Target Prediction (HPA)",
            "splits_file": "hpa_protein_splits.csv",
            "label_map":   {'Drug_target': 1, 'Non_target': 0},
            "pos_name":    "Drug_target",
            "neg_name":    "Non_target",
        },
        "chembl": {
            "name":        "Drug Target Prediction (ChEMBL)",
            "splits_file": "chembl_protein_splits.csv",
            "label_map":   {'Drug_target': 1, 'Non_target': 0},
            "pos_name":    "Drug_target",
            "neg_name":    "Non_target",
        },
    },

    # --- TEST A: annotation-presence control ---------------------------------
    # A fourth tier, HYPER_FLAG = HYPERGRAPH + a single binary feature marking
    # whether the protein has ANY curated stoichiometry. This decomposes the
    # apparent stoichiometry effect into two parts:
    #
    #     hb_graph - hypergraph  =  [hyper_flag - hypergraph]  (annotation presence)
    #                            +  [hb_graph   - hyper_flag]  (stoichiometry VALUES)
    #
    # The flag is recovered exactly from the existing features: a true
    # stoich_MedianRatio lies in (0, 1], so a value of 0 uniquely marks
    # "this protein has no curated stoichiometry anywhere".
    #
    # SET INCLUDE_HYPER_FLAG = False FOR CORUM if the flag is near-constant
    # there (CORUM stoichiometry coverage is ~4% vs CP's ~60%). A near-degenerate
    # binary predictor is harmless to a tree but can produce a large, unstable
    # coefficient under regularised logistic regression. The script also
    # auto-skips the tier per split if the flag has <2 levels in the training
    # fold, or if either level has fewer than MIN_FLAG_COUNT proteins.
    "INCLUDE_HYPER_FLAG":  True,
    "MIN_FLAG_COUNT":      10,
    "ANNOTATION_FLAG":     "flag_HasStoich",
    "FLAG_SOURCE_FEATURE": "stoich_MedianRatio",

    # --- TEST C: reciprocal-of-size control (see header) ---------------------
    # recip = 1/(1 + protein_MedComplexNodes). 1/(1+n) rather than 1/n because
    # MedComplexNodes can be 0 for proteins whose only complexes are
    # homo-oligomers; the +1 keeps the transform finite and monotone throughout.
    "INCLUDE_HYPER_RECIP": True,
    "RECIP_FEATURE":       "recip_MedComplexNodes",
    "RECIP_SOURCE_FEATURE": "protein_MedComplexNodes",

    # --- Fixed settings (matched to the tree scripts) ---
    "RANDOM_STATE": 42,
    "N_SPLITS_CV":  5,
    "PERM_REPEATS": 10,

    # --- Logistic regression ---
    # lbfgs with the default L2 penalty is the standard, fast choice and
    # converges reliably on standardised features. class_weight='balanced'
    # matches the tree scripts. max_iter is set high because the smallest C
    # values converge slowly.
    # NB: 'penalty' is deliberately NOT passed. L2 is the default in every
    # sklearn version, and passing penalty='l2' explicitly raises a
    # FutureWarning from sklearn 1.8 onwards.
    "LOGREG_KWARGS": {
        "solver":       "lbfgs",
        "class_weight": "balanced",
        "max_iter":     5000,
    },
    "PARAM_GRID": {
        "clf__C": list(np.logspace(-6, 4, 11))
    },

    # --- Feature Selection (FROZEN — must match the tree scripts exactly) ---
    "FEATURES": {
        "HB_GRAPH": [
            # --- Base / native higher-order metrics ---
            'base_Degree',
            'base_LocalClustCoeff',
            'base_TriangleCount',
            'base_UniquePartners',
            'base_AvgNeighbourDegree',

            # --- Stoichiometry-based metrics (hb-graph only) ---
            'stoich_WeightedTriangles',
            'stoich_AvgNeighbourDegreeStoich',
            'stoich_RangeComplexSize',
            'stoich_MedComplexSize',
            'stoich_MedianRatio',
            'stoich_RangeRatio',

            # --- Protein-participation metrics ---
            # 'protein_MedianUniqueRatio',   # DROPPED: near-exact reciprocal of
            #                                # protein_MedComplexNodes (Spearman -0.9965).
            'protein_RangeUniqueRatio',
            'protein_MedComplexNodes',
            'protein_RangeComplexNodes',
        ],
        "STOICHIOMETRY_FEATURES": [
            'stoich_WeightedTriangles',
            'stoich_AvgNeighbourDegreeStoich',
            'stoich_RangeComplexSize',
            'stoich_MedComplexSize',
            'stoich_MedianRatio',
            'stoich_RangeRatio',
        ],
        "PAIRWISE": [
            'pair_Degree',
            'pair_LocalClustCoeff',
            'pair_TriangleCount',
            'pair_AvgNeighborDegree',
        ]
    }
}

# Tier order used everywhere (printouts, CSV columns, plots).
TIERS = ['pairwise', 'hypergraph', 'hyper_flag', 'hyper_recip', 'hb_graph']
TIER_LABELS = {
    'pairwise':   'Pairwise',
    'hypergraph': 'Hypergraph',
    'hyper_flag': 'Hypergraph + flag',
    'hyper_recip': 'Hypergraph + 1/size',
    'hb_graph':   'HB-graph',
}


# =======================================================
# DATA LOADING
# =======================================================

def load_all_features() -> pd.DataFrame:
    """Loads higher-order (hb-graph) and pairwise feature CSVs, merges on ProteinId."""
    print("1. Loading feature data...")

    hg_df   = pd.read_csv(CONFIG["DATA_DIR"] / CONFIG["PROTEIN_FEATURES_FILE"])
    pair_df = pd.read_csv(CONFIG["DATA_DIR"] / CONFIG["PAIRWISE_FEATURES_FILE"])

    combined = pd.merge(hg_df, pair_df, on='ProteinId', how='inner')

    print(f"   Higher-order (hb-graph) features shape : {hg_df.shape}")
    print(f"   Pairwise features shape               : {pair_df.shape}")
    print(f"   Combined shape                        : {combined.shape}")

    combined = derive_annotation_flag(combined)
    combined = derive_reciprocal(combined)
    return combined


def derive_reciprocal(df: pd.DataFrame) -> pd.DataFrame:
    """Adds the TEST C control feature: 1 / (1 + complex size).

    Contains no stoichiometry information — it is a deterministic transform
    of a feature the hypergraph tier already holds. Its purpose is to give a
    linear model the 1/n basis function that stoich_MedianRatio would
    otherwise smuggle in.
    """
    if not CONFIG["INCLUDE_HYPER_RECIP"]:
        return df

    recip = CONFIG["RECIP_FEATURE"]
    src   = CONFIG["RECIP_SOURCE_FEATURE"]
    if src not in df.columns:
        raise KeyError(f"Cannot derive {recip}: '{src}' not in feature file.")

    df[recip] = 1.0 / (1.0 + df[src])

    print(f"\n   Derived '{recip}' = 1 / (1 + {src})  [TEST C control]")

    # Report how closely it tracks the stoichiometry features. The comparison
    # that matters is among CURATED proteins only: across all proteins the
    # correlation is dominated by the shared zero/non-zero structure.
    flag = CONFIG["ANNOTATION_FLAG"]
    cur = df[df[flag] == 1] if flag in df.columns else df
    print(f"     Spearman vs stoichiometry features "
          f"(curated proteins only, n = {len(cur):,}):")
    for f_ in CONFIG["FEATURES"]["STOICHIOMETRY_FEATURES"]:
        if f_ in cur.columns and len(cur) > 10 and cur[f_].nunique() > 1:
            rho, _ = spearmanr(cur[recip], cur[f_])
            mark = "   <-- near-deterministic" if abs(rho) > 0.85 else ""
            print(f"       {f_:<34} {rho:+.3f}{mark}")

    return df


def derive_annotation_flag(df: pd.DataFrame) -> pd.DataFrame:
    """
    Adds CONFIG['ANNOTATION_FLAG'] (binary): 1 if the protein has at least one
    complex with curated stoichiometry, 0 otherwise. Derived from
    stoich_MedianRatio, where a genuine ratio lies in (0, 1] and a value of
    exactly 0 unambiguously means "no curated stoichiometry anywhere".
    """
    flag = CONFIG["ANNOTATION_FLAG"]
    src  = CONFIG["FLAG_SOURCE_FEATURE"]

    if src not in df.columns:
        raise KeyError(f"Cannot derive {flag}: '{src}' not in feature file.")

    df[flag] = (df[src] > 0).astype(int)

    n_annot = int(df[flag].sum())
    print(f"\n   Derived '{flag}' from '{src}':")
    print(f"     curated   : {n_annot} / {len(df)}  ({100*n_annot/len(df):.1f}%)")
    print(f"     uncurated : {len(df)-n_annot} / {len(df)}  "
          f"({100*(1-n_annot/len(df)):.1f}%)")

    # Loud warning if the flag is near-degenerate — relevant for CORUM.
    frac = n_annot / len(df) if len(df) else 0.0
    if CONFIG["INCLUDE_HYPER_FLAG"] and (frac < 0.05 or frac > 0.95):
        print(f"     WARNING: '{flag}' is near-constant ({100*frac:.1f}% curated).")
        print(f"              The hyper_flag tier will be unstable under a "
              f"regularised linear model.")
        print(f"              Consider setting INCLUDE_HYPER_FLAG = False.")

    # --- Optional cross-check against the raw incidence file ---
    raw_path = CONFIG.get("RAW_STOICH_FILE")
    if raw_path and Path(raw_path).exists():
        raw = pd.read_csv(raw_path)
        truth = (raw.assign(a=(raw['Stoichiometry'] > 0).astype(int))
                    .groupby('ProteinId')['a'].max())
        chk = df[['ProteinId', flag]].merge(
            truth.rename('truth'), left_on='ProteinId', right_index=True, how='inner')
        n_mismatch = int((chk[flag] != chk['truth']).sum())
        if n_mismatch == 0:
            print(f"     cross-check vs {Path(raw_path).name}: exact match "
                  f"on all {len(chk)} proteins ✓")
        else:
            print(f"     WARNING: cross-check disagrees on "
                  f"{n_mismatch}/{len(chk)} proteins.")
    else:
        print(f"     (raw-file cross-check skipped — RAW_STOICH_FILE not found)")

    return df


def load_splits(task_key: str) -> pd.DataFrame:
    """
    Loads the pre-assigned group-atomic splits file for one task.

    Expected columns:
        split_index   — integer identifying which split
        UniProt_AC    — protein identifier (matches ProteinId in feature files)
        split         — 'train' or 'test'
        protein_label — task-specific label strings (see CONFIG['TASKS'])
        label_mask    — bool; False for Unknown proteins (excluded from metrics)
    """
    task = CONFIG["TASKS"][task_key]
    splits_path = CONFIG["DATA_DIR"] / task["splits_file"]

    print("2. Loading pre-assigned splits...")
    print(f"   File              : {splits_path.name}")
    print(f"   Last modified     : "
          f"{pd.Timestamp(os.path.getmtime(splits_path), unit='s')}")

    splits_df = pd.read_csv(splits_path)
    splits_df = splits_df.rename(columns={'UniProt_AC': 'ProteinId'})

    unmapped = set(splits_df['protein_label'].unique()) - set(task["label_map"]) 
    splits_df['target'] = splits_df['protein_label'].map(task["label_map"])

    print(f"   Splits file rows  : {len(splits_df)}")
    print(f"   Unique proteins   : {splits_df['ProteinId'].nunique()}")
    print(f"   Number of splits  : {splits_df['split_index'].nunique()}")
    if unmapped:
        print(f"   Unmapped labels (treated as Unknown): {sorted(unmapped)}")

    labelled = splits_df[splits_df['label_mask']].drop_duplicates('ProteinId')
    n_pos, n_tot = int((labelled['target'] == 1).sum()), len(labelled)
    print(f"   Labelled proteins : {n_tot}  ({100*n_pos/n_tot:.1f}% positive)")

    # Guard: a label_mask=True row with a NaN target means the label_map is out
    # of date relative to the splits file. Fail loudly rather than silently
    # dropping proteins from the analysis.
    n_bad = int(splits_df.loc[splits_df['label_mask'], 'target'].isna().sum())
    if n_bad:
        raise ValueError(
            f"{n_bad} rows have label_mask=True but an unmapped protein_label. "
            f"Check CONFIG['TASKS']['{task_key}']['label_map'] against "
            f"{splits_path.name}."
        )

    return splits_df


# =======================================================
# MODEL TRAINING & EVALUATION
# =======================================================

def build_pipeline() -> Pipeline:
    """StandardScaler -> LogisticRegression, so scaling is refitted per CV fold."""
    return Pipeline([
        ("scale", StandardScaler()),
        ("clf", LogisticRegression(
            random_state=CONFIG["RANDOM_STATE"], **CONFIG["LOGREG_KWARGS"]
        )),
    ])


def tune_and_train_model(X_train: pd.DataFrame, y_train: pd.Series):
    """Grid search over C + fit. Returns (best_estimator, best_params)."""
    gs = GridSearchCV(
        estimator=build_pipeline(),
        param_grid=CONFIG["PARAM_GRID"],
        scoring='average_precision',
        cv=CONFIG["N_SPLITS_CV"],
        n_jobs=-1,
        verbose=0
    )
    # Small C values on near-separable folds can hit the iteration cap; that is
    # expected and those folds simply lose the grid search on PR-AUC.
    with warnings.catch_warnings():
        warnings.simplefilter("ignore", category=ConvergenceWarning)
        gs.fit(X_train, y_train)
    return gs.best_estimator_, gs.best_params_


def evaluate_model(model, X_test: pd.DataFrame, y_test: pd.Series,
                   pos_name: str, neg_name: str) -> Dict:
    """Returns PR-AUC, F1 for the positive class, and predicted probabilities."""
    y_pred       = model.predict(X_test)
    y_pred_proba = model.predict_proba(X_test)[:, 1]

    report = classification_report(
        y_test, y_pred,
        labels=[0, 1],
        target_names=[neg_name, pos_name],
        output_dict=True,
        zero_division=0
    )

    return {
        'pr_auc':       average_precision_score(y_test, y_pred_proba),
        'f1':           report[pos_name]['f1-score'],
        'y_pred_proba': y_pred_proba
    }


def compute_permutation_importance(
    model, X_test: pd.DataFrame, y_test: pd.Series
) -> Dict[str, float]:
    """Permutation importance scored by average_precision (PR-AUC drop).

    Permuting the raw column and passing it through the fitted pipeline is the
    correct thing to do: the scaler is a fixed monotone transform at this point,
    so permuting before or after scaling gives the same importance.
    """
    result = permutation_importance(
        model, X_test, y_test,
        scoring='average_precision',
        n_repeats=CONFIG["PERM_REPEATS"],
        random_state=CONFIG["RANDOM_STATE"],
        n_jobs=-1
    )
    return dict(zip(X_test.columns, result.importances_mean))


# =======================================================
# PER-SPLIT RUNNER
# =======================================================

def run_split(
    split_idx: int,
    merged_df: pd.DataFrame,
    splits_df: pd.DataFrame,
    feature_sets: Dict[str, List[str]],
    task: Dict
) -> Dict:
    """Runs every configured tier for a single pre-assigned split."""
    split_mask = splits_df['split_index'] == split_idx
    split_info = splits_df[split_mask][
        ['ProteinId', 'split', 'target', 'label_mask']].copy()

    df = pd.merge(merged_df, split_info, on='ProteinId', how='inner')
    labelled_df = df[df['label_mask']].copy()

    train_df = labelled_df[labelled_df['split'] == 'train']
    test_df  = labelled_df[labelled_df['split'] == 'test']

    y_train = train_df['target'].astype(int)
    y_test  = test_df['target'].astype(int)

    if y_train.nunique() < 2 or y_test.nunique() < 2:
        raise ValueError(
            f"split {split_idx}: train or test fold contains a single class "
            f"(train pos={int(y_train.sum())}/{len(y_train)}, "
            f"test pos={int(y_test.sum())}/{len(y_test)})."
        )

    results = {
        'split_index':   split_idx,
        'n_train':       len(train_df),
        'n_test':        len(test_df),
        'train_pos_pct': 100 * y_train.mean(),
        'test_pos_pct':  100 * y_test.mean(),
    }

    for tier, feats in feature_sets.items():
        if not feats:
            continue

        # Guard the TEST A tier against a degenerate flag in this training fold.
        flag = CONFIG["ANNOTATION_FLAG"]
        if tier == 'hyper_flag' and flag in feats:
            counts = train_df[flag].value_counts()
            if len(counts) < 2 or counts.min() < CONFIG["MIN_FLAG_COUNT"]:
                results['hyper_flag_pr_auc'] = np.nan
                results['hyper_flag_f1']     = np.nan
                results['hyper_flag_skipped'] = True
                continue

        X_train, X_test = train_df[feats], test_df[feats]

        model, params = tune_and_train_model(X_train, y_train)
        ev = evaluate_model(model, X_test, y_test,
                            task["pos_name"], task["neg_name"])

        results[f'{tier}_pr_auc']      = ev['pr_auc']
        results[f'{tier}_f1']          = ev['f1']
        results[f'{tier}_best_params'] = params
        results[f'{tier}_importance']  = compute_permutation_importance(
            model, X_test, y_test)

        preds = test_df[['ProteinId']].copy()
        preds['split_index'] = split_idx
        preds['true_label']  = y_test.values
        preds[f'{tier}_pred_proba'] = ev['y_pred_proba']
        results[f'{tier}_predictions'] = preds

    # --- Differences ---
    # Headline representation contrast: hb_graph vs pairwise
    results['pr_auc_diff'] = results['hb_graph_pr_auc'] - results['pairwise_pr_auc']
    results['f1_diff']     = results['hb_graph_f1']     - results['pairwise_f1']
    # Stoichiometry effect: hb_graph vs hypergraph
    results['stoich_pr_auc_diff'] = (results['hb_graph_pr_auc']
                                     - results['hypergraph_pr_auc'])
    results['stoich_f1_diff']     = (results['hb_graph_f1']
                                     - results['hypergraph_f1'])
    # TEST A decomposition
    hf = results.get('hyper_flag_pr_auc', np.nan)
    results['annot_pr_auc_diff'] = hf - results['hypergraph_pr_auc']
    results['value_pr_auc_diff'] = results['hb_graph_pr_auc'] - hf
    # TEST C: stoichiometry net of a pure reciprocal-of-size recoding
    hr = results.get('hyper_recip_pr_auc', np.nan)
    results['recip_pr_auc_diff']     = hr - results['hypergraph_pr_auc']
    results['net_recip_pr_auc_diff'] = results['hb_graph_pr_auc'] - hr

    return results


# =======================================================
# STATISTICAL COMPARISON
# =======================================================

def _sign_test(a: np.ndarray, b: np.ndarray) -> Dict:
    """One-sided sign test on paired differences, with Cohen's dz alongside
    as a descriptive effect size (it is not itself a test).

    Splits where either arm is NaN (e.g. a skipped hyper_flag tier) are dropped
    pairwise, so the comparison stays properly paired.
    """
    a, b = np.asarray(a, dtype=float), np.asarray(b, dtype=float)
    ok = ~(np.isnan(a) | np.isnan(b))
    diffs = a[ok] - b[ok]

    n_wins  = int(np.sum(diffs > 0))
    n_loss  = int(np.sum(diffs < 0))
    n_ties  = int(np.sum(diffs == 0))
    n_valid = n_wins + n_loss

    if n_valid > 0:
        p_greater   = binomtest(n_wins, n_valid, 0.5, alternative='greater').pvalue
        p_two_sided = binomtest(n_wins, n_valid, 0.5, alternative='two-sided').pvalue
    else:
        p_greater = p_two_sided = 1.0

    sd = float(np.std(diffs, ddof=1)) if len(diffs) > 1 else 0.0
    dz = float(np.mean(diffs) / sd) if sd > 0 else 0.0

    return dict(
        n_pairs=int(ok.sum()), wins=n_wins, losses=n_loss, ties=n_ties,
        mean_diff=float(np.mean(diffs)) if len(diffs) else float('nan'),
        std_diff=sd, p_greater=p_greater, p_two_sided=p_two_sided, cohens_dz=dz
    )


def run_sign_test_comparison(all_results: List[Dict]) -> Dict:
    """Paired PR-AUC comparisons across splits, matching the tree scripts:
      1. HB-graph  vs Pairwise    — headline representation effect
      2. HB-graph  vs Hypergraph  — stoichiometry effect
      3. Hypergraph vs Pairwise   — set-based representation effect alone
      4. Hyper+flag vs Hypergraph — annotation presence alone       [TEST A]
      5. HB-graph  vs Hyper+flag  — stoichiometry values, net of presence [TEST A]
    """
    def col(tier, metric):
        return np.array([r.get(f'{tier}_{metric}', np.nan) for r in all_results],
                        dtype=float)

    stats = {'n_runs': len(all_results)}

    for tier in TIERS:
        pr, f1 = col(tier, 'pr_auc'), col(tier, 'f1')
        stats[f'{tier}_pr_auc_mean'] = float(np.nanmean(pr)) if not np.all(np.isnan(pr)) else float('nan')
        stats[f'{tier}_pr_auc_std']  = float(np.nanstd(pr))  if not np.all(np.isnan(pr)) else float('nan')
        stats[f'{tier}_f1_mean']     = float(np.nanmean(f1)) if not np.all(np.isnan(f1)) else float('nan')
        stats[f'{tier}_f1_std']      = float(np.nanstd(f1))  if not np.all(np.isnan(f1)) else float('nan')

    stats['comparisons'] = {
        'hb_graph_vs_pairwise':     _sign_test(col('hb_graph', 'pr_auc'),
                                               col('pairwise', 'pr_auc')),
        'hb_graph_vs_hypergraph':   _sign_test(col('hb_graph', 'pr_auc'),
                                               col('hypergraph', 'pr_auc')),
        'hypergraph_vs_pairwise':   _sign_test(col('hypergraph', 'pr_auc'),
                                               col('pairwise', 'pr_auc')),
        'hyper_flag_vs_hypergraph': _sign_test(col('hyper_flag', 'pr_auc'),
                                               col('hypergraph', 'pr_auc')),
        'hb_graph_vs_hyper_flag':   _sign_test(col('hb_graph', 'pr_auc'),
                                               col('hyper_flag', 'pr_auc')),
        'hyper_recip_vs_hypergraph': _sign_test(col('hyper_recip', 'pr_auc'),
                                                col('hypergraph', 'pr_auc')),
        'hb_graph_vs_hyper_recip':  _sign_test(col('hb_graph', 'pr_auc'),
                                               col('hyper_recip', 'pr_auc')),
    }
    return stats


# =======================================================
# FEATURE IMPORTANCE AGGREGATION
# =======================================================

def aggregate_feature_importance(all_results: List[Dict],
                                 tier: str) -> pd.DataFrame:
    """Aggregates permutation importance across all splits for one tier."""
    key = f'{tier}_importance'
    records = [
        {'split_index': r['split_index'], 'feature': feat, 'importance': imp}
        for r in all_results if key in r
        for feat, imp in r[key].items()
    ]
    if not records:
        return pd.DataFrame()

    agg_df = (
        pd.DataFrame(records)
        .groupby('feature')['importance']
        .agg(mean='mean', std='std', median='median',
             min='min', max='max', n_splits='count')
        .reset_index()
        .sort_values('mean', ascending=False)
        .reset_index(drop=True)
    )
    agg_df['rank'] = range(1, len(agg_df) + 1)
    return agg_df


# =======================================================
# PRINTING
# =======================================================

COMPARISON_LABELS = {
    'hb_graph_vs_pairwise':     "HB-graph vs Pairwise — headline representation effect",
    'hb_graph_vs_hypergraph':   "HB-graph vs Hypergraph — stoichiometry effect",
    'hypergraph_vs_pairwise':   "Hypergraph vs Pairwise — representation effect alone",
    'hyper_flag_vs_hypergraph': "[TEST A] Hyper+flag vs Hypergraph — ANNOTATION PRESENCE alone",
    'hb_graph_vs_hyper_flag':   "[TEST A] HB-graph vs Hyper+flag — STOICHIOMETRY VALUES, net of annotation",
    'hyper_recip_vs_hypergraph': "[TEST C] Hyper+1/size vs Hypergraph — what a pure size recoding buys",
    'hb_graph_vs_hyper_recip':  "[TEST C] HB-graph vs Hyper+1/size — STOICHIOMETRY net of size recoding",
}


def _format_comparison(label: str, d: Dict) -> str:
    return (
        f"\n  --- {label} ---\n"
        f"  Mean diff : {d['mean_diff']:+.4f} ± {d['std_diff']:.4f}"
        f"   (Cohen's dz = {d['cohens_dz']:+.3f})\n"
        f"  Wins/Losses/Ties : {d['wins']}/{d['losses']}/{d['ties']}"
        f"   (n paired = {d['n_pairs']})\n"
        f"  Sign test p (one-sided) : {d['p_greater']:.6f}   "
        f"(two-sided: {d['p_two_sided']:.6f})\n"
    )


def format_statistical_summary(stats: Dict, task: Dict) -> str:
    out = [f"\n{'='*70}", "  STATISTICAL COMPARISON", f"{'='*70}",
           f"\n  Task            : {task['name']}",
           f"  Model           : Logistic regression (L2, standardised)",
           f"  Number of splits: {stats['n_runs']}"]

    for metric, title in [('pr_auc', 'PR-AUC'), ('f1', 'F1 (positive class)')]:
        out += [f"\n  {title}", f"  {'Representation':<20} {'Mean ± Std'}",
                f"  {'-'*45}"]
        for tier in TIERS:
            m, s = stats[f'{tier}_{metric}_mean'], stats[f'{tier}_{metric}_std']
            val = "not run" if np.isnan(m) else f"{m:.4f} ± {s:.4f}"
            out.append(f"  {TIER_LABELS[tier]:<20} {val}")

    for name, d in stats['comparisons'].items():
        if d['n_pairs'] == 0:
            continue
        out.append(_format_comparison(COMPARISON_LABELS[name], d))

    # --- TEST A decomposition ---
    ann = stats['comparisons']['hyper_flag_vs_hypergraph']
    val = stats['comparisons']['hb_graph_vs_hyper_flag']
    tot = stats['comparisons']['hb_graph_vs_hypergraph']

    if ann['n_pairs'] > 0 and val['n_pairs'] > 0:
        out += [f"\n{'='*70}",
                "  TEST A — DECOMPOSITION OF THE STOICHIOMETRY EFFECT",
                f"{'='*70}", "",
                f"  {'Component':<44} {'dPR-AUC':>9} {'W/L':>7} {'p (1-sided)':>12}",
                f"  {'-'*78}",
                f"  {'Annotation presence   (flag - hypergraph)':<44} "
                f"{ann['mean_diff']:>+9.4f} {ann['wins']:>3}/{ann['losses']:<3} "
                f"{ann['p_greater']:>12.4f}",
                f"  {'Stoichiometry values  (hb-graph - flag)':<44} "
                f"{val['mean_diff']:>+9.4f} {val['wins']:>3}/{val['losses']:<3} "
                f"{val['p_greater']:>12.4f}",
                f"  {'-'*78}",
                f"  {'TOTAL  (hb-graph - hypergraph)':<44} "
                f"{tot['mean_diff']:>+9.4f} {tot['wins']:>3}/{tot['losses']:<3} "
                f"{tot['p_greater']:>12.4f}"]
        if abs(tot['mean_diff']) > 1e-9:
            share = 100 * ann['mean_diff'] / tot['mean_diff']
            out.append(f"\n  Annotation presence accounts for {share:.0f}% of the "
                       f"total stoichiometry effect.")
        out.append(f"{'='*70}")
    else:
        out.append("\n  TEST A decomposition skipped "
                   "(hyper_flag tier not run or degenerate).")

    # --- TEST C: is the stoichiometry gain just a reciprocal of size? ---
    rec = stats['comparisons']['hyper_recip_vs_hypergraph']
    net = stats['comparisons']['hb_graph_vs_hyper_recip']

    if rec['n_pairs'] > 0 and net['n_pairs'] > 0:
        out += [f"\n{'='*70}",
                "  TEST C — RECIPROCAL-OF-SIZE CONTROL",
                f"{'='*70}", "",
                f"  {'Component':<44} {'dPR-AUC':>9} {'W/L':>7} {'p (1-sided)':>12}",
                f"  {'-'*78}",
                f"  {'1/size alone   (recip - hypergraph)':<44} "
                f"{rec['mean_diff']:>+9.4f} {rec['wins']:>3}/{rec['losses']:<3} "
                f"{rec['p_greater']:>12.4f}",
                f"  {'Stoichiometry  (hb-graph - recip)':<44} "
                f"{net['mean_diff']:>+9.4f} {net['wins']:>3}/{net['losses']:<3} "
                f"{net['p_greater']:>12.4f}",
                f"  {'-'*78}",
                f"  {'TOTAL  (hb-graph - hypergraph)':<44} "
                f"{tot['mean_diff']:>+9.4f} {tot['wins']:>3}/{tot['losses']:<3} "
                f"{tot['p_greater']:>12.4f}"]

        if tot['mean_diff'] > 0.001:
            absorbed = 100 * (1 - net['mean_diff'] / tot['mean_diff'])
            out.append(f"\n  The reciprocal absorbs {absorbed:.0f}% of the total "
                       f"apparent stoichiometry effect.")
        else:
            out.append("\n  (Absorbed share not shown: the total effect is not "
                       "positive, so the ratio\n   is uninterpretable.)")

        if net['p_greater'] < 0.05 and net['mean_diff'] > 0:
            out += ["\n  VERDICT: SURVIVES. The stoichiometry features add signal "
                    "beyond a pure\n  reciprocal-of-size recoding, so the gain is "
                    "not an artefact of the linear\n  model lacking a 1/n basis "
                    "function."]
        else:
            out += ["\n  VERDICT: DOES NOT SURVIVE. The apparent stoichiometric "
                    "gain is accounted\n  for by 1/(complex size), which carries no "
                    "copy-number information. H2\n  cannot be supported from these "
                    "features under this model."]
        out.append(f"{'='*70}")
    else:
        out.append("\n  TEST C control skipped (hyper_recip tier not run).")

    return "\n".join(out)


def format_feature_importance(imp_dfs: List[tuple], top_n: Optional[int] = None) -> str:
    out = [f"\n{'='*70}",
           "  FEATURE IMPORTANCE (Permutation — mean PR-AUC drop)",
           f"{'='*70}"]
    for label, df in imp_dfs:
        if df.empty:
            continue
        show = df if top_n is None else df.head(top_n)
        out += [f"\n  {label}",
                f"  {'Rank':<6} {'Feature':<36} {'Mean':>10} {'Std':>10} {'Median':>10}",
                f"  {'-'*74}"]
        for _, row in show.iterrows():
            out.append(f"  {int(row['rank']):<6} {row['feature']:<36} "
                       f"{row['mean']:>10.5f} {row['std']:>10.5f} "
                       f"{row['median']:>10.5f}")
    out.append("\n  Note: higher = more important; negative = likely noise.")
    return "\n".join(out)


# =======================================================
# PLOTTING
# =======================================================

def plot_tier_comparison(all_results: List[Dict], stats: Dict,
                         output_dir: Path, task: Dict):
    """Paired scatter (headline contrast) + boxplot across all tiers."""
    pair = np.array([r['pairwise_pr_auc']   for r in all_results], dtype=float)
    hbg  = np.array([r['hb_graph_pr_auc']   for r in all_results], dtype=float)

    fig, axes = plt.subplots(1, 2, figsize=(13, 6))

    # Panel 1: paired scatter, one point per split
    axes[0].scatter(pair, hbg, s=60, alpha=0.7, edgecolor='k', linewidth=0.5,
                    color='steelblue')
    axes[0].plot([0, 1], [0, 1], 'k--', linewidth=1)
    axes[0].set_xlim(0, 1); axes[0].set_ylim(0, 1)
    axes[0].set_xlabel('Pairwise PR-AUC')
    axes[0].set_ylabel('HB-graph PR-AUC')
    axes[0].set_title('Paired splits')
    d = stats['comparisons']['hb_graph_vs_pairwise']
    axes[0].text(0.04, 0.94, f"HB-graph wins {d['wins']}/{d['n_pairs']}\n"
                             f"p = {d['p_greater']:.4f}",
                 transform=axes[0].transAxes, va='top',
                 bbox=dict(boxstyle='round', facecolor='white', alpha=0.85))

    # Panel 2: boxplot across tiers
    data, labels = [], []
    for tier in TIERS:
        vals = np.array([r.get(f'{tier}_pr_auc', np.nan) for r in all_results],
                        dtype=float)
        vals = vals[~np.isnan(vals)]
        if len(vals):
            data.append(vals)
            labels.append(TIER_LABELS[tier].replace(' + ', '\n+ '))
    # 'labels' was renamed 'tick_labels' in Matplotlib 3.9; try the new name
    # first so the script is quiet on both old and new versions.
    try:
        bp = axes[1].boxplot(data, tick_labels=labels, patch_artist=True, widths=0.6)
    except TypeError:
        bp = axes[1].boxplot(data, labels=labels, patch_artist=True, widths=0.6)
    for patch, colour in zip(bp['boxes'],
                             ['gray', 'lightsteelblue', 'cornflowerblue',
                              'lightseagreen', 'steelblue']):
        patch.set_facecolor(colour)
    axes[1].set_ylim(0, 1)
    axes[1].set_ylabel('PR-AUC')
    axes[1].set_title('Distribution across splits')
    axes[1].tick_params(axis='x', labelsize=12)

    fig.suptitle(f"{CONFIG['DATABASE']} — {task['name']} — logistic regression")
    fig.tight_layout()
    fig.savefig(output_dir / 'tier_comparison.png', dpi=300, bbox_inches='tight')
    plt.close(fig)


def plot_feature_importance(imp_dfs: List[tuple], output_dir: Path,
                            task: Dict, top_n: int = 15):
    """Horizontal bar chart of mean permutation importance per tier."""
    panels = [(lab, df, c) for lab, df, c in imp_dfs if not df.empty]
    if not panels:
        return

    fig, axes = plt.subplots(1, len(panels), figsize=(6.5 * len(panels), 7))
    if len(panels) == 1:
        axes = [axes]

    for ax, (label, df, colour) in zip(axes, panels):
        top = df.head(top_n).iloc[::-1]
        ax.barh(top['feature'], top['mean'], xerr=top['std'],
                color=colour, edgecolor='k', linewidth=0.5, capsize=3)
        ax.axvline(0, color='k', linewidth=1)
        ax.set_xlabel('Mean PR-AUC drop')
        ax.set_title(label)
        ax.tick_params(axis='y', labelsize=12)

    fig.suptitle(f"{CONFIG['DATABASE']} — {task['name']} — permutation importance")
    fig.tight_layout()
    fig.savefig(output_dir / 'feature_importance.png', dpi=300, bbox_inches='tight')
    plt.close(fig)


# =======================================================
# PER-TASK RUNNER
# =======================================================

def run_task(task_key: str, features_df: pd.DataFrame,
             feature_sets: Dict[str, List[str]], base_output_dir: Path,
             start_time: float) -> Dict:
    """Runs one task end-to-end and writes its outputs. Returns summary rows."""
    task = CONFIG["TASKS"][task_key]
    output_dir = base_output_dir / task_key
    output_dir.mkdir(parents=True, exist_ok=True)

    splits_path = CONFIG["DATA_DIR"] / task["splits_file"]

    print(f"\n{'#'*70}")
    print(f"  TASK: {task['name']}   [{task_key}]")
    print(f"  Splits : {splits_path}")
    print(f"  Output : {output_dir}")
    print(f"{'#'*70}\n")

    splits_df = load_splits(task_key)
    split_indices = sorted(splits_df['split_index'].unique())
    print(f"\n   Running {len(split_indices)} splits.\n")

    # --- Main loop over splits ---
    all_results, failed_splits = [], []
    checkpoint_path = output_dir / 'split_results_checkpoint.csv'
    if checkpoint_path.exists():
        checkpoint_path.unlink()

    for i, split_idx in enumerate(split_indices, start=1):
        print(f"   Split {split_idx:>3} ({i:>2}/{len(split_indices)})...",
              end=" ", flush=True)
        try:
            result = run_split(split_idx, features_df, splits_df,
                               feature_sets, task)
            all_results.append(result)

            ckpt = {k: result.get(k, np.nan) for k in
                    ['split_index', 'n_train', 'n_test',
                     'train_pos_pct', 'test_pos_pct'] +
                    [f'{t}_pr_auc' for t in TIERS]}
            pd.DataFrame([ckpt]).to_csv(
                checkpoint_path, mode='a', index=False,
                header=not checkpoint_path.exists())

            winner = ("HB-graph" if result['pr_auc_diff'] > 0
                      else "Pair" if result['pr_auc_diff'] < 0 else "Tie")
            hf = result.get('hyper_flag_pr_auc', np.nan)
            hf_str = "skip" if np.isnan(hf) else f"{hf:.4f}"
            hr = result.get('hyper_recip_pr_auc', np.nan)
            hr_str = "skip" if np.isnan(hr) else f"{hr:.4f}"
            print(f"train={result['n_train']} ({result['train_pos_pct']:.1f}% pos)  "
                  f"test={result['n_test']} ({result['test_pos_pct']:.1f}% pos)  |  "
                  f"Pair: {result['pairwise_pr_auc']:.4f}, "
                  f"Hyper: {result['hypergraph_pr_auc']:.4f}, "
                  f"Hyper+flag: {hf_str}, "
                  f"Hyper+1/sz: {hr_str}, "
                  f"HB-graph: {result['hb_graph_pr_auc']:.4f}  [{winner}]")
        except Exception as e:
            failed_splits.append(split_idx)
            print(f"ERROR: {e}")

    if failed_splits:
        print(f"\n   WARNING: {len(failed_splits)} split(s) FAILED and are "
              f"excluded from all statistics: {failed_splits}")
    if not all_results:
        raise RuntimeError(f"[{task_key}] No splits completed — nothing to analyse.")
    print(f"\n   Completed {len(all_results)}/{len(split_indices)} splits.")

    n_skipped = sum(1 for r in all_results if r.get('hyper_flag_skipped'))
    if n_skipped:
        print(f"   NOTE: hyper_flag tier skipped on {n_skipped} split(s) "
              f"(flag degenerate in the training fold).")

    # --- Statistics ---
    print("\n4. Statistical analysis...")
    stats = run_sign_test_comparison(all_results)
    summary_text = format_statistical_summary(stats, task)
    print(summary_text)

    # --- Plots ---
    print("\n5. Generating plots...")
    plot_tier_comparison(all_results, stats, output_dir, task)

    # --- Feature importance ---
    print("\n6. Aggregating feature importance...")
    imp = {tier: aggregate_feature_importance(all_results, tier) for tier in TIERS}
    imp_text = format_feature_importance(
        [(TIER_LABELS[t], imp[t]) for t in TIERS])
    print(imp_text)

    flag = CONFIG["ANNOTATION_FLAG"]
    hf_imp = imp['hyper_flag']
    if not hf_imp.empty and flag in set(hf_imp['feature']):
        row = hf_imp[hf_imp['feature'] == flag].iloc[0]
        print(f"\n   >>> '{flag}' ranks {int(row['rank'])} of {len(hf_imp)} in the "
              f"hypergraph+flag model (mean importance {row['mean']:.5f})")

    plot_feature_importance(
        [(TIER_LABELS['pairwise'],   imp['pairwise'],   'gray'),
         (TIER_LABELS['hypergraph'], imp['hypergraph'], 'skyblue'),
         (TIER_LABELS['hb_graph'],   imp['hb_graph'],   'steelblue')],
        output_dir, task)

    # --- Save CSVs ---
    print("\n7. Saving outputs...")

    summary_cols = (['split_index', 'n_train', 'n_test',
                     'train_pos_pct', 'test_pos_pct'] +
                    [f'{t}_{m}' for t in TIERS for m in ('pr_auc', 'f1')] +
                    ['pr_auc_diff', 'f1_diff', 'stoich_pr_auc_diff',
                     'stoich_f1_diff', 'annot_pr_auc_diff', 'value_pr_auc_diff',
                     'recip_pr_auc_diff', 'net_recip_pr_auc_diff'])
    summary_df = pd.DataFrame(
        [{k: r.get(k, np.nan) for k in summary_cols} for r in all_results])
    summary_df.to_csv(output_dir / 'split_results.csv', index=False)
    print("   Saved: split_results.csv")

    stats_rows = []
    for name, d in stats['comparisons'].items():
        stats_rows.append({
            'database': CONFIG['DATABASE'], 'task': task_key,
            'comparison': name, 'splits_file': task['splits_file'],
            'n_splits': stats['n_runs'], 'model': 'LogisticRegression',
            **{k: d[k] for k in ['mean_diff', 'std_diff', 'cohens_dz', 'wins',
                                 'losses', 'ties', 'n_pairs', 'p_greater',
                                 'p_two_sided']}
        })
    pd.DataFrame(stats_rows).to_csv(output_dir / 'comparison_stats.csv', index=False)
    print("   Saved: comparison_stats.csv")

    for tier in TIERS:
        key = f'{tier}_predictions'
        frames = [r[key] for r in all_results if key in r]
        if frames:
            pd.concat(frames, ignore_index=True).to_csv(
                output_dir / f'{tier}_predictions.csv', index=False)
            print(f"   Saved: {tier}_predictions.csv")
        if not imp[tier].empty:
            imp[tier].to_csv(output_dir / f'{tier}_feature_importance.csv',
                             index=False)
            print(f"   Saved: {tier}_feature_importance.csv")

    # Best C per tier per split — worth eyeballing to check the grid isn't
    # railed at an endpoint (which would mean the C range needs widening).
    c_rows = []
    for r in all_results:
        row = {'split_index': r['split_index']}
        for tier in TIERS:
            bp = r.get(f'{tier}_best_params')
            row[f'{tier}_C'] = bp['clf__C'] if bp else np.nan
        c_rows.append(row)
    c_df = pd.DataFrame(c_rows)
    c_df.to_csv(output_dir / 'best_C_per_split.csv', index=False)
    print("   Saved: best_C_per_split.csv")

    grid_C = CONFIG['PARAM_GRID']['clf__C']
    for tier in TIERS:
        vals = c_df[f'{tier}_C'].dropna()
        if len(vals) and (vals == min(grid_C)).mean() > 0.5:
            print(f"   WARNING: {tier} selected the smallest C on "
                  f"{100*(vals == min(grid_C)).mean():.0f}% of splits — "
                  f"consider extending the grid downwards.")
        if len(vals) and (vals == max(grid_C)).mean() > 0.5:
            print(f"   WARNING: {tier} selected the largest C on "
                  f"{100*(vals == max(grid_C)).mean():.0f}% of splits — "
                  f"consider extending the grid upwards.")

    # --- Text report ---
    with open(output_dir / 'statistical_summary.txt', 'w') as f:
        f.write("REPRESENTATION COMPARISON — LOGISTIC REGRESSION BASELINE\n")
        f.write(f"Database: {CONFIG['DATABASE']}\n")
        f.write(f"Task: {task['name']}\n")
        f.write("\nRUN PROVENANCE\n")
        f.write(f"{'-'*70}\n")
        f.write(f"Run at              : "
                f"{time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(start_time))}\n")
        f.write(f"Model               : LogisticRegression "
                f"(StandardScaler pipeline)\n")
        f.write(f"LogReg settings     : {CONFIG['LOGREG_KWARGS']}\n")
        f.write(f"Hyperparameter grid : {CONFIG['PARAM_GRID']}\n")
        f.write(f"Random state        : {CONFIG['RANDOM_STATE']}\n")
        f.write(f"Inner CV folds      : {CONFIG['N_SPLITS_CV']}\n")
        f.write(f"Permutation repeats : {CONFIG['PERM_REPEATS']}\n")
        f.write(f"Splits file         : {splits_path}\n")
        f.write(f"Splits file mtime   : "
                f"{pd.Timestamp(os.path.getmtime(splits_path), unit='s')}\n")
        f.write(f"Data directory      : {CONFIG['DATA_DIR']}\n")
        f.write(f"Feature files       : {CONFIG['PROTEIN_FEATURES_FILE']}, "
                f"{CONFIG['PAIRWISE_FEATURES_FILE']}\n")
        f.write(f"Splits in file      : {splits_df['split_index'].nunique()}\n")
        f.write(f"Splits attempted    : {len(split_indices)}\n")
        f.write(f"Splits completed    : {stats['n_runs']}\n")
        if failed_splits:
            f.write(f"FAILED splits (excluded from all statistics): "
                    f"{failed_splits}\n")
        f.write(f"Annotation flag     : {flag} "
                f"(derived from {CONFIG['FLAG_SOURCE_FEATURE']})\n")
        f.write(f"hyper_recip tier    : "
                f"{'included' if CONFIG['INCLUDE_HYPER_RECIP'] else 'DISABLED'}"
                f" ({CONFIG['RECIP_FEATURE']} = 1/(1+"
                f"{CONFIG['RECIP_SOURCE_FEATURE']}))\n")
        f.write(f"hyper_flag tier     : "
                f"{'included' if CONFIG['INCLUDE_HYPER_FLAG'] else 'DISABLED'}"
                f"{f'; skipped on {n_skipped} split(s)' if n_skipped else ''}\n\n")

        f.write("CLASS BALANCE (mean over splits)\n")
        f.write(f"{'-'*70}\n")
        f.write(f"Train positives     : {summary_df['train_pos_pct'].mean():.2f}% "
                f"(range {summary_df['train_pos_pct'].min():.2f}"
                f"-{summary_df['train_pos_pct'].max():.2f}%)\n")
        f.write(f"Test  positives     : {summary_df['test_pos_pct'].mean():.2f}% "
                f"(range {summary_df['test_pos_pct'].min():.2f}"
                f"-{summary_df['test_pos_pct'].max():.2f}%)\n")
        f.write(f"Mean train / test n : {summary_df['n_train'].mean():.0f} / "
                f"{summary_df['n_test'].mean():.0f}\n\n")

        for tier in TIERS:
            feats = feature_sets.get(tier, [])
            f.write(f"{TIER_LABELS[tier]} features ({len(feats)}):\n")
            for feat in feats:
                tag = ''
                if feat in CONFIG['FEATURES']['STOICHIOMETRY_FEATURES']:
                    tag = ' [stoich]'
                elif feat == flag:
                    tag = ' [annotation flag]'
                elif feat == CONFIG['RECIP_FEATURE']:
                    tag = ' [1/size control]'
                f.write(f"  - {feat}{tag}\n")
            f.write("\n")

        f.write(summary_text.replace('±', '+/-'))
        f.write("\n\n")
        f.write(imp_text)
        f.write("\n\n")
        f.write(f"{'='*70}\n")
        f.write("PER-SPLIT PR-AUC (also in split_results.csv)\n")
        f.write(f"{'='*70}\n\n")
        f.write(f"{'Split':>6} {'Pairwise':>10} {'Hyper':>10} {'Hyper+flag':>11} "
                f"{'Hyper+1/sz':>11} {'HB-graph':>10} {'HBG-Pair':>10} "
                f"{'HBG-Hyper':>10} {'HBG-1/sz':>10}\n")
        f.write(f"{'-'*94}\n")
        for _, row in summary_df.sort_values('split_index').iterrows():
            def _fmt(v, w=11):
                return " " * (w - 1) + "-" if pd.isna(v) else f"{v:>{w}.4f}"
            f.write(f"{int(row['split_index']):>6} "
                    f"{row['pairwise_pr_auc']:>10.4f} "
                    f"{row['hypergraph_pr_auc']:>10.4f} "
                    f"{_fmt(row['hyper_flag_pr_auc'])} "
                    f"{_fmt(row['hyper_recip_pr_auc'])} "
                    f"{row['hb_graph_pr_auc']:>10.4f} "
                    f"{row['pr_auc_diff']:>+10.4f} "
                    f"{row['stoich_pr_auc_diff']:>+10.4f} "
                    f"{_fmt(row['net_recip_pr_auc_diff'], 10)}\n")
        f.write(f"\n\nRuntime to this point: "
                f"{(time.time() - start_time)/60:.1f} min\n")
    print("   Saved: statistical_summary.txt")

    # --- Rows for the cross-task summary table ---
    perf_rows = [{
        'database': CONFIG['DATABASE'], 'task': task_key,
        'task_name': task['name'], 'model': 'LogisticRegression',
        'n_splits': stats['n_runs'], 'representation': TIER_LABELS[tier],
        'pr_auc_mean': stats[f'{tier}_pr_auc_mean'],
        'pr_auc_std':  stats[f'{tier}_pr_auc_std'],
        'f1_mean':     stats[f'{tier}_f1_mean'],
        'f1_std':      stats[f'{tier}_f1_std'],
    } for tier in TIERS]

    return {'performance': perf_rows, 'comparisons': stats_rows}


# =======================================================
# MAIN
# =======================================================

if __name__ == "__main__":

    start_time = time.time()
    print(f"Process started at "
          f"{time.strftime('%H:%M:%S', time.localtime(start_time))}")

    base_output_dir = Path(CONFIG["BASE_OUTPUT_DIR"])
    base_output_dir.mkdir(parents=True, exist_ok=True)

    # --- Pre-flight: every splits file must exist before any work begins ---
    for key, task in CONFIG["TASKS"].items():
        p = CONFIG["DATA_DIR"] / task["splits_file"]
        if not p.exists():
            raise FileNotFoundError(
                f"Splits file for task '{key}' not found: {p}\n"
                f"   Check CONFIG['TASKS']['{key}']['splits_file'].")

    print(f"\n{'='*70}")
    print(f"  LOGISTIC REGRESSION BASELINE")
    print(f"  Database : {CONFIG['DATABASE']}")
    print(f"  Tasks    : {', '.join(CONFIG['TASKS'])}")
    print(f"  Output   : {base_output_dir}")
    print(f"{'='*70}\n")

    # --- Load features once; they are shared across all three tasks ---
    features_df = load_all_features()

    hb_graph_features = [f for f in CONFIG["FEATURES"]["HB_GRAPH"]
                         if f in features_df.columns]
    pairwise_features = [f for f in CONFIG["FEATURES"]["PAIRWISE"]
                         if f in features_df.columns]
    stoich_features   = CONFIG["FEATURES"].get("STOICHIOMETRY_FEATURES", [])
    hypergraph_features = [f for f in hb_graph_features
                           if f not in stoich_features]

    flag  = CONFIG["ANNOTATION_FLAG"]
    recip = CONFIG["RECIP_FEATURE"]
    feature_sets = {
        'pairwise':   pairwise_features,
        'hypergraph': hypergraph_features,
        'hyper_flag': (hypergraph_features + [flag]
                       if CONFIG["INCLUDE_HYPER_FLAG"] else []),
        'hyper_recip': (hypergraph_features + [recip]
                        if CONFIG["INCLUDE_HYPER_RECIP"] else []),
        'hb_graph':   hb_graph_features,
    }

    missing_hbg  = [f for f in CONFIG["FEATURES"]["HB_GRAPH"]
                    if f not in features_df.columns]
    missing_pair = [f for f in CONFIG["FEATURES"]["PAIRWISE"]
                    if f not in features_df.columns]
    if missing_hbg:
        print(f"   WARNING: {len(missing_hbg)} hb-graph features not found "
              f"in data: {missing_hbg}")
    if missing_pair:
        print(f"   WARNING: {len(missing_pair)} pairwise features not found "
              f"in data: {missing_pair}")

    for tier in TIERS:
        feats = feature_sets[tier]
        if not feats:
            print(f"\n   {TIER_LABELS[tier]} tier: DISABLED")
            continue
        print(f"\n   Active {TIER_LABELS[tier]} features ({len(feats)}):")
        for f_ in feats:
            tag = (' [stoich]' if f_ in stoich_features
                   else ' [annotation flag]' if f_ == flag
                   else ' [1/size control]' if f_ == recip else '')
            print(f"     - {f_}{tag}")

    # --- Fill any NaNs in feature columns ---
    # NB: encoding deliberately UNCHANGED from the tree scripts. Test A measures
    # what the current fillna(0) encoding is buying; fixing it here would defeat that.
    all_feature_cols = sorted(set(hb_graph_features + pairwise_features))
    if CONFIG["INCLUDE_HYPER_RECIP"] and recip in features_df.columns:
        all_feature_cols = sorted(set(all_feature_cols + [recip]))
    n_nans = int(features_df[all_feature_cols].isna().sum().sum())
    if n_nans > 0:
        print(f"\n   Filling {n_nans} missing feature values with 0.")
        features_df[all_feature_cols] = features_df[all_feature_cols].fillna(0)

    # --- Run every task ---
    perf_rows, comp_rows, failed_tasks = [], [], []
    for task_key in CONFIG["TASKS"]:
        try:
            out = run_task(task_key, features_df, feature_sets,
                           base_output_dir, start_time)
            perf_rows += out['performance']
            comp_rows += out['comparisons']
        except Exception as e:
            failed_tasks.append(task_key)
            print(f"\n   ERROR: task '{task_key}' failed: {e}\n")

    # --- Cross-task summary ---
    if perf_rows:
        perf_df = pd.DataFrame(perf_rows)
        perf_df.to_csv(base_output_dir / 'all_tasks_summary.csv', index=False)
        pd.DataFrame(comp_rows).to_csv(
            base_output_dir / 'all_tasks_comparison_stats.csv', index=False)

        print(f"\n{'='*70}")
        print(f"  CROSS-TASK SUMMARY — {CONFIG['DATABASE']} — "
              f"logistic regression PR-AUC")
        print(f"{'='*70}\n")
        print(f"  {'Task':<12} {'Representation':<20} {'PR-AUC':>18} {'F1':>18}")
        print(f"  {'-'*70}")
        for _, r in perf_df.iterrows():
            if np.isnan(r['pr_auc_mean']):
                continue
            print(f"  {r['task']:<12} {r['representation']:<20} "
                  f"{r['pr_auc_mean']:>10.4f} ± {r['pr_auc_std']:.4f}  "
                  f"{r['f1_mean']:>8.4f} ± {r['f1_std']:.4f}")
        print(f"\n  Saved: all_tasks_summary.csv, all_tasks_comparison_stats.csv")

    if failed_tasks:
        print(f"\n  WARNING: {len(failed_tasks)} task(s) failed: {failed_tasks}")

    print(f"\n{'='*70}")
    print("  COMPLETE")
    print(f"{'='*70}")
    elapsed = time.time() - start_time
    print(f"\nTotal time: {elapsed:.1f}s ({elapsed/60:.1f} min)")
# Out:
# Process started at 18:17:00
#
# ======================================================================
#   LOGISTIC REGRESSION BASELINE
#   Database : CP
#   Tasks    : ess, hpa, chembl
#   Output   : logistic/cp_second_testA
# ======================================================================
#
# 1. Loading feature data...
#    Higher-order (hb-graph) features shape : (3394, 35)
#    Pairwise features shape               : (3394, 9)
#    Combined shape                        : (3394, 43)
#
#    Derived 'flag_HasStoich' from 'stoich_MedianRatio':
#      curated   : 2033 / 3394  (59.9%)
#      uncurated : 1361 / 3394  (40.1%)
#      cross-check vs stoich_protein.csv: exact match on all 3394 proteins ✓
#
#    Derived 'recip_MedComplexNodes' = 1 / (1 + protein_MedComplexNodes)  [TEST C control]
#      Spearman vs stoichiometry features (curated proteins only, n = 2,033):
#        stoich_WeightedTriangles           -0.942   <-- near-deterministic
#        stoich_AvgNeighbourDegreeStoich    -0.187
#        stoich_RangeComplexSize            -0.253
#        stoich_MedComplexSize              -0.745
#        stoich_MedianRatio                 +0.918   <-- near-deterministic
#        stoich_RangeRatio                  -0.111
#
#    Active Pairwise features (4):
#      - pair_Degree
#      - pair_LocalClustCoeff
#      - pair_TriangleCount
#      - pair_AvgNeighborDegree
#
#    Active Hypergraph features (8):
#      - base_Degree
#      - base_LocalClustCoeff
#      - base_TriangleCount
#      - base_UniquePartners
#      - base_AvgNeighbourDegree
#      - protein_RangeUniqueRatio
#      - protein_MedComplexNodes
#      - protein_RangeComplexNodes
#
#    Active Hypergraph + flag features (9):
#      - base_Degree
#      - base_LocalClustCoeff
#      - base_TriangleCount
#      - base_UniquePartners
#      - base_AvgNeighbourDegree
#      - protein_RangeUniqueRatio
#      - protein_MedComplexNodes
#      - protein_RangeComplexNodes
#      - flag_HasStoich [annotation flag]
#
#    Active Hypergraph + 1/size features (9):
#      - base_Degree
#      - base_LocalClustCoeff
#      - base_TriangleCount
#      - base_UniquePartners
#      - base_AvgNeighbourDegree
#      - protein_RangeUniqueRatio
#      - protein_MedComplexNodes
#      - protein_RangeComplexNodes
#      - recip_MedComplexNodes [1/size control]
#
#    Active HB-graph features (14):
#      - base_Degree
#      - base_LocalClustCoeff
#      - base_TriangleCount
#      - base_UniquePartners
#      - base_AvgNeighbourDegree
#      - stoich_WeightedTriangles [stoich]
#      - stoich_AvgNeighbourDegreeStoich [stoich]
#      - stoich_RangeComplexSize [stoich]
#      - stoich_MedComplexSize [stoich]
#      - stoich_MedianRatio [stoich]
#      - stoich_RangeRatio [stoich]
#      - protein_RangeUniqueRatio
#      - protein_MedComplexNodes
#      - protein_RangeComplexNodes
#
# ######################################################################
#   TASK: Gene Essentiality   [ess]
#   Splits : /Users/anitaapplegarth/github/dphil/protein_complexes/data/lookup_tables/cp/ess_protein_splits.csv
#   Output : logistic/cp_second_testA/ess
# ######################################################################
#
# 2. Loading pre-assigned splits...
#    File              : ess_protein_splits.csv
#    Last modified     : 2026-08-03 15:16:28.783479929
#    Splits file rows  : 169700
#    Unique proteins   : 3394
#    Number of splits  : 50
#    Unmapped labels (treated as Unknown): ['Unknown']
#    Labelled proteins : 3306  (23.4% positive)
#
#    Running 50 splits.
#
#    Split   1 ( 1/50)... train=2656 (24.0% pos)  test=650 (20.8% pos)  |  Pair: 0.3461, Hyper: 0.4008, Hyper+flag: 0.3921, Hyper+1/sz: 0.4142, HB-graph: 0.3784  [HB-graph]
#    Split   2 ( 2/50)... train=2694 (23.0% pos)  test=612 (25.0% pos)  |  Pair: 0.5266, Hyper: 0.5192, Hyper+flag: 0.4854, Hyper+1/sz: 0.5238, HB-graph: 0.5100  [Pair]
#    Split   3 ( 3/50)... train=2614 (23.2% pos)  test=692 (24.1% pos)  |  Pair: 0.6756, Hyper: 0.6957, Hyper+flag: 0.7032, Hyper+1/sz: 0.6998, HB-graph: 0.6826  [HB-graph]
#    Split   4 ( 4/50)... train=2743 (24.0% pos)  test=563 (20.6% pos)  |  Pair: 0.3740, Hyper: 0.4190, Hyper+flag: 0.4113, Hyper+1/sz: 0.4254, HB-graph: 0.3400  [Pair]
#    Split   5 ( 5/50)... train=2548 (24.2% pos)  test=758 (20.7% pos)  |  Pair: 0.4419, Hyper: 0.4582, Hyper+flag: 0.4700, Hyper+1/sz: 0.4631, HB-graph: 0.4461  [HB-graph]
#    Split   6 ( 6/50)... train=2640 (24.3% pos)  test=666 (19.8% pos)  |  Pair: 0.3709, Hyper: 0.4366, Hyper+flag: 0.4473, Hyper+1/sz: 0.4188, HB-graph: 0.3781  [HB-graph]
#    Split   7 ( 7/50)... train=2680 (22.9% pos)  test=626 (25.4% pos)  |  Pair: 0.5543, Hyper: 0.5831, Hyper+flag: 0.5768, Hyper+1/sz: 0.5734, HB-graph: 0.5548  [HB-graph]
#    Split   8 ( 8/50)... train=2667 (24.3% pos)  test=639 (19.6% pos)  |  Pair: 0.3512, Hyper: 0.4035, Hyper+flag: 0.3846, Hyper+1/sz: 0.3855, HB-graph: 0.3533  [HB-graph]
#    Split   9 ( 9/50)... train=2651 (23.2% pos)  test=655 (24.1% pos)  |  Pair: 0.5143, Hyper: 0.5373, Hyper+flag: 0.5373, Hyper+1/sz: 0.5323, HB-graph: 0.4906  [Pair]
#    Split  10 (10/50)... train=2636 (22.9% pos)  test=670 (25.2% pos)  |  Pair: 0.6073, Hyper: 0.6317, Hyper+flag: 0.6330, Hyper+1/sz: 0.6296, HB-graph: 0.6097  [HB-graph]
#    Split  11 (11/50)... train=2668 (22.7% pos)  test=638 (26.3% pos)  |  Pair: 0.5389, Hyper: 0.5559, Hyper+flag: 0.5567, Hyper+1/sz: 0.5565, HB-graph: 0.5389  [Pair]
#    Split  12 (12/50)... train=2668 (22.9% pos)  test=638 (25.5% pos)  |  Pair: 0.5321, Hyper: 0.5436, Hyper+flag: 0.5419, Hyper+1/sz: 0.5559, HB-graph: 0.5377  [HB-graph]
#    Split  13 (13/50)... train=2620 (24.0% pos)  test=686 (20.8% pos)  |  Pair: 0.6121, Hyper: 0.6371, Hyper+flag: 0.6386, Hyper+1/sz: 0.6266, HB-graph: 0.6310  [HB-graph]
#    Split  14 (14/50)... train=2649 (23.9% pos)  test=657 (21.2% pos)  |  Pair: 0.4731, Hyper: 0.4896, Hyper+flag: 0.4544, Hyper+1/sz: 0.4908, HB-graph: 0.4549  [Pair]
#    Split  15 (15/50)... train=2694 (24.0% pos)  test=612 (20.6% pos)  |  Pair: 0.5611, Hyper: 0.5822, Hyper+flag: 0.5863, Hyper+1/sz: 0.5741, HB-graph: 0.5498  [Pair]
#    Split  16 (16/50)... train=2639 (24.1% pos)  test=667 (20.5% pos)  |  Pair: 0.2881, Hyper: 0.3095, Hyper+flag: 0.3128, Hyper+1/sz: 0.3142, HB-graph: 0.2939  [HB-graph]
#    Split  17 (17/50)... train=2655 (23.7% pos)  test=651 (22.0% pos)  |  Pair: 0.6042, Hyper: 0.6307, Hyper+flag: 0.6326, Hyper+1/sz: 0.6221, HB-graph: 0.6236  [HB-graph]
#    Split  18 (18/50)... train=2638 (23.8% pos)  test=668 (21.6% pos)  |  Pair: 0.4205, Hyper: 0.4428, Hyper+flag: 0.4422, Hyper+1/sz: 0.4440, HB-graph: 0.4381  [HB-graph]
#    Split  19 (19/50)... train=2625 (24.2% pos)  test=681 (20.3% pos)  |  Pair: 0.3535, Hyper: 0.4081, Hyper+flag: 0.3574, Hyper+1/sz: 0.4043, HB-graph: 0.4516  [HB-graph]
#    Split  20 (20/50)... train=2567 (23.9% pos)  test=739 (21.5% pos)  |  Pair: 0.3334, Hyper: 0.3418, Hyper+flag: 0.3799, Hyper+1/sz: 0.3855, HB-graph: 0.3396  [HB-graph]
#    Split  21 (21/50)... train=2686 (22.9% pos)  test=620 (25.3% pos)  |  Pair: 0.4773, Hyper: 0.5084, Hyper+flag: 0.4738, Hyper+1/sz: 0.4933, HB-graph: 0.4990  [HB-graph]
#    Split  22 (22/50)... train=2633 (23.7% pos)  test=673 (22.0% pos)  |  Pair: 0.4452, Hyper: 0.4521, Hyper+flag: 0.4656, Hyper+1/sz: 0.4799, HB-graph: 0.4510  [HB-graph]
#    Split  23 (23/50)... train=2740 (22.6% pos)  test=566 (27.0% pos)  |  Pair: 0.5776, Hyper: 0.5718, Hyper+flag: 0.5877, Hyper+1/sz: 0.5766, HB-graph: 0.5751  [Pair]
#    Split  24 (24/50)... train=2737 (23.9% pos)  test=569 (21.1% pos)  |  Pair: 0.3619, Hyper: 0.3762, Hyper+flag: 0.3635, Hyper+1/sz: 0.3803, HB-graph: 0.3584  [Pair]
#    Split  25 (25/50)... train=2693 (24.0% pos)  test=613 (20.9% pos)  |  Pair: 0.4569, Hyper: 0.4936, Hyper+flag: 0.4996, Hyper+1/sz: 0.4885, HB-graph: 0.4918  [HB-graph]
#    Split  26 (26/50)... train=2602 (23.3% pos)  test=704 (23.9% pos)  |  Pair: 0.5129, Hyper: 0.5468, Hyper+flag: 0.5326, Hyper+1/sz: 0.5202, HB-graph: 0.5021  [Pair]
#    Split  27 (27/50)... train=2709 (23.8% pos)  test=597 (21.3% pos)  |  Pair: 0.4306, Hyper: 0.4518, Hyper+flag: 0.4591, Hyper+1/sz: 0.4513, HB-graph: 0.4139  [Pair]
#    Split  28 (28/50)... train=2712 (23.9% pos)  test=594 (21.0% pos)  |  Pair: 0.4727, Hyper: 0.4935, Hyper+flag: 0.4975, Hyper+1/sz: 0.4969, HB-graph: 0.4937  [HB-graph]
#    Split  29 (29/50)... train=2603 (23.8% pos)  test=703 (21.8% pos)  |  Pair: 0.4208, Hyper: 0.4469, Hyper+flag: 0.4439, Hyper+1/sz: 0.4373, HB-graph: 0.4241  [HB-graph]
#    Split  30 (30/50)... train=2705 (23.4% pos)  test=601 (23.1% pos)  |  Pair: 0.3569, Hyper: 0.4279, Hyper+flag: 0.4144, Hyper+1/sz: 0.4307, HB-graph: 0.3986  [HB-graph]
#    Split  31 (31/50)... train=2678 (22.7% pos)  test=628 (26.1% pos)  |  Pair: 0.6521, Hyper: 0.6373, Hyper+flag: 0.6284, Hyper+1/sz: 0.6501, HB-graph: 0.5949  [Pair]
#    Split  32 (32/50)... train=2683 (24.0% pos)  test=623 (20.5% pos)  |  Pair: 0.3584, Hyper: 0.3817, Hyper+flag: 0.3756, Hyper+1/sz: 0.3828, HB-graph: 0.3460  [Pair]
#    Split  33 (33/50)... train=2641 (23.8% pos)  test=665 (21.7% pos)  |  Pair: 0.5726, Hyper: 0.5969, Hyper+flag: 0.6022, Hyper+1/sz: 0.5977, HB-graph: 0.5821  [HB-graph]
#    Split  34 (34/50)... train=2679 (23.7% pos)  test=627 (22.2% pos)  |  Pair: 0.4512, Hyper: 0.5186, Hyper+flag: 0.5124, Hyper+1/sz: 0.5121, HB-graph: 0.4878  [HB-graph]
#    Split  35 (35/50)... train=2698 (23.6% pos)  test=608 (22.5% pos)  |  Pair: 0.4497, Hyper: 0.4878, Hyper+flag: 0.4804, Hyper+1/sz: 0.4737, HB-graph: 0.4444  [Pair]
#    Split  36 (36/50)... train=2630 (23.7% pos)  test=676 (22.2% pos)  |  Pair: 0.4532, Hyper: 0.5642, Hyper+flag: 0.5468, Hyper+1/sz: 0.5404, HB-graph: 0.5354  [HB-graph]
#    Split  37 (37/50)... train=2724 (22.7% pos)  test=582 (26.6% pos)  |  Pair: 0.5880, Hyper: 0.6217, Hyper+flag: 0.6164, Hyper+1/sz: 0.6187, HB-graph: 0.5958  [HB-graph]
#    Split  38 (38/50)... train=2687 (24.2% pos)  test=619 (19.7% pos)  |  Pair: 0.4063, Hyper: 0.4298, Hyper+flag: 0.4345, Hyper+1/sz: 0.4537, HB-graph: 0.4278  [HB-graph]
#    Split  39 (39/50)... train=2690 (24.3% pos)  test=616 (19.2% pos)  |  Pair: 0.3509, Hyper: 0.3887, Hyper+flag: 0.3911, Hyper+1/sz: 0.4110, HB-graph: 0.3660  [HB-graph]
#    Split  40 (40/50)... train=2615 (23.8% pos)  test=691 (21.9% pos)  |  Pair: 0.3907, Hyper: 0.4283, Hyper+flag: 0.4275, Hyper+1/sz: 0.4427, HB-graph: 0.3870  [Pair]
#    Split  41 (41/50)... train=2598 (24.4% pos)  test=708 (19.8% pos)  |  Pair: 0.3474, Hyper: 0.3439, Hyper+flag: 0.3572, Hyper+1/sz: 0.3706, HB-graph: 0.3472  [Pair]
#    Split  42 (42/50)... train=2720 (24.0% pos)  test=586 (20.3% pos)  |  Pair: 0.4181, Hyper: 0.4667, Hyper+flag: 0.4555, Hyper+1/sz: 0.4837, HB-graph: 0.5083  [HB-graph]
#    Split  43 (43/50)... train=2622 (23.5% pos)  test=684 (23.0% pos)  |  Pair: 0.4907, Hyper: 0.5626, Hyper+flag: 0.5714, Hyper+1/sz: 0.5718, HB-graph: 0.5482  [HB-graph]
#    Split  44 (44/50)... train=2657 (23.0% pos)  test=649 (25.1% pos)  |  Pair: 0.6019, Hyper: 0.6396, Hyper+flag: 0.6398, Hyper+1/sz: 0.6388, HB-graph: 0.6393  [HB-graph]
#    Split  45 (45/50)... train=2728 (22.8% pos)  test=578 (26.3% pos)  |  Pair: 0.4633, Hyper: 0.5207, Hyper+flag: 0.5199, Hyper+1/sz: 0.5167, HB-graph: 0.4897  [HB-graph]
#    Split  46 (46/50)... train=2651 (24.0% pos)  test=655 (20.8% pos)  |  Pair: 0.2959, Hyper: 0.3031, Hyper+flag: 0.3433, Hyper+1/sz: 0.3277, HB-graph: 0.3809  [HB-graph]
#    Split  47 (47/50)... train=2745 (23.6% pos)  test=561 (22.5% pos)  |  Pair: 0.5160, Hyper: 0.5254, Hyper+flag: 0.5318, Hyper+1/sz: 0.5369, HB-graph: 0.5065  [Pair]
#    Split  48 (48/50)... train=2701 (23.4% pos)  test=605 (23.1% pos)  |  Pair: 0.4477, Hyper: 0.4840, Hyper+flag: 0.4851, Hyper+1/sz: 0.4831, HB-graph: 0.4602  [HB-graph]
#    Split  49 (49/50)... train=2689 (23.4% pos)  test=617 (23.3% pos)  |  Pair: 0.5982, Hyper: 0.6019, Hyper+flag: 0.6111, Hyper+1/sz: 0.6065, HB-graph: 0.5989  [HB-graph]
#    Split  50 (50/50)... train=2622 (24.1% pos)  test=684 (20.5% pos)  |  Pair: 0.2686, Hyper: 0.2883, Hyper+flag: 0.2929, Hyper+1/sz: 0.2916, HB-graph: 0.2752  [HB-graph]
#
#    Completed 50/50 splits.
#
# 4. Statistical analysis...
#
# ======================================================================
#   STATISTICAL COMPARISON
# ======================================================================
#
#   Task            : Gene Essentiality
#   Model           : Logistic regression (L2, standardised)
#   Number of splits: 50
#
#   PR-AUC
#   Representation       Mean ± Std
#   ---------------------------------------------
#   Pairwise             0.4623 ± 0.1006
#   Hypergraph           0.4917 ± 0.0977
#   Hypergraph + flag    0.4901 ± 0.0972
#   Hypergraph + 1/size  0.4941 ± 0.0932
#   HB-graph             0.4747 ± 0.0972
#
#   F1 (positive class)
#   Representation       Mean ± Std
#   ---------------------------------------------
#   Pairwise             0.4773 ± 0.0571
#   Hypergraph           0.4599 ± 0.0677
#   Hypergraph + flag    0.4494 ± 0.0691
#   Hypergraph + 1/size  0.4843 ± 0.0538
#   HB-graph             0.4434 ± 0.0756
#
#   --- HB-graph vs Pairwise — headline representation effect ---
#   Mean diff : +0.0124 ± 0.0301   (Cohen's dz = +0.411)
#   Wins/Losses/Ties : 34/16/0   (n paired = 50)
#   Sign test p (one-sided) : 0.007673   (two-sided: 0.015347)
#
#
#   --- HB-graph vs Hypergraph — stoichiometry effect ---
#   Mean diff : -0.0171 ± 0.0255   (Cohen's dz = -0.669)
#   Wins/Losses/Ties : 6/44/0   (n paired = 50)
#   Sign test p (one-sided) : 1.000000   (two-sided: 0.000000)
#
#
#   --- Hypergraph vs Pairwise — representation effect alone ---
#   Mean diff : +0.0295 ± 0.0232   (Cohen's dz = +1.269)
#   Wins/Losses/Ties : 46/4/0   (n paired = 50)
#   Sign test p (one-sided) : 0.000000   (two-sided: 0.000000)
#
#
#   --- [TEST A] Hyper+flag vs Hypergraph — ANNOTATION PRESENCE alone ---
#   Mean diff : -0.0016 ± 0.0158   (Cohen's dz = -0.103)
#   Wins/Losses/Ties : 27/23/0   (n paired = 50)
#   Sign test p (one-sided) : 0.335906   (two-sided: 0.671811)
#
#
#   --- [TEST A] HB-graph vs Hyper+flag — STOICHIOMETRY VALUES, net of annotation ---
#   Mean diff : -0.0155 ± 0.0271   (Cohen's dz = -0.570)
#   Wins/Losses/Ties : 6/44/0   (n paired = 50)
#   Sign test p (one-sided) : 1.000000   (two-sided: 0.000000)
#
#
#   --- [TEST C] Hyper+1/size vs Hypergraph — what a pure size recoding buys ---
#   Mean diff : +0.0024 ± 0.0136   (Cohen's dz = +0.173)
#   Wins/Losses/Ties : 29/21/0   (n paired = 50)
#   Sign test p (one-sided) : 0.161118   (two-sided: 0.322236)
#
#
#   --- [TEST C] HB-graph vs Hyper+1/size — STOICHIOMETRY net of size recoding ---
#   Mean diff : -0.0194 ± 0.0233   (Cohen's dz = -0.833)
#   Wins/Losses/Ties : 8/42/0   (n paired = 50)
#   Sign test p (one-sided) : 1.000000   (two-sided: 0.000001)
#
#
# ======================================================================
#   TEST A — DECOMPOSITION OF THE STOICHIOMETRY EFFECT
# ======================================================================
#
#   Component                                      dPR-AUC     W/L  p (1-sided)
#   ------------------------------------------------------------------------------
#   Annotation presence   (flag - hypergraph)      -0.0016  27/23        0.3359
#   Stoichiometry values  (hb-graph - flag)        -0.0155   6/44        1.0000
#   ------------------------------------------------------------------------------
#   TOTAL  (hb-graph - hypergraph)                 -0.0171   6/44        1.0000
#
#   Annotation presence accounts for 10% of the total stoichiometry effect.
# ======================================================================
#
# ======================================================================
#   TEST C — RECIPROCAL-OF-SIZE CONTROL
# ======================================================================
#
#   Component                                      dPR-AUC     W/L  p (1-sided)
#   ------------------------------------------------------------------------------
#   1/size alone   (recip - hypergraph)            +0.0024  29/21        0.1611
#   Stoichiometry  (hb-graph - recip)              -0.0194   8/42        1.0000
#   ------------------------------------------------------------------------------
#   TOTAL  (hb-graph - hypergraph)                 -0.0171   6/44        1.0000
#
#   (Absorbed share not shown: the total effect is not positive, so the ratio
#    is uninterpretable.)
#
#   VERDICT: DOES NOT SURVIVE. The apparent stoichiometric gain is accounted
#   for by 1/(complex size), which carries no copy-number information. H2
#   cannot be supported from these features under this model.
# ======================================================================
#
# 5. Generating plots...
#
# 6. Aggregating feature importance...
#
# ======================================================================
#   FEATURE IMPORTANCE (Permutation — mean PR-AUC drop)
# ======================================================================
#
#   Pairwise
#   Rank   Feature                                    Mean        Std     Median
#   --------------------------------------------------------------------------
#   1      pair_Degree                             0.21467    0.09879    0.20413
#   2      pair_LocalClustCoeff                    0.03703    0.01494    0.03956
#   3      pair_AvgNeighborDegree                  0.02556    0.01349    0.02459
#   4      pair_TriangleCount                      0.01001    0.02094    0.00463
#
#   Hypergraph
#   Rank   Feature                                    Mean        Std     Median
#   --------------------------------------------------------------------------
#   1      base_UniquePartners                     0.06523    0.03552    0.05809
#   2      protein_RangeComplexNodes               0.06135    0.03734    0.05849
#   3      base_AvgNeighbourDegree                 0.02264    0.01495    0.02339
#   4      base_TriangleCount                      0.02253    0.03370    0.01023
#   5      protein_MedComplexNodes                 0.02193    0.01887    0.01912
#   6      base_LocalClustCoeff                    0.01605    0.01382    0.01487
#   7      protein_RangeUniqueRatio                0.01118    0.01091    0.01130
#   8      base_Degree                             0.00675    0.00963    0.00530
#
#   Hypergraph + flag
#   Rank   Feature                                    Mean        Std     Median
#   --------------------------------------------------------------------------
#   1      base_UniquePartners                     0.06189    0.02470    0.05968
#   2      protein_RangeComplexNodes               0.05105    0.03314    0.04350
#   3      protein_MedComplexNodes                 0.03048    0.02431    0.02958
#   4      base_TriangleCount                      0.02368    0.02917    0.01348
#   5      base_AvgNeighbourDegree                 0.02033    0.01505    0.02297
#   6      base_LocalClustCoeff                    0.01480    0.01354    0.01494
#   7      flag_HasStoich                          0.01084    0.01818    0.00603
#   8      protein_RangeUniqueRatio                0.01068    0.00891    0.00972
#   9      base_Degree                             0.00463    0.00805    0.00221
#
#   Hypergraph + 1/size
#   Rank   Feature                                    Mean        Std     Median
#   --------------------------------------------------------------------------
#   1      recip_MedComplexNodes                   0.07311    0.04079    0.05830
#   2      protein_RangeComplexNodes               0.04180    0.02949    0.03427
#   3      base_TriangleCount                      0.01930    0.03407    0.00972
#   4      base_AvgNeighbourDegree                 0.01652    0.01425    0.01608
#   5      base_LocalClustCoeff                    0.01498    0.01315    0.01345
#   6      base_UniquePartners                     0.01176    0.01464    0.00943
#   7      base_Degree                             0.00526    0.00830    0.00243
#   8      protein_MedComplexNodes                 0.00323    0.01328    0.00098
#   9      protein_RangeUniqueRatio                0.00187    0.00366    0.00120
#
#   HB-graph
#   Rank   Feature                                    Mean        Std     Median
#   --------------------------------------------------------------------------
#   1      protein_RangeComplexNodes               0.02985    0.02503    0.02030
#   2      base_UniquePartners                     0.02940    0.01402    0.03083
#   3      stoich_WeightedTriangles                0.01534    0.01562    0.01085
#   4      stoich_MedianRatio                      0.01151    0.01272    0.00923
#   5      protein_MedComplexNodes                 0.01118    0.01257    0.01249
#   6      base_AvgNeighbourDegree                 0.01025    0.00637    0.01036
#   7      base_LocalClustCoeff                    0.00947    0.00619    0.00834
#   8      base_TriangleCount                      0.00942    0.01228    0.00729
#   9      stoich_MedComplexSize                   0.00714    0.01211    0.00500
#   10     stoich_AvgNeighbourDegreeStoich         0.00481    0.00458    0.00457
#   11     base_Degree                             0.00440    0.00878    0.00205
#   12     stoich_RangeRatio                       0.00123    0.00291    0.00103
#   13     protein_RangeUniqueRatio                0.00073    0.00330    0.00070
#   14     stoich_RangeComplexSize                 0.00006    0.00560    0.00035
#
#   Note: higher = more important; negative = likely noise.
#
#    >>> 'flag_HasStoich' ranks 7 of 9 in the hypergraph+flag model (mean importance 0.01084)
#
# 7. Saving outputs...
#    Saved: split_results.csv
#    Saved: comparison_stats.csv
#    Saved: pairwise_predictions.csv
#    Saved: pairwise_feature_importance.csv
#    Saved: hypergraph_predictions.csv
#    Saved: hypergraph_feature_importance.csv
#    Saved: hyper_flag_predictions.csv
#    Saved: hyper_flag_feature_importance.csv
#    Saved: hyper_recip_predictions.csv
#    Saved: hyper_recip_feature_importance.csv
#    Saved: hb_graph_predictions.csv
#    Saved: hb_graph_feature_importance.csv
#    Saved: best_C_per_split.csv
#    Saved: statistical_summary.txt
#
# ######################################################################
#   TASK: Drug Target Prediction (HPA)   [hpa]
#   Splits : /Users/anitaapplegarth/github/dphil/protein_complexes/data/lookup_tables/cp/hpa_protein_splits.csv
#   Output : logistic/cp_second_testA/hpa
# ######################################################################
#
# 2. Loading pre-assigned splits...
#    File              : hpa_protein_splits.csv
#    Last modified     : 2026-08-03 15:29:18.942100286
#    Splits file rows  : 169700
#    Unique proteins   : 3394
#    Number of splits  : 50
#    Labelled proteins : 3388  (8.0% positive)
#
#    Running 50 splits.
#
#    Split   1 ( 1/50)... train=2763 (7.9% pos)  test=625 (8.5% pos)  |  Pair: 0.1247, Hyper: 0.2074, Hyper+flag: 0.2375, Hyper+1/sz: 0.2560, HB-graph: 0.3321  [HB-graph]
#    Split   2 ( 2/50)... train=2693 (8.0% pos)  test=695 (8.2% pos)  |  Pair: 0.1308, Hyper: 0.1782, Hyper+flag: 0.2109, Hyper+1/sz: 0.1772, HB-graph: 0.2188  [HB-graph]
#    Split   3 ( 3/50)... train=2704 (7.8% pos)  test=684 (8.9% pos)  |  Pair: 0.1752, Hyper: 0.2168, Hyper+flag: 0.2080, Hyper+1/sz: 0.2167, HB-graph: 0.2115  [HB-graph]
#    Split   4 ( 4/50)... train=2773 (7.8% pos)  test=615 (8.9% pos)  |  Pair: 0.1469, Hyper: 0.2045, Hyper+flag: 0.2177, Hyper+1/sz: 0.2020, HB-graph: 0.1874  [HB-graph]
#    Split   5 ( 5/50)... train=2599 (7.6% pos)  test=789 (9.5% pos)  |  Pair: 0.1568, Hyper: 0.2215, Hyper+flag: 0.2369, Hyper+1/sz: 0.2213, HB-graph: 0.2220  [HB-graph]
#    Split   6 ( 6/50)... train=2705 (8.3% pos)  test=683 (6.9% pos)  |  Pair: 0.1871, Hyper: 0.2145, Hyper+flag: 0.2436, Hyper+1/sz: 0.2295, HB-graph: 0.2566  [HB-graph]
#    Split   7 ( 7/50)... train=2782 (8.3% pos)  test=606 (6.9% pos)  |  Pair: 0.1263, Hyper: 0.2295, Hyper+flag: 0.2437, Hyper+1/sz: 0.2329, HB-graph: 0.2403  [HB-graph]
#    Split   8 ( 8/50)... train=2743 (7.9% pos)  test=645 (8.7% pos)  |  Pair: 0.1485, Hyper: 0.2179, Hyper+flag: 0.2518, Hyper+1/sz: 0.1921, HB-graph: 0.1992  [HB-graph]
#    Split   9 ( 9/50)... train=2813 (8.2% pos)  test=575 (7.0% pos)  |  Pair: 0.1430, Hyper: 0.2638, Hyper+flag: 0.2966, Hyper+1/sz: 0.2623, HB-graph: 0.3368  [HB-graph]
#    Split  10 (10/50)... train=2763 (7.8% pos)  test=625 (9.1% pos)  |  Pair: 0.1456, Hyper: 0.2892, Hyper+flag: 0.2757, Hyper+1/sz: 0.2199, HB-graph: 0.2515  [HB-graph]
#    Split  11 (11/50)... train=2740 (8.3% pos)  test=648 (6.8% pos)  |  Pair: 0.1221, Hyper: 0.2616, Hyper+flag: 0.2562, Hyper+1/sz: 0.2507, HB-graph: 0.2035  [HB-graph]
#    Split  12 (12/50)... train=2752 (7.8% pos)  test=636 (9.1% pos)  |  Pair: 0.1299, Hyper: 0.2300, Hyper+flag: 0.2269, Hyper+1/sz: 0.1841, HB-graph: 0.2255  [HB-graph]
#    Split  13 (13/50)... train=2670 (7.7% pos)  test=718 (9.2% pos)  |  Pair: 0.1463, Hyper: 0.1841, Hyper+flag: 0.2095, Hyper+1/sz: 0.1921, HB-graph: 0.2534  [HB-graph]
#    Split  14 (14/50)... train=2713 (8.4% pos)  test=675 (6.7% pos)  |  Pair: 0.1148, Hyper: 0.1935, Hyper+flag: 0.2336, Hyper+1/sz: 0.1661, HB-graph: 0.2356  [HB-graph]
#    Split  15 (15/50)... train=2731 (7.9% pos)  test=657 (8.4% pos)  |  Pair: 0.1392, Hyper: 0.2657, Hyper+flag: 0.3251, Hyper+1/sz: 0.2946, HB-graph: 0.3075  [HB-graph]
#    Split  16 (16/50)... train=2752 (8.4% pos)  test=636 (6.6% pos)  |  Pair: 0.1333, Hyper: 0.2178, Hyper+flag: 0.2319, Hyper+1/sz: 0.1952, HB-graph: 0.2610  [HB-graph]
#    Split  17 (17/50)... train=2702 (7.7% pos)  test=686 (9.5% pos)  |  Pair: 0.1424, Hyper: 0.2046, Hyper+flag: 0.2259, Hyper+1/sz: 0.1929, HB-graph: 0.2234  [HB-graph]
#    Split  18 (18/50)... train=2693 (7.8% pos)  test=695 (9.1% pos)  |  Pair: 0.1263, Hyper: 0.1743, Hyper+flag: 0.2435, Hyper+1/sz: 0.1885, HB-graph: 0.2362  [HB-graph]
#    Split  19 (19/50)... train=2736 (8.2% pos)  test=652 (7.5% pos)  |  Pair: 0.1480, Hyper: 0.2692, Hyper+flag: 0.2753, Hyper+1/sz: 0.2679, HB-graph: 0.2789  [HB-graph]
#    Split  20 (20/50)... train=2637 (8.4% pos)  test=751 (6.7% pos)  |  Pair: 0.1579, Hyper: 0.2540, Hyper+flag: 0.2996, Hyper+1/sz: 0.2643, HB-graph: 0.3064  [HB-graph]
#    Split  21 (21/50)... train=2775 (8.1% pos)  test=613 (7.7% pos)  |  Pair: 0.1203, Hyper: 0.2983, Hyper+flag: 0.2986, Hyper+1/sz: 0.2624, HB-graph: 0.2451  [HB-graph]
#    Split  22 (22/50)... train=2701 (8.3% pos)  test=687 (7.0% pos)  |  Pair: 0.1349, Hyper: 0.1853, Hyper+flag: 0.1805, Hyper+1/sz: 0.1961, HB-graph: 0.1891  [HB-graph]
#    Split  23 (23/50)... train=2809 (8.1% pos)  test=579 (7.8% pos)  |  Pair: 0.1630, Hyper: 0.3255, Hyper+flag: 0.3599, Hyper+1/sz: 0.3402, HB-graph: 0.3550  [HB-graph]
#    Split  24 (24/50)... train=2805 (8.3% pos)  test=583 (6.7% pos)  |  Pair: 0.1249, Hyper: 0.2493, Hyper+flag: 0.2473, Hyper+1/sz: 0.2397, HB-graph: 0.2386  [HB-graph]
#    Split  25 (25/50)... train=2652 (7.7% pos)  test=736 (9.1% pos)  |  Pair: 0.1553, Hyper: 0.2965, Hyper+flag: 0.3260, Hyper+1/sz: 0.2557, HB-graph: 0.2888  [HB-graph]
#    Split  26 (26/50)... train=2778 (8.1% pos)  test=610 (7.7% pos)  |  Pair: 0.2570, Hyper: 0.1905, Hyper+flag: 0.2129, Hyper+1/sz: 0.2165, HB-graph: 0.2596  [HB-graph]
#    Split  27 (27/50)... train=2780 (8.2% pos)  test=608 (7.4% pos)  |  Pair: 0.1373, Hyper: 0.1343, Hyper+flag: 0.1673, Hyper+1/sz: 0.1470, HB-graph: 0.1785  [HB-graph]
#    Split  28 (28/50)... train=2781 (8.1% pos)  test=607 (7.9% pos)  |  Pair: 0.1334, Hyper: 0.2306, Hyper+flag: 0.2354, Hyper+1/sz: 0.2222, HB-graph: 0.2582  [HB-graph]
#    Split  29 (29/50)... train=2652 (8.2% pos)  test=736 (7.5% pos)  |  Pair: 0.1037, Hyper: 0.1491, Hyper+flag: 0.1812, Hyper+1/sz: 0.1480, HB-graph: 0.1794  [HB-graph]
#    Split  30 (30/50)... train=2637 (7.9% pos)  test=751 (8.5% pos)  |  Pair: 0.1318, Hyper: 0.2062, Hyper+flag: 0.2268, Hyper+1/sz: 0.2038, HB-graph: 0.2052  [HB-graph]
#    Split  31 (31/50)... train=2748 (8.3% pos)  test=640 (6.7% pos)  |  Pair: 0.1249, Hyper: 0.2032, Hyper+flag: 0.1986, Hyper+1/sz: 0.1725, HB-graph: 0.2038  [HB-graph]
#    Split  32 (32/50)... train=2692 (8.3% pos)  test=696 (7.0% pos)  |  Pair: 0.1452, Hyper: 0.1952, Hyper+flag: 0.2061, Hyper+1/sz: 0.1965, HB-graph: 0.1800  [HB-graph]
#    Split  33 (33/50)... train=2742 (8.1% pos)  test=646 (7.7% pos)  |  Pair: 0.1222, Hyper: 0.2029, Hyper+flag: 0.2273, Hyper+1/sz: 0.1984, HB-graph: 0.2023  [HB-graph]
#    Split  34 (34/50)... train=2753 (8.3% pos)  test=635 (6.8% pos)  |  Pair: 0.1148, Hyper: 0.1838, Hyper+flag: 0.1953, Hyper+1/sz: 0.1519, HB-graph: 0.1978  [HB-graph]
#    Split  35 (35/50)... train=2775 (7.7% pos)  test=613 (9.3% pos)  |  Pair: 0.1545, Hyper: 0.2268, Hyper+flag: 0.2782, Hyper+1/sz: 0.2461, HB-graph: 0.3056  [HB-graph]
#    Split  36 (36/50)... train=2737 (8.3% pos)  test=651 (6.9% pos)  |  Pair: 0.2111, Hyper: 0.2293, Hyper+flag: 0.2252, Hyper+1/sz: 0.2530, HB-graph: 0.2823  [HB-graph]
#    Split  37 (37/50)... train=2793 (8.3% pos)  test=595 (6.7% pos)  |  Pair: 0.1102, Hyper: 0.1178, Hyper+flag: 0.1298, Hyper+1/sz: 0.1345, HB-graph: 0.1333  [HB-graph]
#    Split  38 (38/50)... train=2750 (7.8% pos)  test=638 (9.1% pos)  |  Pair: 0.1625, Hyper: 0.2515, Hyper+flag: 0.2897, Hyper+1/sz: 0.2360, HB-graph: 0.2803  [HB-graph]
#    Split  39 (39/50)... train=2756 (7.8% pos)  test=632 (9.2% pos)  |  Pair: 0.1715, Hyper: 0.2341, Hyper+flag: 0.2438, Hyper+1/sz: 0.2642, HB-graph: 0.2899  [HB-graph]
#    Split  40 (40/50)... train=2682 (8.4% pos)  test=706 (6.7% pos)  |  Pair: 0.1653, Hyper: 0.2067, Hyper+flag: 0.2296, Hyper+1/sz: 0.2342, HB-graph: 0.2212  [HB-graph]
#    Split  41 (41/50)... train=2759 (8.2% pos)  test=629 (7.3% pos)  |  Pair: 0.1369, Hyper: 0.2535, Hyper+flag: 0.2543, Hyper+1/sz: 0.2208, HB-graph: 0.2213  [HB-graph]
#    Split  42 (42/50)... train=2740 (7.8% pos)  test=648 (8.8% pos)  |  Pair: 0.1623, Hyper: 0.2738, Hyper+flag: 0.2542, Hyper+1/sz: 0.2904, HB-graph: 0.2828  [HB-graph]
#    Split  43 (43/50)... train=2676 (7.9% pos)  test=712 (8.6% pos)  |  Pair: 0.1223, Hyper: 0.1754, Hyper+flag: 0.1910, Hyper+1/sz: 0.1718, HB-graph: 0.1772  [HB-graph]
#    Split  44 (44/50)... train=2760 (8.2% pos)  test=628 (7.3% pos)  |  Pair: 0.1075, Hyper: 0.2430, Hyper+flag: 0.2747, Hyper+1/sz: 0.2317, HB-graph: 0.2380  [HB-graph]
#    Split  45 (45/50)... train=2801 (8.3% pos)  test=587 (6.6% pos)  |  Pair: 0.1854, Hyper: 0.2292, Hyper+flag: 0.2641, Hyper+1/sz: 0.2502, HB-graph: 0.3116  [HB-graph]
#    Split  46 (46/50)... train=2753 (8.1% pos)  test=635 (7.9% pos)  |  Pair: 0.1661, Hyper: 0.2663, Hyper+flag: 0.2827, Hyper+1/sz: 0.2774, HB-graph: 0.3230  [HB-graph]
#    Split  47 (47/50)... train=2817 (7.9% pos)  test=571 (8.8% pos)  |  Pair: 0.1415, Hyper: 0.2276, Hyper+flag: 0.2530, Hyper+1/sz: 0.2113, HB-graph: 0.2616  [HB-graph]
#    Split  48 (48/50)... train=2779 (7.9% pos)  test=609 (8.5% pos)  |  Pair: 0.1562, Hyper: 0.1942, Hyper+flag: 0.1732, Hyper+1/sz: 0.1803, HB-graph: 0.1579  [HB-graph]
#    Split  49 (49/50)... train=2793 (8.1% pos)  test=595 (7.7% pos)  |  Pair: 0.1267, Hyper: 0.1700, Hyper+flag: 0.1881, Hyper+1/sz: 0.1724, HB-graph: 0.1703  [HB-graph]
#    Split  50 (50/50)... train=2780 (7.8% pos)  test=608 (9.0% pos)  |  Pair: 0.1147, Hyper: 0.2036, Hyper+flag: 0.2243, Hyper+1/sz: 0.2018, HB-graph: 0.2141  [HB-graph]
#
#    Completed 50/50 splits.
#
# 4. Statistical analysis...
#
# ======================================================================
#   STATISTICAL COMPARISON
# ======================================================================
#
#   Task            : Drug Target Prediction (HPA)
#   Model           : Logistic regression (L2, standardised)
#   Number of splits: 50
#
#   PR-AUC
#   Representation       Mean ± Std
#   ---------------------------------------------
#   Pairwise             0.1442 ± 0.0272
#   Hypergraph           0.2210 ± 0.0415
#   Hypergraph + flag    0.2394 ± 0.0435
#   Hypergraph + 1/size  0.2187 ± 0.0422
#   HB-graph             0.2408 ± 0.0502
#
#   F1 (positive class)
#   Representation       Mean ± Std
#   ---------------------------------------------
#   Pairwise             0.2547 ± 0.0379
#   Hypergraph           0.2643 ± 0.0396
#   Hypergraph + flag    0.2433 ± 0.0283
#   Hypergraph + 1/size  0.2797 ± 0.0329
#   HB-graph             0.2947 ± 0.0339
#
#   --- HB-graph vs Pairwise — headline representation effect ---
#   Mean diff : +0.0966 ± 0.0469   (Cohen's dz = +2.059)
#   Wins/Losses/Ties : 50/0/0   (n paired = 50)
#   Sign test p (one-sided) : 0.000000   (two-sided: 0.000000)
#
#
#   --- HB-graph vs Hypergraph — stoichiometry effect ---
#   Mean diff : +0.0198 ± 0.0371   (Cohen's dz = +0.532)
#   Wins/Losses/Ties : 35/15/0   (n paired = 50)
#   Sign test p (one-sided) : 0.003300   (two-sided: 0.006600)
#
#
#   --- Hypergraph vs Pairwise — representation effect alone ---
#   Mean diff : +0.0769 ± 0.0450   (Cohen's dz = +1.709)
#   Wins/Losses/Ties : 48/2/0   (n paired = 50)
#   Sign test p (one-sided) : 0.000000   (two-sided: 0.000000)
#
#
#   --- [TEST A] Hyper+flag vs Hypergraph — ANNOTATION PRESENCE alone ---
#   Mean diff : +0.0183 ± 0.0194   (Cohen's dz = +0.948)
#   Wins/Losses/Ties : 40/10/0   (n paired = 50)
#   Sign test p (one-sided) : 0.000012   (two-sided: 0.000024)
#
#
#   --- [TEST A] HB-graph vs Hyper+flag — STOICHIOMETRY VALUES, net of annotation ---
#   Mean diff : +0.0014 ± 0.0302   (Cohen's dz = +0.047)
#   Wins/Losses/Ties : 24/26/0   (n paired = 50)
#   Sign test p (one-sided) : 0.664094   (two-sided: 0.887725)
#
#
#   --- [TEST C] Hyper+1/size vs Hypergraph — what a pure size recoding buys ---
#   Mean diff : -0.0024 ± 0.0224   (Cohen's dz = -0.106)
#   Wins/Losses/Ties : 21/29/0   (n paired = 50)
#   Sign test p (one-sided) : 0.898681   (two-sided: 0.322236)
#
#
#   --- [TEST C] HB-graph vs Hyper+1/size — STOICHIOMETRY net of size recoding ---
#   Mean diff : +0.0221 ± 0.0283   (Cohen's dz = +0.781)
#   Wins/Losses/Ties : 38/12/0   (n paired = 50)
#   Sign test p (one-sided) : 0.000153   (two-sided: 0.000306)
#
#
# ======================================================================
#   TEST A — DECOMPOSITION OF THE STOICHIOMETRY EFFECT
# ======================================================================
#
#   Component                                      dPR-AUC     W/L  p (1-sided)
#   ------------------------------------------------------------------------------
#   Annotation presence   (flag - hypergraph)      +0.0183  40/10        0.0000
#   Stoichiometry values  (hb-graph - flag)        +0.0014  24/26        0.6641
#   ------------------------------------------------------------------------------
#   TOTAL  (hb-graph - hypergraph)                 +0.0198  35/15        0.0033
#
#   Annotation presence accounts for 93% of the total stoichiometry effect.
# ======================================================================
#
# ======================================================================
#   TEST C — RECIPROCAL-OF-SIZE CONTROL
# ======================================================================
#
#   Component                                      dPR-AUC     W/L  p (1-sided)
#   ------------------------------------------------------------------------------
#   1/size alone   (recip - hypergraph)            -0.0024  21/29        0.8987
#   Stoichiometry  (hb-graph - recip)              +0.0221  38/12        0.0002
#   ------------------------------------------------------------------------------
#   TOTAL  (hb-graph - hypergraph)                 +0.0198  35/15        0.0033
#
#   The reciprocal absorbs -12% of the total apparent stoichiometry effect.
#
#   VERDICT: SURVIVES. The stoichiometry features add signal beyond a pure
#   reciprocal-of-size recoding, so the gain is not an artefact of the linear
#   model lacking a 1/n basis function.
# ======================================================================
#
# 5. Generating plots...
#
# 6. Aggregating feature importance...
#
# ======================================================================
#   FEATURE IMPORTANCE (Permutation — mean PR-AUC drop)
# ======================================================================
#
#   Pairwise
#   Rank   Feature                                    Mean        Std     Median
#   --------------------------------------------------------------------------
#   1      pair_LocalClustCoeff                    0.03317    0.01936    0.03074
#   2      pair_AvgNeighborDegree                  0.00266    0.01315   -0.00058
#   3      pair_TriangleCount                     -0.00334    0.00591   -0.00317
#   4      pair_Degree                            -0.00353    0.00732   -0.00483
#
#   Hypergraph
#   Rank   Feature                                    Mean        Std     Median
#   --------------------------------------------------------------------------
#   1      protein_RangeUniqueRatio                0.05093    0.03149    0.04467
#   2      protein_MedComplexNodes                 0.03557    0.01599    0.03662
#   3      base_UniquePartners                     0.03037    0.01610    0.02916
#   4      base_LocalClustCoeff                    0.02461    0.01984    0.02367
#   5      base_Degree                             0.02233    0.02060    0.01777
#   6      base_TriangleCount                      0.01106    0.01149    0.00743
#   7      base_AvgNeighbourDegree                 0.01042    0.01029    0.00828
#   8      protein_RangeComplexNodes               0.00303    0.00413    0.00261
#
#   Hypergraph + flag
#   Rank   Feature                                    Mean        Std     Median
#   --------------------------------------------------------------------------
#   1      flag_HasStoich                          0.05413    0.02134    0.04859
#   2      protein_RangeUniqueRatio                0.04016    0.03267    0.03875
#   3      protein_MedComplexNodes                 0.02678    0.01317    0.02780
#   4      base_UniquePartners                     0.02550    0.01441    0.02568
#   5      base_LocalClustCoeff                    0.02487    0.02147    0.02462
#   6      base_Degree                             0.02158    0.01722    0.01849
#   7      base_AvgNeighbourDegree                 0.01267    0.00990    0.01278
#   8      base_TriangleCount                      0.00654    0.00672    0.00504
#   9      protein_RangeComplexNodes               0.00233    0.00433    0.00179
#
#   Hypergraph + 1/size
#   Rank   Feature                                    Mean        Std     Median
#   --------------------------------------------------------------------------
#   1      recip_MedComplexNodes                   0.04904    0.02163    0.04111
#   2      protein_RangeUniqueRatio                0.04328    0.02932    0.03385
#   3      base_LocalClustCoeff                    0.02797    0.02300    0.02470
#   4      base_Degree                             0.01841    0.01586    0.01467
#   5      protein_MedComplexNodes                 0.01243    0.00903    0.01105
#   6      base_UniquePartners                     0.01092    0.01021    0.01025
#   7      base_TriangleCount                      0.00562    0.00557    0.00541
#   8      base_AvgNeighbourDegree                 0.00349    0.00680    0.00393
#   9      protein_RangeComplexNodes               0.00122    0.00215    0.00122
#
#   HB-graph
#   Rank   Feature                                    Mean        Std     Median
#   --------------------------------------------------------------------------
#   1      stoich_MedianRatio                      0.05501    0.02185    0.05383
#   2      stoich_RangeRatio                       0.03554    0.02493    0.03219
#   3      base_LocalClustCoeff                    0.02418    0.01749    0.02200
#   4      protein_RangeUniqueRatio                0.02356    0.01689    0.02086
#   5      base_Degree                             0.01692    0.00956    0.01516
#   6      protein_MedComplexNodes                 0.01305    0.00870    0.01213
#   7      base_UniquePartners                     0.01131    0.00852    0.01020
#   8      base_TriangleCount                      0.00596    0.00487    0.00438
#   9      base_AvgNeighbourDegree                 0.00412    0.00431    0.00405
#   10     stoich_MedComplexSize                   0.00242    0.00267    0.00239
#   11     stoich_AvgNeighbourDegreeStoich         0.00238    0.00290    0.00240
#   12     stoich_WeightedTriangles                0.00229    0.00184    0.00214
#   13     protein_RangeComplexNodes               0.00184    0.00180    0.00150
#   14     stoich_RangeComplexSize                 0.00075    0.00133    0.00051
#
#   Note: higher = more important; negative = likely noise.
#
#    >>> 'flag_HasStoich' ranks 1 of 9 in the hypergraph+flag model (mean importance 0.05413)
#
# 7. Saving outputs...
#    Saved: split_results.csv
#    Saved: comparison_stats.csv
#    Saved: pairwise_predictions.csv
#    Saved: pairwise_feature_importance.csv
#    Saved: hypergraph_predictions.csv
#    Saved: hypergraph_feature_importance.csv
#    Saved: hyper_flag_predictions.csv
#    Saved: hyper_flag_feature_importance.csv
#    Saved: hyper_recip_predictions.csv
#    Saved: hyper_recip_feature_importance.csv
#    Saved: hb_graph_predictions.csv
#    Saved: hb_graph_feature_importance.csv
#    Saved: best_C_per_split.csv
#    Saved: statistical_summary.txt
#
# ######################################################################
#   TASK: Drug Target Prediction (ChEMBL)   [chembl]
#   Splits : /Users/anitaapplegarth/github/dphil/protein_complexes/data/lookup_tables/cp/chembl_protein_splits.csv
#   Output : logistic/cp_second_testA/chembl
# ######################################################################
#
# 2. Loading pre-assigned splits...
#    File              : chembl_protein_splits.csv
#    Last modified     : 2026-08-03 15:14:28.194519758
#    Splits file rows  : 169700
#    Unique proteins   : 3394
#    Number of splits  : 50
#    Labelled proteins : 3388  (6.1% positive)
#
#    Running 50 splits.
#
#    Split   1 ( 1/50)... train=2763 (6.0% pos)  test=625 (6.6% pos)  |  Pair: 0.1167, Hyper: 0.2555, Hyper+flag: 0.2690, Hyper+1/sz: 0.2094, HB-graph: 0.2518  [HB-graph]
#    Split   2 ( 2/50)... train=2766 (6.4% pos)  test=622 (4.8% pos)  |  Pair: 0.1026, Hyper: 0.1374, Hyper+flag: 0.1490, Hyper+1/sz: 0.1380, HB-graph: 0.1612  [HB-graph]
#    Split   3 ( 3/50)... train=2731 (6.2% pos)  test=657 (5.5% pos)  |  Pair: 0.1756, Hyper: 0.1574, Hyper+flag: 0.1611, Hyper+1/sz: 0.1690, HB-graph: 0.1619  [Pair]
#    Split   4 ( 4/50)... train=2806 (6.3% pos)  test=582 (4.8% pos)  |  Pair: 0.1043, Hyper: 0.2462, Hyper+flag: 0.2388, Hyper+1/sz: 0.2513, HB-graph: 0.2351  [HB-graph]
#    Split   5 ( 5/50)... train=2660 (6.1% pos)  test=728 (5.9% pos)  |  Pair: 0.0926, Hyper: 0.1445, Hyper+flag: 0.1532, Hyper+1/sz: 0.1374, HB-graph: 0.1643  [HB-graph]
#    Split   6 ( 6/50)... train=2780 (6.3% pos)  test=608 (5.1% pos)  |  Pair: 0.0874, Hyper: 0.2248, Hyper+flag: 0.2507, Hyper+1/sz: 0.2583, HB-graph: 0.3312  [HB-graph]
#    Split   7 ( 7/50)... train=2682 (5.7% pos)  test=706 (7.5% pos)  |  Pair: 0.1336, Hyper: 0.1641, Hyper+flag: 0.1815, Hyper+1/sz: 0.1570, HB-graph: 0.1805  [HB-graph]
#    Split   8 ( 8/50)... train=2723 (6.0% pos)  test=665 (6.3% pos)  |  Pair: 0.1474, Hyper: 0.1953, Hyper+flag: 0.2047, Hyper+1/sz: 0.2120, HB-graph: 0.2349  [HB-graph]
#    Split   9 ( 9/50)... train=2813 (6.2% pos)  test=575 (5.7% pos)  |  Pair: 0.1248, Hyper: 0.2909, Hyper+flag: 0.3020, Hyper+1/sz: 0.2576, HB-graph: 0.3001  [HB-graph]
#    Split  10 (10/50)... train=2750 (5.8% pos)  test=638 (7.2% pos)  |  Pair: 0.1367, Hyper: 0.2768, Hyper+flag: 0.2940, Hyper+1/sz: 0.2636, HB-graph: 0.3371  [HB-graph]
#    Split  11 (11/50)... train=2592 (5.7% pos)  test=796 (7.2% pos)  |  Pair: 0.1151, Hyper: 0.2565, Hyper+flag: 0.2634, Hyper+1/sz: 0.2438, HB-graph: 0.2946  [HB-graph]
#    Split  12 (12/50)... train=2775 (5.8% pos)  test=613 (7.2% pos)  |  Pair: 0.1750, Hyper: 0.2198, Hyper+flag: 0.2493, Hyper+1/sz: 0.2574, HB-graph: 0.2443  [HB-graph]
#    Split  13 (13/50)... train=2758 (6.0% pos)  test=630 (6.3% pos)  |  Pair: 0.1019, Hyper: 0.1956, Hyper+flag: 0.2029, Hyper+1/sz: 0.1655, HB-graph: 0.1835  [HB-graph]
#    Split  14 (14/50)... train=2713 (6.3% pos)  test=675 (5.3% pos)  |  Pair: 0.1136, Hyper: 0.1986, Hyper+flag: 0.2153, Hyper+1/sz: 0.1669, HB-graph: 0.1919  [HB-graph]
#    Split  15 (15/50)... train=2731 (6.4% pos)  test=657 (4.9% pos)  |  Pair: 0.1456, Hyper: 0.1990, Hyper+flag: 0.2153, Hyper+1/sz: 0.1664, HB-graph: 0.1995  [HB-graph]
#    Split  16 (16/50)... train=2710 (6.4% pos)  test=678 (4.7% pos)  |  Pair: 0.1532, Hyper: 0.1840, Hyper+flag: 0.2043, Hyper+1/sz: 0.2139, HB-graph: 0.2571  [HB-graph]
#    Split  17 (17/50)... train=2702 (5.9% pos)  test=686 (6.9% pos)  |  Pair: 0.1063, Hyper: 0.2462, Hyper+flag: 0.2754, Hyper+1/sz: 0.2401, HB-graph: 0.2642  [HB-graph]
#    Split  18 (18/50)... train=2677 (6.5% pos)  test=711 (4.6% pos)  |  Pair: 0.0987, Hyper: 0.2472, Hyper+flag: 0.2632, Hyper+1/sz: 0.3050, HB-graph: 0.3008  [HB-graph]
#    Split  19 (19/50)... train=2700 (6.4% pos)  test=688 (4.7% pos)  |  Pair: 0.0848, Hyper: 0.1370, Hyper+flag: 0.1463, Hyper+1/sz: 0.1491, HB-graph: 0.1569  [HB-graph]
#    Split  20 (20/50)... train=2637 (6.4% pos)  test=751 (5.1% pos)  |  Pair: 0.0922, Hyper: 0.1836, Hyper+flag: 0.2055, Hyper+1/sz: 0.1879, HB-graph: 0.3219  [HB-graph]
#    Split  21 (21/50)... train=2758 (5.8% pos)  test=630 (7.3% pos)  |  Pair: 0.1596, Hyper: 0.2569, Hyper+flag: 0.2822, Hyper+1/sz: 0.2405, HB-graph: 0.3077  [HB-graph]
#    Split  22 (22/50)... train=2701 (6.0% pos)  test=687 (6.6% pos)  |  Pair: 0.1605, Hyper: 0.1570, Hyper+flag: 0.1735, Hyper+1/sz: 0.1648, HB-graph: 0.1749  [HB-graph]
#    Split  23 (23/50)... train=2809 (6.1% pos)  test=579 (5.9% pos)  |  Pair: 0.1780, Hyper: 0.2688, Hyper+flag: 0.2891, Hyper+1/sz: 0.2774, HB-graph: 0.3209  [HB-graph]
#    Split  24 (24/50)... train=2800 (6.0% pos)  test=588 (6.5% pos)  |  Pair: 0.2420, Hyper: 0.1604, Hyper+flag: 0.1648, Hyper+1/sz: 0.1606, HB-graph: 0.1629  [Pair]
#    Split  25 (25/50)... train=2652 (6.1% pos)  test=736 (6.1% pos)  |  Pair: 0.1134, Hyper: 0.2348, Hyper+flag: 0.2325, Hyper+1/sz: 0.2449, HB-graph: 0.2376  [HB-graph]
#    Split  26 (26/50)... train=2676 (6.4% pos)  test=712 (4.8% pos)  |  Pair: 0.1025, Hyper: 0.2758, Hyper+flag: 0.2875, Hyper+1/sz: 0.1966, HB-graph: 0.2907  [HB-graph]
#    Split  27 (27/50)... train=2769 (6.2% pos)  test=619 (5.5% pos)  |  Pair: 0.1425, Hyper: 0.2474, Hyper+flag: 0.2682, Hyper+1/sz: 0.2411, HB-graph: 0.3037  [HB-graph]
#    Split  28 (28/50)... train=2781 (6.1% pos)  test=607 (6.1% pos)  |  Pair: 0.1324, Hyper: 0.1817, Hyper+flag: 0.2133, Hyper+1/sz: 0.2055, HB-graph: 0.2405  [HB-graph]
#    Split  29 (29/50)... train=2652 (6.0% pos)  test=736 (6.5% pos)  |  Pair: 0.0995, Hyper: 0.1549, Hyper+flag: 0.1639, Hyper+1/sz: 0.1513, HB-graph: 0.1737  [HB-graph]
#    Split  30 (30/50)... train=2728 (6.1% pos)  test=660 (5.9% pos)  |  Pair: 0.1368, Hyper: 0.2253, Hyper+flag: 0.2414, Hyper+1/sz: 0.2517, HB-graph: 0.2832  [HB-graph]
#    Split  31 (31/50)... train=2762 (6.3% pos)  test=626 (5.1% pos)  |  Pair: 0.1093, Hyper: 0.1726, Hyper+flag: 0.1854, Hyper+1/sz: 0.1509, HB-graph: 0.1958  [HB-graph]
#    Split  32 (32/50)... train=2754 (6.2% pos)  test=634 (5.4% pos)  |  Pair: 0.1367, Hyper: 0.2420, Hyper+flag: 0.2708, Hyper+1/sz: 0.2477, HB-graph: 0.2775  [HB-graph]
#    Split  33 (33/50)... train=2742 (6.3% pos)  test=646 (5.3% pos)  |  Pair: 0.0926, Hyper: 0.1542, Hyper+flag: 0.1652, Hyper+1/sz: 0.1525, HB-graph: 0.1799  [HB-graph]
#    Split  34 (34/50)... train=2753 (6.0% pos)  test=635 (6.5% pos)  |  Pair: 0.1030, Hyper: 0.1945, Hyper+flag: 0.2107, Hyper+1/sz: 0.1767, HB-graph: 0.1970  [HB-graph]
#    Split  35 (35/50)... train=2774 (6.2% pos)  test=614 (5.7% pos)  |  Pair: 0.1506, Hyper: 0.1243, Hyper+flag: 0.1211, Hyper+1/sz: 0.1219, HB-graph: 0.1389  [Pair]
#    Split  36 (36/50)... train=2737 (6.1% pos)  test=651 (5.8% pos)  |  Pair: 0.2005, Hyper: 0.2825, Hyper+flag: 0.2960, Hyper+1/sz: 0.2920, HB-graph: 0.3197  [HB-graph]
#    Split  37 (37/50)... train=2793 (5.9% pos)  test=595 (6.7% pos)  |  Pair: 0.1405, Hyper: 0.2144, Hyper+flag: 0.2214, Hyper+1/sz: 0.2032, HB-graph: 0.2325  [HB-graph]
#    Split  38 (38/50)... train=2789 (5.9% pos)  test=599 (6.8% pos)  |  Pair: 0.1081, Hyper: 0.3231, Hyper+flag: 0.3236, Hyper+1/sz: 0.2132, HB-graph: 0.3881  [HB-graph]
#    Split  39 (39/50)... train=2702 (6.1% pos)  test=686 (6.0% pos)  |  Pair: 0.1717, Hyper: 0.1254, Hyper+flag: 0.1374, Hyper+1/sz: 0.1408, HB-graph: 0.1571  [Pair]
#    Split  40 (40/50)... train=2682 (6.3% pos)  test=706 (5.4% pos)  |  Pair: 0.1353, Hyper: 0.2018, Hyper+flag: 0.2193, Hyper+1/sz: 0.2041, HB-graph: 0.2369  [HB-graph]
#    Split  41 (41/50)... train=2727 (5.7% pos)  test=661 (7.6% pos)  |  Pair: 0.1858, Hyper: 0.2744, Hyper+flag: 0.2940, Hyper+1/sz: 0.2750, HB-graph: 0.2857  [HB-graph]
#    Split  42 (42/50)... train=2789 (6.0% pos)  test=599 (6.3% pos)  |  Pair: 0.1229, Hyper: 0.2938, Hyper+flag: 0.3424, Hyper+1/sz: 0.3030, HB-graph: 0.3569  [HB-graph]
#    Split  43 (43/50)... train=2793 (6.0% pos)  test=595 (6.4% pos)  |  Pair: 0.1708, Hyper: 0.2758, Hyper+flag: 0.2915, Hyper+1/sz: 0.3001, HB-graph: 0.3053  [HB-graph]
#    Split  44 (44/50)... train=2710 (5.8% pos)  test=678 (7.4% pos)  |  Pair: 0.0994, Hyper: 0.1976, Hyper+flag: 0.2098, Hyper+1/sz: 0.1936, HB-graph: 0.2261  [HB-graph]
#    Split  45 (45/50)... train=2791 (5.8% pos)  test=597 (7.4% pos)  |  Pair: 0.1241, Hyper: 0.2173, Hyper+flag: 0.2259, Hyper+1/sz: 0.2205, HB-graph: 0.2217  [HB-graph]
#    Split  46 (46/50)... train=2753 (6.2% pos)  test=635 (5.4% pos)  |  Pair: 0.1258, Hyper: 0.2235, Hyper+flag: 0.2337, Hyper+1/sz: 0.1995, HB-graph: 0.2246  [HB-graph]
#    Split  47 (47/50)... train=2785 (6.2% pos)  test=603 (5.6% pos)  |  Pair: 0.1157, Hyper: 0.2370, Hyper+flag: 0.2591, Hyper+1/sz: 0.2183, HB-graph: 0.2396  [HB-graph]
#    Split  48 (48/50)... train=2778 (6.0% pos)  test=610 (6.4% pos)  |  Pair: 0.1463, Hyper: 0.2838, Hyper+flag: 0.3015, Hyper+1/sz: 0.2577, HB-graph: 0.3284  [HB-graph]
#    Split  49 (49/50)... train=2686 (6.3% pos)  test=702 (5.1% pos)  |  Pair: 0.1123, Hyper: 0.2355, Hyper+flag: 0.2304, Hyper+1/sz: 0.2858, HB-graph: 0.2933  [HB-graph]
#    Split  50 (50/50)... train=2780 (5.8% pos)  test=608 (7.2% pos)  |  Pair: 0.1394, Hyper: 0.1735, Hyper+flag: 0.1892, Hyper+1/sz: 0.1659, HB-graph: 0.1754  [HB-graph]
#
#    Completed 50/50 splits.
#
# 4. Statistical analysis...
#
# ======================================================================
#   STATISTICAL COMPARISON
# ======================================================================
#
#   Task            : Drug Target Prediction (ChEMBL)
#   Model           : Logistic regression (L2, standardised)
#   Number of splits: 50
#
#   PR-AUC
#   Representation       Mean ± Std
#   ---------------------------------------------
#   Pairwise             0.1313 ± 0.0323
#   Hypergraph           0.2154 ± 0.0497
#   Hypergraph + flag    0.2298 ± 0.0528
#   Hypergraph + 1/size  0.2121 ± 0.0500
#   HB-graph             0.2450 ± 0.0623
#
#   F1 (positive class)
#   Representation       Mean ± Std
#   ---------------------------------------------
#   Pairwise             0.1826 ± 0.0255
#   Hypergraph           0.1982 ± 0.0373
#   Hypergraph + flag    0.2150 ± 0.0273
#   Hypergraph + 1/size  0.2122 ± 0.0278
#   HB-graph             0.2402 ± 0.0365
#
#   --- HB-graph vs Pairwise — headline representation effect ---
#   Mean diff : +0.1137 ± 0.0709   (Cohen's dz = +1.603)
#   Wins/Losses/Ties : 46/4/0   (n paired = 50)
#   Sign test p (one-sided) : 0.000000   (two-sided: 0.000000)
#
#
#   --- HB-graph vs Hypergraph — stoichiometry effect ---
#   Mean diff : +0.0296 ± 0.0295   (Cohen's dz = +1.001)
#   Wins/Losses/Ties : 46/4/0   (n paired = 50)
#   Sign test p (one-sided) : 0.000000   (two-sided: 0.000000)
#
#
#   --- Hypergraph vs Pairwise — representation effect alone ---
#   Mean diff : +0.0841 ± 0.0583   (Cohen's dz = +1.443)
#   Wins/Losses/Ties : 45/5/0   (n paired = 50)
#   Sign test p (one-sided) : 0.000000   (two-sided: 0.000000)
#
#
#   --- [TEST A] Hyper+flag vs Hypergraph — ANNOTATION PRESENCE alone ---
#   Mean diff : +0.0144 ± 0.0100   (Cohen's dz = +1.437)
#   Wins/Losses/Ties : 46/4/0   (n paired = 50)
#   Sign test p (one-sided) : 0.000000   (two-sided: 0.000000)
#
#
#   --- [TEST A] HB-graph vs Hyper+flag — STOICHIOMETRY VALUES, net of annotation ---
#   Mean diff : +0.0152 ± 0.0273   (Cohen's dz = +0.556)
#   Wins/Losses/Ties : 34/16/0   (n paired = 50)
#   Sign test p (one-sided) : 0.007673   (two-sided: 0.015347)
#
#
#   --- [TEST C] Hyper+1/size vs Hypergraph — what a pure size recoding buys ---
#   Mean diff : -0.0033 ± 0.0285   (Cohen's dz = -0.115)
#   Wins/Losses/Ties : 25/25/0   (n paired = 50)
#   Sign test p (one-sided) : 0.556138   (two-sided: 1.000000)
#
#
#   --- [TEST C] HB-graph vs Hyper+1/size — STOICHIOMETRY net of size recoding ---
#   Mean diff : +0.0328 ± 0.0346   (Cohen's dz = +0.950)
#   Wins/Losses/Ties : 45/5/0   (n paired = 50)
#   Sign test p (one-sided) : 0.000000   (two-sided: 0.000000)
#
#
# ======================================================================
#   TEST A — DECOMPOSITION OF THE STOICHIOMETRY EFFECT
# ======================================================================
#
#   Component                                      dPR-AUC     W/L  p (1-sided)
#   ------------------------------------------------------------------------------
#   Annotation presence   (flag - hypergraph)      +0.0144  46/4         0.0000
#   Stoichiometry values  (hb-graph - flag)        +0.0152  34/16        0.0077
#   ------------------------------------------------------------------------------
#   TOTAL  (hb-graph - hypergraph)                 +0.0296  46/4         0.0000
#
#   Annotation presence accounts for 49% of the total stoichiometry effect.
# ======================================================================
#
# ======================================================================
#   TEST C — RECIPROCAL-OF-SIZE CONTROL
# ======================================================================
#
#   Component                                      dPR-AUC     W/L  p (1-sided)
#   ------------------------------------------------------------------------------
#   1/size alone   (recip - hypergraph)            -0.0033  25/25        0.5561
#   Stoichiometry  (hb-graph - recip)              +0.0328  45/5         0.0000
#   ------------------------------------------------------------------------------
#   TOTAL  (hb-graph - hypergraph)                 +0.0296  46/4         0.0000
#
#   The reciprocal absorbs -11% of the total apparent stoichiometry effect.
#
#   VERDICT: SURVIVES. The stoichiometry features add signal beyond a pure
#   reciprocal-of-size recoding, so the gain is not an artefact of the linear
#   model lacking a 1/n basis function.
# ======================================================================
#
# 5. Generating plots...
#
# 6. Aggregating feature importance...
#
# ======================================================================
#   FEATURE IMPORTANCE (Permutation — mean PR-AUC drop)
# ======================================================================
#
#   Pairwise
#   Rank   Feature                                    Mean        Std     Median
#   --------------------------------------------------------------------------
#   1      pair_TriangleCount                      0.02991    0.03227    0.02541
#   2      pair_LocalClustCoeff                    0.02778    0.02162    0.02267
#   3      pair_Degree                             0.01590    0.02423    0.00963
#   4      pair_AvgNeighborDegree                  0.01331    0.01843    0.00955
#
#   Hypergraph
#   Rank   Feature                                    Mean        Std     Median
#   --------------------------------------------------------------------------
#   1      protein_RangeUniqueRatio                0.10259    0.04460    0.10155
#   2      base_UniquePartners                     0.03017    0.02253    0.02579
#   3      protein_MedComplexNodes                 0.02947    0.01671    0.02605
#   4      base_Degree                             0.01796    0.02663    0.00911
#   5      base_AvgNeighbourDegree                 0.01073    0.01340    0.00888
#   6      protein_RangeComplexNodes               0.00669    0.02328    0.00080
#   7      base_TriangleCount                      0.00630    0.00687    0.00520
#   8      base_LocalClustCoeff                   -0.00283    0.00873   -0.00154
#
#   Hypergraph + flag
#   Rank   Feature                                    Mean        Std     Median
#   --------------------------------------------------------------------------
#   1      protein_RangeUniqueRatio                0.09354    0.04346    0.08570
#   2      flag_HasStoich                          0.04513    0.01805    0.04209
#   3      base_UniquePartners                     0.02749    0.02258    0.02234
#   4      protein_MedComplexNodes                 0.02546    0.01707    0.02297
#   5      base_Degree                             0.01744    0.02787    0.01077
#   6      base_AvgNeighbourDegree                 0.01101    0.01587    0.00773
#   7      protein_RangeComplexNodes               0.01078    0.02926    0.00056
#   8      base_TriangleCount                      0.00484    0.00699    0.00329
#   9      base_LocalClustCoeff                   -0.00198    0.00835   -0.00081
#
#   Hypergraph + 1/size
#   Rank   Feature                                    Mean        Std     Median
#   --------------------------------------------------------------------------
#   1      protein_RangeUniqueRatio                0.08636    0.04041    0.08147
#   2      recip_MedComplexNodes                   0.03718    0.02384    0.03232
#   3      base_Degree                             0.00283    0.01402    0.00098
#   4      protein_RangeComplexNodes               0.00267    0.01833   -0.00112
#   5      base_AvgNeighbourDegree                 0.00255    0.00779    0.00080
#   6      protein_MedComplexNodes                 0.00216    0.01274    0.00042
#   7      base_TriangleCount                      0.00184    0.00963    0.00017
#   8      base_UniquePartners                     0.00037    0.01580   -0.00178
#   9      base_LocalClustCoeff                   -0.00245    0.00830   -0.00017
#
#   HB-graph
#   Rank   Feature                                    Mean        Std     Median
#   --------------------------------------------------------------------------
#   1      stoich_MedianRatio                      0.06188    0.02771    0.05546
#   2      protein_RangeUniqueRatio                0.03931    0.01990    0.03521
#   3      stoich_RangeRatio                       0.03488    0.02460    0.03017
#   4      protein_MedComplexNodes                 0.00571    0.00956    0.00372
#   5      base_AvgNeighbourDegree                 0.00393    0.00707    0.00192
#   6      base_UniquePartners                     0.00390    0.01207    0.00153
#   7      base_Degree                             0.00338    0.00470    0.00276
#   8      base_TriangleCount                      0.00300    0.00655    0.00139
#   9      stoich_AvgNeighbourDegreeStoich         0.00271    0.00598    0.00111
#   10     stoich_MedComplexSize                   0.00219    0.00698    0.00045
#   11     stoich_WeightedTriangles                0.00179    0.00385    0.00043
#   12     base_LocalClustCoeff                    0.00111    0.00491    0.00095
#   13     stoich_RangeComplexSize                 0.00076    0.00397    0.00012
#   14     protein_RangeComplexNodes              -0.00008    0.00350   -0.00038
#
#   Note: higher = more important; negative = likely noise.
#
#    >>> 'flag_HasStoich' ranks 2 of 9 in the hypergraph+flag model (mean importance 0.04513)
#
# 7. Saving outputs...
#    Saved: split_results.csv
#    Saved: comparison_stats.csv
#    Saved: pairwise_predictions.csv
#    Saved: pairwise_feature_importance.csv
#    Saved: hypergraph_predictions.csv
#    Saved: hypergraph_feature_importance.csv
#    Saved: hyper_flag_predictions.csv
#    Saved: hyper_flag_feature_importance.csv
#    Saved: hyper_recip_predictions.csv
#    Saved: hyper_recip_feature_importance.csv
#    Saved: hb_graph_predictions.csv
#    Saved: hb_graph_feature_importance.csv
#    Saved: best_C_per_split.csv
#    Saved: statistical_summary.txt
#
# ======================================================================
#   CROSS-TASK SUMMARY — CP — logistic regression PR-AUC
# ======================================================================
#
#   Task         Representation                   PR-AUC                 F1
#   ----------------------------------------------------------------------
#   ess          Pairwise                 0.4623 ± 0.1006    0.4773 ± 0.0571
#   ess          Hypergraph               0.4917 ± 0.0977    0.4599 ± 0.0677
#   ess          Hypergraph + flag        0.4901 ± 0.0972    0.4494 ± 0.0691
#   ess          Hypergraph + 1/size      0.4941 ± 0.0932    0.4843 ± 0.0538
#   ess          HB-graph                 0.4747 ± 0.0972    0.4434 ± 0.0756
#   hpa          Pairwise                 0.1442 ± 0.0272    0.2547 ± 0.0379
#   hpa          Hypergraph               0.2210 ± 0.0415    0.2643 ± 0.0396
#   hpa          Hypergraph + flag        0.2394 ± 0.0435    0.2433 ± 0.0283
#   hpa          Hypergraph + 1/size      0.2187 ± 0.0422    0.2797 ± 0.0329
#   hpa          HB-graph                 0.2408 ± 0.0502    0.2947 ± 0.0339
#   chembl       Pairwise                 0.1313 ± 0.0323    0.1826 ± 0.0255
#   chembl       Hypergraph               0.2154 ± 0.0497    0.1982 ± 0.0373
#   chembl       Hypergraph + flag        0.2298 ± 0.0528    0.2150 ± 0.0273
#   chembl       Hypergraph + 1/size      0.2121 ± 0.0500    0.2122 ± 0.0278
#   chembl       HB-graph                 0.2450 ± 0.0623    0.2402 ± 0.0365
#
#   Saved: all_tasks_summary.csv, all_tasks_comparison_stats.csv
#
# ======================================================================
#   COMPLETE
# ======================================================================
#
# Total time: 369.7s (6.2 min)
