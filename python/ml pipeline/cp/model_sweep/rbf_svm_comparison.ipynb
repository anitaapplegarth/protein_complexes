# %%
"""
RBF-SVM hyperparameter choice under the two splitting regimes.
Reads the existing sweep CSVs; nothing is refitted.
"""

from pathlib import Path
import pandas as pd

# ======================================================================
# CONFIG
# ======================================================================
CONFIG = {
    "GROUP_CSV":  Path("cp_ess/sweep_results.csv"),
    "RANDOM_CSV": Path("cp_ess/randomprotein/sweep_results_randomprotein.csv"),
    "MODEL":      "RBF-SVM",
}


def main():
    C = CONFIG
    for arm, path in [("group", C["GROUP_CSV"]), ("random", C["RANDOM_CSV"])]:
        df = pd.read_csv(path)
        sub = df[df["model"] == C["MODEL"]]
        print(f"\n{'='*70}\n{arm.upper()}  ({path.name})\n{'='*70}")
        print(f"features per tier: "
              f"{sub.groupby('tier')['n_features'].first().to_dict()}")
        print(sub.groupby(["tier", "best_params"]).size()
                 .unstack(level=0, fill_value=0).to_string())


main()
# Out:
# ======================================================================
# GROUP  (sweep_results.csv)
# ======================================================================
# features per tier: {'hb_graph': 14, 'hypergraph': 8, 'pairwise': 4}
# tier                                     hb_graph  hypergraph  pairwise
# best_params
# {'clf__C': 0.1, 'clf__gamma': 'scale'}          0           0        11
# {'clf__C': 1, 'clf__gamma': 'scale'}            1           5         1
# {'clf__C': 1, 'clf__gamma': 0.001}             12          32         1
# {'clf__C': 1, 'clf__gamma': 0.01}               2           2        32
# {'clf__C': 10, 'clf__gamma': 'scale'}           0           2         0
# {'clf__C': 10, 'clf__gamma': 0.001}            24           8         1
# {'clf__C': 10, 'clf__gamma': 0.01}              0           0         1
# {'clf__C': 100, 'clf__gamma': 0.001}           10           1         1
# {'clf__C': 1000, 'clf__gamma': 'scale'}         0           0         2
# {'clf__C': 1000, 'clf__gamma': 0.001}           1           0         0
#
# ======================================================================
# RANDOM  (sweep_results_randomprotein.csv)
# ======================================================================
# features per tier: {'hb_graph': 14, 'hypergraph': 8, 'pairwise': 4}
# tier                                    hb_graph  hypergraph  pairwise
# best_params
# {'clf__C': 0.1, 'clf__gamma': 'scale'}         0           0        12
# {'clf__C': 1, 'clf__gamma': 'scale'}           1           1         0
# {'clf__C': 1, 'clf__gamma': 0.001}            11          48         1
# {'clf__C': 1, 'clf__gamma': 0.01}              0           0        35
# {'clf__C': 10, 'clf__gamma': 0.001}           17           1         0
# {'clf__C': 100, 'clf__gamma': 0.001}          21           0         2

# %%
"""
RBF-SVM hyperparameter choice under the two splitting regimes.
Reads the existing sweep CSVs; nothing is refitted.
"""

from pathlib import Path
import pandas as pd

# ======================================================================
# CONFIG
# ======================================================================
CONFIG = {
    "GROUP_CSV":  Path("cp_hpa/sweep_results.csv"),
    "RANDOM_CSV": Path("cp_hpa/randomprotein/sweep_results_randomprotein.csv"),
    "MODEL":      "RBF-SVM",
}


def main():
    C = CONFIG
    for arm, path in [("group", C["GROUP_CSV"]), ("random", C["RANDOM_CSV"])]:
        df = pd.read_csv(path)
        sub = df[df["model"] == C["MODEL"]]
        print(f"\n{'='*70}\n{arm.upper()}  ({path.name})\n{'='*70}")
        print(f"features per tier: "
              f"{sub.groupby('tier')['n_features'].first().to_dict()}")
        print(sub.groupby(["tier", "best_params"]).size()
                 .unstack(level=0, fill_value=0).to_string())


main()
# Out:
# ======================================================================
# GROUP  (sweep_results.csv)
# ======================================================================
# features per tier: {'hb_graph': 14, 'hypergraph': 8, 'pairwise': 4}
# tier                                     hb_graph  hypergraph  pairwise
# best_params
# {'clf__C': 0.1, 'clf__gamma': 'scale'}         21           0         0
# {'clf__C': 0.1, 'clf__gamma': 0.01}             7           0         0
# {'clf__C': 0.1, 'clf__gamma': 0.1}              0           6         0
# {'clf__C': 0.1, 'clf__gamma': 1}                0           0         5
# {'clf__C': 1, 'clf__gamma': 'scale'}            5           2         0
# {'clf__C': 1, 'clf__gamma': 0.001}              5           0         0
# {'clf__C': 1, 'clf__gamma': 0.01}               2           0         0
# {'clf__C': 1, 'clf__gamma': 0.1}                1           6         0
# {'clf__C': 1, 'clf__gamma': 1}                  0           0        17
# {'clf__C': 10, 'clf__gamma': 0.001}             3           6         0
# {'clf__C': 10, 'clf__gamma': 0.01}              3           0         0
# {'clf__C': 10, 'clf__gamma': 0.1}               0           4         0
# {'clf__C': 10, 'clf__gamma': 1}                 0           0         5
# {'clf__C': 100, 'clf__gamma': 'scale'}          0          11         0
# {'clf__C': 100, 'clf__gamma': 0.001}            0           1         0
# {'clf__C': 100, 'clf__gamma': 0.01}             0           4         0
# {'clf__C': 100, 'clf__gamma': 0.1}              0           0         4
# {'clf__C': 1000, 'clf__gamma': 'scale'}         3           5         2
# {'clf__C': 1000, 'clf__gamma': 0.01}            0           5         0
# {'clf__C': 1000, 'clf__gamma': 0.1}             0           0        17
#
# ======================================================================
# RANDOM  (sweep_results_randomprotein.csv)
# ======================================================================
# features per tier: {'hb_graph': 14, 'hypergraph': 8, 'pairwise': 4}
# tier                                     hb_graph  hypergraph  pairwise
# best_params
# {'clf__C': 0.1, 'clf__gamma': 'scale'}         30           0         0
# {'clf__C': 0.1, 'clf__gamma': 0.01}             6           0         0
# {'clf__C': 0.1, 'clf__gamma': 0.1}              0          15         0
# {'clf__C': 0.1, 'clf__gamma': 1}                0           1         2
# {'clf__C': 1, 'clf__gamma': 'scale'}            3           0         0
# {'clf__C': 1, 'clf__gamma': 0.001}              1           0         0
# {'clf__C': 1, 'clf__gamma': 0.01}               1           0         0
# {'clf__C': 1, 'clf__gamma': 0.1}                0           6         0
# {'clf__C': 1, 'clf__gamma': 1}                  0           0        15
# {'clf__C': 10, 'clf__gamma': 'scale'}           0           2         0
# {'clf__C': 10, 'clf__gamma': 0.001}             5           0         0
# {'clf__C': 10, 'clf__gamma': 0.01}              0           1         0
# {'clf__C': 10, 'clf__gamma': 0.1}               0           1         0
# {'clf__C': 10, 'clf__gamma': 1}                 0           0         3
# {'clf__C': 100, 'clf__gamma': 'scale'}          1           8         0
# {'clf__C': 100, 'clf__gamma': 0.01}             2           8         0
# {'clf__C': 100, 'clf__gamma': 0.1}              0           0         5
# {'clf__C': 1000, 'clf__gamma': 'scale'}         1           2         0
# {'clf__C': 1000, 'clf__gamma': 0.01}            0           6         0
# {'clf__C': 1000, 'clf__gamma': 0.1}             0           0        25

# %%
"""
RBF-SVM hyperparameter choice under the two splitting regimes.
Reads the existing sweep CSVs; nothing is refitted.
"""

from pathlib import Path
import pandas as pd

# ======================================================================
# CONFIG
# ======================================================================
CONFIG = {
    "GROUP_CSV":  Path("cp_chembl/sweep_results.csv"),
    "RANDOM_CSV": Path("cp_chembl/randomprotein/sweep_results_randomprotein.csv"),
    "MODEL":      "RBF-SVM",
}


def main():
    C = CONFIG
    for arm, path in [("group", C["GROUP_CSV"]), ("random", C["RANDOM_CSV"])]:
        df = pd.read_csv(path)
        sub = df[df["model"] == C["MODEL"]]
        print(f"\n{'='*70}\n{arm.upper()}  ({path.name})\n{'='*70}")
        print(f"features per tier: "
              f"{sub.groupby('tier')['n_features'].first().to_dict()}")
        print(sub.groupby(["tier", "best_params"]).size()
                 .unstack(level=0, fill_value=0).to_string())


main()
# Out:
# ======================================================================
# GROUP  (sweep_results.csv)
# ======================================================================
# features per tier: {'hb_graph': 14, 'hypergraph': 8, 'pairwise': 4}
# tier                                     hb_graph  hypergraph  pairwise
# best_params
# {'clf__C': 0.1, 'clf__gamma': 'scale'}          4           0         3
# {'clf__C': 0.1, 'clf__gamma': 0.1}              2           8         2
# {'clf__C': 0.1, 'clf__gamma': 1}                0           0        13
# {'clf__C': 1, 'clf__gamma': 'scale'}            2           5         0
# {'clf__C': 1, 'clf__gamma': 0.001}              1           0         0
# {'clf__C': 1, 'clf__gamma': 0.01}               1           4         0
# {'clf__C': 1, 'clf__gamma': 0.1}                0           0         4
# {'clf__C': 1, 'clf__gamma': 1}                  0           0         2
# {'clf__C': 10, 'clf__gamma': 'scale'}           0           2         1
# {'clf__C': 10, 'clf__gamma': 0.001}            40           0         0
# {'clf__C': 10, 'clf__gamma': 0.1}               0           0         1
# {'clf__C': 100, 'clf__gamma': 0.001}            0          20         0
# {'clf__C': 100, 'clf__gamma': 0.01}             0           4         6
# {'clf__C': 100, 'clf__gamma': 0.1}              0           0         7
# {'clf__C': 1000, 'clf__gamma': 'scale'}         0           0         3
# {'clf__C': 1000, 'clf__gamma': 0.001}           0           5         2
# {'clf__C': 1000, 'clf__gamma': 0.01}            0           2         1
# {'clf__C': 1000, 'clf__gamma': 0.1}             0           0         5
#
# ======================================================================
# RANDOM  (sweep_results_randomprotein.csv)
# ======================================================================
# features per tier: {'hb_graph': 14, 'hypergraph': 8, 'pairwise': 4}
# tier                                    hb_graph  hypergraph  pairwise
# best_params
# {'clf__C': 0.1, 'clf__gamma': 'scale'}         1           0         0
# {'clf__C': 0.1, 'clf__gamma': 0.01}            3           0         0
# {'clf__C': 0.1, 'clf__gamma': 0.1}             0           4         3
# {'clf__C': 0.1, 'clf__gamma': 1}               0           0        22
# {'clf__C': 1, 'clf__gamma': 'scale'}           1           3         1
# {'clf__C': 1, 'clf__gamma': 0.01}              0           4         0
# {'clf__C': 1, 'clf__gamma': 0.1}               0           0        11
# {'clf__C': 1, 'clf__gamma': 1}                 0           0         3
# {'clf__C': 10, 'clf__gamma': 'scale'}          0           1         0
# {'clf__C': 10, 'clf__gamma': 0.001}           45           0         0
# {'clf__C': 10, 'clf__gamma': 0.01}             0           0         1
# {'clf__C': 10, 'clf__gamma': 0.1}              0           0         2
# {'clf__C': 100, 'clf__gamma': 'scale'}         0           1         0
# {'clf__C': 100, 'clf__gamma': 0.001}           0          30         0
# {'clf__C': 100, 'clf__gamma': 0.01}            0           0         3
# {'clf__C': 100, 'clf__gamma': 0.1}             0           0         3
# {'clf__C': 1000, 'clf__gamma': 0.001}          0           6         1
# {'clf__C': 1000, 'clf__gamma': 0.01}           0           1         0
