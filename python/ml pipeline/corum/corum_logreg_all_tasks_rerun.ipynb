# %%
"""
=======================================================================
LOGISTIC REGRESSION BASELINE — REPRESENTATION COMPARISON (CORUM)
=======================================================================

Runs the same four-tier representation comparison as the tree-ensemble
scripts (cp_ess_second.py / cp_hpa_second.py / cp_chembl_second.py), but
with an L2-penalised logistic regression, across ALL THREE tasks in one
run:

    gene essentiality  |  HPA drug targets  |  ChEMBL drug targets

Tiers (identical to the tree scripts, nested pairwise ⊂ hypergraph ⊂ hb_graph):
    pairwise   — dyadic PPI features
    hypergraph — set-based higher-order features (no stoichiometry)
    hyper_flag — hypergraph + binary annotation-presence flag   [TEST A]
    hyper_recip— hypergraph + 1/(1+complex size)                [TEST C]
    hb_graph   — hypergraph + stoichiometry (multiset hyperedges)

TEST C — the reciprocal-of-size control
    Among curated CP proteins stoich_MedianRatio correlates with
    protein_MedComplexNodes at Spearman -0.918 (CORUM -0.659), and
    stoich_WeightedTriangles at +0.942. The mechanism is arithmetic: for a
    complex of n roughly equimolar subunits, one protein's share of total
    stoichiometry is about 1/n, so stoich_MedianRatio ~= 1/MedComplexNodes.

    A reciprocal is monotone but strongly NONLINEAR. L2 logistic regression
    on x cannot represent 1/x, so supplying stoich_MedianRatio hands it a
    basis function it structurally lacked; a random forest already
    approximates 1/x by splitting repeatedly on x. That is exactly the
    observed pattern (large LR stoichiometry gains, RF null, one feature
    carrying the whole effect), so the two must be told apart.

    The hyper_recip tier adds recip_MedComplexNodes = 1/(1 + MedComplexNodes),
    a deterministic transform of a feature the hypergraph tier ALREADY has
    and which contains NO stoichiometry information. The contrast that
    matters is then hb_graph - hyper_recip: if it collapses to zero, the
    apparent stoichiometric gain was a size recoding.

WHAT DIFFERS FROM THE TREE SCRIPTS
    1. The estimator is a Pipeline: StandardScaler -> LogisticRegression.
       Scaling is MANDATORY here (unlike for trees) because the features span
       orders of magnitude — base_Degree is an unbounded count, stoich_MedianRatio
       is bounded in (0, 1] — and an L2 penalty applied to unscaled features
       penalises them by an arbitrary amount that depends only on their units.
       The scaler sits INSIDE the pipeline, so it is refitted on each inner CV
       training fold and never sees the test split.
    2. The hyperparameter grid is over C (inverse regularisation strength) only.
    3. Feature importance is permutation importance (PR-AUC drop), exactly as
       in the tree scripts, so the numbers are directly comparable. Coefficients
       are deliberately NOT reported: with correlated features they are not a
       reliable importance ranking.

EVERYTHING ELSE IS HELD FIXED so the comparison is like-for-like:
    same splits files, same frozen feature sets, same fillna(0) encoding,
    same average_precision scorer, same 5-fold inner CV, same PR-AUC / F1
    metrics, same one-sided sign tests, same output file names.

USAGE
    Set DATA_DIR and BASE_OUTPUT_DIR below, then:  python lr_corum_all_tasks.py
    Outputs land in BASE_OUTPUT_DIR/<task_key>/ , one directory per task,
    plus a cross-task summary at BASE_OUTPUT_DIR/all_tasks_summary.csv.
"""

import os
import time
import warnings
from pathlib import Path
from typing import List, Dict, Optional

import numpy as np
import pandas as pd
import matplotlib
matplotlib.use("Agg")
import matplotlib.pyplot as plt

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report, average_precision_score
from sklearn.inspection import permutation_importance
from sklearn.exceptions import ConvergenceWarning
from scipy.stats import binomtest, spearmanr

# =======================================================
# Plotting Style Configuration
# =======================================================
plt.rcParams.update({
    'font.size': 16,
    'axes.titlesize': 18,
    'axes.labelsize': 16,
    'xtick.labelsize': 14,
    'ytick.labelsize': 14,
    'legend.fontsize': 14,
    'figure.titlesize': 20
})

# =======================================================
# CONFIGURATION
# =======================================================
CONFIG = {
    # --- Database identity (used in printouts and output filenames) ---
    "DATABASE": "CORUM",

    # --- Paths ---
    "DATA_DIR": Path("/Users/anitaapplegarth/github/dphil/protein_complexes/data/lookup_tables/corum/"),
    "BASE_OUTPUT_DIR": Path("./logistic/corum_second_testA"),

    "PROTEIN_FEATURES_FILE":  "hypergraph_features.csv",
    "PAIRWISE_FEATURES_FILE": "pairwise_features.csv",

    # Optional sanity check of the annotation flag against the raw incidence file.
    # Must sit in the SAME subdirectory as DATA_DIR. Set to None to skip.
    "RAW_STOICH_FILE": Path("/Users/anitaapplegarth/github/dphil/protein_complexes/data/lookup_tables/corum/stoich_protein.csv"),

    # --- TASKS ---------------------------------------------------------------
    # All three tasks run in a single invocation. Each writes to its own
    # subdirectory of BASE_OUTPUT_DIR. To run only a subset, comment one out.
    #
    # 'label_map' must match the protein_label strings in that task's splits
    # file; anything not in the map is treated as Unknown (NaN) and excluded
    # by label_mask, exactly as in the tree scripts.
    "TASKS": {
        "ess": {
            "name":        "Gene Essentiality",
            "splits_file": "ess_protein_splits.csv",
            "label_map":   {'Essential': 1, 'Non-essential': 0},
            "pos_name":    "Essential",
            "neg_name":    "Non-Essential",
        },
        "hpa": {
            "name":        "Drug Target Prediction (HPA)",
            "splits_file": "hpa_protein_splits.csv",
            "label_map":   {'Drug_target': 1, 'Non_target': 0},
            "pos_name":    "Drug_target",
            "neg_name":    "Non_target",
        },
        "chembl": {
            "name":        "Drug Target Prediction (ChEMBL)",
            "splits_file": "chembl_protein_splits.csv",
            "label_map":   {'Drug_target': 1, 'Non_target': 0},
            "pos_name":    "Drug_target",
            "neg_name":    "Non_target",
        },
    },

    # --- TEST A: annotation-presence control ---------------------------------
    # A fourth tier, HYPER_FLAG = HYPERGRAPH + a single binary feature marking
    # whether the protein has ANY curated stoichiometry. This decomposes the
    # apparent stoichiometry effect into two parts:
    #
    #     hb_graph - hypergraph  =  [hyper_flag - hypergraph]  (annotation presence)
    #                            +  [hb_graph   - hyper_flag]  (stoichiometry VALUES)
    #
    # The flag is recovered exactly from the existing features: a true
    # stoich_MedianRatio lies in (0, 1], so a value of 0 uniquely marks
    # "this protein has no curated stoichiometry anywhere".
    #
    # SET INCLUDE_HYPER_FLAG = False FOR CORUM if the flag is near-constant
    # there (CORUM stoichiometry coverage is ~4% vs CP's ~60%). A near-degenerate
    # binary predictor is harmless to a tree but can produce a large, unstable
    # coefficient under regularised logistic regression. The script also
    # auto-skips the tier per split if the flag has <2 levels in the training
    # fold, or if either level has fewer than MIN_FLAG_COUNT proteins.
    # CORUM: stoichiometry coverage is ~4% of incidences (10.5% of proteins),
    # so the flag is close to constant. Left ON for symmetry with CP; the
    # loader prints a near-degeneracy warning.
    "INCLUDE_HYPER_FLAG":  True,
    "MIN_FLAG_COUNT":      10,
    "ANNOTATION_FLAG":     "flag_HasStoich",
    "FLAG_SOURCE_FEATURE": "stoich_MedianRatio",

    # --- TEST C: reciprocal-of-size control (see header) ---------------------
    # recip = 1/(1 + protein_MedComplexNodes). 1/(1+n) rather than 1/n because
    # MedComplexNodes can be 0 for proteins whose only complexes are
    # homo-oligomers; the +1 keeps the transform finite and monotone throughout.
    "INCLUDE_HYPER_RECIP": True,
    "RECIP_FEATURE":       "recip_MedComplexNodes",
    "RECIP_SOURCE_FEATURE": "protein_MedComplexNodes",

    # --- Fixed settings (matched to the tree scripts) ---
    "RANDOM_STATE": 42,
    "N_SPLITS_CV":  5,
    "PERM_REPEATS": 10,

    # --- Logistic regression ---
    # lbfgs with the default L2 penalty is the standard, fast choice and
    # converges reliably on standardised features. class_weight='balanced'
    # matches the tree scripts. max_iter is set high because the smallest C
    # values converge slowly.
    # NB: 'penalty' is deliberately NOT passed. L2 is the default in every
    # sklearn version, and passing penalty='l2' explicitly raises a
    # FutureWarning from sklearn 1.8 onwards.
    "LOGREG_KWARGS": {
        "solver":       "lbfgs",
        "class_weight": "balanced",
        "max_iter":     5000,
    },
    "PARAM_GRID": {
        "clf__C": list(np.logspace(-6, 4, 11))
    },

    # --- Feature Selection (FROZEN — must match the tree scripts exactly) ---
    "FEATURES": {
        "HB_GRAPH": [
            # --- Base / native higher-order metrics ---
            'base_Degree',
            'base_LocalClustCoeff',
            'base_TriangleCount',
            'base_UniquePartners',
            'base_AvgNeighbourDegree',

            # --- Stoichiometry-based metrics (hb-graph only) ---
            'stoich_WeightedTriangles',
            'stoich_AvgNeighbourDegreeStoich',
            'stoich_RangeComplexSize',
            'stoich_MedComplexSize',
            'stoich_MedianRatio',
            'stoich_RangeRatio',

            # --- Protein-participation metrics ---
            # 'protein_MedianUniqueRatio',   # DROPPED: near-exact reciprocal of
            #                                # protein_MedComplexNodes (Spearman -0.9965).
            'protein_RangeUniqueRatio',
            'protein_MedComplexNodes',
            'protein_RangeComplexNodes',
        ],
        "STOICHIOMETRY_FEATURES": [
            'stoich_WeightedTriangles',
            'stoich_AvgNeighbourDegreeStoich',
            'stoich_RangeComplexSize',
            'stoich_MedComplexSize',
            'stoich_MedianRatio',
            'stoich_RangeRatio',
        ],
        "PAIRWISE": [
            'pair_Degree',
            'pair_LocalClustCoeff',
            'pair_TriangleCount',
            'pair_AvgNeighborDegree',
        ]
    }
}

# Tier order used everywhere (printouts, CSV columns, plots).
TIERS = ['pairwise', 'hypergraph', 'hyper_flag', 'hyper_recip', 'hb_graph']
TIER_LABELS = {
    'pairwise':   'Pairwise',
    'hypergraph': 'Hypergraph',
    'hyper_flag': 'Hypergraph + flag',
    'hyper_recip': 'Hypergraph + 1/size',
    'hb_graph':   'HB-graph',
}


# =======================================================
# DATA LOADING
# =======================================================

def load_all_features() -> pd.DataFrame:
    """Loads higher-order (hb-graph) and pairwise feature CSVs, merges on ProteinId."""
    print("1. Loading feature data...")

    hg_df   = pd.read_csv(CONFIG["DATA_DIR"] / CONFIG["PROTEIN_FEATURES_FILE"])
    pair_df = pd.read_csv(CONFIG["DATA_DIR"] / CONFIG["PAIRWISE_FEATURES_FILE"])

    combined = pd.merge(hg_df, pair_df, on='ProteinId', how='inner')

    print(f"   Higher-order (hb-graph) features shape : {hg_df.shape}")
    print(f"   Pairwise features shape               : {pair_df.shape}")
    print(f"   Combined shape                        : {combined.shape}")

    combined = derive_annotation_flag(combined)
    combined = derive_reciprocal(combined)
    return combined


def derive_reciprocal(df: pd.DataFrame) -> pd.DataFrame:
    """Adds the TEST C control feature: 1 / (1 + complex size).

    Contains no stoichiometry information — it is a deterministic transform
    of a feature the hypergraph tier already holds. Its purpose is to give a
    linear model the 1/n basis function that stoich_MedianRatio would
    otherwise smuggle in.
    """
    if not CONFIG["INCLUDE_HYPER_RECIP"]:
        return df

    recip = CONFIG["RECIP_FEATURE"]
    src   = CONFIG["RECIP_SOURCE_FEATURE"]
    if src not in df.columns:
        raise KeyError(f"Cannot derive {recip}: '{src}' not in feature file.")

    df[recip] = 1.0 / (1.0 + df[src])

    print(f"\n   Derived '{recip}' = 1 / (1 + {src})  [TEST C control]")

    # Report how closely it tracks the stoichiometry features. The comparison
    # that matters is among CURATED proteins only: across all proteins the
    # correlation is dominated by the shared zero/non-zero structure.
    flag = CONFIG["ANNOTATION_FLAG"]
    cur = df[df[flag] == 1] if flag in df.columns else df
    print(f"     Spearman vs stoichiometry features "
          f"(curated proteins only, n = {len(cur):,}):")
    for f_ in CONFIG["FEATURES"]["STOICHIOMETRY_FEATURES"]:
        if f_ in cur.columns and len(cur) > 10 and cur[f_].nunique() > 1:
            rho, _ = spearmanr(cur[recip], cur[f_])
            mark = "   <-- near-deterministic" if abs(rho) > 0.85 else ""
            print(f"       {f_:<34} {rho:+.3f}{mark}")

    return df


def derive_annotation_flag(df: pd.DataFrame) -> pd.DataFrame:
    """
    Adds CONFIG['ANNOTATION_FLAG'] (binary): 1 if the protein has at least one
    complex with curated stoichiometry, 0 otherwise. Derived from
    stoich_MedianRatio, where a genuine ratio lies in (0, 1] and a value of
    exactly 0 unambiguously means "no curated stoichiometry anywhere".
    """
    flag = CONFIG["ANNOTATION_FLAG"]
    src  = CONFIG["FLAG_SOURCE_FEATURE"]

    if src not in df.columns:
        raise KeyError(f"Cannot derive {flag}: '{src}' not in feature file.")

    df[flag] = (df[src] > 0).astype(int)

    n_annot = int(df[flag].sum())
    print(f"\n   Derived '{flag}' from '{src}':")
    print(f"     curated   : {n_annot} / {len(df)}  ({100*n_annot/len(df):.1f}%)")
    print(f"     uncurated : {len(df)-n_annot} / {len(df)}  "
          f"({100*(1-n_annot/len(df)):.1f}%)")

    # Loud warning if the flag is near-degenerate — relevant for CORUM.
    frac = n_annot / len(df) if len(df) else 0.0
    if CONFIG["INCLUDE_HYPER_FLAG"] and (frac < 0.05 or frac > 0.95):
        print(f"     WARNING: '{flag}' is near-constant ({100*frac:.1f}% curated).")
        print(f"              The hyper_flag tier will be unstable under a "
              f"regularised linear model.")
        print(f"              Consider setting INCLUDE_HYPER_FLAG = False.")

    # --- Optional cross-check against the raw incidence file ---
    raw_path = CONFIG.get("RAW_STOICH_FILE")
    if raw_path and Path(raw_path).exists():
        raw = pd.read_csv(raw_path)
        truth = (raw.assign(a=(raw['Stoichiometry'] > 0).astype(int))
                    .groupby('ProteinId')['a'].max())
        chk = df[['ProteinId', flag]].merge(
            truth.rename('truth'), left_on='ProteinId', right_index=True, how='inner')
        n_mismatch = int((chk[flag] != chk['truth']).sum())
        if n_mismatch == 0:
            print(f"     cross-check vs {Path(raw_path).name}: exact match "
                  f"on all {len(chk)} proteins ✓")
        else:
            print(f"     WARNING: cross-check disagrees on "
                  f"{n_mismatch}/{len(chk)} proteins.")
    else:
        print(f"     (raw-file cross-check skipped — RAW_STOICH_FILE not found)")

    return df


def load_splits(task_key: str) -> pd.DataFrame:
    """
    Loads the pre-assigned group-atomic splits file for one task.

    Expected columns:
        split_index   — integer identifying which split
        UniProt_AC    — protein identifier (matches ProteinId in feature files)
        split         — 'train' or 'test'
        protein_label — task-specific label strings (see CONFIG['TASKS'])
        label_mask    — bool; False for Unknown proteins (excluded from metrics)
    """
    task = CONFIG["TASKS"][task_key]
    splits_path = CONFIG["DATA_DIR"] / task["splits_file"]

    print("2. Loading pre-assigned splits...")
    print(f"   File              : {splits_path.name}")
    print(f"   Last modified     : "
          f"{pd.Timestamp(os.path.getmtime(splits_path), unit='s')}")

    splits_df = pd.read_csv(splits_path)
    splits_df = splits_df.rename(columns={'UniProt_AC': 'ProteinId'})

    unmapped = set(splits_df['protein_label'].unique()) - set(task["label_map"]) 
    splits_df['target'] = splits_df['protein_label'].map(task["label_map"])

    print(f"   Splits file rows  : {len(splits_df)}")
    print(f"   Unique proteins   : {splits_df['ProteinId'].nunique()}")
    print(f"   Number of splits  : {splits_df['split_index'].nunique()}")
    if unmapped:
        print(f"   Unmapped labels (treated as Unknown): {sorted(unmapped)}")

    labelled = splits_df[splits_df['label_mask']].drop_duplicates('ProteinId')
    n_pos, n_tot = int((labelled['target'] == 1).sum()), len(labelled)
    print(f"   Labelled proteins : {n_tot}  ({100*n_pos/n_tot:.1f}% positive)")

    # Guard: a label_mask=True row with a NaN target means the label_map is out
    # of date relative to the splits file. Fail loudly rather than silently
    # dropping proteins from the analysis.
    n_bad = int(splits_df.loc[splits_df['label_mask'], 'target'].isna().sum())
    if n_bad:
        raise ValueError(
            f"{n_bad} rows have label_mask=True but an unmapped protein_label. "
            f"Check CONFIG['TASKS']['{task_key}']['label_map'] against "
            f"{splits_path.name}."
        )

    return splits_df


# =======================================================
# MODEL TRAINING & EVALUATION
# =======================================================

def build_pipeline() -> Pipeline:
    """StandardScaler -> LogisticRegression, so scaling is refitted per CV fold."""
    return Pipeline([
        ("scale", StandardScaler()),
        ("clf", LogisticRegression(
            random_state=CONFIG["RANDOM_STATE"], **CONFIG["LOGREG_KWARGS"]
        )),
    ])


def tune_and_train_model(X_train: pd.DataFrame, y_train: pd.Series):
    """Grid search over C + fit. Returns (best_estimator, best_params)."""
    gs = GridSearchCV(
        estimator=build_pipeline(),
        param_grid=CONFIG["PARAM_GRID"],
        scoring='average_precision',
        cv=CONFIG["N_SPLITS_CV"],
        n_jobs=-1,
        verbose=0
    )
    # Small C values on near-separable folds can hit the iteration cap; that is
    # expected and those folds simply lose the grid search on PR-AUC.
    with warnings.catch_warnings():
        warnings.simplefilter("ignore", category=ConvergenceWarning)
        gs.fit(X_train, y_train)
    return gs.best_estimator_, gs.best_params_


def evaluate_model(model, X_test: pd.DataFrame, y_test: pd.Series,
                   pos_name: str, neg_name: str) -> Dict:
    """Returns PR-AUC, F1 for the positive class, and predicted probabilities."""
    y_pred       = model.predict(X_test)
    y_pred_proba = model.predict_proba(X_test)[:, 1]

    report = classification_report(
        y_test, y_pred,
        labels=[0, 1],
        target_names=[neg_name, pos_name],
        output_dict=True,
        zero_division=0
    )

    return {
        'pr_auc':       average_precision_score(y_test, y_pred_proba),
        'f1':           report[pos_name]['f1-score'],
        'y_pred_proba': y_pred_proba
    }


def compute_permutation_importance(
    model, X_test: pd.DataFrame, y_test: pd.Series
) -> Dict[str, float]:
    """Permutation importance scored by average_precision (PR-AUC drop).

    Permuting the raw column and passing it through the fitted pipeline is the
    correct thing to do: the scaler is a fixed monotone transform at this point,
    so permuting before or after scaling gives the same importance.
    """
    result = permutation_importance(
        model, X_test, y_test,
        scoring='average_precision',
        n_repeats=CONFIG["PERM_REPEATS"],
        random_state=CONFIG["RANDOM_STATE"],
        n_jobs=-1
    )
    return dict(zip(X_test.columns, result.importances_mean))


# =======================================================
# PER-SPLIT RUNNER
# =======================================================

def run_split(
    split_idx: int,
    merged_df: pd.DataFrame,
    splits_df: pd.DataFrame,
    feature_sets: Dict[str, List[str]],
    task: Dict
) -> Dict:
    """Runs every configured tier for a single pre-assigned split."""
    split_mask = splits_df['split_index'] == split_idx
    split_info = splits_df[split_mask][
        ['ProteinId', 'split', 'target', 'label_mask']].copy()

    df = pd.merge(merged_df, split_info, on='ProteinId', how='inner')
    labelled_df = df[df['label_mask']].copy()

    train_df = labelled_df[labelled_df['split'] == 'train']
    test_df  = labelled_df[labelled_df['split'] == 'test']

    y_train = train_df['target'].astype(int)
    y_test  = test_df['target'].astype(int)

    if y_train.nunique() < 2 or y_test.nunique() < 2:
        raise ValueError(
            f"split {split_idx}: train or test fold contains a single class "
            f"(train pos={int(y_train.sum())}/{len(y_train)}, "
            f"test pos={int(y_test.sum())}/{len(y_test)})."
        )

    results = {
        'split_index':   split_idx,
        'n_train':       len(train_df),
        'n_test':        len(test_df),
        'train_pos_pct': 100 * y_train.mean(),
        'test_pos_pct':  100 * y_test.mean(),
    }

    for tier, feats in feature_sets.items():
        if not feats:
            continue

        # Guard the TEST A tier against a degenerate flag in this training fold.
        flag = CONFIG["ANNOTATION_FLAG"]
        if tier == 'hyper_flag' and flag in feats:
            counts = train_df[flag].value_counts()
            if len(counts) < 2 or counts.min() < CONFIG["MIN_FLAG_COUNT"]:
                results['hyper_flag_pr_auc'] = np.nan
                results['hyper_flag_f1']     = np.nan
                results['hyper_flag_skipped'] = True
                continue

        X_train, X_test = train_df[feats], test_df[feats]

        model, params = tune_and_train_model(X_train, y_train)
        ev = evaluate_model(model, X_test, y_test,
                            task["pos_name"], task["neg_name"])

        results[f'{tier}_pr_auc']      = ev['pr_auc']
        results[f'{tier}_f1']          = ev['f1']
        results[f'{tier}_best_params'] = params
        results[f'{tier}_importance']  = compute_permutation_importance(
            model, X_test, y_test)

        preds = test_df[['ProteinId']].copy()
        preds['split_index'] = split_idx
        preds['true_label']  = y_test.values
        preds[f'{tier}_pred_proba'] = ev['y_pred_proba']
        results[f'{tier}_predictions'] = preds

    # --- Differences ---
    # Headline representation contrast: hb_graph vs pairwise
    results['pr_auc_diff'] = results['hb_graph_pr_auc'] - results['pairwise_pr_auc']
    results['f1_diff']     = results['hb_graph_f1']     - results['pairwise_f1']
    # Stoichiometry effect: hb_graph vs hypergraph
    results['stoich_pr_auc_diff'] = (results['hb_graph_pr_auc']
                                     - results['hypergraph_pr_auc'])
    results['stoich_f1_diff']     = (results['hb_graph_f1']
                                     - results['hypergraph_f1'])
    # TEST A decomposition
    hf = results.get('hyper_flag_pr_auc', np.nan)
    results['annot_pr_auc_diff'] = hf - results['hypergraph_pr_auc']
    results['value_pr_auc_diff'] = results['hb_graph_pr_auc'] - hf
    # TEST C: stoichiometry net of a pure reciprocal-of-size recoding
    hr = results.get('hyper_recip_pr_auc', np.nan)
    results['recip_pr_auc_diff']     = hr - results['hypergraph_pr_auc']
    results['net_recip_pr_auc_diff'] = results['hb_graph_pr_auc'] - hr

    return results


# =======================================================
# STATISTICAL COMPARISON
# =======================================================

def _sign_test(a: np.ndarray, b: np.ndarray) -> Dict:
    """One-sided sign test on paired differences, with Cohen's dz alongside
    as a descriptive effect size (it is not itself a test).

    Splits where either arm is NaN (e.g. a skipped hyper_flag tier) are dropped
    pairwise, so the comparison stays properly paired.
    """
    a, b = np.asarray(a, dtype=float), np.asarray(b, dtype=float)
    ok = ~(np.isnan(a) | np.isnan(b))
    diffs = a[ok] - b[ok]

    n_wins  = int(np.sum(diffs > 0))
    n_loss  = int(np.sum(diffs < 0))
    n_ties  = int(np.sum(diffs == 0))
    n_valid = n_wins + n_loss

    if n_valid > 0:
        p_greater   = binomtest(n_wins, n_valid, 0.5, alternative='greater').pvalue
        p_two_sided = binomtest(n_wins, n_valid, 0.5, alternative='two-sided').pvalue
    else:
        p_greater = p_two_sided = 1.0

    sd = float(np.std(diffs, ddof=1)) if len(diffs) > 1 else 0.0
    dz = float(np.mean(diffs) / sd) if sd > 0 else 0.0

    return dict(
        n_pairs=int(ok.sum()), wins=n_wins, losses=n_loss, ties=n_ties,
        mean_diff=float(np.mean(diffs)) if len(diffs) else float('nan'),
        std_diff=sd, p_greater=p_greater, p_two_sided=p_two_sided, cohens_dz=dz
    )


def run_sign_test_comparison(all_results: List[Dict]) -> Dict:
    """Paired PR-AUC comparisons across splits, matching the tree scripts:
      1. HB-graph  vs Pairwise    — headline representation effect
      2. HB-graph  vs Hypergraph  — stoichiometry effect
      3. Hypergraph vs Pairwise   — set-based representation effect alone
      4. Hyper+flag vs Hypergraph — annotation presence alone       [TEST A]
      5. HB-graph  vs Hyper+flag  — stoichiometry values, net of presence [TEST A]
    """
    def col(tier, metric):
        return np.array([r.get(f'{tier}_{metric}', np.nan) for r in all_results],
                        dtype=float)

    stats = {'n_runs': len(all_results)}

    for tier in TIERS:
        pr, f1 = col(tier, 'pr_auc'), col(tier, 'f1')
        stats[f'{tier}_pr_auc_mean'] = float(np.nanmean(pr)) if not np.all(np.isnan(pr)) else float('nan')
        stats[f'{tier}_pr_auc_std']  = float(np.nanstd(pr))  if not np.all(np.isnan(pr)) else float('nan')
        stats[f'{tier}_f1_mean']     = float(np.nanmean(f1)) if not np.all(np.isnan(f1)) else float('nan')
        stats[f'{tier}_f1_std']      = float(np.nanstd(f1))  if not np.all(np.isnan(f1)) else float('nan')

    stats['comparisons'] = {
        'hb_graph_vs_pairwise':     _sign_test(col('hb_graph', 'pr_auc'),
                                               col('pairwise', 'pr_auc')),
        'hb_graph_vs_hypergraph':   _sign_test(col('hb_graph', 'pr_auc'),
                                               col('hypergraph', 'pr_auc')),
        'hypergraph_vs_pairwise':   _sign_test(col('hypergraph', 'pr_auc'),
                                               col('pairwise', 'pr_auc')),
        'hyper_flag_vs_hypergraph': _sign_test(col('hyper_flag', 'pr_auc'),
                                               col('hypergraph', 'pr_auc')),
        'hb_graph_vs_hyper_flag':   _sign_test(col('hb_graph', 'pr_auc'),
                                               col('hyper_flag', 'pr_auc')),
        'hyper_recip_vs_hypergraph': _sign_test(col('hyper_recip', 'pr_auc'),
                                                col('hypergraph', 'pr_auc')),
        'hb_graph_vs_hyper_recip':  _sign_test(col('hb_graph', 'pr_auc'),
                                               col('hyper_recip', 'pr_auc')),
    }
    return stats


# =======================================================
# FEATURE IMPORTANCE AGGREGATION
# =======================================================

def aggregate_feature_importance(all_results: List[Dict],
                                 tier: str) -> pd.DataFrame:
    """Aggregates permutation importance across all splits for one tier."""
    key = f'{tier}_importance'
    records = [
        {'split_index': r['split_index'], 'feature': feat, 'importance': imp}
        for r in all_results if key in r
        for feat, imp in r[key].items()
    ]
    if not records:
        return pd.DataFrame()

    agg_df = (
        pd.DataFrame(records)
        .groupby('feature')['importance']
        .agg(mean='mean', std='std', median='median',
             min='min', max='max', n_splits='count')
        .reset_index()
        .sort_values('mean', ascending=False)
        .reset_index(drop=True)
    )
    agg_df['rank'] = range(1, len(agg_df) + 1)
    return agg_df


# =======================================================
# PRINTING
# =======================================================

COMPARISON_LABELS = {
    'hb_graph_vs_pairwise':     "HB-graph vs Pairwise — headline representation effect",
    'hb_graph_vs_hypergraph':   "HB-graph vs Hypergraph — stoichiometry effect",
    'hypergraph_vs_pairwise':   "Hypergraph vs Pairwise — representation effect alone",
    'hyper_flag_vs_hypergraph': "[TEST A] Hyper+flag vs Hypergraph — ANNOTATION PRESENCE alone",
    'hb_graph_vs_hyper_flag':   "[TEST A] HB-graph vs Hyper+flag — STOICHIOMETRY VALUES, net of annotation",
    'hyper_recip_vs_hypergraph': "[TEST C] Hyper+1/size vs Hypergraph — what a pure size recoding buys",
    'hb_graph_vs_hyper_recip':  "[TEST C] HB-graph vs Hyper+1/size — STOICHIOMETRY net of size recoding",
}


def _format_comparison(label: str, d: Dict) -> str:
    return (
        f"\n  --- {label} ---\n"
        f"  Mean diff : {d['mean_diff']:+.4f} ± {d['std_diff']:.4f}"
        f"   (Cohen's dz = {d['cohens_dz']:+.3f})\n"
        f"  Wins/Losses/Ties : {d['wins']}/{d['losses']}/{d['ties']}"
        f"   (n paired = {d['n_pairs']})\n"
        f"  Sign test p (one-sided) : {d['p_greater']:.6f}   "
        f"(two-sided: {d['p_two_sided']:.6f})\n"
    )


def format_statistical_summary(stats: Dict, task: Dict) -> str:
    out = [f"\n{'='*70}", "  STATISTICAL COMPARISON", f"{'='*70}",
           f"\n  Task            : {task['name']}",
           f"  Model           : Logistic regression (L2, standardised)",
           f"  Number of splits: {stats['n_runs']}"]

    for metric, title in [('pr_auc', 'PR-AUC'), ('f1', 'F1 (positive class)')]:
        out += [f"\n  {title}", f"  {'Representation':<20} {'Mean ± Std'}",
                f"  {'-'*45}"]
        for tier in TIERS:
            m, s = stats[f'{tier}_{metric}_mean'], stats[f'{tier}_{metric}_std']
            val = "not run" if np.isnan(m) else f"{m:.4f} ± {s:.4f}"
            out.append(f"  {TIER_LABELS[tier]:<20} {val}")

    for name, d in stats['comparisons'].items():
        if d['n_pairs'] == 0:
            continue
        out.append(_format_comparison(COMPARISON_LABELS[name], d))

    # --- TEST A decomposition ---
    ann = stats['comparisons']['hyper_flag_vs_hypergraph']
    val = stats['comparisons']['hb_graph_vs_hyper_flag']
    tot = stats['comparisons']['hb_graph_vs_hypergraph']

    if ann['n_pairs'] > 0 and val['n_pairs'] > 0:
        out += [f"\n{'='*70}",
                "  TEST A — DECOMPOSITION OF THE STOICHIOMETRY EFFECT",
                f"{'='*70}", "",
                f"  {'Component':<44} {'dPR-AUC':>9} {'W/L':>7} {'p (1-sided)':>12}",
                f"  {'-'*78}",
                f"  {'Annotation presence   (flag - hypergraph)':<44} "
                f"{ann['mean_diff']:>+9.4f} {ann['wins']:>3}/{ann['losses']:<3} "
                f"{ann['p_greater']:>12.4f}",
                f"  {'Stoichiometry values  (hb-graph - flag)':<44} "
                f"{val['mean_diff']:>+9.4f} {val['wins']:>3}/{val['losses']:<3} "
                f"{val['p_greater']:>12.4f}",
                f"  {'-'*78}",
                f"  {'TOTAL  (hb-graph - hypergraph)':<44} "
                f"{tot['mean_diff']:>+9.4f} {tot['wins']:>3}/{tot['losses']:<3} "
                f"{tot['p_greater']:>12.4f}"]
        if abs(tot['mean_diff']) > 1e-9:
            share = 100 * ann['mean_diff'] / tot['mean_diff']
            out.append(f"\n  Annotation presence accounts for {share:.0f}% of the "
                       f"total stoichiometry effect.")
        out.append(f"{'='*70}")
    else:
        out.append("\n  TEST A decomposition skipped "
                   "(hyper_flag tier not run or degenerate).")

    # --- TEST C: is the stoichiometry gain just a reciprocal of size? ---
    rec = stats['comparisons']['hyper_recip_vs_hypergraph']
    net = stats['comparisons']['hb_graph_vs_hyper_recip']

    if rec['n_pairs'] > 0 and net['n_pairs'] > 0:
        out += [f"\n{'='*70}",
                "  TEST C — RECIPROCAL-OF-SIZE CONTROL",
                f"{'='*70}", "",
                f"  {'Component':<44} {'dPR-AUC':>9} {'W/L':>7} {'p (1-sided)':>12}",
                f"  {'-'*78}",
                f"  {'1/size alone   (recip - hypergraph)':<44} "
                f"{rec['mean_diff']:>+9.4f} {rec['wins']:>3}/{rec['losses']:<3} "
                f"{rec['p_greater']:>12.4f}",
                f"  {'Stoichiometry  (hb-graph - recip)':<44} "
                f"{net['mean_diff']:>+9.4f} {net['wins']:>3}/{net['losses']:<3} "
                f"{net['p_greater']:>12.4f}",
                f"  {'-'*78}",
                f"  {'TOTAL  (hb-graph - hypergraph)':<44} "
                f"{tot['mean_diff']:>+9.4f} {tot['wins']:>3}/{tot['losses']:<3} "
                f"{tot['p_greater']:>12.4f}"]

        if tot['mean_diff'] > 0.001:
            absorbed = 100 * (1 - net['mean_diff'] / tot['mean_diff'])
            out.append(f"\n  The reciprocal absorbs {absorbed:.0f}% of the total "
                       f"apparent stoichiometry effect.")
        else:
            out.append("\n  (Absorbed share not shown: the total effect is not "
                       "positive, so the ratio\n   is uninterpretable.)")

        if net['p_greater'] < 0.05 and net['mean_diff'] > 0:
            out += ["\n  VERDICT: SURVIVES. The stoichiometry features add signal "
                    "beyond a pure\n  reciprocal-of-size recoding, so the gain is "
                    "not an artefact of the linear\n  model lacking a 1/n basis "
                    "function."]
        else:
            out += ["\n  VERDICT: DOES NOT SURVIVE. The apparent stoichiometric "
                    "gain is accounted\n  for by 1/(complex size), which carries no "
                    "copy-number information. H2\n  cannot be supported from these "
                    "features under this model."]
        out.append(f"{'='*70}")
    else:
        out.append("\n  TEST C control skipped (hyper_recip tier not run).")

    return "\n".join(out)


def format_feature_importance(imp_dfs: List[tuple], top_n: Optional[int] = None) -> str:
    out = [f"\n{'='*70}",
           "  FEATURE IMPORTANCE (Permutation — mean PR-AUC drop)",
           f"{'='*70}"]
    for label, df in imp_dfs:
        if df.empty:
            continue
        show = df if top_n is None else df.head(top_n)
        out += [f"\n  {label}",
                f"  {'Rank':<6} {'Feature':<36} {'Mean':>10} {'Std':>10} {'Median':>10}",
                f"  {'-'*74}"]
        for _, row in show.iterrows():
            out.append(f"  {int(row['rank']):<6} {row['feature']:<36} "
                       f"{row['mean']:>10.5f} {row['std']:>10.5f} "
                       f"{row['median']:>10.5f}")
    out.append("\n  Note: higher = more important; negative = likely noise.")
    return "\n".join(out)


# =======================================================
# PLOTTING
# =======================================================

def plot_tier_comparison(all_results: List[Dict], stats: Dict,
                         output_dir: Path, task: Dict):
    """Paired scatter (headline contrast) + boxplot across all tiers."""
    pair = np.array([r['pairwise_pr_auc']   for r in all_results], dtype=float)
    hbg  = np.array([r['hb_graph_pr_auc']   for r in all_results], dtype=float)

    fig, axes = plt.subplots(1, 2, figsize=(13, 6))

    # Panel 1: paired scatter, one point per split
    axes[0].scatter(pair, hbg, s=60, alpha=0.7, edgecolor='k', linewidth=0.5,
                    color='steelblue')
    axes[0].plot([0, 1], [0, 1], 'k--', linewidth=1)
    axes[0].set_xlim(0, 1); axes[0].set_ylim(0, 1)
    axes[0].set_xlabel('Pairwise PR-AUC')
    axes[0].set_ylabel('HB-graph PR-AUC')
    axes[0].set_title('Paired splits')
    d = stats['comparisons']['hb_graph_vs_pairwise']
    axes[0].text(0.04, 0.94, f"HB-graph wins {d['wins']}/{d['n_pairs']}\n"
                             f"p = {d['p_greater']:.4f}",
                 transform=axes[0].transAxes, va='top',
                 bbox=dict(boxstyle='round', facecolor='white', alpha=0.85))

    # Panel 2: boxplot across tiers
    data, labels = [], []
    for tier in TIERS:
        vals = np.array([r.get(f'{tier}_pr_auc', np.nan) for r in all_results],
                        dtype=float)
        vals = vals[~np.isnan(vals)]
        if len(vals):
            data.append(vals)
            labels.append(TIER_LABELS[tier].replace(' + ', '\n+ '))
    # 'labels' was renamed 'tick_labels' in Matplotlib 3.9; try the new name
    # first so the script is quiet on both old and new versions.
    try:
        bp = axes[1].boxplot(data, tick_labels=labels, patch_artist=True, widths=0.6)
    except TypeError:
        bp = axes[1].boxplot(data, labels=labels, patch_artist=True, widths=0.6)
    for patch, colour in zip(bp['boxes'],
                             ['gray', 'lightsteelblue', 'cornflowerblue',
                              'lightseagreen', 'steelblue']):
        patch.set_facecolor(colour)
    axes[1].set_ylim(0, 1)
    axes[1].set_ylabel('PR-AUC')
    axes[1].set_title('Distribution across splits')
    axes[1].tick_params(axis='x', labelsize=12)

    fig.suptitle(f"{CONFIG['DATABASE']} — {task['name']} — logistic regression")
    fig.tight_layout()
    fig.savefig(output_dir / 'tier_comparison.png', dpi=300, bbox_inches='tight')
    plt.close(fig)


def plot_feature_importance(imp_dfs: List[tuple], output_dir: Path,
                            task: Dict, top_n: int = 15):
    """Horizontal bar chart of mean permutation importance per tier."""
    panels = [(lab, df, c) for lab, df, c in imp_dfs if not df.empty]
    if not panels:
        return

    fig, axes = plt.subplots(1, len(panels), figsize=(6.5 * len(panels), 7))
    if len(panels) == 1:
        axes = [axes]

    for ax, (label, df, colour) in zip(axes, panels):
        top = df.head(top_n).iloc[::-1]
        ax.barh(top['feature'], top['mean'], xerr=top['std'],
                color=colour, edgecolor='k', linewidth=0.5, capsize=3)
        ax.axvline(0, color='k', linewidth=1)
        ax.set_xlabel('Mean PR-AUC drop')
        ax.set_title(label)
        ax.tick_params(axis='y', labelsize=12)

    fig.suptitle(f"{CONFIG['DATABASE']} — {task['name']} — permutation importance")
    fig.tight_layout()
    fig.savefig(output_dir / 'feature_importance.png', dpi=300, bbox_inches='tight')
    plt.close(fig)


# =======================================================
# PER-TASK RUNNER
# =======================================================

def run_task(task_key: str, features_df: pd.DataFrame,
             feature_sets: Dict[str, List[str]], base_output_dir: Path,
             start_time: float) -> Dict:
    """Runs one task end-to-end and writes its outputs. Returns summary rows."""
    task = CONFIG["TASKS"][task_key]
    output_dir = base_output_dir / task_key
    output_dir.mkdir(parents=True, exist_ok=True)

    splits_path = CONFIG["DATA_DIR"] / task["splits_file"]

    print(f"\n{'#'*70}")
    print(f"  TASK: {task['name']}   [{task_key}]")
    print(f"  Splits : {splits_path}")
    print(f"  Output : {output_dir}")
    print(f"{'#'*70}\n")

    splits_df = load_splits(task_key)
    split_indices = sorted(splits_df['split_index'].unique())
    print(f"\n   Running {len(split_indices)} splits.\n")

    # --- Main loop over splits ---
    all_results, failed_splits = [], []
    checkpoint_path = output_dir / 'split_results_checkpoint.csv'
    if checkpoint_path.exists():
        checkpoint_path.unlink()

    for i, split_idx in enumerate(split_indices, start=1):
        print(f"   Split {split_idx:>3} ({i:>2}/{len(split_indices)})...",
              end=" ", flush=True)
        try:
            result = run_split(split_idx, features_df, splits_df,
                               feature_sets, task)
            all_results.append(result)

            ckpt = {k: result.get(k, np.nan) for k in
                    ['split_index', 'n_train', 'n_test',
                     'train_pos_pct', 'test_pos_pct'] +
                    [f'{t}_pr_auc' for t in TIERS]}
            pd.DataFrame([ckpt]).to_csv(
                checkpoint_path, mode='a', index=False,
                header=not checkpoint_path.exists())

            winner = ("HB-graph" if result['pr_auc_diff'] > 0
                      else "Pair" if result['pr_auc_diff'] < 0 else "Tie")
            hf = result.get('hyper_flag_pr_auc', np.nan)
            hf_str = "skip" if np.isnan(hf) else f"{hf:.4f}"
            hr = result.get('hyper_recip_pr_auc', np.nan)
            hr_str = "skip" if np.isnan(hr) else f"{hr:.4f}"
            print(f"train={result['n_train']} ({result['train_pos_pct']:.1f}% pos)  "
                  f"test={result['n_test']} ({result['test_pos_pct']:.1f}% pos)  |  "
                  f"Pair: {result['pairwise_pr_auc']:.4f}, "
                  f"Hyper: {result['hypergraph_pr_auc']:.4f}, "
                  f"Hyper+flag: {hf_str}, "
                  f"Hyper+1/sz: {hr_str}, "
                  f"HB-graph: {result['hb_graph_pr_auc']:.4f}  [{winner}]")
        except Exception as e:
            failed_splits.append(split_idx)
            print(f"ERROR: {e}")

    if failed_splits:
        print(f"\n   WARNING: {len(failed_splits)} split(s) FAILED and are "
              f"excluded from all statistics: {failed_splits}")
    if not all_results:
        raise RuntimeError(f"[{task_key}] No splits completed — nothing to analyse.")
    print(f"\n   Completed {len(all_results)}/{len(split_indices)} splits.")

    n_skipped = sum(1 for r in all_results if r.get('hyper_flag_skipped'))
    if n_skipped:
        print(f"   NOTE: hyper_flag tier skipped on {n_skipped} split(s) "
              f"(flag degenerate in the training fold).")

    # --- Statistics ---
    print("\n4. Statistical analysis...")
    stats = run_sign_test_comparison(all_results)
    summary_text = format_statistical_summary(stats, task)
    print(summary_text)

    # --- Plots ---
    print("\n5. Generating plots...")
    plot_tier_comparison(all_results, stats, output_dir, task)

    # --- Feature importance ---
    print("\n6. Aggregating feature importance...")
    imp = {tier: aggregate_feature_importance(all_results, tier) for tier in TIERS}
    imp_text = format_feature_importance(
        [(TIER_LABELS[t], imp[t]) for t in TIERS])
    print(imp_text)

    flag = CONFIG["ANNOTATION_FLAG"]
    hf_imp = imp['hyper_flag']
    if not hf_imp.empty and flag in set(hf_imp['feature']):
        row = hf_imp[hf_imp['feature'] == flag].iloc[0]
        print(f"\n   >>> '{flag}' ranks {int(row['rank'])} of {len(hf_imp)} in the "
              f"hypergraph+flag model (mean importance {row['mean']:.5f})")

    plot_feature_importance(
        [(TIER_LABELS['pairwise'],   imp['pairwise'],   'gray'),
         (TIER_LABELS['hypergraph'], imp['hypergraph'], 'skyblue'),
         (TIER_LABELS['hb_graph'],   imp['hb_graph'],   'steelblue')],
        output_dir, task)

    # --- Save CSVs ---
    print("\n7. Saving outputs...")

    summary_cols = (['split_index', 'n_train', 'n_test',
                     'train_pos_pct', 'test_pos_pct'] +
                    [f'{t}_{m}' for t in TIERS for m in ('pr_auc', 'f1')] +
                    ['pr_auc_diff', 'f1_diff', 'stoich_pr_auc_diff',
                     'stoich_f1_diff', 'annot_pr_auc_diff', 'value_pr_auc_diff',
                     'recip_pr_auc_diff', 'net_recip_pr_auc_diff'])
    summary_df = pd.DataFrame(
        [{k: r.get(k, np.nan) for k in summary_cols} for r in all_results])
    summary_df.to_csv(output_dir / 'split_results.csv', index=False)
    print("   Saved: split_results.csv")

    stats_rows = []
    for name, d in stats['comparisons'].items():
        stats_rows.append({
            'database': CONFIG['DATABASE'], 'task': task_key,
            'comparison': name, 'splits_file': task['splits_file'],
            'n_splits': stats['n_runs'], 'model': 'LogisticRegression',
            **{k: d[k] for k in ['mean_diff', 'std_diff', 'cohens_dz', 'wins',
                                 'losses', 'ties', 'n_pairs', 'p_greater',
                                 'p_two_sided']}
        })
    pd.DataFrame(stats_rows).to_csv(output_dir / 'comparison_stats.csv', index=False)
    print("   Saved: comparison_stats.csv")

    for tier in TIERS:
        key = f'{tier}_predictions'
        frames = [r[key] for r in all_results if key in r]
        if frames:
            pd.concat(frames, ignore_index=True).to_csv(
                output_dir / f'{tier}_predictions.csv', index=False)
            print(f"   Saved: {tier}_predictions.csv")
        if not imp[tier].empty:
            imp[tier].to_csv(output_dir / f'{tier}_feature_importance.csv',
                             index=False)
            print(f"   Saved: {tier}_feature_importance.csv")

    # Best C per tier per split — worth eyeballing to check the grid isn't
    # railed at an endpoint (which would mean the C range needs widening).
    c_rows = []
    for r in all_results:
        row = {'split_index': r['split_index']}
        for tier in TIERS:
            bp = r.get(f'{tier}_best_params')
            row[f'{tier}_C'] = bp['clf__C'] if bp else np.nan
        c_rows.append(row)
    c_df = pd.DataFrame(c_rows)
    c_df.to_csv(output_dir / 'best_C_per_split.csv', index=False)
    print("   Saved: best_C_per_split.csv")

    grid_C = CONFIG['PARAM_GRID']['clf__C']
    for tier in TIERS:
        vals = c_df[f'{tier}_C'].dropna()
        if len(vals) and (vals == min(grid_C)).mean() > 0.5:
            print(f"   WARNING: {tier} selected the smallest C on "
                  f"{100*(vals == min(grid_C)).mean():.0f}% of splits — "
                  f"consider extending the grid downwards.")
        if len(vals) and (vals == max(grid_C)).mean() > 0.5:
            print(f"   WARNING: {tier} selected the largest C on "
                  f"{100*(vals == max(grid_C)).mean():.0f}% of splits — "
                  f"consider extending the grid upwards.")

    # --- Text report ---
    with open(output_dir / 'statistical_summary.txt', 'w') as f:
        f.write("REPRESENTATION COMPARISON — LOGISTIC REGRESSION BASELINE\n")
        f.write(f"Database: {CONFIG['DATABASE']}\n")
        f.write(f"Task: {task['name']}\n")
        f.write("\nRUN PROVENANCE\n")
        f.write(f"{'-'*70}\n")
        f.write(f"Run at              : "
                f"{time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(start_time))}\n")
        f.write(f"Model               : LogisticRegression "
                f"(StandardScaler pipeline)\n")
        f.write(f"LogReg settings     : {CONFIG['LOGREG_KWARGS']}\n")
        f.write(f"Hyperparameter grid : {CONFIG['PARAM_GRID']}\n")
        f.write(f"Random state        : {CONFIG['RANDOM_STATE']}\n")
        f.write(f"Inner CV folds      : {CONFIG['N_SPLITS_CV']}\n")
        f.write(f"Permutation repeats : {CONFIG['PERM_REPEATS']}\n")
        f.write(f"Splits file         : {splits_path}\n")
        f.write(f"Splits file mtime   : "
                f"{pd.Timestamp(os.path.getmtime(splits_path), unit='s')}\n")
        f.write(f"Data directory      : {CONFIG['DATA_DIR']}\n")
        f.write(f"Feature files       : {CONFIG['PROTEIN_FEATURES_FILE']}, "
                f"{CONFIG['PAIRWISE_FEATURES_FILE']}\n")
        f.write(f"Splits in file      : {splits_df['split_index'].nunique()}\n")
        f.write(f"Splits attempted    : {len(split_indices)}\n")
        f.write(f"Splits completed    : {stats['n_runs']}\n")
        if failed_splits:
            f.write(f"FAILED splits (excluded from all statistics): "
                    f"{failed_splits}\n")
        f.write(f"Annotation flag     : {flag} "
                f"(derived from {CONFIG['FLAG_SOURCE_FEATURE']})\n")
        f.write(f"hyper_recip tier    : "
                f"{'included' if CONFIG['INCLUDE_HYPER_RECIP'] else 'DISABLED'}"
                f" ({CONFIG['RECIP_FEATURE']} = 1/(1+"
                f"{CONFIG['RECIP_SOURCE_FEATURE']}))\n")
        f.write(f"hyper_flag tier     : "
                f"{'included' if CONFIG['INCLUDE_HYPER_FLAG'] else 'DISABLED'}"
                f"{f'; skipped on {n_skipped} split(s)' if n_skipped else ''}\n\n")

        f.write("CLASS BALANCE (mean over splits)\n")
        f.write(f"{'-'*70}\n")
        f.write(f"Train positives     : {summary_df['train_pos_pct'].mean():.2f}% "
                f"(range {summary_df['train_pos_pct'].min():.2f}"
                f"-{summary_df['train_pos_pct'].max():.2f}%)\n")
        f.write(f"Test  positives     : {summary_df['test_pos_pct'].mean():.2f}% "
                f"(range {summary_df['test_pos_pct'].min():.2f}"
                f"-{summary_df['test_pos_pct'].max():.2f}%)\n")
        f.write(f"Mean train / test n : {summary_df['n_train'].mean():.0f} / "
                f"{summary_df['n_test'].mean():.0f}\n\n")

        for tier in TIERS:
            feats = feature_sets.get(tier, [])
            f.write(f"{TIER_LABELS[tier]} features ({len(feats)}):\n")
            for feat in feats:
                tag = ''
                if feat in CONFIG['FEATURES']['STOICHIOMETRY_FEATURES']:
                    tag = ' [stoich]'
                elif feat == flag:
                    tag = ' [annotation flag]'
                elif feat == CONFIG['RECIP_FEATURE']:
                    tag = ' [1/size control]'
                f.write(f"  - {feat}{tag}\n")
            f.write("\n")

        f.write(summary_text.replace('±', '+/-'))
        f.write("\n\n")
        f.write(imp_text)
        f.write("\n\n")
        f.write(f"{'='*70}\n")
        f.write("PER-SPLIT PR-AUC (also in split_results.csv)\n")
        f.write(f"{'='*70}\n\n")
        f.write(f"{'Split':>6} {'Pairwise':>10} {'Hyper':>10} {'Hyper+flag':>11} "
                f"{'Hyper+1/sz':>11} {'HB-graph':>10} {'HBG-Pair':>10} "
                f"{'HBG-Hyper':>10} {'HBG-1/sz':>10}\n")
        f.write(f"{'-'*94}\n")
        for _, row in summary_df.sort_values('split_index').iterrows():
            def _fmt(v, w=11):
                return " " * (w - 1) + "-" if pd.isna(v) else f"{v:>{w}.4f}"
            f.write(f"{int(row['split_index']):>6} "
                    f"{row['pairwise_pr_auc']:>10.4f} "
                    f"{row['hypergraph_pr_auc']:>10.4f} "
                    f"{_fmt(row['hyper_flag_pr_auc'])} "
                    f"{_fmt(row['hyper_recip_pr_auc'])} "
                    f"{row['hb_graph_pr_auc']:>10.4f} "
                    f"{row['pr_auc_diff']:>+10.4f} "
                    f"{row['stoich_pr_auc_diff']:>+10.4f} "
                    f"{_fmt(row['net_recip_pr_auc_diff'], 10)}\n")
        f.write(f"\n\nRuntime to this point: "
                f"{(time.time() - start_time)/60:.1f} min\n")
    print("   Saved: statistical_summary.txt")

    # --- Rows for the cross-task summary table ---
    perf_rows = [{
        'database': CONFIG['DATABASE'], 'task': task_key,
        'task_name': task['name'], 'model': 'LogisticRegression',
        'n_splits': stats['n_runs'], 'representation': TIER_LABELS[tier],
        'pr_auc_mean': stats[f'{tier}_pr_auc_mean'],
        'pr_auc_std':  stats[f'{tier}_pr_auc_std'],
        'f1_mean':     stats[f'{tier}_f1_mean'],
        'f1_std':      stats[f'{tier}_f1_std'],
    } for tier in TIERS]

    return {'performance': perf_rows, 'comparisons': stats_rows}


# =======================================================
# MAIN
# =======================================================

if __name__ == "__main__":

    start_time = time.time()
    print(f"Process started at "
          f"{time.strftime('%H:%M:%S', time.localtime(start_time))}")

    base_output_dir = Path(CONFIG["BASE_OUTPUT_DIR"])
    base_output_dir.mkdir(parents=True, exist_ok=True)

    # --- Pre-flight: every splits file must exist before any work begins ---
    for key, task in CONFIG["TASKS"].items():
        p = CONFIG["DATA_DIR"] / task["splits_file"]
        if not p.exists():
            raise FileNotFoundError(
                f"Splits file for task '{key}' not found: {p}\n"
                f"   Check CONFIG['TASKS']['{key}']['splits_file'].")

    print(f"\n{'='*70}")
    print(f"  LOGISTIC REGRESSION BASELINE")
    print(f"  Database : {CONFIG['DATABASE']}")
    print(f"  Tasks    : {', '.join(CONFIG['TASKS'])}")
    print(f"  Output   : {base_output_dir}")
    print(f"{'='*70}\n")

    # --- Load features once; they are shared across all three tasks ---
    features_df = load_all_features()

    hb_graph_features = [f for f in CONFIG["FEATURES"]["HB_GRAPH"]
                         if f in features_df.columns]
    pairwise_features = [f for f in CONFIG["FEATURES"]["PAIRWISE"]
                         if f in features_df.columns]
    stoich_features   = CONFIG["FEATURES"].get("STOICHIOMETRY_FEATURES", [])
    hypergraph_features = [f for f in hb_graph_features
                           if f not in stoich_features]

    flag  = CONFIG["ANNOTATION_FLAG"]
    recip = CONFIG["RECIP_FEATURE"]
    feature_sets = {
        'pairwise':   pairwise_features,
        'hypergraph': hypergraph_features,
        'hyper_flag': (hypergraph_features + [flag]
                       if CONFIG["INCLUDE_HYPER_FLAG"] else []),
        'hyper_recip': (hypergraph_features + [recip]
                        if CONFIG["INCLUDE_HYPER_RECIP"] else []),
        'hb_graph':   hb_graph_features,
    }

    missing_hbg  = [f for f in CONFIG["FEATURES"]["HB_GRAPH"]
                    if f not in features_df.columns]
    missing_pair = [f for f in CONFIG["FEATURES"]["PAIRWISE"]
                    if f not in features_df.columns]
    if missing_hbg:
        print(f"   WARNING: {len(missing_hbg)} hb-graph features not found "
              f"in data: {missing_hbg}")
    if missing_pair:
        print(f"   WARNING: {len(missing_pair)} pairwise features not found "
              f"in data: {missing_pair}")

    for tier in TIERS:
        feats = feature_sets[tier]
        if not feats:
            print(f"\n   {TIER_LABELS[tier]} tier: DISABLED")
            continue
        print(f"\n   Active {TIER_LABELS[tier]} features ({len(feats)}):")
        for f_ in feats:
            tag = (' [stoich]' if f_ in stoich_features
                   else ' [annotation flag]' if f_ == flag
                   else ' [1/size control]' if f_ == recip else '')
            print(f"     - {f_}{tag}")

    # --- Fill any NaNs in feature columns ---
    # NB: encoding deliberately UNCHANGED from the tree scripts. Test A measures
    # what the current fillna(0) encoding is buying; fixing it here would defeat that.
    all_feature_cols = sorted(set(hb_graph_features + pairwise_features))
    if CONFIG["INCLUDE_HYPER_RECIP"] and recip in features_df.columns:
        all_feature_cols = sorted(set(all_feature_cols + [recip]))
    n_nans = int(features_df[all_feature_cols].isna().sum().sum())
    if n_nans > 0:
        print(f"\n   Filling {n_nans} missing feature values with 0.")
        features_df[all_feature_cols] = features_df[all_feature_cols].fillna(0)

    # --- Run every task ---
    perf_rows, comp_rows, failed_tasks = [], [], []
    for task_key in CONFIG["TASKS"]:
        try:
            out = run_task(task_key, features_df, feature_sets,
                           base_output_dir, start_time)
            perf_rows += out['performance']
            comp_rows += out['comparisons']
        except Exception as e:
            failed_tasks.append(task_key)
            print(f"\n   ERROR: task '{task_key}' failed: {e}\n")

    # --- Cross-task summary ---
    if perf_rows:
        perf_df = pd.DataFrame(perf_rows)
        perf_df.to_csv(base_output_dir / 'all_tasks_summary.csv', index=False)
        pd.DataFrame(comp_rows).to_csv(
            base_output_dir / 'all_tasks_comparison_stats.csv', index=False)

        print(f"\n{'='*70}")
        print(f"  CROSS-TASK SUMMARY — {CONFIG['DATABASE']} — "
              f"logistic regression PR-AUC")
        print(f"{'='*70}\n")
        print(f"  {'Task':<12} {'Representation':<20} {'PR-AUC':>18} {'F1':>18}")
        print(f"  {'-'*70}")
        for _, r in perf_df.iterrows():
            if np.isnan(r['pr_auc_mean']):
                continue
            print(f"  {r['task']:<12} {r['representation']:<20} "
                  f"{r['pr_auc_mean']:>10.4f} ± {r['pr_auc_std']:.4f}  "
                  f"{r['f1_mean']:>8.4f} ± {r['f1_std']:.4f}")
        print(f"\n  Saved: all_tasks_summary.csv, all_tasks_comparison_stats.csv")

    if failed_tasks:
        print(f"\n  WARNING: {len(failed_tasks)} task(s) failed: {failed_tasks}")

    print(f"\n{'='*70}")
    print("  COMPLETE")
    print(f"{'='*70}")
    elapsed = time.time() - start_time
    print(f"\nTotal time: {elapsed:.1f}s ({elapsed/60:.1f} min)")
# Out:
# Process started at 18:27:44
#
# ======================================================================
#   LOGISTIC REGRESSION BASELINE
#   Database : CORUM
#   Tasks    : ess, hpa, chembl
#   Output   : logistic/corum_second_testA
# ======================================================================
#
# 1. Loading feature data...
#    Higher-order (hb-graph) features shape : (5132, 35)
#    Pairwise features shape               : (5132, 9)
#    Combined shape                        : (5132, 43)
#
#    Derived 'flag_HasStoich' from 'stoich_MedianRatio':
#      curated   : 539 / 5132  (10.5%)
#      uncurated : 4593 / 5132  (89.5%)
#      cross-check vs stoich_protein.csv: exact match on all 5132 proteins ✓
#
#    Derived 'recip_MedComplexNodes' = 1 / (1 + protein_MedComplexNodes)  [TEST C control]
#      Spearman vs stoichiometry features (curated proteins only, n = 539):
#        stoich_WeightedTriangles           -0.704
#        stoich_AvgNeighbourDegreeStoich    -0.502
#        stoich_RangeComplexSize            -0.139
#        stoich_MedComplexSize              -0.461
#        stoich_MedianRatio                 +0.659
#        stoich_RangeRatio                  -0.149
#
#    Active Pairwise features (4):
#      - pair_Degree
#      - pair_LocalClustCoeff
#      - pair_TriangleCount
#      - pair_AvgNeighborDegree
#
#    Active Hypergraph features (8):
#      - base_Degree
#      - base_LocalClustCoeff
#      - base_TriangleCount
#      - base_UniquePartners
#      - base_AvgNeighbourDegree
#      - protein_RangeUniqueRatio
#      - protein_MedComplexNodes
#      - protein_RangeComplexNodes
#
#    Active Hypergraph + flag features (9):
#      - base_Degree
#      - base_LocalClustCoeff
#      - base_TriangleCount
#      - base_UniquePartners
#      - base_AvgNeighbourDegree
#      - protein_RangeUniqueRatio
#      - protein_MedComplexNodes
#      - protein_RangeComplexNodes
#      - flag_HasStoich [annotation flag]
#
#    Active Hypergraph + 1/size features (9):
#      - base_Degree
#      - base_LocalClustCoeff
#      - base_TriangleCount
#      - base_UniquePartners
#      - base_AvgNeighbourDegree
#      - protein_RangeUniqueRatio
#      - protein_MedComplexNodes
#      - protein_RangeComplexNodes
#      - recip_MedComplexNodes [1/size control]
#
#    Active HB-graph features (14):
#      - base_Degree
#      - base_LocalClustCoeff
#      - base_TriangleCount
#      - base_UniquePartners
#      - base_AvgNeighbourDegree
#      - stoich_WeightedTriangles [stoich]
#      - stoich_AvgNeighbourDegreeStoich [stoich]
#      - stoich_RangeComplexSize [stoich]
#      - stoich_MedComplexSize [stoich]
#      - stoich_MedianRatio [stoich]
#      - stoich_RangeRatio [stoich]
#      - protein_RangeUniqueRatio
#      - protein_MedComplexNodes
#      - protein_RangeComplexNodes
#
# ######################################################################
#   TASK: Gene Essentiality   [ess]
#   Splits : /Users/anitaapplegarth/github/dphil/protein_complexes/data/lookup_tables/corum/ess_protein_splits.csv
#   Output : logistic/corum_second_testA/ess
# ######################################################################
#
# 2. Loading pre-assigned splits...
#    File              : ess_protein_splits.csv
#    Last modified     : 2026-08-03 15:50:36.646443844
#    Splits file rows  : 256600
#    Unique proteins   : 5132
#    Number of splits  : 50
#    Unmapped labels (treated as Unknown): ['Unknown']
#    Labelled proteins : 5054  (17.3% positive)
#
#    Running 50 splits.
#
#    Split   1 ( 1/50)... train=3995 (16.8% pos)  test=1059 (19.3% pos)  |  Pair: 0.5334, Hyper: 0.5036, Hyper+flag: 0.5117, Hyper+1/sz: 0.5989, HB-graph: 0.5165  [Pair]
#    Split   2 ( 2/50)... train=4149 (17.2% pos)  test=905 (17.8% pos)  |  Pair: 0.3614, Hyper: 0.3993, Hyper+flag: 0.4052, Hyper+1/sz: 0.4128, HB-graph: 0.4039  [HB-graph]
#    Split   3 ( 3/50)... train=4179 (17.3% pos)  test=875 (17.7% pos)  |  Pair: 0.4051, Hyper: 0.4211, Hyper+flag: 0.4259, Hyper+1/sz: 0.4433, HB-graph: 0.4226  [HB-graph]
#    Split   4 ( 4/50)... train=4119 (16.5% pos)  test=935 (20.9% pos)  |  Pair: 0.4931, Hyper: 0.5118, Hyper+flag: 0.5150, Hyper+1/sz: 0.5599, HB-graph: 0.5203  [HB-graph]
#    Split   5 ( 5/50)... train=4100 (16.6% pos)  test=954 (20.4% pos)  |  Pair: 0.4127, Hyper: 0.4521, Hyper+flag: 0.4536, Hyper+1/sz: 0.4630, HB-graph: 0.4570  [HB-graph]
#    Split   6 ( 6/50)... train=4111 (17.9% pos)  test=943 (14.8% pos)  |  Pair: 0.3706, Hyper: 0.3581, Hyper+flag: 0.3670, Hyper+1/sz: 0.4373, HB-graph: 0.3727  [HB-graph]
#    Split   7 ( 7/50)... train=4127 (16.5% pos)  test=927 (21.1% pos)  |  Pair: 0.5770, Hyper: 0.5777, Hyper+flag: 0.5740, Hyper+1/sz: 0.6236, HB-graph: 0.5818  [HB-graph]
#    Split   8 ( 8/50)... train=4069 (17.5% pos)  test=985 (16.4% pos)  |  Pair: 0.3409, Hyper: 0.3727, Hyper+flag: 0.3693, Hyper+1/sz: 0.3828, HB-graph: 0.3713  [HB-graph]
#    Split   9 ( 9/50)... train=4078 (17.9% pos)  test=976 (14.9% pos)  |  Pair: 0.5048, Hyper: 0.4983, Hyper+flag: 0.5005, Hyper+1/sz: 0.5495, HB-graph: 0.5075  [HB-graph]
#    Split  10 (10/50)... train=3886 (18.1% pos)  test=1168 (14.7% pos)  |  Pair: 0.3541, Hyper: 0.3387, Hyper+flag: 0.3446, Hyper+1/sz: 0.3632, HB-graph: 0.3441  [Pair]
#    Split  11 (11/50)... train=3854 (18.4% pos)  test=1200 (14.0% pos)  |  Pair: 0.2854, Hyper: 0.2828, Hyper+flag: 0.2848, Hyper+1/sz: 0.3029, HB-graph: 0.2865  [HB-graph]
#    Split  12 (12/50)... train=4138 (18.2% pos)  test=916 (13.4% pos)  |  Pair: 0.2424, Hyper: 0.2615, Hyper+flag: 0.2637, Hyper+1/sz: 0.2934, HB-graph: 0.2674  [HB-graph]
#    Split  13 (13/50)... train=4036 (17.5% pos)  test=1018 (16.6% pos)  |  Pair: 0.5638, Hyper: 0.5855, Hyper+flag: 0.5968, Hyper+1/sz: 0.6260, HB-graph: 0.5872  [HB-graph]
#    Split  14 (14/50)... train=4072 (17.5% pos)  test=982 (16.8% pos)  |  Pair: 0.4948, Hyper: 0.4952, Hyper+flag: 0.5006, Hyper+1/sz: 0.5449, HB-graph: 0.5038  [HB-graph]
#    Split  15 (15/50)... train=4033 (18.4% pos)  test=1021 (13.1% pos)  |  Pair: 0.3218, Hyper: 0.2878, Hyper+flag: 0.2927, Hyper+1/sz: 0.3702, HB-graph: 0.2976  [Pair]
#    Split  16 (16/50)... train=3831 (16.8% pos)  test=1223 (19.0% pos)  |  Pair: 0.4869, Hyper: 0.5452, Hyper+flag: 0.5455, Hyper+1/sz: 0.5548, HB-graph: 0.5386  [HB-graph]
#    Split  17 (17/50)... train=3905 (16.3% pos)  test=1149 (20.7% pos)  |  Pair: 0.5560, Hyper: 0.5471, Hyper+flag: 0.5519, Hyper+1/sz: 0.5981, HB-graph: 0.5553  [Pair]
#    Split  18 (18/50)... train=4140 (18.2% pos)  test=914 (13.5% pos)  |  Pair: 0.2435, Hyper: 0.2522, Hyper+flag: 0.2549, Hyper+1/sz: 0.2540, HB-graph: 0.2589  [HB-graph]
#    Split  19 (19/50)... train=4047 (18.4% pos)  test=1007 (13.2% pos)  |  Pair: 0.3858, Hyper: 0.3709, Hyper+flag: 0.3741, Hyper+1/sz: 0.4401, HB-graph: 0.3796  [Pair]
#    Split  20 (20/50)... train=3941 (17.8% pos)  test=1113 (15.5% pos)  |  Pair: 0.4520, Hyper: 0.4546, Hyper+flag: 0.4544, Hyper+1/sz: 0.4886, HB-graph: 0.4578  [HB-graph]
#    Split  21 (21/50)... train=4087 (16.7% pos)  test=967 (20.0% pos)  |  Pair: 0.4712, Hyper: 0.4938, Hyper+flag: 0.4951, Hyper+1/sz: 0.5217, HB-graph: 0.4983  [HB-graph]
#    Split  22 (22/50)... train=4132 (16.4% pos)  test=922 (21.7% pos)  |  Pair: 0.5571, Hyper: 0.5558, Hyper+flag: 0.5591, Hyper+1/sz: 0.5883, HB-graph: 0.5637  [HB-graph]
#    Split  23 (23/50)... train=3920 (18.4% pos)  test=1134 (13.5% pos)  |  Pair: 0.2920, Hyper: 0.2888, Hyper+flag: 0.2916, Hyper+1/sz: 0.3038, HB-graph: 0.2936  [HB-graph]
#    Split  24 (24/50)... train=4008 (17.9% pos)  test=1046 (15.3% pos)  |  Pair: 0.4451, Hyper: 0.4512, Hyper+flag: 0.4574, Hyper+1/sz: 0.4866, HB-graph: 0.4556  [HB-graph]
#    Split  25 (25/50)... train=3908 (17.3% pos)  test=1146 (17.5% pos)  |  Pair: 0.3781, Hyper: 0.4029, Hyper+flag: 0.4052, Hyper+1/sz: 0.4205, HB-graph: 0.4065  [HB-graph]
#    Split  26 (26/50)... train=4165 (17.3% pos)  test=889 (17.7% pos)  |  Pair: 0.3881, Hyper: 0.4247, Hyper+flag: 0.4181, Hyper+1/sz: 0.4244, HB-graph: 0.4249  [HB-graph]
#    Split  27 (27/50)... train=4123 (17.0% pos)  test=931 (18.8% pos)  |  Pair: 0.3346, Hyper: 0.3346, Hyper+flag: 0.3385, Hyper+1/sz: 0.3426, HB-graph: 0.3387  [HB-graph]
#    Split  28 (28/50)... train=3926 (18.0% pos)  test=1128 (15.1% pos)  |  Pair: 0.5266, Hyper: 0.5015, Hyper+flag: 0.5083, Hyper+1/sz: 0.5678, HB-graph: 0.5123  [Pair]
#    Split  29 (29/50)... train=3924 (16.9% pos)  test=1130 (18.7% pos)  |  Pair: 0.5245, Hyper: 0.5326, Hyper+flag: 0.5378, Hyper+1/sz: 0.5748, HB-graph: 0.5374  [HB-graph]
#    Split  30 (30/50)... train=4080 (18.1% pos)  test=974 (14.2% pos)  |  Pair: 0.2855, Hyper: 0.2842, Hyper+flag: 0.2865, Hyper+1/sz: 0.3145, HB-graph: 0.2855  [Pair]
#    Split  31 (31/50)... train=4026 (17.8% pos)  test=1028 (15.4% pos)  |  Pair: 0.5405, Hyper: 0.5576, Hyper+flag: 0.5657, Hyper+1/sz: 0.5962, HB-graph: 0.5658  [HB-graph]
#    Split  32 (32/50)... train=4037 (18.3% pos)  test=1017 (13.7% pos)  |  Pair: 0.3714, Hyper: 0.3387, Hyper+flag: 0.3434, Hyper+1/sz: 0.4128, HB-graph: 0.3479  [Pair]
#    Split  33 (33/50)... train=4061 (17.8% pos)  test=993 (15.3% pos)  |  Pair: 0.4206, Hyper: 0.4125, Hyper+flag: 0.4159, Hyper+1/sz: 0.4327, HB-graph: 0.4199  [Pair]
#    Split  34 (34/50)... train=4027 (18.3% pos)  test=1027 (13.5% pos)  |  Pair: 0.3190, Hyper: 0.3537, Hyper+flag: 0.3523, Hyper+1/sz: 0.3719, HB-graph: 0.3554  [HB-graph]
#    Split  35 (35/50)... train=4143 (17.0% pos)  test=911 (19.0% pos)  |  Pair: 0.5436, Hyper: 0.5438, Hyper+flag: 0.5451, Hyper+1/sz: 0.5914, HB-graph: 0.5486  [HB-graph]
#    Split  36 (36/50)... train=4020 (17.0% pos)  test=1034 (18.8% pos)  |  Pair: 0.5450, Hyper: 0.5228, Hyper+flag: 0.5309, Hyper+1/sz: 0.5479, HB-graph: 0.5294  [Pair]
#    Split  37 (37/50)... train=4214 (18.0% pos)  test=840 (13.9% pos)  |  Pair: 0.3808, Hyper: 0.4084, Hyper+flag: 0.4141, Hyper+1/sz: 0.4597, HB-graph: 0.4123  [HB-graph]
#    Split  38 (38/50)... train=4003 (17.7% pos)  test=1051 (15.9% pos)  |  Pair: 0.4739, Hyper: 0.4637, Hyper+flag: 0.4644, Hyper+1/sz: 0.5394, HB-graph: 0.4671  [Pair]
#    Split  39 (39/50)... train=4079 (17.4% pos)  test=975 (17.1% pos)  |  Pair: 0.5205, Hyper: 0.5241, Hyper+flag: 0.5335, Hyper+1/sz: 0.5657, HB-graph: 0.5318  [HB-graph]
#    Split  40 (40/50)... train=4109 (17.5% pos)  test=945 (16.6% pos)  |  Pair: 0.3124, Hyper: 0.3075, Hyper+flag: 0.3116, Hyper+1/sz: 0.3499, HB-graph: 0.3100  [Pair]
#    Split  41 (41/50)... train=3845 (17.4% pos)  test=1209 (17.1% pos)  |  Pair: 0.4885, Hyper: 0.5041, Hyper+flag: 0.5084, Hyper+1/sz: 0.5566, HB-graph: 0.5128  [HB-graph]
#    Split  42 (42/50)... train=4029 (17.0% pos)  test=1025 (18.8% pos)  |  Pair: 0.6021, Hyper: 0.5854, Hyper+flag: 0.5895, Hyper+1/sz: 0.6171, HB-graph: 0.5914  [Pair]
#    Split  43 (43/50)... train=4035 (16.6% pos)  test=1019 (20.1% pos)  |  Pair: 0.4673, Hyper: 0.4959, Hyper+flag: 0.4969, Hyper+1/sz: 0.5215, HB-graph: 0.5017  [HB-graph]
#    Split  44 (44/50)... train=4065 (17.8% pos)  test=989 (15.6% pos)  |  Pair: 0.3826, Hyper: 0.3802, Hyper+flag: 0.3899, Hyper+1/sz: 0.4454, HB-graph: 0.3903  [HB-graph]
#    Split  45 (45/50)... train=3975 (17.5% pos)  test=1079 (16.9% pos)  |  Pair: 0.5978, Hyper: 0.5873, Hyper+flag: 0.5910, Hyper+1/sz: 0.6040, HB-graph: 0.5937  [Pair]
#    Split  46 (46/50)... train=4097 (17.2% pos)  test=957 (18.0% pos)  |  Pair: 0.3613, Hyper: 0.3483, Hyper+flag: 0.3521, Hyper+1/sz: 0.3707, HB-graph: 0.3537  [Pair]
#    Split  47 (47/50)... train=4045 (17.7% pos)  test=1009 (15.9% pos)  |  Pair: 0.4224, Hyper: 0.4360, Hyper+flag: 0.4414, Hyper+1/sz: 0.4789, HB-graph: 0.4425  [HB-graph]
#    Split  48 (48/50)... train=4097 (18.1% pos)  test=957 (13.9% pos)  |  Pair: 0.3792, Hyper: 0.3985, Hyper+flag: 0.3991, Hyper+1/sz: 0.4498, HB-graph: 0.3999  [HB-graph]
#    Split  49 (49/50)... train=3984 (17.6% pos)  test=1070 (16.3% pos)  |  Pair: 0.5063, Hyper: 0.5108, Hyper+flag: 0.5098, Hyper+1/sz: 0.5576, HB-graph: 0.5154  [HB-graph]
#    Split  50 (50/50)... train=3835 (16.6% pos)  test=1219 (19.5% pos)  |  Pair: 0.5417, Hyper: 0.5251, Hyper+flag: 0.5325, Hyper+1/sz: 0.5795, HB-graph: 0.5355  [Pair]
#
#    Completed 50/50 splits.
#
# 4. Statistical analysis...
#
# ======================================================================
#   STATISTICAL COMPARISON
# ======================================================================
#
#   Task            : Gene Essentiality
#   Model           : Logistic regression (L2, standardised)
#   Number of splits: 50
#
#   PR-AUC
#   Representation       Mean ± Std
#   ---------------------------------------------
#   Pairwise             0.4353 ± 0.0970
#   Hypergraph           0.4398 ± 0.0962
#   Hypergraph + flag    0.4434 ± 0.0967
#   Hypergraph + 1/size  0.4780 ± 0.1016
#   HB-graph             0.4454 ± 0.0965
#
#   F1 (positive class)
#   Representation       Mean ± Std
#   ---------------------------------------------
#   Pairwise             0.4567 ± 0.0681
#   Hypergraph           0.4391 ± 0.0953
#   Hypergraph + flag    0.4396 ± 0.0929
#   Hypergraph + 1/size  0.4690 ± 0.0765
#   HB-graph             0.4384 ± 0.0922
#
#   --- HB-graph vs Pairwise — headline representation effect ---
#   Mean diff : +0.0101 ± 0.0182   (Cohen's dz = +0.557)
#   Wins/Losses/Ties : 34/16/0   (n paired = 50)
#   Sign test p (one-sided) : 0.007673   (two-sided: 0.015347)
#
#
#   --- HB-graph vs Hypergraph — stoichiometry effect ---
#   Mean diff : +0.0056 ± 0.0037   (Cohen's dz = +1.521)
#   Wins/Losses/Ties : 48/2/0   (n paired = 50)
#   Sign test p (one-sided) : 0.000000   (two-sided: 0.000000)
#
#
#   --- Hypergraph vs Pairwise — representation effect alone ---
#   Mean diff : +0.0045 ± 0.0204   (Cohen's dz = +0.221)
#   Wins/Losses/Ties : 27/23/0   (n paired = 50)
#   Sign test p (one-sided) : 0.335906   (two-sided: 0.671811)
#
#
#   --- [TEST A] Hyper+flag vs Hypergraph — ANNOTATION PRESENCE alone ---
#   Mean diff : +0.0036 ± 0.0035   (Cohen's dz = +1.024)
#   Wins/Losses/Ties : 44/6/0   (n paired = 50)
#   Sign test p (one-sided) : 0.000000   (two-sided: 0.000000)
#
#
#   --- [TEST A] HB-graph vs Hyper+flag — STOICHIOMETRY VALUES, net of annotation ---
#   Mean diff : +0.0020 ± 0.0034   (Cohen's dz = +0.594)
#   Wins/Losses/Ties : 38/12/0   (n paired = 50)
#   Sign test p (one-sided) : 0.000153   (two-sided: 0.000306)
#
#
#   --- [TEST C] Hyper+1/size vs Hypergraph — what a pure size recoding buys ---
#   Mean diff : +0.0382 ± 0.0222   (Cohen's dz = +1.719)
#   Wins/Losses/Ties : 49/1/0   (n paired = 50)
#   Sign test p (one-sided) : 0.000000   (two-sided: 0.000000)
#
#
#   --- [TEST C] HB-graph vs Hyper+1/size — STOICHIOMETRY net of size recoding ---
#   Mean diff : -0.0326 ± 0.0201   (Cohen's dz = -1.622)
#   Wins/Losses/Ties : 2/48/0   (n paired = 50)
#   Sign test p (one-sided) : 1.000000   (two-sided: 0.000000)
#
#
# ======================================================================
#   TEST A — DECOMPOSITION OF THE STOICHIOMETRY EFFECT
# ======================================================================
#
#   Component                                      dPR-AUC     W/L  p (1-sided)
#   ------------------------------------------------------------------------------
#   Annotation presence   (flag - hypergraph)      +0.0036  44/6         0.0000
#   Stoichiometry values  (hb-graph - flag)        +0.0020  38/12        0.0002
#   ------------------------------------------------------------------------------
#   TOTAL  (hb-graph - hypergraph)                 +0.0056  48/2         0.0000
#
#   Annotation presence accounts for 64% of the total stoichiometry effect.
# ======================================================================
#
# ======================================================================
#   TEST C — RECIPROCAL-OF-SIZE CONTROL
# ======================================================================
#
#   Component                                      dPR-AUC     W/L  p (1-sided)
#   ------------------------------------------------------------------------------
#   1/size alone   (recip - hypergraph)            +0.0382  49/1         0.0000
#   Stoichiometry  (hb-graph - recip)              -0.0326   2/48        1.0000
#   ------------------------------------------------------------------------------
#   TOTAL  (hb-graph - hypergraph)                 +0.0056  48/2         0.0000
#
#   The reciprocal absorbs 679% of the total apparent stoichiometry effect.
#
#   VERDICT: DOES NOT SURVIVE. The apparent stoichiometric gain is accounted
#   for by 1/(complex size), which carries no copy-number information. H2
#   cannot be supported from these features under this model.
# ======================================================================
#
# 5. Generating plots...
#
# 6. Aggregating feature importance...
#
# ======================================================================
#   FEATURE IMPORTANCE (Permutation — mean PR-AUC drop)
# ======================================================================
#
#   Pairwise
#   Rank   Feature                                    Mean        Std     Median
#   --------------------------------------------------------------------------
#   1      pair_Degree                             0.26874    0.09347    0.27541
#   2      pair_LocalClustCoeff                    0.05126    0.01982    0.05131
#   3      pair_AvgNeighborDegree                  0.00402    0.00808    0.00501
#   4      pair_TriangleCount                     -0.00951    0.01673   -0.00751
#
#   Hypergraph
#   Rank   Feature                                    Mean        Std     Median
#   --------------------------------------------------------------------------
#   1      base_UniquePartners                     0.04987    0.04959    0.04121
#   2      protein_RangeComplexNodes               0.03758    0.01489    0.03788
#   3      protein_MedComplexNodes                 0.03224    0.01222    0.03131
#   4      base_TriangleCount                      0.02898    0.01562    0.02712
#   5      base_AvgNeighbourDegree                 0.01090    0.00636    0.00954
#   6      base_Degree                            -0.00136    0.00436   -0.00139
#   7      protein_RangeUniqueRatio               -0.00243    0.00310   -0.00272
#   8      base_LocalClustCoeff                   -0.00304    0.00529   -0.00241
#
#   Hypergraph + flag
#   Rank   Feature                                    Mean        Std     Median
#   --------------------------------------------------------------------------
#   1      base_UniquePartners                     0.04410    0.01821    0.04206
#   2      protein_RangeComplexNodes               0.03839    0.01522    0.03828
#   3      protein_MedComplexNodes                 0.03294    0.01219    0.03296
#   4      base_TriangleCount                      0.02744    0.01362    0.02583
#   5      base_AvgNeighbourDegree                 0.01284    0.00745    0.01247
#   6      flag_HasStoich                          0.00626    0.00345    0.00614
#   7      base_Degree                            -0.00125    0.00449   -0.00150
#   8      protein_RangeUniqueRatio               -0.00165    0.00314   -0.00224
#   9      base_LocalClustCoeff                   -0.00364    0.00497   -0.00277
#
#   Hypergraph + 1/size
#   Rank   Feature                                    Mean        Std     Median
#   --------------------------------------------------------------------------
#   1      recip_MedComplexNodes                   0.18880    0.09280    0.20998
#   2      base_AvgNeighbourDegree                 0.01969    0.01388    0.02343
#   3      base_UniquePartners                     0.01504    0.00691    0.01373
#   4      protein_RangeComplexNodes               0.01386    0.00853    0.01465
#   5      base_TriangleCount                      0.01117    0.00718    0.01085
#   6      protein_MedComplexNodes                 0.00437    0.00851    0.00436
#   7      base_Degree                             0.00227    0.00625    0.00217
#   8      protein_RangeUniqueRatio                0.00099    0.00419    0.00099
#   9      base_LocalClustCoeff                   -0.00058    0.00229   -0.00013
#
#   HB-graph
#   Rank   Feature                                    Mean        Std     Median
#   --------------------------------------------------------------------------
#   1      base_UniquePartners                     0.04305    0.01707    0.03993
#   2      protein_RangeComplexNodes               0.03759    0.01413    0.03764
#   3      protein_MedComplexNodes                 0.03182    0.01127    0.03131
#   4      base_TriangleCount                      0.02948    0.01492    0.02721
#   5      base_AvgNeighbourDegree                 0.01131    0.00467    0.01156
#   6      stoich_MedianRatio                      0.00802    0.00338    0.00774
#   7      stoich_WeightedTriangles                0.00141    0.00179    0.00104
#   8      stoich_AvgNeighbourDegreeStoich         0.00136    0.00100    0.00125
#   9      stoich_MedComplexSize                   0.00037    0.00134    0.00017
#   10     stoich_RangeComplexSize                 0.00010    0.00038    0.00009
#   11     stoich_RangeRatio                       0.00005    0.00078    0.00015
#   12     base_Degree                            -0.00040    0.00422   -0.00042
#   13     protein_RangeUniqueRatio               -0.00082    0.00272   -0.00115
#   14     base_LocalClustCoeff                   -0.00301    0.00484   -0.00204
#
#   Note: higher = more important; negative = likely noise.
#
#    >>> 'flag_HasStoich' ranks 6 of 9 in the hypergraph+flag model (mean importance 0.00626)
#
# 7. Saving outputs...
#    Saved: split_results.csv
#    Saved: comparison_stats.csv
#    Saved: pairwise_predictions.csv
#    Saved: pairwise_feature_importance.csv
#    Saved: hypergraph_predictions.csv
#    Saved: hypergraph_feature_importance.csv
#    Saved: hyper_flag_predictions.csv
#    Saved: hyper_flag_feature_importance.csv
#    Saved: hyper_recip_predictions.csv
#    Saved: hyper_recip_feature_importance.csv
#    Saved: hb_graph_predictions.csv
#    Saved: hb_graph_feature_importance.csv
#    Saved: best_C_per_split.csv
#    Saved: statistical_summary.txt
#
# ######################################################################
#   TASK: Drug Target Prediction (HPA)   [hpa]
#   Splits : /Users/anitaapplegarth/github/dphil/protein_complexes/data/lookup_tables/corum/hpa_protein_splits.csv
#   Output : logistic/corum_second_testA/hpa
# ######################################################################
#
# 2. Loading pre-assigned splits...
#    File              : hpa_protein_splits.csv
#    Last modified     : 2026-08-03 15:47:51.526610851
#    Splits file rows  : 256600
#    Unique proteins   : 5132
#    Number of splits  : 50
#    Labelled proteins : 5122  (11.6% positive)
#
#    Running 50 splits.
#
#    Split   1 ( 1/50)... train=4051 (11.6% pos)  test=1071 (11.6% pos)  |  Pair: 0.2413, Hyper: 0.3933, Hyper+flag: 0.4255, Hyper+1/sz: 0.4604, HB-graph: 0.4465  [HB-graph]
#    Split   2 ( 2/50)... train=4204 (11.3% pos)  test=918 (12.5% pos)  |  Pair: 0.3272, Hyper: 0.4293, Hyper+flag: 0.4425, Hyper+1/sz: 0.5657, HB-graph: 0.4533  [HB-graph]
#    Split   3 ( 3/50)... train=4163 (11.9% pos)  test=959 (10.1% pos)  |  Pair: 0.2537, Hyper: 0.3949, Hyper+flag: 0.4192, Hyper+1/sz: 0.4592, HB-graph: 0.4313  [HB-graph]
#    Split   4 ( 4/50)... train=4095 (11.7% pos)  test=1027 (10.8% pos)  |  Pair: 0.2377, Hyper: 0.4277, Hyper+flag: 0.4537, Hyper+1/sz: 0.4720, HB-graph: 0.4517  [HB-graph]
#    Split   5 ( 5/50)... train=4161 (11.5% pos)  test=961 (11.8% pos)  |  Pair: 0.2000, Hyper: 0.3390, Hyper+flag: 0.3504, Hyper+1/sz: 0.3380, HB-graph: 0.3525  [HB-graph]
#    Split   6 ( 6/50)... train=4164 (11.5% pos)  test=958 (12.0% pos)  |  Pair: 0.2685, Hyper: 0.4147, Hyper+flag: 0.4561, Hyper+1/sz: 0.4636, HB-graph: 0.4835  [HB-graph]
#    Split   7 ( 7/50)... train=4175 (11.4% pos)  test=947 (12.1% pos)  |  Pair: 0.2726, Hyper: 0.3295, Hyper+flag: 0.3861, Hyper+1/sz: 0.4392, HB-graph: 0.3883  [HB-graph]
#    Split   8 ( 8/50)... train=4199 (11.8% pos)  test=923 (10.4% pos)  |  Pair: 0.2392, Hyper: 0.2998, Hyper+flag: 0.3782, Hyper+1/sz: 0.3767, HB-graph: 0.3880  [HB-graph]
#    Split   9 ( 9/50)... train=4125 (11.2% pos)  test=997 (13.0% pos)  |  Pair: 0.2507, Hyper: 0.3987, Hyper+flag: 0.4609, Hyper+1/sz: 0.4867, HB-graph: 0.4739  [HB-graph]
#    Split  10 (10/50)... train=4074 (11.7% pos)  test=1048 (11.1% pos)  |  Pair: 0.2878, Hyper: 0.3342, Hyper+flag: 0.3819, Hyper+1/sz: 0.4119, HB-graph: 0.3994  [HB-graph]
#    Split  11 (11/50)... train=4079 (11.5% pos)  test=1043 (11.9% pos)  |  Pair: 0.2659, Hyper: 0.3884, Hyper+flag: 0.4232, Hyper+1/sz: 0.4310, HB-graph: 0.4152  [HB-graph]
#    Split  12 (12/50)... train=4033 (11.3% pos)  test=1089 (12.5% pos)  |  Pair: 0.2728, Hyper: 0.3459, Hyper+flag: 0.3744, Hyper+1/sz: 0.4027, HB-graph: 0.3857  [HB-graph]
#    Split  13 (13/50)... train=4082 (11.2% pos)  test=1040 (13.0% pos)  |  Pair: 0.2959, Hyper: 0.3595, Hyper+flag: 0.4021, Hyper+1/sz: 0.4541, HB-graph: 0.4171  [HB-graph]
#    Split  14 (14/50)... train=4124 (11.5% pos)  test=998 (11.9% pos)  |  Pair: 0.3040, Hyper: 0.3358, Hyper+flag: 0.3826, Hyper+1/sz: 0.3978, HB-graph: 0.3911  [HB-graph]
#    Split  15 (15/50)... train=4087 (11.3% pos)  test=1035 (12.5% pos)  |  Pair: 0.2402, Hyper: 0.4298, Hyper+flag: 0.4348, Hyper+1/sz: 0.4919, HB-graph: 0.4024  [HB-graph]
#    Split  16 (16/50)... train=3987 (11.7% pos)  test=1135 (11.1% pos)  |  Pair: 0.2137, Hyper: 0.2967, Hyper+flag: 0.3291, Hyper+1/sz: 0.3414, HB-graph: 0.3369  [HB-graph]
#    Split  17 (17/50)... train=3983 (11.2% pos)  test=1139 (12.8% pos)  |  Pair: 0.2853, Hyper: 0.3869, Hyper+flag: 0.4048, Hyper+1/sz: 0.4441, HB-graph: 0.3730  [HB-graph]
#    Split  18 (18/50)... train=4230 (11.3% pos)  test=892 (12.7% pos)  |  Pair: 0.3510, Hyper: 0.2732, Hyper+flag: 0.3567, Hyper+1/sz: 0.4019, HB-graph: 0.3553  [HB-graph]
#    Split  19 (19/50)... train=4314 (11.7% pos)  test=808 (10.9% pos)  |  Pair: 0.2636, Hyper: 0.3712, Hyper+flag: 0.3867, Hyper+1/sz: 0.4683, HB-graph: 0.3392  [HB-graph]
#    Split  20 (20/50)... train=3992 (11.9% pos)  test=1130 (10.4% pos)  |  Pair: 0.2464, Hyper: 0.3526, Hyper+flag: 0.3724, Hyper+1/sz: 0.4209, HB-graph: 0.3863  [HB-graph]
#    Split  21 (21/50)... train=3959 (11.9% pos)  test=1163 (10.4% pos)  |  Pair: 0.2583, Hyper: 0.3666, Hyper+flag: 0.4082, Hyper+1/sz: 0.4387, HB-graph: 0.4252  [HB-graph]
#    Split  22 (22/50)... train=4090 (11.8% pos)  test=1032 (10.7% pos)  |  Pair: 0.2548, Hyper: 0.3636, Hyper+flag: 0.3706, Hyper+1/sz: 0.4286, HB-graph: 0.3856  [HB-graph]
#    Split  23 (23/50)... train=3952 (11.2% pos)  test=1170 (12.7% pos)  |  Pair: 0.2799, Hyper: 0.3130, Hyper+flag: 0.3311, Hyper+1/sz: 0.3887, HB-graph: 0.3418  [HB-graph]
#    Split  24 (24/50)... train=4063 (11.3% pos)  test=1059 (12.6% pos)  |  Pair: 0.2886, Hyper: 0.4156, Hyper+flag: 0.4541, Hyper+1/sz: 0.4419, HB-graph: 0.4199  [HB-graph]
#    Split  25 (25/50)... train=3968 (11.5% pos)  test=1154 (11.8% pos)  |  Pair: 0.2578, Hyper: 0.3792, Hyper+flag: 0.4020, Hyper+1/sz: 0.4659, HB-graph: 0.4123  [HB-graph]
#    Split  26 (26/50)... train=4221 (11.8% pos)  test=901 (10.5% pos)  |  Pair: 0.2178, Hyper: 0.2705, Hyper+flag: 0.2803, Hyper+1/sz: 0.3185, HB-graph: 0.2866  [HB-graph]
#    Split  27 (27/50)... train=4154 (11.7% pos)  test=968 (11.2% pos)  |  Pair: 0.3371, Hyper: 0.3429, Hyper+flag: 0.4072, Hyper+1/sz: 0.4632, HB-graph: 0.4324  [HB-graph]
#    Split  28 (28/50)... train=4209 (11.4% pos)  test=913 (12.3% pos)  |  Pair: 0.2255, Hyper: 0.3068, Hyper+flag: 0.3396, Hyper+1/sz: 0.3680, HB-graph: 0.3473  [HB-graph]
#    Split  29 (29/50)... train=4206 (11.6% pos)  test=916 (11.5% pos)  |  Pair: 0.3172, Hyper: 0.3488, Hyper+flag: 0.3658, Hyper+1/sz: 0.4133, HB-graph: 0.3773  [HB-graph]
#    Split  30 (30/50)... train=4141 (11.6% pos)  test=981 (11.3% pos)  |  Pair: 0.2414, Hyper: 0.2863, Hyper+flag: 0.3592, Hyper+1/sz: 0.3371, HB-graph: 0.3534  [HB-graph]
#    Split  31 (31/50)... train=4074 (11.3% pos)  test=1048 (12.6% pos)  |  Pair: 0.2526, Hyper: 0.4404, Hyper+flag: 0.4280, Hyper+1/sz: 0.4690, HB-graph: 0.4203  [HB-graph]
#    Split  32 (32/50)... train=3950 (11.7% pos)  test=1172 (11.2% pos)  |  Pair: 0.2673, Hyper: 0.3100, Hyper+flag: 0.3392, Hyper+1/sz: 0.3759, HB-graph: 0.3497  [HB-graph]
#    Split  33 (33/50)... train=4176 (11.8% pos)  test=946 (10.6% pos)  |  Pair: 0.3213, Hyper: 0.3361, Hyper+flag: 0.3928, Hyper+1/sz: 0.4520, HB-graph: 0.3910  [HB-graph]
#    Split  34 (34/50)... train=4077 (11.8% pos)  test=1045 (10.7% pos)  |  Pair: 0.2293, Hyper: 0.3429, Hyper+flag: 0.3674, Hyper+1/sz: 0.4181, HB-graph: 0.3816  [HB-graph]
#    Split  35 (35/50)... train=4198 (11.7% pos)  test=924 (10.7% pos)  |  Pair: 0.2702, Hyper: 0.3258, Hyper+flag: 0.3375, Hyper+1/sz: 0.3956, HB-graph: 0.3485  [HB-graph]
#    Split  36 (36/50)... train=4144 (11.2% pos)  test=978 (13.0% pos)  |  Pair: 0.2922, Hyper: 0.3399, Hyper+flag: 0.3719, Hyper+1/sz: 0.4178, HB-graph: 0.3904  [HB-graph]
#    Split  37 (37/50)... train=4264 (11.5% pos)  test=858 (12.0% pos)  |  Pair: 0.2045, Hyper: 0.3278, Hyper+flag: 0.3450, Hyper+1/sz: 0.3692, HB-graph: 0.3555  [HB-graph]
#    Split  38 (38/50)... train=4111 (11.2% pos)  test=1011 (13.0% pos)  |  Pair: 0.3109, Hyper: 0.4073, Hyper+flag: 0.4243, Hyper+1/sz: 0.4091, HB-graph: 0.4055  [HB-graph]
#    Split  39 (39/50)... train=4141 (11.5% pos)  test=981 (11.8% pos)  |  Pair: 0.2240, Hyper: 0.3141, Hyper+flag: 0.3472, Hyper+1/sz: 0.3517, HB-graph: 0.3524  [HB-graph]
#    Split  40 (40/50)... train=4154 (11.3% pos)  test=968 (12.8% pos)  |  Pair: 0.3433, Hyper: 0.3603, Hyper+flag: 0.4068, Hyper+1/sz: 0.4920, HB-graph: 0.4136  [HB-graph]
#    Split  41 (41/50)... train=4067 (11.3% pos)  test=1055 (12.4% pos)  |  Pair: 0.2868, Hyper: 0.3542, Hyper+flag: 0.3781, Hyper+1/sz: 0.3999, HB-graph: 0.3911  [HB-graph]
#    Split  42 (42/50)... train=4085 (11.6% pos)  test=1037 (11.6% pos)  |  Pair: 0.2474, Hyper: 0.3476, Hyper+flag: 0.3672, Hyper+1/sz: 0.3907, HB-graph: 0.3663  [HB-graph]
#    Split  43 (43/50)... train=4086 (11.4% pos)  test=1036 (12.3% pos)  |  Pair: 0.2273, Hyper: 0.4360, Hyper+flag: 0.4802, Hyper+1/sz: 0.4470, HB-graph: 0.4637  [HB-graph]
#    Split  44 (44/50)... train=4125 (11.8% pos)  test=997 (10.5% pos)  |  Pair: 0.2520, Hyper: 0.3752, Hyper+flag: 0.4394, Hyper+1/sz: 0.4952, HB-graph: 0.4515  [HB-graph]
#    Split  45 (45/50)... train=4051 (11.2% pos)  test=1071 (12.8% pos)  |  Pair: 0.2595, Hyper: 0.4144, Hyper+flag: 0.4232, Hyper+1/sz: 0.4762, HB-graph: 0.4375  [HB-graph]
#    Split  46 (46/50)... train=4156 (11.7% pos)  test=966 (10.9% pos)  |  Pair: 0.2880, Hyper: 0.3650, Hyper+flag: 0.3892, Hyper+1/sz: 0.4622, HB-graph: 0.3889  [HB-graph]
#    Split  47 (47/50)... train=4100 (11.7% pos)  test=1022 (10.9% pos)  |  Pair: 0.2890, Hyper: 0.3519, Hyper+flag: 0.3742, Hyper+1/sz: 0.4134, HB-graph: 0.3843  [HB-graph]
#    Split  48 (48/50)... train=4151 (11.8% pos)  test=971 (10.6% pos)  |  Pair: 0.2441, Hyper: 0.4167, Hyper+flag: 0.3898, Hyper+1/sz: 0.4546, HB-graph: 0.4087  [HB-graph]
#    Split  49 (49/50)... train=4041 (11.2% pos)  test=1081 (12.8% pos)  |  Pair: 0.2547, Hyper: 0.3168, Hyper+flag: 0.3702, Hyper+1/sz: 0.4083, HB-graph: 0.3991  [HB-graph]
#    Split  50 (50/50)... train=3892 (11.9% pos)  test=1230 (10.5% pos)  |  Pair: 0.2512, Hyper: 0.3785, Hyper+flag: 0.4021, Hyper+1/sz: 0.4928, HB-graph: 0.4162  [HB-graph]
#
#    Completed 50/50 splits.
#
# 4. Statistical analysis...
#
# ======================================================================
#   STATISTICAL COMPARISON
# ======================================================================
#
#   Task            : Drug Target Prediction (HPA)
#   Model           : Logistic regression (L2, standardised)
#   Number of splits: 50
#
#   PR-AUC
#   Representation       Mean ± Std
#   ---------------------------------------------
#   Pairwise             0.2662 ± 0.0350
#   Hypergraph           0.3591 ± 0.0435
#   Hypergraph + flag    0.3903 ± 0.0400
#   Hypergraph + 1/size  0.4276 ± 0.0489
#   HB-graph             0.3954 ± 0.0397
#
#   F1 (positive class)
#   Representation       Mean ± Std
#   ---------------------------------------------
#   Pairwise             0.3378 ± 0.0249
#   Hypergraph           0.3469 ± 0.0257
#   Hypergraph + flag    0.3928 ± 0.0342
#   Hypergraph + 1/size  0.3580 ± 0.0237
#   HB-graph             0.3913 ± 0.0333
#
#   --- HB-graph vs Pairwise — headline representation effect ---
#   Mean diff : +0.1291 ± 0.0482   (Cohen's dz = +2.676)
#   Wins/Losses/Ties : 50/0/0   (n paired = 50)
#   Sign test p (one-sided) : 0.000000   (two-sided: 0.000000)
#
#
#   --- HB-graph vs Hypergraph — stoichiometry effect ---
#   Mean diff : +0.0362 ± 0.0286   (Cohen's dz = +1.265)
#   Wins/Losses/Ties : 44/6/0   (n paired = 50)
#   Sign test p (one-sided) : 0.000000   (two-sided: 0.000000)
#
#
#   --- Hypergraph vs Pairwise — representation effect alone ---
#   Mean diff : +0.0929 ± 0.0555   (Cohen's dz = +1.674)
#   Wins/Losses/Ties : 49/1/0   (n paired = 50)
#   Sign test p (one-sided) : 0.000000   (two-sided: 0.000000)
#
#
#   --- [TEST A] Hyper+flag vs Hypergraph — ANNOTATION PRESENCE alone ---
#   Mean diff : +0.0311 ± 0.0219   (Cohen's dz = +1.423)
#   Wins/Losses/Ties : 48/2/0   (n paired = 50)
#   Sign test p (one-sided) : 0.000000   (two-sided: 0.000000)
#
#
#   --- [TEST A] HB-graph vs Hyper+flag — STOICHIOMETRY VALUES, net of annotation ---
#   Mean diff : +0.0051 ± 0.0158   (Cohen's dz = +0.323)
#   Wins/Losses/Ties : 36/14/0   (n paired = 50)
#   Sign test p (one-sided) : 0.001301   (two-sided: 0.002602)
#
#
#   --- [TEST C] Hyper+1/size vs Hypergraph — what a pure size recoding buys ---
#   Mean diff : +0.0685 ± 0.0322   (Cohen's dz = +2.129)
#   Wins/Losses/Ties : 49/1/0   (n paired = 50)
#   Sign test p (one-sided) : 0.000000   (two-sided: 0.000000)
#
#
#   --- [TEST C] HB-graph vs Hyper+1/size — STOICHIOMETRY net of size recoding ---
#   Mean diff : -0.0323 ± 0.0314   (Cohen's dz = -1.029)
#   Wins/Losses/Ties : 6/44/0   (n paired = 50)
#   Sign test p (one-sided) : 1.000000   (two-sided: 0.000000)
#
#
# ======================================================================
#   TEST A — DECOMPOSITION OF THE STOICHIOMETRY EFFECT
# ======================================================================
#
#   Component                                      dPR-AUC     W/L  p (1-sided)
#   ------------------------------------------------------------------------------
#   Annotation presence   (flag - hypergraph)      +0.0311  48/2         0.0000
#   Stoichiometry values  (hb-graph - flag)        +0.0051  36/14        0.0013
#   ------------------------------------------------------------------------------
#   TOTAL  (hb-graph - hypergraph)                 +0.0362  44/6         0.0000
#
#   Annotation presence accounts for 86% of the total stoichiometry effect.
# ======================================================================
#
# ======================================================================
#   TEST C — RECIPROCAL-OF-SIZE CONTROL
# ======================================================================
#
#   Component                                      dPR-AUC     W/L  p (1-sided)
#   ------------------------------------------------------------------------------
#   1/size alone   (recip - hypergraph)            +0.0685  49/1         0.0000
#   Stoichiometry  (hb-graph - recip)              -0.0323   6/44        1.0000
#   ------------------------------------------------------------------------------
#   TOTAL  (hb-graph - hypergraph)                 +0.0362  44/6         0.0000
#
#   The reciprocal absorbs 189% of the total apparent stoichiometry effect.
#
#   VERDICT: DOES NOT SURVIVE. The apparent stoichiometric gain is accounted
#   for by 1/(complex size), which carries no copy-number information. H2
#   cannot be supported from these features under this model.
# ======================================================================
#
# 5. Generating plots...
#
# 6. Aggregating feature importance...
#
# ======================================================================
#   FEATURE IMPORTANCE (Permutation — mean PR-AUC drop)
# ======================================================================
#
#   Pairwise
#   Rank   Feature                                    Mean        Std     Median
#   --------------------------------------------------------------------------
#   1      pair_LocalClustCoeff                    0.09423    0.02553    0.09244
#   2      pair_AvgNeighborDegree                  0.08688    0.02970    0.08390
#   3      pair_Degree                             0.04748    0.02566    0.04445
#   4      pair_TriangleCount                      0.00150    0.00838    0.00007
#
#   Hypergraph
#   Rank   Feature                                    Mean        Std     Median
#   --------------------------------------------------------------------------
#   1      base_UniquePartners                     0.13891    0.03251    0.13857
#   2      protein_RangeUniqueRatio                0.13118    0.03952    0.12912
#   3      base_Degree                             0.12312    0.05018    0.11567
#   4      base_TriangleCount                      0.11556    0.03354    0.11828
#   5      protein_MedComplexNodes                 0.05885    0.02706    0.05510
#   6      protein_RangeComplexNodes               0.03480    0.03264    0.02872
#   7      base_AvgNeighbourDegree                 0.03106    0.01293    0.03253
#   8      base_LocalClustCoeff                    0.00523    0.00361    0.00519
#
#   Hypergraph + flag
#   Rank   Feature                                    Mean        Std     Median
#   --------------------------------------------------------------------------
#   1      base_UniquePartners                     0.14132    0.03741    0.14679
#   2      base_TriangleCount                      0.11735    0.03462    0.11879
#   3      base_Degree                             0.11282    0.04195    0.10925
#   4      flag_HasStoich                          0.09549    0.02014    0.09555
#   5      protein_MedComplexNodes                 0.04484    0.02002    0.04569
#   6      protein_RangeUniqueRatio                0.04404    0.02148    0.04247
#   7      protein_RangeComplexNodes               0.02353    0.02937    0.01206
#   8      base_AvgNeighbourDegree                 0.02053    0.01090    0.02163
#   9      base_LocalClustCoeff                    0.00254    0.00280    0.00266
#
#   Hypergraph + 1/size
#   Rank   Feature                                    Mean        Std     Median
#   --------------------------------------------------------------------------
#   1      recip_MedComplexNodes                   0.22324    0.03528    0.22403
#   2      protein_RangeUniqueRatio                0.10968    0.03218    0.10200
#   3      base_Degree                             0.06804    0.03770    0.06416
#   4      base_AvgNeighbourDegree                 0.02191    0.01234    0.02318
#   5      protein_MedComplexNodes                 0.01418    0.02080    0.00538
#   6      base_UniquePartners                     0.01385    0.02482    0.00399
#   7      protein_RangeComplexNodes               0.00320    0.00637    0.00237
#   8      base_TriangleCount                      0.00030    0.00562   -0.00118
#   9      base_LocalClustCoeff                   -0.00053    0.00218   -0.00087
#
#   HB-graph
#   Rank   Feature                                    Mean        Std     Median
#   --------------------------------------------------------------------------
#   1      base_UniquePartners                     0.13277    0.03985    0.13788
#   2      base_TriangleCount                      0.10958    0.03664    0.10563
#   3      base_Degree                             0.10753    0.04025    0.10560
#   4      stoich_MedianRatio                      0.10615    0.02308    0.10687
#   5      protein_MedComplexNodes                 0.03655    0.01595    0.03622
#   6      protein_RangeUniqueRatio                0.02514    0.01385    0.02386
#   7      base_AvgNeighbourDegree                 0.02098    0.01188    0.02192
#   8      protein_RangeComplexNodes               0.01755    0.02202    0.00883
#   9      stoich_AvgNeighbourDegreeStoich         0.00442    0.00659    0.00481
#   10     stoich_RangeComplexSize                 0.00277    0.00513    0.00286
#   11     stoich_WeightedTriangles                0.00255    0.00390    0.00225
#   12     base_LocalClustCoeff                    0.00207    0.00246    0.00246
#   13     stoich_RangeRatio                       0.00148    0.00621    0.00169
#   14     stoich_MedComplexSize                  -0.00187    0.00386   -0.00032
#
#   Note: higher = more important; negative = likely noise.
#
#    >>> 'flag_HasStoich' ranks 4 of 9 in the hypergraph+flag model (mean importance 0.09549)
#
# 7. Saving outputs...
#    Saved: split_results.csv
#    Saved: comparison_stats.csv
#    Saved: pairwise_predictions.csv
#    Saved: pairwise_feature_importance.csv
#    Saved: hypergraph_predictions.csv
#    Saved: hypergraph_feature_importance.csv
#    Saved: hyper_flag_predictions.csv
#    Saved: hyper_flag_feature_importance.csv
#    Saved: hyper_recip_predictions.csv
#    Saved: hyper_recip_feature_importance.csv
#    Saved: hb_graph_predictions.csv
#    Saved: hb_graph_feature_importance.csv
#    Saved: best_C_per_split.csv
#    Saved: statistical_summary.txt
#
# ######################################################################
#   TASK: Drug Target Prediction (ChEMBL)   [chembl]
#   Splits : /Users/anitaapplegarth/github/dphil/protein_complexes/data/lookup_tables/corum/chembl_protein_splits.csv
#   Output : logistic/corum_second_testA/chembl
# ######################################################################
#
# 2. Loading pre-assigned splits...
#    File              : chembl_protein_splits.csv
#    Last modified     : 2026-08-03 15:52:59.709674120
#    Splits file rows  : 256600
#    Unique proteins   : 5132
#    Number of splits  : 50
#    Labelled proteins : 5122  (12.0% positive)
#
#    Running 50 splits.
#
#    Split   1 ( 1/50)... train=4051 (12.0% pos)  test=1071 (12.1% pos)  |  Pair: 0.2494, Hyper: 0.3552, Hyper+flag: 0.3821, Hyper+1/sz: 0.4061, HB-graph: 0.4028  [HB-graph]
#    Split   2 ( 2/50)... train=4192 (12.2% pos)  test=930 (11.2% pos)  |  Pair: 0.2786, Hyper: 0.3273, Hyper+flag: 0.3400, Hyper+1/sz: 0.3994, HB-graph: 0.3727  [HB-graph]
#    Split   3 ( 3/50)... train=3971 (12.2% pos)  test=1151 (11.4% pos)  |  Pair: 0.2241, Hyper: 0.3319, Hyper+flag: 0.3532, Hyper+1/sz: 0.3740, HB-graph: 0.3593  [HB-graph]
#    Split   4 ( 4/50)... train=4212 (12.4% pos)  test=910 (10.5% pos)  |  Pair: 0.2869, Hyper: 0.3142, Hyper+flag: 0.3463, Hyper+1/sz: 0.3883, HB-graph: 0.3760  [HB-graph]
#    Split   5 ( 5/50)... train=4146 (12.4% pos)  test=976 (10.7% pos)  |  Pair: 0.2329, Hyper: 0.3147, Hyper+flag: 0.3195, Hyper+1/sz: 0.3735, HB-graph: 0.3425  [HB-graph]
#    Split   6 ( 6/50)... train=4208 (12.3% pos)  test=914 (10.9% pos)  |  Pair: 0.2965, Hyper: 0.3977, Hyper+flag: 0.4019, Hyper+1/sz: 0.4328, HB-graph: 0.4194  [HB-graph]
#    Split   7 ( 7/50)... train=4175 (12.3% pos)  test=947 (11.1% pos)  |  Pair: 0.2132, Hyper: 0.3019, Hyper+flag: 0.3397, Hyper+1/sz: 0.3655, HB-graph: 0.3634  [HB-graph]
#    Split   8 ( 8/50)... train=4199 (12.0% pos)  test=923 (12.2% pos)  |  Pair: 0.2613, Hyper: 0.3604, Hyper+flag: 0.4140, Hyper+1/sz: 0.3754, HB-graph: 0.4289  [HB-graph]
#    Split   9 ( 9/50)... train=4125 (12.1% pos)  test=997 (11.8% pos)  |  Pair: 0.2073, Hyper: 0.3866, Hyper+flag: 0.4023, Hyper+1/sz: 0.4124, HB-graph: 0.4336  [HB-graph]
#    Split  10 (10/50)... train=4074 (12.2% pos)  test=1048 (11.5% pos)  |  Pair: 0.3083, Hyper: 0.4176, Hyper+flag: 0.4662, Hyper+1/sz: 0.5155, HB-graph: 0.4983  [HB-graph]
#    Split  11 (11/50)... train=4137 (12.1% pos)  test=985 (11.7% pos)  |  Pair: 0.3183, Hyper: 0.4200, Hyper+flag: 0.4622, Hyper+1/sz: 0.4804, HB-graph: 0.4977  [HB-graph]
#    Split  12 (12/50)... train=4196 (11.8% pos)  test=926 (13.2% pos)  |  Pair: 0.3313, Hyper: 0.4688, Hyper+flag: 0.4949, Hyper+1/sz: 0.5367, HB-graph: 0.5215  [HB-graph]
#    Split  13 (13/50)... train=4195 (12.2% pos)  test=927 (11.4% pos)  |  Pair: 0.2557, Hyper: 0.3951, Hyper+flag: 0.4104, Hyper+1/sz: 0.4168, HB-graph: 0.4250  [HB-graph]
#    Split  14 (14/50)... train=4124 (12.3% pos)  test=998 (11.0% pos)  |  Pair: 0.2290, Hyper: 0.3234, Hyper+flag: 0.3561, Hyper+1/sz: 0.3905, HB-graph: 0.3939  [HB-graph]
#    Split  15 (15/50)... train=4059 (12.1% pos)  test=1063 (11.9% pos)  |  Pair: 0.3017, Hyper: 0.4071, Hyper+flag: 0.4366, Hyper+1/sz: 0.4768, HB-graph: 0.4490  [HB-graph]
#    Split  16 (16/50)... train=3987 (12.0% pos)  test=1135 (12.3% pos)  |  Pair: 0.2369, Hyper: 0.3205, Hyper+flag: 0.3156, Hyper+1/sz: 0.3668, HB-graph: 0.3407  [HB-graph]
#    Split  17 (17/50)... train=3963 (12.4% pos)  test=1159 (10.8% pos)  |  Pair: 0.2753, Hyper: 0.3347, Hyper+flag: 0.3809, Hyper+1/sz: 0.4406, HB-graph: 0.4138  [HB-graph]
#    Split  18 (18/50)... train=4230 (12.2% pos)  test=892 (11.5% pos)  |  Pair: 0.2891, Hyper: 0.3018, Hyper+flag: 0.3497, Hyper+1/sz: 0.3913, HB-graph: 0.3735  [HB-graph]
#    Split  19 (19/50)... train=3913 (12.3% pos)  test=1209 (11.1% pos)  |  Pair: 0.2386, Hyper: 0.3150, Hyper+flag: 0.3270, Hyper+1/sz: 0.3797, HB-graph: 0.3553  [HB-graph]
#    Split  20 (20/50)... train=3992 (11.8% pos)  test=1130 (12.8% pos)  |  Pair: 0.2795, Hyper: 0.3729, Hyper+flag: 0.3918, Hyper+1/sz: 0.4078, HB-graph: 0.4073  [HB-graph]
#    Split  21 (21/50)... train=4150 (12.2% pos)  test=972 (11.3% pos)  |  Pair: 0.3333, Hyper: 0.4127, Hyper+flag: 0.4454, Hyper+1/sz: 0.4944, HB-graph: 0.4500  [HB-graph]
#    Split  22 (22/50)... train=4228 (12.2% pos)  test=894 (11.3% pos)  |  Pair: 0.2511, Hyper: 0.3783, Hyper+flag: 0.3940, Hyper+1/sz: 0.4549, HB-graph: 0.4073  [HB-graph]
#    Split  23 (23/50)... train=3952 (11.9% pos)  test=1170 (12.6% pos)  |  Pair: 0.2292, Hyper: 0.3507, Hyper+flag: 0.3511, Hyper+1/sz: 0.3868, HB-graph: 0.3555  [HB-graph]
#    Split  24 (24/50)... train=4128 (12.2% pos)  test=994 (11.5% pos)  |  Pair: 0.2471, Hyper: 0.3767, Hyper+flag: 0.3846, Hyper+1/sz: 0.4157, HB-graph: 0.4039  [HB-graph]
#    Split  25 (25/50)... train=3968 (11.8% pos)  test=1154 (13.0% pos)  |  Pair: 0.2647, Hyper: 0.4400, Hyper+flag: 0.4438, Hyper+1/sz: 0.5072, HB-graph: 0.4604  [HB-graph]
#    Split  26 (26/50)... train=4221 (11.9% pos)  test=901 (12.8% pos)  |  Pair: 0.2365, Hyper: 0.3233, Hyper+flag: 0.3335, Hyper+1/sz: 0.3455, HB-graph: 0.3459  [HB-graph]
#    Split  27 (27/50)... train=4148 (11.9% pos)  test=974 (12.6% pos)  |  Pair: 0.2834, Hyper: 0.3206, Hyper+flag: 0.3323, Hyper+1/sz: 0.3834, HB-graph: 0.3543  [HB-graph]
#    Split  28 (28/50)... train=4209 (12.2% pos)  test=913 (11.3% pos)  |  Pair: 0.2431, Hyper: 0.3427, Hyper+flag: 0.3794, Hyper+1/sz: 0.4007, HB-graph: 0.3621  [HB-graph]
#    Split  29 (29/50)... train=4206 (12.0% pos)  test=916 (12.4% pos)  |  Pair: 0.2944, Hyper: 0.3898, Hyper+flag: 0.3784, Hyper+1/sz: 0.4237, HB-graph: 0.3944  [HB-graph]
#    Split  30 (30/50)... train=3981 (12.0% pos)  test=1141 (12.4% pos)  |  Pair: 0.2567, Hyper: 0.4220, Hyper+flag: 0.4136, Hyper+1/sz: 0.4628, HB-graph: 0.4420  [HB-graph]
#    Split  31 (31/50)... train=4236 (12.3% pos)  test=886 (10.6% pos)  |  Pair: 0.2600, Hyper: 0.3407, Hyper+flag: 0.3671, Hyper+1/sz: 0.3860, HB-graph: 0.3633  [HB-graph]
#    Split  32 (32/50)... train=3950 (11.9% pos)  test=1172 (12.5% pos)  |  Pair: 0.2717, Hyper: 0.3627, Hyper+flag: 0.3802, Hyper+1/sz: 0.4041, HB-graph: 0.3996  [HB-graph]
#    Split  33 (33/50)... train=4211 (12.2% pos)  test=911 (11.4% pos)  |  Pair: 0.3150, Hyper: 0.3784, Hyper+flag: 0.4139, Hyper+1/sz: 0.4375, HB-graph: 0.4296  [HB-graph]
#    Split  34 (34/50)... train=4077 (12.1% pos)  test=1045 (11.8% pos)  |  Pair: 0.2943, Hyper: 0.4406, Hyper+flag: 0.4752, Hyper+1/sz: 0.5313, HB-graph: 0.5020  [HB-graph]
#    Split  35 (35/50)... train=4027 (12.0% pos)  test=1095 (12.1% pos)  |  Pair: 0.2911, Hyper: 0.4559, Hyper+flag: 0.4574, Hyper+1/sz: 0.4702, HB-graph: 0.4667  [HB-graph]
#    Split  36 (36/50)... train=4146 (12.4% pos)  test=976 (10.6% pos)  |  Pair: 0.2265, Hyper: 0.3370, Hyper+flag: 0.3613, Hyper+1/sz: 0.3709, HB-graph: 0.3715  [HB-graph]
#    Split  37 (37/50)... train=3917 (12.4% pos)  test=1205 (11.0% pos)  |  Pair: 0.2642, Hyper: 0.3451, Hyper+flag: 0.3516, Hyper+1/sz: 0.4020, HB-graph: 0.3824  [HB-graph]
#    Split  38 (38/50)... train=4067 (11.9% pos)  test=1055 (12.6% pos)  |  Pair: 0.2994, Hyper: 0.3483, Hyper+flag: 0.3617, Hyper+1/sz: 0.4151, HB-graph: 0.3804  [HB-graph]
#    Split  39 (39/50)... train=4141 (12.0% pos)  test=981 (12.3% pos)  |  Pair: 0.2354, Hyper: 0.3578, Hyper+flag: 0.3367, Hyper+1/sz: 0.3751, HB-graph: 0.3652  [HB-graph]
#    Split  40 (40/50)... train=4154 (12.3% pos)  test=968 (11.2% pos)  |  Pair: 0.3189, Hyper: 0.3836, Hyper+flag: 0.3940, Hyper+1/sz: 0.4714, HB-graph: 0.4476  [HB-graph]
#    Split  41 (41/50)... train=3903 (11.9% pos)  test=1219 (12.5% pos)  |  Pair: 0.2671, Hyper: 0.4307, Hyper+flag: 0.4391, Hyper+1/sz: 0.4814, HB-graph: 0.4599  [HB-graph]
#    Split  42 (42/50)... train=4085 (11.9% pos)  test=1037 (12.4% pos)  |  Pair: 0.2661, Hyper: 0.4401, Hyper+flag: 0.4504, Hyper+1/sz: 0.4891, HB-graph: 0.4682  [HB-graph]
#    Split  43 (43/50)... train=4033 (12.2% pos)  test=1089 (11.6% pos)  |  Pair: 0.3294, Hyper: 0.4120, Hyper+flag: 0.4442, Hyper+1/sz: 0.5003, HB-graph: 0.4797  [HB-graph]
#    Split  44 (44/50)... train=4192 (12.2% pos)  test=930 (11.2% pos)  |  Pair: 0.3097, Hyper: 0.3602, Hyper+flag: 0.3985, Hyper+1/sz: 0.4679, HB-graph: 0.4134  [HB-graph]
#    Split  45 (45/50)... train=3897 (12.3% pos)  test=1225 (11.3% pos)  |  Pair: 0.2754, Hyper: 0.2984, Hyper+flag: 0.3090, Hyper+1/sz: 0.3660, HB-graph: 0.3305  [HB-graph]
#    Split  46 (46/50)... train=4156 (12.3% pos)  test=966 (11.1% pos)  |  Pair: 0.3378, Hyper: 0.3946, Hyper+flag: 0.4101, Hyper+1/sz: 0.5020, HB-graph: 0.4251  [HB-graph]
#    Split  47 (47/50)... train=4100 (11.9% pos)  test=1022 (12.8% pos)  |  Pair: 0.2568, Hyper: 0.3440, Hyper+flag: 0.3550, Hyper+1/sz: 0.3592, HB-graph: 0.3678  [HB-graph]
#    Split  48 (48/50)... train=4151 (12.3% pos)  test=971 (11.1% pos)  |  Pair: 0.2442, Hyper: 0.3760, Hyper+flag: 0.3630, Hyper+1/sz: 0.4158, HB-graph: 0.3882  [HB-graph]
#    Split  49 (49/50)... train=4176 (12.1% pos)  test=946 (11.8% pos)  |  Pair: 0.2528, Hyper: 0.3493, Hyper+flag: 0.4096, Hyper+1/sz: 0.3947, HB-graph: 0.3978  [HB-graph]
#    Split  50 (50/50)... train=3892 (11.9% pos)  test=1230 (12.4% pos)  |  Pair: 0.2808, Hyper: 0.4100, Hyper+flag: 0.4342, Hyper+1/sz: 0.4781, HB-graph: 0.4574  [HB-graph]
#
#    Completed 50/50 splits.
#
# 4. Statistical analysis...
#
# ======================================================================
#   STATISTICAL COMPARISON
# ======================================================================
#
#   Task            : Drug Target Prediction (ChEMBL)
#   Model           : Logistic regression (L2, standardised)
#   Number of splits: 50
#
#   PR-AUC
#   Representation       Mean ± Std
#   ---------------------------------------------
#   Pairwise             0.2710 ± 0.0332
#   Hypergraph           0.3698 ± 0.0438
#   Hypergraph + flag    0.3892 ± 0.0459
#   Hypergraph + 1/size  0.4265 ± 0.0507
#   HB-graph             0.4089 ± 0.0475
#
#   F1 (positive class)
#   Representation       Mean ± Std
#   ---------------------------------------------
#   Pairwise             0.3562 ± 0.0242
#   Hypergraph           0.3698 ± 0.0279
#   Hypergraph + flag    0.4003 ± 0.0277
#   Hypergraph + 1/size  0.3654 ± 0.0262
#   HB-graph             0.4055 ± 0.0294
#
#   --- HB-graph vs Pairwise — headline representation effect ---
#   Mean diff : +0.1379 ± 0.0389   (Cohen's dz = +3.548)
#   Wins/Losses/Ties : 50/0/0   (n paired = 50)
#   Sign test p (one-sided) : 0.000000   (two-sided: 0.000000)
#
#
#   --- HB-graph vs Hypergraph — stoichiometry effect ---
#   Mean diff : +0.0391 ± 0.0202   (Cohen's dz = +1.935)
#   Wins/Losses/Ties : 50/0/0   (n paired = 50)
#   Sign test p (one-sided) : 0.000000   (two-sided: 0.000000)
#
#
#   --- Hypergraph vs Pairwise — representation effect alone ---
#   Mean diff : +0.0988 ± 0.0403   (Cohen's dz = +2.452)
#   Wins/Losses/Ties : 50/0/0   (n paired = 50)
#   Sign test p (one-sided) : 0.000000   (two-sided: 0.000000)
#
#
#   --- [TEST A] Hyper+flag vs Hypergraph — ANNOTATION PRESENCE alone ---
#   Mean diff : +0.0194 ± 0.0179   (Cohen's dz = +1.085)
#   Wins/Losses/Ties : 45/5/0   (n paired = 50)
#   Sign test p (one-sided) : 0.000000   (two-sided: 0.000000)
#
#
#   --- [TEST A] HB-graph vs Hyper+flag — STOICHIOMETRY VALUES, net of annotation ---
#   Mean diff : +0.0198 ± 0.0123   (Cohen's dz = +1.608)
#   Wins/Losses/Ties : 47/3/0   (n paired = 50)
#   Sign test p (one-sided) : 0.000000   (two-sided: 0.000000)
#
#
#   --- [TEST C] Hyper+1/size vs Hypergraph — what a pure size recoding buys ---
#   Mean diff : +0.0567 ± 0.0249   (Cohen's dz = +2.273)
#   Wins/Losses/Ties : 50/0/0   (n paired = 50)
#   Sign test p (one-sided) : 0.000000   (two-sided: 0.000000)
#
#
#   --- [TEST C] HB-graph vs Hyper+1/size — STOICHIOMETRY net of size recoding ---
#   Mean diff : -0.0175 ± 0.0211   (Cohen's dz = -0.832)
#   Wins/Losses/Ties : 9/41/0   (n paired = 50)
#   Sign test p (one-sided) : 0.999999   (two-sided: 0.000006)
#
#
# ======================================================================
#   TEST A — DECOMPOSITION OF THE STOICHIOMETRY EFFECT
# ======================================================================
#
#   Component                                      dPR-AUC     W/L  p (1-sided)
#   ------------------------------------------------------------------------------
#   Annotation presence   (flag - hypergraph)      +0.0194  45/5         0.0000
#   Stoichiometry values  (hb-graph - flag)        +0.0198  47/3         0.0000
#   ------------------------------------------------------------------------------
#   TOTAL  (hb-graph - hypergraph)                 +0.0391  50/0         0.0000
#
#   Annotation presence accounts for 50% of the total stoichiometry effect.
# ======================================================================
#
# ======================================================================
#   TEST C — RECIPROCAL-OF-SIZE CONTROL
# ======================================================================
#
#   Component                                      dPR-AUC     W/L  p (1-sided)
#   ------------------------------------------------------------------------------
#   1/size alone   (recip - hypergraph)            +0.0567  50/0         0.0000
#   Stoichiometry  (hb-graph - recip)              -0.0175   9/41        1.0000
#   ------------------------------------------------------------------------------
#   TOTAL  (hb-graph - hypergraph)                 +0.0391  50/0         0.0000
#
#   The reciprocal absorbs 145% of the total apparent stoichiometry effect.
#
#   VERDICT: DOES NOT SURVIVE. The apparent stoichiometric gain is accounted
#   for by 1/(complex size), which carries no copy-number information. H2
#   cannot be supported from these features under this model.
# ======================================================================
#
# 5. Generating plots...
#
# 6. Aggregating feature importance...
#
# ======================================================================
#   FEATURE IMPORTANCE (Permutation — mean PR-AUC drop)
# ======================================================================
#
#   Pairwise
#   Rank   Feature                                    Mean        Std     Median
#   --------------------------------------------------------------------------
#   1      pair_LocalClustCoeff                    0.10820    0.02749    0.10842
#   2      pair_AvgNeighborDegree                  0.05821    0.02749    0.05345
#   3      pair_Degree                             0.04011    0.02100    0.03556
#   4      pair_TriangleCount                      0.01559    0.01229    0.01203
#
#   Hypergraph
#   Rank   Feature                                    Mean        Std     Median
#   --------------------------------------------------------------------------
#   1      protein_MedComplexNodes                 0.16108    0.04153    0.15832
#   2      protein_RangeUniqueRatio                0.13431    0.03301    0.12858
#   3      protein_RangeComplexNodes               0.13140    0.04206    0.13045
#   4      base_TriangleCount                      0.10801    0.03357    0.10098
#   5      base_Degree                             0.04170    0.03331    0.03442
#   6      base_UniquePartners                     0.04155    0.05477    0.01623
#   7      base_AvgNeighbourDegree                 0.01358    0.00681    0.01354
#   8      base_LocalClustCoeff                    0.00140    0.00229    0.00150
#
#   Hypergraph + flag
#   Rank   Feature                                    Mean        Std     Median
#   --------------------------------------------------------------------------
#   1      protein_MedComplexNodes                 0.15087    0.04347    0.15234
#   2      protein_RangeComplexNodes               0.13018    0.04736    0.12070
#   3      base_TriangleCount                      0.10315    0.03527    0.10631
#   4      protein_RangeUniqueRatio                0.06692    0.02557    0.05988
#   5      flag_HasStoich                          0.05104    0.01415    0.05069
#   6      base_UniquePartners                     0.04755    0.05823    0.01920
#   7      base_Degree                             0.03552    0.03159    0.03217
#   8      base_AvgNeighbourDegree                 0.00692    0.00467    0.00724
#   9      base_LocalClustCoeff                    0.00061    0.00199    0.00073
#
#   Hypergraph + 1/size
#   Rank   Feature                                    Mean        Std     Median
#   --------------------------------------------------------------------------
#   1      recip_MedComplexNodes                   0.21230    0.03653    0.20987
#   2      protein_RangeUniqueRatio                0.09674    0.02813    0.09031
#   3      protein_RangeComplexNodes               0.08938    0.05286    0.08714
#   4      base_UniquePartners                     0.04323    0.05267    0.02430
#   5      base_Degree                             0.02761    0.02615    0.03208
#   6      base_TriangleCount                      0.01301    0.02479    0.00503
#   7      base_AvgNeighbourDegree                 0.00880    0.00604    0.00838
#   8      protein_MedComplexNodes                 0.00730    0.01134    0.00364
#   9      base_LocalClustCoeff                    0.00001    0.00251   -0.00017
#
#   HB-graph
#   Rank   Feature                                    Mean        Std     Median
#   --------------------------------------------------------------------------
#   1      protein_MedComplexNodes                 0.13365    0.04339    0.12572
#   2      protein_RangeComplexNodes               0.12553    0.05117    0.12193
#   3      stoich_MedianRatio                      0.11689    0.02808    0.11694
#   4      base_TriangleCount                      0.10553    0.03800    0.10506
#   5      base_Degree                             0.04534    0.03391    0.04418
#   6      protein_RangeUniqueRatio                0.03866    0.01692    0.03785
#   7      base_UniquePartners                     0.03674    0.05148    0.01659
#   8      stoich_MedComplexSize                   0.00837    0.00645    0.00862
#   9      base_AvgNeighbourDegree                 0.00800    0.00488    0.00693
#   10     stoich_AvgNeighbourDegreeStoich         0.00155    0.00943    0.00299
#   11     stoich_RangeComplexSize                 0.00115    0.00365    0.00135
#   12     stoich_WeightedTriangles                0.00105    0.00166    0.00097
#   13     base_LocalClustCoeff                    0.00075    0.00230    0.00081
#   14     stoich_RangeRatio                      -0.00173    0.00498   -0.00045
#
#   Note: higher = more important; negative = likely noise.
#
#    >>> 'flag_HasStoich' ranks 5 of 9 in the hypergraph+flag model (mean importance 0.05104)
#
# 7. Saving outputs...
#    Saved: split_results.csv
#    Saved: comparison_stats.csv
#    Saved: pairwise_predictions.csv
#    Saved: pairwise_feature_importance.csv
#    Saved: hypergraph_predictions.csv
#    Saved: hypergraph_feature_importance.csv
#    Saved: hyper_flag_predictions.csv
#    Saved: hyper_flag_feature_importance.csv
#    Saved: hyper_recip_predictions.csv
#    Saved: hyper_recip_feature_importance.csv
#    Saved: hb_graph_predictions.csv
#    Saved: hb_graph_feature_importance.csv
#    Saved: best_C_per_split.csv
#    Saved: statistical_summary.txt
#
# ======================================================================
#   CROSS-TASK SUMMARY — CORUM — logistic regression PR-AUC
# ======================================================================
#
#   Task         Representation                   PR-AUC                 F1
#   ----------------------------------------------------------------------
#   ess          Pairwise                 0.4353 ± 0.0970    0.4567 ± 0.0681
#   ess          Hypergraph               0.4398 ± 0.0962    0.4391 ± 0.0953
#   ess          Hypergraph + flag        0.4434 ± 0.0967    0.4396 ± 0.0929
#   ess          Hypergraph + 1/size      0.4780 ± 0.1016    0.4690 ± 0.0765
#   ess          HB-graph                 0.4454 ± 0.0965    0.4384 ± 0.0922
#   hpa          Pairwise                 0.2662 ± 0.0350    0.3378 ± 0.0249
#   hpa          Hypergraph               0.3591 ± 0.0435    0.3469 ± 0.0257
#   hpa          Hypergraph + flag        0.3903 ± 0.0400    0.3928 ± 0.0342
#   hpa          Hypergraph + 1/size      0.4276 ± 0.0489    0.3580 ± 0.0237
#   hpa          HB-graph                 0.3954 ± 0.0397    0.3913 ± 0.0333
#   chembl       Pairwise                 0.2710 ± 0.0332    0.3562 ± 0.0242
#   chembl       Hypergraph               0.3698 ± 0.0438    0.3698 ± 0.0279
#   chembl       Hypergraph + flag        0.3892 ± 0.0459    0.4003 ± 0.0277
#   chembl       Hypergraph + 1/size      0.4265 ± 0.0507    0.3654 ± 0.0262
#   chembl       HB-graph                 0.4089 ± 0.0475    0.4055 ± 0.0294
#
#   Saved: all_tasks_summary.csv, all_tasks_comparison_stats.csv
#
# ======================================================================
#   COMPLETE
# ======================================================================
#
# Total time: 360.9s (6.0 min)
