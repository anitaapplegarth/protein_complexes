# %%
"""
Repeated random structural-group-level splits -- HPA drug-target labels.

All logic lives in split_common.py; this file is configuration only.

LABELS: Human Protein Atlas drug targets, kept strictly separate from the
ChEMBL set (Jaccard ~31%). Nothing is shared between the two label
derivations; they are independent prediction tasks.
"""

from split_common import run_splits

BASE = '/Users/anitaapplegarth/github/dphil/protein_complexes/data/lookup_tables'

CONFIG = {
    'task_description': 'Drug Target Labels (HPA)',

    # ---- Input files -------------------------------------------------------
    'group_mapping':      f'{BASE}/cp/mapping_struct.csv',
    'complex_membership': f'{BASE}/cp/stoich_protein.csv',
    'label_file':         f'{BASE}/cp_drug_target_hpa.csv',

    # ---- Input column names ------------------------------------------------
    'col_group_protein':   'uniprot_id',
    'col_group_id':        'group_id',
    'col_complex_id':      'ComplexId',
    'col_complex_protein': 'ProteinId',
    'col_label_protein':   'ProteinId',
    'col_label_value':     'target',

    # ---- Label scheme ------------------------------------------------------
    'label_scheme': {
        'positive': 'Drug_target',
        'negative': 'Non_target',
        'noun':     'drug target',
        'binarise': lambda v: 'Drug_target' if v == 1 else 'Non_target',
    },

    # ---- Output files ------------------------------------------------------
    'output_all_splits':   f'{BASE}/cp/hpa_protein_splits.csv',
    'output_balance':      f'{BASE}/cp/hpa_split_balance.csv',
    'output_summary':      f'{BASE}/cp/hpa_split_summary.txt',
    'output_rate_by_size': f'{BASE}/cp/avg_hpa_by_group_size.csv',

    # ---- Split parameters --------------------------------------------------
    'n_splits':    50,
    'train_ratio': 0.80,
    'test_ratio':  0.20,
    'base_seed':   42,

    'max_size_deviation': 5.0,   # pp -- acceptable range [15%, 25%]

    # Check the printed global rate on the first run. If HPA's positive rate
    # differs materially from ChEMBL's, 1.5pp is a different level of
    # strictness and should be retuned -- roughly a tenth of the global rate
    # is a reasonable starting point.
    'max_label_rate_deviation': 1.5,

    'max_attempts': 25,

    # ---- Validation tuning -------------------------------------------------
    'validate_abs_tol':            0.15,
    'validate_min_groups':         3,
    'min_test_groups_per_bucket':  1,
    'strict_duplicate_check':      False,
    'require_full_n_splits':       True,

    # ---- Bucket ablation ---------------------------------------------------
    'stratify_by_bucket': True,
    'unstrat_suffix':     '_unstrat',
}


if __name__ == '__main__':
    run_splits(CONFIG)
# Out:
# ======================================================================
# Repeated Random group-Level Splitting -- Size-Stratified, N=50
# Drug Target Labels (HPA)
# ======================================================================
#
# --- Loading data ---
#   Groups:    3388 rows, 955 unique groups
#   Complexes: 2220 complexes, 3394 unique proteins
#   Labels:    3394 rows from /Users/anitaapplegarth/github/dphil/protein_complexes/data/lookup_tables/cp_drug_target_hpa.csv
#   Duplicate group assignments: none
#
#   Label distribution (3394 total complex proteins):
#     Drug_target    :   272
#     Non_target     :  3122
#     Unknown        :     0  (no usable label -- excluded)
#     No-group       :     6  (no structural assignment -- excluded)
#   Analysis population (labelled + structured): 3388
#   Global drug target rate (analysis population): 8.0%  (272 / 3388)
#
# --- Group size buckets (largest first) ---
#   large        (>20 proteins (merged large + very large)):   22 groups,   970 proteins -- 4 grps drawn to test each split
#   medium       (6-20                                    ):  106 groups,  1075 proteins -- 21 grps drawn to test each split
#   small        (2-5                                     ):  277 groups,   793 proteins -- 55 grps drawn to test each split
#   singleton    (1 protein                               ):  550 groups,   550 proteins -- 110 grps drawn to test each split
#   No-group proteins: 6
#
# --- Allocation mode: SIZE-STRATIFIED ---
# --- Generating 50 splits (tolerance +/-1.5pp label, +/-5.0pp size, max 25 attempts each) ---
#   Split  1 | train=2768 (81.6%) pos=7.9% | test=626 (18.4%) pos=8.5% | size_dev=1.6pp label_dev=0.5pp (accepted on attempt 3)
#   Split  2 | train=2698 (79.5%) pos=8.0% | test=696 (20.5%) pos=8.2% | size_dev=0.5pp label_dev=0.2pp (accepted on attempt 3)
#   Split  3 | train=2709 (79.8%) pos=7.8% | test=685 (20.2%) pos=8.9% | size_dev=0.2pp label_dev=0.9pp (accepted on attempt 6)
#   Split  4 | train=2778 (81.8%) pos=7.8% | test=616 (18.1%) pos=8.9% | size_dev=1.9pp label_dev=0.9pp (accepted on attempt 5)
#   Split  5 | train=2604 (76.7%) pos=7.6% | test=790 (23.3%) pos=9.5% | size_dev=3.3pp label_dev=1.5pp
#   Split  6 | train=2710 (79.8%) pos=8.3% | test=684 (20.1%) pos=6.9% | size_dev=0.1pp label_dev=1.1pp (accepted on attempt 3)
#   Split  7 | train=2787 (82.1%) pos=8.3% | test=607 (17.9%) pos=6.9% | size_dev=2.1pp label_dev=1.1pp
#   Split  8 | train=2748 (81.0%) pos=7.9% | test=646 (19.0%) pos=8.7% | size_dev=1.0pp label_dev=0.7pp (accepted on attempt 5)
#   Split  9 | train=2818 (83.0%) pos=8.2% | test=576 (17.0%) pos=7.0% | size_dev=3.0pp label_dev=1.1pp
#   Split 10 | train=2768 (81.6%) pos=7.8% | test=626 (18.4%) pos=9.1% | size_dev=1.6pp label_dev=1.1pp (accepted on attempt 3)
#   Split 11 | train=2745 (80.9%) pos=8.3% | test=649 (19.1%) pos=6.8% | size_dev=0.9pp label_dev=1.2pp (accepted on attempt 4)
#   Split 12 | train=2757 (81.2%) pos=7.8% | test=637 (18.8%) pos=9.1% | size_dev=1.2pp label_dev=1.1pp (accepted on attempt 4)
#   Split 13 | train=2675 (78.8%) pos=7.7% | test=719 (21.2%) pos=9.2% | size_dev=1.2pp label_dev=1.2pp
#   Split 14 | train=2718 (80.1%) pos=8.4% | test=676 (19.9%) pos=6.7% | size_dev=0.1pp label_dev=1.4pp
#   Split 15 | train=2736 (80.6%) pos=8.0% | test=658 (19.4%) pos=8.4% | size_dev=0.6pp label_dev=0.3pp (accepted on attempt 3)
#   Split 16 | train=2757 (81.2%) pos=8.4% | test=637 (18.8%) pos=6.6% | size_dev=1.2pp label_dev=1.4pp (accepted on attempt 5)
#   Split 17 | train=2707 (79.8%) pos=7.7% | test=687 (20.2%) pos=9.5% | size_dev=0.2pp label_dev=1.4pp (accepted on attempt 2)
#   Split 18 | train=2698 (79.5%) pos=7.8% | test=696 (20.5%) pos=9.1% | size_dev=0.5pp label_dev=1.0pp
#   Split 19 | train=2741 (80.8%) pos=8.2% | test=653 (19.2%) pos=7.5% | size_dev=0.8pp label_dev=0.5pp (accepted on attempt 5)
#   Split 20 | train=2642 (77.8%) pos=8.4% | test=752 (22.2%) pos=6.7% | size_dev=2.2pp label_dev=1.4pp
#   Split 21 | train=2780 (81.9%) pos=8.1% | test=614 (18.1%) pos=7.7% | size_dev=1.9pp label_dev=0.4pp (accepted on attempt 2)
#   Split 22 | train=2706 (79.7%) pos=8.3% | test=688 (20.3%) pos=7.0% | size_dev=0.3pp label_dev=1.0pp
#   Split 23 | train=2814 (82.9%) pos=8.1% | test=580 (17.1%) pos=7.8% | size_dev=2.9pp label_dev=0.3pp (accepted on attempt 2)
#   Split 24 | train=2810 (82.8%) pos=8.3% | test=584 (17.2%) pos=6.7% | size_dev=2.8pp label_dev=1.3pp
#   Split 25 | train=2657 (78.3%) pos=7.7% | test=737 (21.7%) pos=9.1% | size_dev=1.7pp label_dev=1.1pp (accepted on attempt 4)
#   Split 26 | train=2783 (82.0%) pos=8.1% | test=611 (18.0%) pos=7.7% | size_dev=2.0pp label_dev=0.3pp (accepted on attempt 6)
#   Split 27 | train=2785 (82.1%) pos=8.2% | test=609 (17.9%) pos=7.4% | size_dev=2.1pp label_dev=0.6pp (accepted on attempt 5)
#   Split 28 | train=2786 (82.1%) pos=8.1% | test=608 (17.9%) pos=7.9% | size_dev=2.1pp label_dev=0.1pp
#   Split 29 | train=2657 (78.3%) pos=8.2% | test=737 (21.7%) pos=7.5% | size_dev=1.7pp label_dev=0.6pp
#   Split 30 | train=2642 (77.8%) pos=7.9% | test=752 (22.2%) pos=8.5% | size_dev=2.2pp label_dev=0.5pp (accepted on attempt 5)
#   Split 31 | train=2753 (81.1%) pos=8.3% | test=641 (18.9%) pos=6.7% | size_dev=1.1pp label_dev=1.3pp (accepted on attempt 2)
#   Split 32 | train=2697 (79.5%) pos=8.3% | test=697 (20.5%) pos=7.0% | size_dev=0.5pp label_dev=1.0pp (accepted on attempt 3)
#   Split 33 | train=2747 (80.9%) pos=8.1% | test=647 (19.1%) pos=7.7% | size_dev=0.9pp label_dev=0.3pp (accepted on attempt 2)
#   Split 34 | train=2758 (81.3%) pos=8.3% | test=636 (18.7%) pos=6.8% | size_dev=1.3pp label_dev=1.3pp
#   Split 35 | train=2780 (81.9%) pos=7.8% | test=614 (18.1%) pos=9.3% | size_dev=1.9pp label_dev=1.3pp (accepted on attempt 4)
#   Split 36 | train=2742 (80.8%) pos=8.3% | test=652 (19.2%) pos=6.9% | size_dev=0.8pp label_dev=1.1pp
#   Split 37 | train=2798 (82.4%) pos=8.3% | test=596 (17.6%) pos=6.7% | size_dev=2.4pp label_dev=1.3pp (accepted on attempt 2)
#   Split 38 | train=2755 (81.2%) pos=7.8% | test=639 (18.8%) pos=9.1% | size_dev=1.2pp label_dev=1.1pp
#   Split 39 | train=2761 (81.3%) pos=7.8% | test=633 (18.6%) pos=9.2% | size_dev=1.4pp label_dev=1.1pp
#   Split 40 | train=2687 (79.2%) pos=8.4% | test=707 (20.8%) pos=6.7% | size_dev=0.8pp label_dev=1.4pp (accepted on attempt 2)
#   Split 41 | train=2764 (81.4%) pos=8.2% | test=630 (18.6%) pos=7.3% | size_dev=1.4pp label_dev=0.7pp (accepted on attempt 5)
#   Split 42 | train=2745 (80.9%) pos=7.8% | test=649 (19.1%) pos=8.8% | size_dev=0.9pp label_dev=0.8pp
#   Split 43 | train=2681 (79.0%) pos=7.9% | test=713 (21.0%) pos=8.6% | size_dev=1.0pp label_dev=0.5pp
#   Split 44 | train=2765 (81.5%) pos=8.2% | test=629 (18.5%) pos=7.3% | size_dev=1.5pp label_dev=0.7pp (accepted on attempt 2)
#   Split 45 | train=2806 (82.7%) pos=8.3% | test=588 (17.3%) pos=6.6% | size_dev=2.7pp label_dev=1.4pp
#   Split 46 | train=2758 (81.3%) pos=8.1% | test=636 (18.7%) pos=7.9% | size_dev=1.3pp label_dev=0.2pp
#   Split 47 | train=2822 (83.2%) pos=7.9% | test=572 (16.9%) pos=8.8% | size_dev=3.1pp label_dev=0.7pp (accepted on attempt 2)
#   Split 48 | train=2784 (82.0%) pos=7.9% | test=610 (18.0%) pos=8.5% | size_dev=2.0pp label_dev=0.5pp (accepted on attempt 2)
#   Split 49 | train=2798 (82.4%) pos=8.1% | test=596 (17.6%) pos=7.7% | size_dev=2.4pp label_dev=0.3pp (accepted on attempt 2)
#   Split 50 | train=2785 (82.1%) pos=7.8% | test=609 (17.9%) pos=9.1% | size_dev=2.1pp label_dev=1.0pp (accepted on attempt 2)
#
# group-size bucket distribution after split (groups counted):
# BUCKET           TRAIN   TEST  TOTAL TEST_FRAC
# large               18      4     22     0.182
# medium              85     21    106     0.198
# singleton          440    110    550     0.200
# small              222     55    277     0.199
#
# --- Integrity check ---
#   Splits emitted:            50 / 50
#   split_index contiguous:    True
#   Total leakage violations:  0
#   Splits failing validation: 0
#
# --- Saving outputs ---
#   Saved: /Users/anitaapplegarth/github/dphil/protein_complexes/data/lookup_tables/cp
#     38       166 17.1%  17.5%        207 19.3%   3.4%       155 19.5%   9.0%           110 20.0%   7.3%
#     39       152 15.7%   4.6%        218 20.3%  15.6%       152 19.2%   5.3%           110 20.0%   8.2%
#     40       210 21.6%   2.4%        240 22.3%   9.6%       146 18.4%   4.8%           110 20.0%  10.9%
#     41       149 15.4%   8.1%        213 19.8%   7.0%       157 19.8%   5.1%           110 20.0%  10.0%
#     42       165 17.0%   6.1%        222 20.7%  11.3%       151 19.0%   6.6%           110 20.0%  10.9%
#     43       220 22.7%  18.2%        230 21.4%   1.7%       152 19.2%   3.9%           110 20.0%  10.0%
#     44       142 14.6%   7.7%        222 20.7%   7.7%       154 19.4%   8.4%           110 20.0%   4.5%
#     45       124 12.8%   8.9%        191 17.8%   1.0%       162 20.4%   8.0%           110 20.0%  11.8%
#     46       164 16.9%   9.8%        198 18.4%   9.6%       163 20.6%   4.9%           110 20.0%   6.4%
#     47       135 13.9%  17.0%        176 16.4%   2.8%       150 18.9%   6.7%           110 20.0%  10.9%
#     48       129 13.3%   0.0%        213 19.8%  13.6%       157 19.8%   8.9%           110 20.0%   8.2%
#     49       127 13.1%   7.1%        210 19.5%   7.6%       148 18.7%   7.4%           110 20.0%   9.1%
#     50       134 13.8%  10.4%        200 18.6%  10.5%       164 20.7%   7.3%           110 20.0%   7.3%
# ------------------------------------------------------------------------------------------
#   Mean     168.5 17.4%   8.5%      214.7 20.0%   8.2%     156.4 19.7%   6.5%         110.0 20.0%   8.3%
#    Std      44.1 4.55%  5.60%       16.6 1.54%  3.28%       6.0 0.77%  2.81%           0.0 0.00%  2.09%
#
#   N% = % of that bucket's proteins going to test.
#   Pos% = drug target rate among analysis-population test proteins in that bucket.
#
# ==========================================================================================
# LARGE-BUCKET PROFILE ANALYSIS
# ==========================================================================================
#
# 1. Which large groups are in TEST per split?
# ------------------------------------------------------------
#   Split  1: grp_0110, grp_0644, grp_0916, grp_1004
#   Split  2: grp_0033, grp_0222, grp_0336, grp_0644
#   Split  3: grp_0644, grp_1179, grp_1186, grp_1341
#   Split  4: grp_0091, grp_0644, grp_0738, grp_0821
#   Split  5: grp_0000, grp_0222, grp_1179, grp_1341
#   Split  6: grp_0000, grp_0018, grp_0065, grp_1186
#   Split  7: grp_0091, grp_0336, grp_0916, grp_1186
#   Split  8: grp_0000, grp_0018, grp_0738, grp_0821
#   Split  9: grp_0072, grp_0113, grp_0644, grp_0738
#   Split 10: grp_0065, grp_0101, grp_0113, grp_1004
#   Split 11: grp_0000, grp_0072, grp_0110, grp_0113
#   Split 12: grp_0065, grp_0101, grp_0644, grp_0821
#   Split 13: grp_0091, grp_0113, grp_0222, grp_1186
#   Split 14: grp_0018, grp_0064, grp_0113, grp_0916
#   Split 15: grp_0018, grp_0091, grp_0110, grp_1186
#   Split 16: grp_0018, grp_0336, grp_0644, grp_1186
#   Split 17: grp_0091, grp_0113, grp_0222, grp_0738
#   Split 18: grp_0072, grp_0222, grp_0336, grp_0644
#   Split 19: grp_0018, grp_0064, grp_0336, grp_1341
#   Split 20: grp_0064, grp_1091, grp_1179, grp_1186
#   Split 21: grp_0018, grp_0738, grp_1004, grp_1341
#   Split 22: grp_0916, grp_1004, grp_1179, grp_1186
#   Split 23: grp_0033, grp_0336, grp_0738, grp_1004
#   Split 24: grp_0091, grp_0336, grp_0738, grp_1004
#   Split 25: grp_0000, grp_0064, grp_0101, grp_0110
#   Split 26: grp_0091, grp_0113, grp_0916, grp_1004
#   Split 27: grp_0000, grp_0091, grp_0101, grp_0336
#   Split 28: grp_0065, grp_0644, grp_1004, grp_1186
#   Split 29: grp_0110, grp_0222, grp_0673, grp_1341
#   Split 30: grp_0113, grp_0222, grp_0673, grp_1341
#   Split 31: grp_0000, grp_0644, grp_0673, grp_1091
#   Split 32: grp_0018, grp_0064, grp_0738, grp_1341
#   Split 33: grp_0018, grp_0336, grp_0821, grp_1091
#   Split 34: grp_0033, grp_0091, grp_0101, grp_0916
#   Split 35: grp_0072, grp_0101, grp_0113, grp_0673
#   Split 36: grp_0033, grp_0113, grp_0673, grp_1004
#   Split 37: grp_0072, grp_0916, grp_1091, grp_1341
#   Split 38: grp_0101, grp_0110, grp_0916, grp_1186
#   Split 39: grp_0091, grp_0673, grp_0916, grp_1341
#   Split 40: grp_0000, grp_0738, grp_1179, grp_1186
#   Split 41: grp_0018, grp_0033, grp_0113, grp_0738
#   Split 42: grp_0018, grp_0033, grp_0113, grp_0673
#   Split 43: grp_0000, grp_0222, grp_0738, grp_0821
#   Split 44: grp_0000, grp_0018, grp_0072, grp_1004
#   Split 45: grp_0018, grp_0033, grp_0738, grp_1004
#   Split 46: grp_0000, grp_0018, grp_0033, grp_0821
#   Split 47: grp_0000, grp_0101, grp_0738, grp_1004
#   Split 48: grp_0091, grp_1004, grp_1091, grp_1341
#   Split 49: grp_0336, grp_0916, grp_1004, grp_1186
#   Split 50: grp_0072, grp_0821, grp_0916, grp_1341
#
# 2. All large groups and their sizes (analysis population proteins)
# ------------------------------------------------------------
#   grp_0000:   51 proteins  |  in test for splits [5, 6, 8, 11, 25, 27, 31, 40, 43, 44, 46, 47]
#   grp_0018:   48 proteins  |  in test for splits [6, 8, 14, 15, 16, 19, 21, 32, 33, 41, 42, 44, 45, 46]
#   grp_0033:   32 proteins  |  in test for splits [2, 23, 34, 36, 41, 42, 45, 46]
#   grp_0064:   90 proteins  |  in test for splits [14, 19, 20, 25, 32]
#   grp_0065:   25 proteins  |  in test for splits [6, 10, 12, 28]
#   grp_0072:   22 proteins  |  in test for splits [9, 11, 18, 35, 37, 44, 50]
#   grp_0091:   34 proteins  |  in test for splits [4, 7, 13, 15, 17, 24, 26, 27, 34, 39, 48]
#   grp_0101:   40 proteins  |  in test for splits [10, 12, 25, 27, 34, 35, 38, 47]
#   grp_0110:   45 proteins  |  in test for splits [1, 11, 15, 25, 29, 38]
#   grp_0113:   46 proteins  |  in test for splits [9, 10, 11, 13, 14, 17, 26, 30, 35, 36, 41, 42]
#   grp_0222:  113 proteins  |  in test for splits [2, 5, 13, 17, 18, 29, 30, 43]
#   grp_0336:   25 proteins  |  in test for splits [2, 7, 16, 18, 19, 23, 24, 27, 33, 49]
#   grp_0644:   39 proteins  |  in test for splits [1, 2, 3, 4, 9, 12, 16, 18, 28, 31]
#   grp_0673:   39 proteins  |  in test for splits [29, 30, 31, 35, 36, 39, 42]
#   grp_0738:   23 proteins  |  in test for splits [4, 8, 9, 17, 21, 23, 24, 32, 40, 41, 43, 45, 47]
#   grp_0821:   33 proteins  |  in test for splits [4, 8, 12, 33, 43, 46, 50]
#   grp_0916:   34 proteins  |  in test for splits [1, 7, 14, 22, 26, 34, 37, 38, 39, 49, 50]
#   grp_1004:   21 proteins  |  in test for splits [1, 10, 21, 22, 23, 24, 26, 28, 36, 44, 45, 47, 48, 49]
#   grp_1091:   29 proteins  |  in test for splits [20, 31, 33, 37, 48]
#   grp_1179:   89 proteins  |  in test for splits [3, 5, 20, 22, 40]
#   grp_1186:   47 proteins  |  in test for splits [3, 6, 7, 13, 15, 16, 20, 22, 28, 38, 40, 49]
#   grp_1341:   45 proteins  |  in test for splits [3, 5, 19, 21, 29, 30, 32, 37, 39, 48, 50]
#
# 3. Large test set size per split (all proteins)
# ------------------------------------------------------------
#   Split  1:  139 proteins
#   Split  2:  209 proteins
#   Split  3:  220 proteins
#   Split  4:  129 proteins
#   Split  5:  298 proteins
#   Split  6:  171 proteins
#   Split  7:  140 proteins
#   Split  8:  155 proteins
#   Split  9:  130 proteins
#   Split 10:  132 proteins
#   Split 11:  164 proteins
#   Split 12:  137 proteins
#   Split 13:  240 proteins
#   Split 14:  218 proteins
#   Split 15:  174 proteins
#   Split 16:  159 proteins
#   Split 17:  216 proteins
#   Split 18:  199 proteins
#   Split 19:  208 proteins
#   Split 20:  255 proteins
#   Split 21:  137 proteins
#   Split 22:  191 proteins
#   Split 23:  101 proteins
#   Split 24:  103 proteins
#   Split 25:  226 proteins
#   Split 26:  135 proteins
#   Split 27:  150 proteins
#   Split 28:  132 proteins
#   Split 29:  242 proteins
#   Split 30:  243 proteins
#   Split 31:  158 proteins
#   Split 32:  206 proteins
#   Split 33:  135 proteins
#   Split 34:  140 proteins
#   Split 35:  147 proteins
#   Split 36:  138 proteins
#   Split 37:  130 proteins
#   Split 38:  166 proteins
#   Split 39:  152 proteins
#   Split 40:  210 proteins
#   Split 41:  149 proteins
#   Split 42:  165 proteins
#   Split 43:  220 proteins
#   Split 44:  142 proteins
#   Split 45:  124 proteins
#   Split 46:  164 proteins
#   Split 47:  135 proteins
#   Split 48:  129 proteins
#   Split 49:  127 proteins
#   Split 50:  134 proteins
#
# 4. Overlap statistics across all splits
# ------------------------------------------------------------
#   Intersection (in ALL test sets): 0
#   Union (in ANY test set):         970
#   Jaccard similarity:              0.000
#
# 5. Per-protein test frequency (how many splits each protein is in test)
# ------------------------------------------------------------
#   4 split(s): 25 proteins
#   5 split(s): 208 proteins
#   6 split(s): 45 proteins
#   7 split(s): 94 proteins
#   8 split(s): 185 proteins
#   10 split(s): 64 proteins
#   11 split(s): 113 proteins
#   12 split(s): 144 proteins
#   13 split(s): 23 proteins
#   14 split(s): 69 proteins
#
# 6. Per-group test frequency -- randomness check
# ------------------------------------------------------------
#   Total large groups:          22
#   Groups drawn to test/split:  4  (18.2%)
#   Expected test freq per group over 50 splits: 9.1
#   Binomial SD: 2.73   2 SD band: [3.6, 14.5]
#   With this many groups, roughly one falling outside the band by chance is expected.
#
#   Group                           AP size  Test count  Note
#   grp_0000                             51          12  ok
#   grp_0018                             48          14  ok
#   grp_0033                             32           8  ok
#   grp_0064                             90           5  ok
#   grp_0065                             25           4  ok
#   grp_0072                             22           7  ok
#   grp_0091                             34          11  ok
#   grp_0101                             40           8  ok
#   grp_0110                             45           6  ok
#   grp_0113                             46          12  ok
#   grp_0222                            113           8  ok
#   grp_0336                             25          10  ok
#   grp_0644                             39          10  ok
#   grp_0673                             39           7  ok
#   grp_0738                             23          13  ok
#   grp_0821                             33           7  ok
#   grp_0916                             34          11  ok
#   grp_1004                             21          14  ok
#   grp_1091                             29           5  ok
#   grp_1179                             89           5  ok
#   grp_1186                             47          12  ok
#   grp_1341                             45          11  ok
#
#   Min test count: 4  Max: 14  Mean: 9.09  Std: 3.04
#   Groups outside the 2 SD band: 0 / 22  (~1 expected by chance)
#   Observed SD vs binomial SD: 3.04 vs 2.73  -- wider than a fair draw would give.
#
# ==========================================================================================
# 7. Drug target rate per group size  (analysis population only)
# ==========================================================================================
#   Analysis population = labelled (Drug_target/Non_target) + structured
#   Global drug target rate: 8.0%
#   n = 3388
#
#     group_size   n_groups    n_proteins    n_positive      pos_rate
#   --------------------------------------------------------------------
#              1        550           550            46          8.4%
#              2        135           270            11          4.1%
#              3         71           213            22         10.3%
#              4         45           180            11          6.1%
#              5         26           130             7          5.4%
#              6         22           132             7          5.3%
#              7         18           126             6          4.8%
#              8         13           104             3          2.9%
#              9          9            81             9         11.1%
#             10          4            40             1          2.5%
#             11          3            33             0          0.0%
#             12          6            72             9         12.5%
#             13          3            39             0          0.0%
#             14          8           112             4          3.6%
#             15          4            60            13         21.7%
#             16          4            64            23         35.9%
#             17          6           102             7          6.9%
#             18          4            72             7          9.7%
#             19          2            38             5         13.2%
#             21          1            21             0          0.0%
#             22          1            22             1          4.5%
#             23          1            23             2          8.7%
#             25          2            50             1          2.0%
#             29          1            29             0          0.0%
#             32          1            32             0          0.0%
#             33          1            33             6         18.2%
#             34          2            68             7         10.3%
#             39          2            78             0          0.0%
#             40          1            40            20         50.0%
#             45          2            90             0          0.0%
#             46          1            46             1          2.2%
#             47          1            47             2          4.3%
#             48          1            48             9         18.8%
#             51          1            51             1          2.0%
#             89          1            89             0          0.0%
#             90          1            90             0          0.0%
#            113          1           113            31         27.4%
#
#   Saved: /Users/anitaapplegarth/github/dphil/protein_complexes/data/lookup_tables/cp/avg_hpa_by_group_size.csv
#
# ==========================================================================================
# 8. Large-bucket test drug target rate by split
# ==========================================================================================
#   Global drug target rate: 8.0%
#
#   Split   Groups in test   Test proteins  Bucket rate
#   ------------------------------------------------------
#       1                4             139         5.0%
#       2                4             209        14.8%
#       3                4             220         0.9%
#       4                4             129         6.2%
#       5                4             298        10.7%
#       6                4             171         7.6%
#       7                4             140         6.4%
#       8                4             155        11.6%
#       9                4             130         3.1%
#      10                4             132        16.7%
#      11                4             164         1.8%
#      12                4             137        19.7%
#      13                4             240        14.2%
#      14                4             218         7.8%
#      15                4             174         6.3%
#      16                4             159         6.9%
#      17                4             216        15.7%
#      18                4             199        16.1%
#      19                4             208         4.3%
#      20                4             255         0.8%
#      21                4             137         8.0%
#      22                4             191         4.7%
#      23                4             101         2.0%
#      24                4             103         1.9%
#      25                4             226         9.3%
#      26                4             135         5.9%
#      27                4             150        14.0%
#      28                4             132         2.3%
#      29                4             242        12.8%
#      30                4             243        13.2%
#      31                4             158         0.6%
#      32                4             206         5.3%
#      33                4             135        11.1%
#      34                4             140        19.3%
#      35                4             147        15.0%
#      36                4             138         0.7%
#      37                4             130         6.2%
#      38                4             166        17.5%
#      39                4             152         4.6%
#      40                4             210         2.4%
#      41                4             149         8.1%
#      42                4             165         6.1%
#      43                4             220        18.2%
#      44                4             142         7.7%
#      45                4             124         8.9%
#      46                4             164         9.8%
#      47                4             135        17.0%
#      48                4             129         0.0%
#      49                4             127         7.1%
#      50                4             134        10.4%
#
#   Saved: /Users/anitaapplegarth/github/dphil/protein_complexes/data/lookup_tables/cp/hpa_split_summary.txt
#
# Done!
