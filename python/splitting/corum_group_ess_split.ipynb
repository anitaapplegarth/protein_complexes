# %%
"""
Repeated random structural-group-level splits -- essentiality labels.

All logic lives in split_common.py; this file is configuration only.

LABELS: OGEE v3 + DepMap. Core -> Essential; Cancer and Non-essential ->
Non-essential; anything else -> dropped to Unknown and excluded from the
analysis population. This is the binarisation used throughout the paper.

"""

from split_common import run_splits

BASE = '/Users/anitaapplegarth/github/dphil/protein_complexes/data/lookup_tables'


def binarise_essentiality(raw):
    """Core -> Essential; Cancer & Non-essential -> Non-essential; else drop."""
    if raw == 'Core':
        return 'Essential'
    if raw in ('Cancer', 'Non-essential'):
        return 'Non-essential'
    return None


CONFIG = {
    'task_description': 'Essentiality Labels (OGEE v3 + DepMap)',

    # ---- Input files -------------------------------------------------------
    'group_mapping':      f'{BASE}/corum/mapping_struct.csv',
    'complex_membership': f'{BASE}/corum/stoich_protein.csv',
    'label_file':         f'{BASE}/lu_essentiality_protein.csv',

    # ---- Input column names ------------------------------------------------
    # NOTE: the essentiality table keys on 'Protein', not 'ProteinId' as the
    # drug-target tables do. This asymmetry is the reason the column names are
    # configurable rather than hardcoded.
    'col_group_protein':   'uniprot_id',
    'col_group_id':        'group_id',
    'col_complex_id':      'ComplexId',
    'col_complex_protein': 'ProteinId',
    'col_label_protein':   'Protein',
    'col_label_value':     'essential_category',

    # ---- Label scheme ------------------------------------------------------
    'label_scheme': {
        'positive': 'Essential',
        'negative': 'Non-essential',
        'noun':     'essential',
        'binarise': binarise_essentiality,
    },

    # ---- Output files ------------------------------------------------------
    'output_all_splits':   f'{BASE}/corum/ess_protein_splits.csv',
    'output_balance':      f'{BASE}/corum/ess_split_balance.csv',
    'output_summary':      f'{BASE}/corum/ess_split_summary.txt',
    'output_rate_by_size': f'{BASE}/corum/avg_essentiality_by_group_size.csv',

    # ---- Split parameters --------------------------------------------------
    'n_splits':    50,
    'train_ratio': 0.80,
    'test_ratio':  0.20,
    'base_seed':   42,

    'max_size_deviation': 5.0,   # pp -- acceptable range [15%, 25%]

    # Looser than the drug-target tasks (4.5pp vs 1.5pp) because the global
    # essential rate is far higher, so the same absolute pp tolerance is
    # proportionally much tighter. Renamed from 'max_ess_rate_deviation' to
    # match the shared engine.
    'max_label_rate_deviation': 4.5,

    'max_attempts': 25,

    # ---- Validation tuning -------------------------------------------------
    'validate_abs_tol':            0.15,
    'validate_min_groups':         3,
    'min_test_groups_per_bucket':  1,
    'strict_duplicate_check':      False,
    'require_full_n_splits':       True,

    # ---- Bucket ablation ---------------------------------------------------
    'stratify_by_bucket': True,
    'unstrat_suffix':     '_unstrat',
}


if __name__ == '__main__':
    run_splits(CONFIG)
# Out:
# ======================================================================
# Repeated Random group-Level Splitting -- Size-Stratified, N=50
# Essentiality Labels (OGEE v3 + DepMap)
# ======================================================================
#
# --- Loading data ---
#   Groups:    5122 rows, 2129 unique groups
#   Complexes: 5454 complexes, 5132 unique proteins
#   Labels:    18392 rows from /Users/anitaapplegarth/github/dphil/protein_complexes/data/lookup_tables/lu_essentiality_protein.csv
#   Duplicate group assignments: none
#
#   Label distribution (5132 total complex proteins):
#     Essential      :   876
#     Non-essential  :  4186
#     Unknown        :    70  (no usable label -- excluded)
#     No-group       :    10  (no structural assignment -- excluded)
#   Analysis population (labelled + structured): 5054
#   Global essential rate (analysis population): 17.3%  (876 / 5054)
#
# --- Group size buckets (largest first) ---
#   large        (>20 proteins (merged large + very large)):   23 groups,  1057 proteins -- 5 grps drawn to test each split
#   medium       (6-20                                    ):  115 groups,  1115 proteins -- 23 grps drawn to test each split
#   small        (2-5                                     ):  540 groups,  1499 proteins -- 108 grps drawn to test each split
#   singleton    (1 protein                               ): 1451 groups,  1451 proteins -- 290 grps drawn to test each split
#   No-group proteins: 10
#
# --- Allocation mode: SIZE-STRATIFIED ---
# --- Generating 50 splits (tolerance +/-4.5pp label, +/-5.0pp size, max 25 attempts each) ---
#   Split  1 | train=4171 (81.3%) pos=17.8% | test=961 (18.7%) pos=15.4% | size_dev=1.3pp label_dev=1.9pp
#   Split  2 | train=4144 (80.8%) pos=17.6% | test=988 (19.2%) pos=16.1% | size_dev=0.8pp label_dev=1.3pp
#   Split  3 | train=3930 (76.6%) pos=18.1% | test=1202 (23.4%) pos=14.8% | size_dev=3.4pp label_dev=2.5pp
#   Split  4 | train=4135 (80.6%) pos=16.5% | test=997 (19.4%) pos=20.7% | size_dev=0.6pp label_dev=3.4pp
#   Split  5 | train=4116 (80.2%) pos=17.1% | test=1016 (19.8%) pos=18.1% | size_dev=0.2pp label_dev=0.8pp
#   Split  6 | train=4117 (80.2%) pos=17.6% | test=1015 (19.8%) pos=16.5% | size_dev=0.2pp label_dev=0.9pp
#   Split  7 | train=4151 (80.9%) pos=17.4% | test=981 (19.1%) pos=17.1% | size_dev=0.9pp label_dev=0.2pp
#   Split  8 | train=4142 (80.7%) pos=17.7% | test=990 (19.3%) pos=15.8% | size_dev=0.7pp label_dev=1.6pp
#   Split  9 | train=4037 (78.7%) pos=18.1% | test=1095 (21.3%) pos=14.4% | size_dev=1.3pp label_dev=2.9pp
#   Split 10 | train=3958 (77.1%) pos=18.4% | test=1174 (22.9%) pos=13.7% | size_dev=2.9pp label_dev=3.7pp
#   Split 11 | train=4073 (79.4%) pos=17.4% | test=1059 (20.6%) pos=17.2% | size_dev=0.6pp label_dev=0.2pp
#   Split 12 | train=4164 (81.1%) pos=17.5% | test=968 (18.9%) pos=16.8% | size_dev=1.1pp label_dev=0.6pp (accepted on attempt 2)
#   Split 13 | train=4119 (80.3%) pos=17.6% | test=1013 (19.7%) pos=16.2% | size_dev=0.3pp label_dev=1.1pp
#   Split 14 | train=4114 (80.2%) pos=16.2% | test=1018 (19.8%) pos=21.8% | size_dev=0.2pp label_dev=4.4pp
#   Split 15 | train=4073 (79.4%) pos=17.0% | test=1059 (20.6%) pos=18.8% | size_dev=0.6pp label_dev=1.4pp
#   Split 16 | train=3955 (77.1%) pos=17.3% | test=1177 (22.9%) pos=17.4% | size_dev=2.9pp label_dev=0.1pp
#   Split 17 | train=4123 (80.3%) pos=17.2% | test=1009 (19.7%) pos=17.9% | size_dev=0.3pp label_dev=0.6pp
#   Split 18 | train=4094 (79.8%) pos=16.8% | test=1038 (20.2%) pos=19.3% | size_dev=0.2pp label_dev=2.0pp
#   Split 19 | train=3929 (76.6%) pos=16.5% | test=1203 (23.4%) pos=20.2% | size_dev=3.4pp label_dev=2.9pp
#   Split 20 | train=4060 (79.1%) pos=16.8% | test=1072 (20.9%) pos=19.3% | size_dev=0.9pp label_dev=2.0pp
#   Split 21 | train=4099 (79.9%) pos=18.1% | test=1033 (20.1%) pos=14.1% | size_dev=0.1pp label_dev=3.2pp
#   Split 22 | train=4156 (81.0%) pos=18.2% | test=976 (19.0%) pos=13.6% | size_dev=1.0pp label_dev=3.8pp
#   Split 23 | train=4080 (79.5%) pos=18.0% | test=1052 (20.5%) pos=14.8% | size_dev=0.5pp label_dev=2.6pp
#   Split 24 | train=4059 (79.1%) pos=16.7% | test=1073 (20.9%) pos=19.8% | size_dev=0.9pp label_dev=2.4pp (accepted on attempt 2)
#   Split 25 | train=4077 (79.4%) pos=18.0% | test=1055 (20.6%) pos=14.9% | size_dev=0.6pp label_dev=2.4pp
#   Split 26 | train=4058 (79.1%) pos=16.4% | test=1074 (20.9%) pos=20.9% | size_dev=0.9pp label_dev=3.5pp
#   Split 27 | train=4164 (81.1%) pos=17.2% | test=968 (18.9%) pos=17.7% | size_dev=1.1pp label_dev=0.3pp
#   Split 28 | train=4075 (79.4%) pos=17.5% | test=1057 (20.6%) pos=16.7% | size_dev=0.6pp label_dev=0.7pp
#   Split 29 | train=4044 (78.8%) pos=16.3% | test=1088 (21.2%) pos=21.1% | size_dev=1.2pp label_dev=3.8pp
#   Split 30 | train=3984 (77.6%) pos=18.1% | test=1148 (22.4%) pos=14.6% | size_dev=2.4pp label_dev=2.8pp
#   Split 31 | train=4142 (80.7%) pos=17.6% | test=990 (19.3%) pos=16.1% | size_dev=0.7pp label_dev=1.2pp
#   Split 32 | train=4010 (78.1%) pos=18.1% | test=1122 (21.9%) pos=14.6% | size_dev=1.9pp label_dev=2.7pp
#   Split 33 | train=4058 (79.1%) pos=18.1% | test=1074 (20.9%) pos=14.3% | size_dev=0.9pp label_dev=3.1pp
#   Split 34 | train=4140 (80.7%) pos=17.2% | test=992 (19.3%) pos=17.8% | size_dev=0.7pp label_dev=0.5pp (accepted on attempt 2)
#   Split 35 | train=3993 (77.8%) pos=17.0% | test=1139 (22.2%) pos=18.4% | size_dev=2.2pp label_dev=1.1pp (accepted on attempt 2)
#   Split 36 | train=4046 (78.8%) pos=18.2% | test=1086 (21.2%) pos=14.3% | size_dev=1.2pp label_dev=3.1pp (accepted on attempt 3)
#   Split 37 | train=4110 (80.1%) pos=17.6% | test=1022 (19.9%) pos=16.3% | size_dev=0.1pp label_dev=1.0pp
#   Split 38 | train=4030 (78.5%) pos=18.1% | test=1102 (21.5%) pos=14.7% | size_dev=1.5pp label_dev=2.7pp
#   Split 39 | train=4130 (80.5%) pos=17.8% | test=1002 (19.5%) pos=15.5% | size_dev=0.5pp label_dev=1.8pp
#   Split 40 | train=4147 (80.8%) pos=17.2% | test=985 (19.2%) pos=17.8% | size_dev=0.8pp label_dev=0.5pp
#   Split 41 | train=4165 (81.2%) pos=17.5% | test=967 (18.8%) pos=16.6% | size_dev=1.2pp label_dev=0.7pp
#   Split 42 | train=4116 (80.2%) pos=18.3% | test=1016 (19.8%) pos=13.3% | size_dev=0.2pp label_dev=4.0pp
#   Split 43 | train=4121 (80.3%) pos=16.6% | test=1011 (19.7%) pos=20.3% | size_dev=0.3pp label_dev=3.0pp
#   Split 44 | train=4066 (79.2%) pos=16.8% | test=1066 (20.8%) pos=19.2% | size_dev=0.8pp label_dev=1.9pp
#   Split 45 | train=4109 (80.1%) pos=17.6% | test=1023 (19.9%) pos=16.2% | size_dev=0.1pp label_dev=1.1pp
#   Split 46 | train=4140 (80.7%) pos=17.6% | test=992 (19.3%) pos=16.2% | size_dev=0.7pp label_dev=1.2pp (accepted on attempt 2)
#   Split 47 | train=4108 (80.0%) pos=17.6% | test=1024 (19.9%) pos=16.1% | size_dev=0.1pp label_dev=1.3pp
#   Split 48 | train=4031 (78.5%) pos=17.7% | test=1101 (21.4%) pos=16.0% | size_dev=1.4pp label_dev=1.3pp
#   Split 49 | train=4166 (81.2%) pos=17.6% | test=966 (18.8%) pos=16.0% | size_dev=1.2pp label_dev=1.3pp (accepted on attempt 2)
#   Split 50 | train=4055 (79.0%) pos=18.2% | test=1077 (21.0%) pos=14.0% | size_dev=1.0pp label_dev=3.3pp
#
# group-size bucket distribution after split (groups counted):
# BUCKET           TRAIN   TEST  TOTAL TEST_FRAC
# large               18      5     23     0.217
# medium              92     23    115     0.200
# singleton         1161    290   1451     0.200
# small              432    108    540     0.200
#
# --- Integrity check ---
#   Splits emitted:            50 / 50
#   split_index contiguous:    True
#   Total leakage violations:  0
#   Splits failing validation: 0
#
# --- Saving outputs ---
#   Saved: /Users/anitaapplegarth/github/dphil/protein_complexes/data/lookup_tables/corum/ess_protein_splits.csv  (256,600 rows)
#   Saved: /Users/anitaapplegarth/github/dphil/protein_complexes/data/lookup_tables/corum/ess_split_balance.csv
#
# ==========================================================================================
# SPLIT SUMMARY -- Size-stratified repeated random group-level splits
# Essentiality Labels (OGEE v3 + DepMap)
# ==========================================================================================
# Total unique proteins:            5132
# Total complexes:                  5454
# Total groups:                     2129
#   Large      (>20, merged):       23
#   Medium     (6-20):              115
#   Small      (2-5):               540
#   Singleton  (1 protein):         1451
# Analysis population:              5054  (labelled + structured; excludes 70 Unknown, 10 no-group)
# Global essential rate:                17.3%  (876 / 5054)
# Allocation mode:                  size-stratified
# Number of splits:                 50
# Train/test ratio:                 80% / 20%
# Size tolerance:                   +/-5.0pp  (acceptable range: 15%-25%)
# Balance tolerance:                +/-4.5pp
# Max redraw attempts per split:    25
# Splits requiring redraw:          7 / 50
# Splits with size warnings:        0 / 50
# Splits with balance warnings:     0 / 50
# Splits with leakage violations:   0 / 50
# Splits emitted without full accept: 0 / 50
#
# Test positive COUNT across splits: min 130, median 164, max 239. On an imbalanced task the per-split positive count drives PR-AUC variance more than the rate does.
#
# Denominators above are the number of splits actually emitted, not the requested n_splits.
#
#  Split  Att   Train N  Train%  Train pos%   Test N  Test%  Test pos%  Test pos n   SzDev  LblDev  Flag
#     33    1      4058   79.1%       18.1%     1074  20.9%      14.3%         150    0.9pp    3.1pp
#     34    2      4140   80.7%       17.2%      992  19.3%      17.8%         175    0.7pp    0.5pp
#     35    2      3993   77.8%       17.0%     1139  22.2%      18.4%         207    2.2pp    1.1pp
#     36    3      4046   78.8%       18.2%     1086  21.2%      14.3%         153    1.2pp    3.1pp
#     37    1      4110   80.1%       17.6%     1022  19.9%      16.3%         163    0.1pp    1.0pp
#     38    1      4030   78.5%       18.1%     1102  21.5%      14.7%         158    1.5pp    2.7pp
#     39    1      4130   80.5%       17.8%     1002  19.5%      15.5%         153    0.5pp    1.8pp
#     40    1      4147   80.8%       17.2%      985  19.2%      17.8%         173    0.8pp    0.5pp
#     41    1      4165   81.2%       17.5%      967  18.8%      16.6%         158    1.2pp    0.7pp
#     42    1      4116   80.2%       18.3%     1016  19.8%      13.3%         133    0.2pp    4.0pp
#     43    1      4121   80.3%       16.6%     1011  19.7%      20.3%         201    0.3pp    3.0pp
#     44    1      4066   79.2%       16.8%     1066  20.8%      19.2%         201    0.8pp    1.9pp
#     45    1      4109   80.1%       17.6%     1023  19.9%      16.2%         163    0.1pp    1.1pp
#     46    2      4140   80.7%       17.6%      992  19.3%      16.2%         158    0.7pp    1.2pp
#     47    1      4108   80.0%       17.6%     1024  19.9%      16.1%         162    0.1pp    1.3pp
#     48    1      4031   78.5%       17.7%     1101  21.4%      16.0%         175    1.4pp    1.3pp
#     49    2      4166   81.2%       17.6%      966  18.8%      16.0%         152    1.2pp    1.3pp
#     50    1      4055   79.0%       18.2%     1077  21.0%      14.0%         149    1.0pp    3.3pp
# ----------------------------------------------------------------------------------------------------
#   Mean                  79.6%       17.5%           20.4%      16.8%       172.7    1.0pp
#    Std                  1.24%       0.58%           1.24%      2.21%       25.11   0.83pp
#    Min                  76.6%       16.2%           18.7%      13.3%         130    0.1pp
#    Max                  81.3%       18.4%           23.4%      21.8%         239    3.4pp
#
# Leakage guarantee: all structural groups are atomic -- no group spans train and test. Complexes are NOT atomic by design; see the split_common module docstring.
# Flag key: Sz = size out of range, Lb = label imbalance, Lk = leakage, Vd = failed validation
#
# Bucket distribution (final split):
# group-size bucket distribution after split (groups counted):
# BUCKET           TRAIN   TEST  TOTAL TEST_FRAC
# large               18      5     23     0.217
# medium              92     23    115     0.200
# singleton         1161    290   1451     0.200
# small              432    108    540     0.200
#
# ==========================================================================================
# TEST SET BREAKDOWN BY STRUCTURAL GROUP SIZE BUCKET (proteins in test)
# ==========================================================================================
#  Split   Large N    L%   Pos%   Medium N    M%   Pos%   Small N    S%   Pos%   Singleton N   Sg%   Pos%
# ------------------------------------------------------------------------------------------
#      1       139 13.2%  19.8%        218 19.6%  18.5%       312 20.8%  13.5%           290 20.0%  13.2%
#      2       172 16.3%  13.0%        200 17.9%  20.8%       324 21.6%  20.0%           290 20.0%  10.1%
#      3       392 37.1%   6.8%        221 19.8%  34.4%       297 19.8%  10.1%           290 20.0%  15.8%
#     33       273 25.8%  10.2%        196 17.6%  25.8%       313 20.9%  11.3%           290 20.0%  13.6%
#     34       171 16.2%  30.6%        223 20.0%  19.5%       306 20.4%  15.8%           290 20.0%  11.2%
#     35       323 30.6%  30.5%        235 21.1%  17.2%       289 19.3%  11.8%           290 20.0%  12.6%
#     36       292 27.6%   5.8%        211 18.9%  28.2%       291 19.4%  10.0%           290 20.0%  16.9%
#     37       199 18.8%   4.8%        221 19.8%  33.3%       310 20.7%  15.3%           290 20.0%  11.9%
#     38       300 28.4%  13.3%        214 19.2%  20.9%       296 19.7%  10.9%           290 20.0%  15.3%
#     39       219 20.7%  18.1%        187 16.8%  15.6%       304 20.3%  15.2%           290 20.0%  13.9%
#     40       142 13.4%  17.7%        239 21.4%  28.8%       312 20.8%  13.9%           290 20.0%  12.9%
#     41       159 15.0%  16.4%        221 19.8%  21.8%       295 19.7%  15.4%           290 20.0%  14.1%
#     42       183 17.3%  14.9%        237 21.3%  12.8%       304 20.3%  14.8%           290 20.0%  11.2%
#     43       200 18.9%  43.1%        216 19.4%  23.5%       303 20.2%  11.3%           290 20.0%  12.5%
#     44       263 24.9%  26.7%        221 19.8%  31.6%       290 19.3%  11.1%           290 20.0%  11.6%
#     45       196 18.5%  21.1%        237 21.3%  19.7%       298 19.9%  11.6%           290 20.0%  14.8%
#     46       200 18.9%  13.3%        219 19.6%  22.5%       281 18.7%  14.6%           290 20.0%  14.8%
#     47       212 20.1%  11.9%        227 20.4%  25.6%       293 19.5%  16.1%           290 20.0%  11.6%
#     48       320 30.3%  16.6%        186 16.7%  17.3%       303 20.2%  16.9%           290 20.0%  13.7%
#     49       141 13.3%   3.6%        236 21.2%  29.1%       297 19.8%  13.6%           290 20.0%  14.0%
#     50       282 26.7%  12.3%        207 18.6%  16.7%       296 19.7%  15.2%           290 20.0%  12.6%
# ------------------------------------------------------------------------------------------
#   Mean     232.1 22.0%  19.9%      221.1 19.8%  22.4%     301.1 20.1%  13.6%         290.0 20.0%  13.3%
#    Std      66.3 6.27% 10.32%       15.0 1.34%  6.07%      10.9 0.73%  2.62%           0.0 0.00%  1.76%
#
#   N% = % of that bucket's proteins going to test.
#   Pos% = essential rate among analysis-population test proteins in that bucket.
#
# ==========================================================================================
# LARGE-BUCKET PROFILE ANALYSIS
# ==========================================================================================
#
# 1. Which large groups are in TEST per split?
# ------------------------------------------------------------
#   Split  1: grp_0757, grp_1261, grp_1325, grp_1411, grp_2721
#   Split  2: grp_0288, grp_0456, grp_0757, grp_0879, grp_0886
#   Split  3: grp_0287, grp_0756, grp_1114, grp_2003, grp_2161
#   Split  4: grp_0335, grp_0639, grp_0849, grp_0942, grp_2161
#   Split  5: grp_0287, grp_0684, grp_0757, grp_0886, grp_2721
#   Split  6: grp_0302, grp_0456, grp_0639, grp_0879, grp_1411
#   Split  7: grp_0639, grp_0849, grp_1261, grp_1325, grp_2161
#   Split  8: grp_0288, grp_0757, grp_0849, grp_0942, grp_1411
#   Split  9: grp_0456, grp_0756, grp_0879, grp_0942, grp_1261
#   Split 50: grp_0287, grp_1261, grp_1883, grp_2003, grp_2721
#
# 2. All large groups and their sizes (analysis population proteins)
# ------------------------------------------------------------
#   grp_0287:   90 proteins  |  in test for splits [3, 5, 16, 17, 21, 36, 48, 50]
#   grp_0288:   25 proteins  |  in test for splits [2, 8, 14, 21, 31, 42, 45]
#   grp_0302:   40 proteins  |  in test for splits [6, 13, 15, 24, 26, 31, 36, 42, 45, 46]
#   grp_0320:   82 proteins  |  in test for splits [14, 16, 19, 20, 24, 26, 35, 43]
#   grp_0335:   40 proteins  |  in test for splits [4, 17, 18, 23, 28, 30, 31, 32, 34]
#   grp_0456:   54 proteins  |  in test for splits [2, 6, 9, 10, 16, 26, 30, 38, 47]
#   grp_0639:   23 proteins  |  in test for splits [4, 6, 7, 12, 13, 18, 39, 40, 41]
#   grp_0684:   37 proteins  |  in test for splits [5, 15, 27, 31, 33, 37, 41, 47, 48, 49]
#   grp_0688:   24 proteins  |  in test for splits [11, 12, 25, 29, 34, 38, 48]
#   grp_0756:   80 proteins  |  in test for splits [3, 9, 10, 11, 13, 16, 19, 25, 28, 29, 30, 33, 35]
#   grp_0757:   20 proteins  |  in test for splits [1, 2, 5, 8, 13, 17, 20, 23, 28, 37, 38, 39, 42, 43, 44]
#   grp_0849:   23 proteins  |  in test for splits [4, 7, 8, 18, 21, 22, 37, 40, 41, 49]
#   grp_0879:   42 proteins  |  in test for splits [2, 6, 9, 11, 18, 27, 28, 33, 44, 45]
#   grp_0886:   21 proteins  |  in test for splits [2, 5, 17, 27, 35, 40, 46]
#   grp_0942:   61 proteins  |  in test for splits [4, 8, 9, 11, 12, 14, 24, 28, 42, 44, 45, 47, 48]
#   grp_1114:  107 proteins  |  in test for splits [3, 10, 19, 30, 32, 35, 36, 38, 39, 44, 48]
#   grp_1261:   32 proteins  |  in test for splits [1, 7, 9, 12, 15, 16, 19, 34, 39, 43, 47, 50]
#   grp_1325:   28 proteins  |  in test for splits [1, 7, 10, 12, 13, 14, 22, 31, 35, 36, 39, 41, 42, 43, 46, 49]
#   grp_1411:   26 proteins  |  in test for splits [1, 6, 8, 11, 14, 20, 22, 23, 24, 25, 34, 36, 37, 45, 47, 49]
#   grp_1883:   48 proteins  |  in test for splits [20, 26, 29, 30, 32, 34, 40, 41, 50]
#   grp_2003:   81 proteins  |  in test for splits [3, 10, 15, 18, 19, 20, 21, 22, 23, 25, 29, 32, 33, 37, 38, 46, 50]
#   grp_2161:   26 proteins  |  in test for splits [3, 4, 7, 22, 23, 24, 25, 27, 32, 33, 40, 43, 49]
#   grp_2721:   25 proteins  |  in test for splits [1, 5, 15, 17, 21, 26, 27, 29, 44, 46, 50]
#
# 3. Large test set size per split (all proteins)
# ------------------------------------------------------------
#   Split  1:  139 proteins
#   Split  2:  172 proteins
#   Split  3:  392 proteins
#   Split  4:  174 proteins
#   Split  5:  200 proteins
#   Split  6:  186 proteins
#   Split  7:  134 proteins
#   Split  8:  164 proteins
#   Split  9:  272 proteins
#   Split 10:  358 proteins
#   Split 11:  234 proteins
#   Split 12:  169 proteins
#   Split 13:  199 proteins
#   Split 14:  227 proteins
#   Split 15:  221 proteins
#   Split 16:  344 proteins
#   Split 17:  203 proteins
#   Split 18:  214 proteins
#   Split 19:  393 proteins
#   Split 20:  272 proteins
#   Split 21:  251 proteins
#   Split 22:  190 proteins
#   Split 23:  206 proteins
#   Split 24:  239 proteins
#   Split 25:  244 proteins
#   Split 26:  253 proteins
#   Split 27:  152 proteins
#   Split 28:  251 proteins
#   Split 29:  264 proteins
#   Split 30:  332 proteins
#   Split 31:  172 proteins
#   Split 32:  309 proteins
#   Split 33:  273 proteins
#   Split 34:  171 proteins
#   Split 35:  323 proteins
#   Split 36:  292 proteins
#   Split 37:  199 proteins
#   Split 38:  300 proteins
#   Split 39:  219 proteins
#   Split 40:  142 proteins
#   Split 41:  159 proteins
#   Split 42:  183 proteins
#   Split 43:  200 proteins
#   Split 44:  263 proteins
#   Split 45:  196 proteins
#   Split 46:  200 proteins
#   Split 47:  212 proteins
#   Split 48:  320 proteins
#   Split 49:  141 proteins
#   Split 50:  282 proteins
#
# 4. Overlap statistics across all splits
# ------------------------------------------------------------
#   Intersection (in ALL test sets): 0
#   Union (in ANY test set):         1057
#   Jaccard similarity:              0.000
#
# 5. Per-protein test frequency (how many splits each protein is in test)
# ------------------------------------------------------------
#   7 split(s): 72 proteins
#   8 split(s): 175 proteins
#   9 split(s): 166 proteins
#   10 split(s): 142 proteins
#   11 split(s): 133 proteins
#   12 split(s): 33 proteins
#   13 split(s): 169 proteins
#   15 split(s): 27 proteins
#   16 split(s): 54 proteins
#   17 split(s): 86 proteins
#
# 6. Per-group test frequency -- randomness check
# ------------------------------------------------------------
#   Total large groups:          23
#   Groups drawn to test/split:  5  (21.7%)
#   Expected test freq per group over 50 splits: 10.9
#   Binomial SD: 2.92   2 SD band: [5.0, 16.7]
#   With this many groups, roughly one falling outside the band by chance is expected.
#
#   Group                           AP size  Test count  Note
#   grp_0287                             90           8  ok
#   grp_0288                             25           7  ok
#   grp_0302                             40          10  ok
#   grp_0320                             82           8  ok
#   grp_0335                             40           9  ok
#   grp_0456                             54           9  ok
#   grp_0639                             23           9  ok
#   grp_0684                             37          10  ok
#   grp_0688                             24           7  ok
#   grp_0756                             80          13  ok
#   grp_0757                             20          15  ok
#   grp_0849                             23          10  ok
#   grp_0879                             42          10  ok
#   grp_0886                             21           7  ok
#   grp_0942                             61          13  ok
#   grp_1114                            107          11  ok
#   grp_1261                             32          12  ok
#   grp_1325                             28          16  ok
#   grp_1411                             26          16  ok
#   grp_1883                             48           9  ok
#   grp_2003                             81          17  !! outside 2 SD
#   grp_2161                             26          13  ok
#   grp_2721                             25          11  ok
#
#   Min test count: 7  Max: 17  Mean: 10.87  Std: 2.95
#   Groups outside the 2 SD band: 1 / 23  (~1 expected by chance)
#   Observed SD vs binomial SD: 2.95 vs 2.92  -- wider than a fair draw would give.
#
# ==========================================================================================
# 7. Essential rate per group size  (analysis population only)
# ==========================================================================================
#   Analysis population = labelled (Essential/Non-essential) + structured
#   Global essential rate: 17.3%
#   n = 5054
#
#     group_size   n_groups    n_proteins    n_positive      pos_rate
#   --------------------------------------------------------------------
#              1       1432          1432           191         13.3%
#              2        285           570            89         15.6%
#              3        138           414            56         13.5%
#              4         68           272            37         13.6%
#              5         48           240            25         10.4%
#              6         20           120            32         26.7%
#              7         19           133            18         13.5%
#              8         20           160            31         19.4%
#              9          9            81             4          4.9%
#             10          8            80            11         13.8%
#             11          8            88            13         14.8%
#             12          8            96            36         37.5%
#             13          2            26            10         38.5%
#             14          5            70            17         24.3%
#             15          1            15            12         80.0%
#             16          4            64             8         12.5%
#             17          5            85            30         35.3%
#             18          3            54            16         29.6%
#             19          1            19             4         21.1%
#             20          1            20             0          0.0%
#             21          1            21             0          0.0%
#             23          2            46            21         45.7%
#             24          1            24            19         79.2%
#             25          2            50            26         52.0%
#             26          2            52             0          0.0%
#             28          1            28             0          0.0%
#             32          1            32             6         18.8%
#             37          1            37             1          2.7%
#             40          2            80            25         31.2%
#             42          1            42            15         35.7%
#             48          1            48             4          8.3%
#             54          1            54             0          0.0%
#             61          1            61            18         29.5%
#             80          1            80             7          8.8%
#             81          1            81             4          4.9%
#             82          1            82            75         91.5%
#             90          1            90             0          0.0%
#            107          1           107            15         14.0%
#
#   Saved: /Users/anitaapplegarth/github/dphil/protein_complexes/data/lookup_tables/corum/avg_essentiality_by_group_size.csv
#
# ==========================================================================================
# 8. Large-bucket test essential rate by split
# ==========================================================================================
#   Global essential rate: 17.3%
#
#   Split   Groups in test   Test proteins  Bucket rate
#   ------------------------------------------------------
#       1                5             139        19.8%
#       2                5             172        13.0%
#       3                5             392         6.8%
#       4                5             174        35.8%
#       5                5             200        10.9%
#       6                5             186        18.4%
#       7                5             134        20.5%
#       8                5             164        18.1%
#       9                5             272        17.1%
#      10                5             358         7.4%
#      11                5             234        25.3%
#      12                5             169        35.7%
#      13                5             199        13.6%
#      14                5             227        44.6%
#      15                5             221        15.3%
#      16                5             344        26.0%
#      17                5             203        21.9%
#      18                5             214        30.1%
#      19                5             393        28.0%
#      20                5             272        32.3%
#      21                5             251        13.9%
#      22                5             190         4.3%
#      23                5             206        14.0%
#      24                5             239        40.4%
#      25                5             244        12.7%
#      26                5             253        40.6%
#      27                5             152        23.8%
#      28                5             251        25.9%
#      29                5             264        20.9%
#      30                5             332        14.9%
#      31                5             172        18.8%
#      32                5             309        15.2%
#      33                5             273        10.2%
#      34                5             171        30.6%
#      35                5             323        30.5%
#      36                5             292         5.8%
#      37                5             199         4.8%
#      38                5             300        13.3%
#      39                5             219        18.1%
#      40                5             142        17.7%
#      41                5             159        16.4%
#      42                5             183        14.9%
#      43                5             200        43.1%
#      44                5             263        26.7%
#      45                5             196        21.1%
#      46                5             200        13.3%
#      47                5             212        11.9%
#      48                5             320        16.6%
#      49                5             141         3.6%
#      50                5             282        12.3%
#
#   Saved: /Users/anitaapplegarth/github/dphil/protein_complexes/data/lookup_tables/corum/ess_split_summary.txt
#
# Done!
