# %%
"""
Repeated random structural-group-level splits -- ChEMBL drug-target labels.

All logic lives in split_common.py; this file is configuration only.

LABELS: single-protein ChEMBL targets only (primary analysis). Complex-level
(PROTEIN COMPLEX) targets are NOT in this set, so no positive label is shared
across the train/test boundary. To split the mixed set for the Supplementary,
point 'label_file' at the _mixed CSV and change the output paths.

NOTE: corum_drug_targets_chembl.py currently writes to the rotations/gesine
repository with a _single / _mixed suffix. 'label_file' below must point at
whichever file that script actually produced.
"""

from split_common import run_splits

BASE = '/Users/anitaapplegarth/github/dphil/protein_complexes/data/lookup_tables'

CONFIG = {
    'task_description': 'Drug Target Labels (ChEMBL, single-protein targets only)',

    # ---- Input files -------------------------------------------------------
    'group_mapping':      f'{BASE}/corum/mapping_struct.csv',
    'complex_membership': f'{BASE}/corum/stoich_protein.csv',
    'label_file':         f'{BASE}/corum_drug_target_chembl_single.csv',

    # ---- Input column names ------------------------------------------------
    'col_group_protein':   'uniprot_id',
    'col_group_id':        'group_id',
    'col_complex_id':      'ComplexId',
    'col_complex_protein': 'ProteinId',
    'col_label_protein':   'ProteinId',
    'col_label_value':     'target',

    # ---- Label scheme ------------------------------------------------------
    'label_scheme': {
        'positive': 'Drug_target',
        'negative': 'Non_target',
        'noun':     'drug target',
        # 1 -> positive, anything else -> negative. Never returns None:
        # every protein in the master list carries an explicit 0 or 1.
        'binarise': lambda v: 'Drug_target' if v == 1 else 'Non_target',
    },

    # ---- Output files ------------------------------------------------------
    'output_all_splits':   f'{BASE}/corum/chembl_protein_splits.csv',
    'output_balance':      f'{BASE}/corum/chembl_split_balance.csv',
    'output_summary':      f'{BASE}/corum/chembl_split_summary.txt',
    'output_rate_by_size': f'{BASE}/corum/avg_chembl_by_group_size.csv',

    # ---- Split parameters --------------------------------------------------
    'n_splits':    50,
    'train_ratio': 0.80,
    'test_ratio':  0.20,
    'base_seed':   42,

    # Flag a split if test set size deviates more than this from 20%
    'max_size_deviation': 5.0,   # pp -- acceptable range [15%, 25%]

    # Flag a split if the test positive rate deviates more than this from the
    # global rate. Tight because the global rate is low. If the printed global
    # rate moves materially, revisit -- too tight and every attempt fails and
    # falls through to the flagged-best-candidate path.
    'max_label_rate_deviation': 1.5,

    'max_attempts': 25,

    # ---- Validation tuning -------------------------------------------------
    'validate_abs_tol':            0.15,
    'validate_min_groups':         3,
    'min_test_groups_per_bucket':  1,
    'strict_duplicate_check':      False,
    'require_full_n_splits':       True,

    # ---- Bucket ablation ---------------------------------------------------
    # False pools all groups and ignores size buckets; output paths gain the
    # '_unstrat' suffix so the stratified files are never overwritten.
    'stratify_by_bucket': True,
    'unstrat_suffix':     '_unstrat',
}


if __name__ == '__main__':
    run_splits(CONFIG)
# Out:
# ======================================================================
# Repeated Random group-Level Splitting -- Size-Stratified, N=50
# Drug Target Labels (ChEMBL, single-protein targets only)
# ======================================================================
#
# --- Loading data ---
#   Groups:    5122 rows, 2129 unique groups
#   Complexes: 5454 complexes, 5132 unique proteins
#   Labels:    5132 rows from /Users/anitaapplegarth/github/dphil/protein_complexes/data/lookup_tables/corum_drug_target_chembl_single.csv
#   Duplicate group assignments: none
#
#   Label distribution (5132 total complex proteins):
#     Drug_target    :   617
#     Non_target     :  4515
#     Unknown        :     0  (no usable label -- excluded)
#     No-group       :    10  (no structural assignment -- excluded)
#   Analysis population (labelled + structured): 5122
#   Global drug target rate (analysis population): 12.0%  (617 / 5122)
#
# --- Group size buckets (largest first) ---
#   large        (>20 proteins (merged large + very large)):   23 groups,  1057 proteins -- 5 grps drawn to test each split
#   medium       (6-20                                    ):  115 groups,  1115 proteins -- 23 grps drawn to test each split
#   small        (2-5                                     ):  540 groups,  1499 proteins -- 108 grps drawn to test each split
#   singleton    (1 protein                               ): 1451 groups,  1451 proteins -- 290 grps drawn to test each split
#   No-group proteins: 10
#
# --- Allocation mode: SIZE-STRATIFIED ---
# --- Generating 50 splits (tolerance +/-1.5pp label, +/-5.0pp size, max 25 attempts each) ---
#   Split  1 | train=4171 (81.3%) pos=12.2% | test=961 (18.7%) pos=11.2% | size_dev=1.3pp label_dev=0.9pp
#   Split  2 | train=4157 (81.0%) pos=12.1% | test=975 (19.0%) pos=12.0% | size_dev=1.0pp label_dev=0.0pp (accepted on attempt 3)
#   Split  3 | train=4095 (79.8%) pos=11.8% | test=1037 (20.2%) pos=13.1% | size_dev=0.2pp label_dev=1.1pp (accepted on attempt 2)
#   Split  4 | train=4078 (79.5%) pos=11.7% | test=1054 (20.5%) pos=13.5% | size_dev=0.5pp label_dev=1.4pp (accepted on attempt 7)
#   Split  5 | train=4054 (79.0%) pos=12.0% | test=1078 (21.0%) pos=12.1% | size_dev=1.0pp label_dev=0.0pp (accepted on attempt 4)
#   Split  6 | train=4140 (80.7%) pos=12.2% | test=992 (19.3%) pos=11.2% | size_dev=0.7pp label_dev=0.8pp (accepted on attempt 5)
#   Split  7 | train=3998 (77.9%) pos=12.1% | test=1134 (22.1%) pos=11.8% | size_dev=2.1pp label_dev=0.2pp (accepted on attempt 3)
#   Split  8 | train=4105 (80.0%) pos=12.0% | test=1027 (20.0%) pos=12.1% | size_dev=0.0pp label_dev=0.1pp (accepted on attempt 2)
#   Split  9 | train=4075 (79.4%) pos=11.8% | test=1057 (20.6%) pos=12.8% | size_dev=0.6pp label_dev=0.8pp (accepted on attempt 3)
#   Split 10 | train=4054 (79.0%) pos=12.0% | test=1078 (21.0%) pos=12.3% | size_dev=1.0pp label_dev=0.2pp (accepted on attempt 4)
#   Split 11 | train=4072 (79.3%) pos=12.2% | test=1060 (20.6%) pos=11.5% | size_dev=0.7pp label_dev=0.5pp (accepted on attempt 2)
#   Split 12 | train=3978 (77.5%) pos=11.9% | test=1154 (22.5%) pos=12.4% | size_dev=2.5pp label_dev=0.4pp (accepted on attempt 4)
#   Split 13 | train=4049 (78.9%) pos=12.2% | test=1083 (21.1%) pos=11.7% | size_dev=1.1pp label_dev=0.4pp (accepted on attempt 7)
#   Split 14 | train=4114 (80.2%) pos=12.2% | test=1018 (19.8%) pos=11.2% | size_dev=0.2pp label_dev=0.8pp
#   Split 15 | train=4073 (79.4%) pos=11.9% | test=1059 (20.6%) pos=12.5% | size_dev=0.6pp label_dev=0.4pp
#   Split 16 | train=4160 (81.1%) pos=12.3% | test=972 (18.9%) pos=11.0% | size_dev=1.1pp label_dev=1.0pp (accepted on attempt 5)
#   Split 17 | train=4087 (79.6%) pos=12.4% | test=1045 (20.4%) pos=10.6% | size_dev=0.4pp label_dev=1.5pp (accepted on attempt 2)
#   Split 18 | train=4094 (79.8%) pos=12.2% | test=1038 (20.2%) pos=11.4% | size_dev=0.2pp label_dev=0.7pp
#   Split 19 | train=4089 (79.7%) pos=12.3% | test=1043 (20.3%) pos=10.8% | size_dev=0.3pp label_dev=1.2pp (accepted on attempt 4)
#   Split 20 | train=4171 (81.3%) pos=12.3% | test=961 (18.7%) pos=11.1% | size_dev=1.3pp label_dev=1.0pp (accepted on attempt 9)
#   Split 21 | train=4105 (80.0%) pos=12.0% | test=1027 (20.0%) pos=12.3% | size_dev=0.0pp label_dev=0.2pp (accepted on attempt 2)
#   Split 22 | train=4156 (81.0%) pos=11.8% | test=976 (19.0%) pos=13.1% | size_dev=1.0pp label_dev=1.1pp
#   Split 23 | train=4080 (79.5%) pos=12.2% | test=1052 (20.5%) pos=11.4% | size_dev=0.5pp label_dev=0.6pp
#   Split 24 | train=4155 (81.0%) pos=11.7% | test=977 (19.0%) pos=13.4% | size_dev=1.0pp label_dev=1.4pp (accepted on attempt 5)
#   Split 25 | train=4077 (79.4%) pos=12.2% | test=1055 (20.6%) pos=11.4% | size_dev=0.6pp label_dev=0.7pp
#   Split 26 | train=4100 (79.9%) pos=12.2% | test=1032 (20.1%) pos=11.5% | size_dev=0.1pp label_dev=0.6pp (accepted on attempt 4)
#   Split 27 | train=4164 (81.1%) pos=12.4% | test=968 (18.9%) pos=10.7% | size_dev=1.1pp label_dev=1.4pp
#   Split 28 | train=4018 (78.3%) pos=12.0% | test=1114 (21.7%) pos=12.2% | size_dev=1.7pp label_dev=0.2pp (accepted on attempt 3)
#   Split 29 | train=4044 (78.8%) pos=12.2% | test=1088 (21.2%) pos=11.5% | size_dev=1.2pp label_dev=0.5pp (accepted on attempt 2)
#   Split 30 | train=3984 (77.6%) pos=11.7% | test=1148 (22.4%) pos=13.3% | size_dev=2.4pp label_dev=1.2pp
#   Split 31 | train=4142 (80.7%) pos=12.1% | test=990 (19.3%) pos=11.7% | size_dev=0.7pp label_dev=0.3pp
#   Split 32 | train=3998 (77.9%) pos=12.0% | test=1134 (22.1%) pos=12.3% | size_dev=2.1pp label_dev=0.2pp (accepted on attempt 3)
#   Split 33 | train=4058 (79.1%) pos=11.7% | test=1074 (20.9%) pos=13.3% | size_dev=0.9pp label_dev=1.3pp
#   Split 34 | train=4028 (78.5%) pos=12.4% | test=1104 (21.5%) pos=10.9% | size_dev=1.5pp label_dev=1.2pp
#   Split 35 | train=3993 (77.8%) pos=11.7% | test=1139 (22.2%) pos=13.4% | size_dev=2.2pp label_dev=1.3pp (accepted on attempt 2)
#   Split 36 | train=4108 (80.0%) pos=12.3% | test=1024 (19.9%) pos=11.0% | size_dev=0.1pp label_dev=1.1pp (accepted on attempt 5)
#   Split 37 | train=4110 (80.1%) pos=11.9% | test=1022 (19.9%) pos=12.6% | size_dev=0.1pp label_dev=0.5pp
#   Split 38 | train=4036 (78.6%) pos=11.9% | test=1096 (21.4%) pos=12.5% | size_dev=1.4pp label_dev=0.5pp (accepted on attempt 5)
#   Split 39 | train=4134 (80.5%) pos=11.8% | test=998 (19.4%) pos=13.2% | size_dev=0.6pp label_dev=1.1pp (accepted on attempt 2)
#   Split 40 | train=4142 (80.7%) pos=12.0% | test=990 (19.3%) pos=12.3% | size_dev=0.7pp label_dev=0.3pp (accepted on attempt 5)
#   Split 41 | train=4165 (81.2%) pos=12.0% | test=967 (18.8%) pos=12.2% | size_dev=1.2pp label_dev=0.2pp
#   Split 42 | train=4043 (78.8%) pos=11.8% | test=1089 (21.2%) pos=12.8% | size_dev=1.2pp label_dev=0.7pp (accepted on attempt 2)
#   Split 43 | train=4144 (80.8%) pos=12.0% | test=988 (19.2%) pos=12.3% | size_dev=0.8pp label_dev=0.2pp (accepted on attempt 2)
#   Split 44 | train=4066 (79.2%) pos=11.9% | test=1066 (20.8%) pos=12.7% | size_dev=0.8pp label_dev=0.6pp
#   Split 45 | train=4068 (79.3%) pos=12.0% | test=1064 (20.7%) pos=12.3% | size_dev=0.7pp label_dev=0.3pp (accepted on attempt 7)
#   Split 46 | train=4140 (80.7%) pos=11.8% | test=992 (19.3%) pos=12.9% | size_dev=0.7pp label_dev=0.9pp (accepted on attempt 2)
#   Split 47 | train=4201 (81.9%) pos=12.3% | test=931 (18.1%) pos=10.9% | size_dev=1.9pp label_dev=1.2pp (accepted on attempt 8)
#   Split 48 | train=4107 (80.0%) pos=11.7% | test=1025 (20.0%) pos=13.4% | size_dev=0.0pp label_dev=1.3pp (accepted on attempt 4)
#   Split 49 | train=4166 (81.2%) pos=12.0% | test=966 (18.8%) pos=12.1% | size_dev=1.2pp label_dev=0.1pp (accepted on attempt 2)
#   Split 50 | train=4190 (81.6%) pos=11.9% | test=942 (18.4%) pos=12.7% | size_dev=1.6pp label_dev=0.6pp (accepted on attempt 3)
#
# group-size bucket distribution after split (groups counted):
# BUCKET           TRAIN   TEST  TOTAL TEST_FRAC
# large               18      5     23     0.217
# medium              92     23    115     0.200
# singleton         1161    290   1451     0.200
# small              432    108    540     0.200
#
# --- Integrity check ---
#   Splits emitted:            50 / 50
#   split_index contiguous:    True
#   Total leakage violations:  0
#   Splits failing validation: 0
#
# --- Saving outputs ---
#   Saved: /Users/anitaapplegarth/github/dphil/protein_complexes/data/lookup_tables/corum/chembl_protein_splits.csv  (256,600 rows)
#   Saved: /Users/anitaapplegarth/github/dphil/protein_complexes/data/lookup_tables/corum/chembl_split_balance.csv
#
# ==========================================================================================
# SPLIT SUMMARY -- Size-stratified repeated random group-level splits
# Drug Target Labels (ChEMBL, single-protein targets only)
# ==========================================================================================
# Total unique proteins:            5132
# Total complexes:                  5454
# Total groups:                     2129
#   Large      (>20, merged):       23
#   Medium     (6-20):              115
#   Small      (2-5):               540
#   Singleton  (1 protein):         1451
# Analysis population:              5122  (labelled + structured; excludes 0 Unknown, 10 no-group)
# Global drug target rate:              12.0%  (617 / 5122)
# Allocation mode:                  size-stratified
# Number of splits:                 50
# Train/test ratio:                 80% / 20%
# Size tolerance:                   +/-5.0pp  (acceptable range: 15%-25%)
# Balance tolerance:                +/-1.5pp
# Max redraw attempts per split:    25
# Splits requiring redraw:          35 / 50
# Splits with size warnings:        0 / 50
# Splits with balance warnings:     0 / 50
# Splits with leakage violations:   0 / 50
# Splits emitted without full accept: 0 / 50
#
# Test positive COUNT across splits: min 101, median 125, max 152. On an imbalanced task the per-split positive count drives PR-AUC variance more than the rate does.
#
# Denominators above are the number of splits actually emitted, not the requested n_splits.
#
#  Split  Att   Train N  Train%  Train pos%   Test N  Test%  Test pos%  Test pos n   SzDev  LblDev  Flag
# ----------------------------------------------------------------------------------------------------
#      1    1      4171   81.3%       12.2%      961  18.7%      11.2%         107    1.3pp    0.9pp
#      2    3      4157   81.0%       12.1%      975  19.0%      12.0%         117    1.0pp    0.0pp
#      3    2      4095   79.8%       11.8%     1037  20.2%      13.1%         136    0.2pp    1.1pp
#      4    7      4078   79.5%       11.7%     1054  20.5%      13.5%         142    0.5pp    1.4pp
#      5    4      4054   79.0%       12.0%     1078  21.0%      12.1%         130    1.0pp    0.0pp
#      6    5      4140   80.7%       12.2%      992  19.3%      11.2%         111    0.7pp    0.8pp
#      7    3      3998   77.9%       12.1%     1134  22.1%      11.8%         134    2.1pp    0.2pp
#      8    2      4105   80.0%       12.0%     1027  20.0%      12.1%         124    0.0pp    0.1pp
#      9    3      4075   79.4%       11.8%     1057  20.6%      12.8%         135    0.6pp    0.8pp
#     10    4      4054   79.0%       12.0%     1078  21.0%      12.3%         132    1.0pp    0.2pp
#     11    2      4072   79.3%       12.2%     1060  20.6%      11.5%         122    0.7pp    0.5pp
#     12    4      3978   77.5%       11.9%     1154  22.5%      12.4%         143    2.5pp    0.4pp
#     13    7      4049   78.9%       12.2%     1083  21.1%      11.7%         126    1.1pp    0.4pp
#     14    1      4114   80.2%       12.2%     1018  19.8%      11.2%         114    0.2pp    0.8pp
#     15    1      4073   79.4%       11.9%     1059  20.6%      12.5%         132    0.6pp    0.4pp
#     16    5      4160   81.1%       12.3%      972  18.9%      11.0%         107    1.1pp    1.0pp
#   Split 40: grp_0302, grp_0639, grp_0886, grp_0942, grp_1325
#   Split 41: grp_0639, grp_0684, grp_0849, grp_1325, grp_1883
#   Split 42: grp_0335, grp_0688, grp_0757, grp_0879, grp_1114
#   Split 43: grp_0288, grp_0639, grp_1261, grp_2003, grp_2161
#   Split 44: grp_0757, grp_0879, grp_0942, grp_1114, grp_2721
#   Split 45: grp_0456, grp_1883, grp_2003, grp_2161, grp_2721
#   Split 46: grp_0302, grp_0886, grp_1325, grp_2003, grp_2721
#   Split 47: grp_0302, grp_0639, grp_0886, grp_1325, grp_1411
#   Split 48: grp_0287, grp_0688, grp_0757, grp_0849, grp_0942
#   Split 49: grp_0684, grp_0849, grp_1325, grp_1411, grp_2161
#   Split 50: grp_0335, grp_0639, grp_0684, grp_0886, grp_1411
#
# 2. All large groups and their sizes (analysis population proteins)
# ------------------------------------------------------------
#   grp_0287:   90 proteins  |  in test for splits [48]
#   grp_0288:   27 proteins  |  in test for splits [7, 14, 16, 21, 31, 32, 43]
#   grp_0302:   40 proteins  |  in test for splits [2, 15, 31, 34, 38, 40, 46, 47]
#   grp_0320:   85 proteins  |  in test for splits [11, 12, 14, 32, 34, 35, 38]
#   grp_0335:   40 proteins  |  in test for splits [11, 12, 13, 18, 23, 28, 30, 31, 39, 42, 50]
#   grp_0456:   55 proteins  |  in test for splits [5, 6, 16, 26, 30, 36, 45]
#   grp_0639:   23 proteins  |  in test for splits [4, 6, 13, 16, 17, 18, 19, 26, 34, 40, 41, 43, 47, 50]
#   grp_0684:   37 proteins  |  in test for splits [5, 10, 12, 15, 21, 27, 31, 33, 37, 41, 49, 50]
#   grp_0688:   24 proteins  |  in test for splits [2, 3, 10, 19, 25, 42, 48]
#   grp_0756:   81 proteins  |  in test for splits [7, 9, 10, 17, 19, 25, 28, 29, 30, 33, 34, 35]
#   grp_0757:   27 proteins  |  in test for splits [1, 3, 11, 13, 17, 19, 23, 37, 38, 42, 44, 48]
#   grp_0849:   23 proteins  |  in test for splits [5, 18, 22, 24, 29, 36, 37, 41, 48, 49]
#   grp_0879:   42 proteins  |  in test for splits [4, 9, 12, 16, 18, 24, 27, 29, 33, 42, 44]
#   grp_0886:   21 proteins  |  in test for splits [2, 6, 8, 9, 16, 20, 26, 27, 35, 39, 40, 46, 47, 50]
#   grp_0942:   61 proteins  |  in test for splits [5, 7, 8, 10, 14, 17, 21, 26, 32, 36, 40, 44, 48]
#   grp_1114:  108 proteins  |  in test for splits [3, 4, 7, 12, 28, 30, 32, 35, 38, 42, 44]
#   grp_1261:   33 proteins  |  in test for splits [1, 6, 8, 15, 20, 29, 36, 43]
#   grp_1325:   28 proteins  |  in test for splits [1, 2, 3, 4, 9, 14, 17, 20, 22, 24, 26, 31, 32, 35, 40, 41, 46, 47, 49]
#   grp_1411:   26 proteins  |  in test for splits [1, 14, 22, 23, 24, 25, 28, 36, 37, 39, 47, 49, 50]
#   grp_1883:   48 proteins  |  in test for splits [6, 7, 13, 28, 30, 39, 41, 45]
#   grp_2003:   86 proteins  |  in test for splits [5, 8, 9, 10, 11, 13, 15, 18, 19, 21, 22, 23, 24, 25, 29, 33, 34, 37, 39, 43, 45, 46]
#   grp_2161:   27 proteins  |  in test for splits [4, 8, 20, 22, 23, 25, 27, 33, 38, 43, 45, 49]
#   grp_2721:   25 proteins  |  in test for splits [1, 2, 3, 11, 15, 20, 21, 27, 44, 45, 46]
#
# 3. Large test set size per split (all proteins)
# ------------------------------------------------------------
#   Split  1:  139 proteins
#   Split  2:  138 proteins
#   Split  3:  212 proteins
#   Split  4:  228 proteins
#   Split  5:  262 proteins
#   Split  6:  180 proteins
#   Split  7:  325 proteins
#   Split  8:  228 proteins
#   Split  9:  258 proteins
#   Split 10:  289 proteins
#   Split 11:  263 proteins
#   Split 12:  312 proteins
#   Split 13:  224 proteins
#   Split 14:  227 proteins
#   Split 15:  221 proteins
#   Split 16:  168 proteins
#   Split 17:  220 proteins
#   Split 18:  214 proteins
#   Split 19:  241 proteins
#   Split 20:  134 proteins
#   Split 21:  236 proteins
#   Split 22:  190 proteins
#   Split 23:  206 proteins
#   Split 24:  205 proteins
#   Split 25:  244 proteins
#   Split 26:  188 proteins
#   Split 27:  152 proteins
#   Split 28:  303 proteins
#   Split 29:  265 proteins
#   Split 30:  332 proteins
#   Split 31:  172 proteins
#   Split 32:  309 proteins
#   Split 33:  273 proteins
#   Split 34:  315 proteins
#   Split 35:  323 proteins
#   Split 36:  198 proteins
#   Split 37:  199 proteins
#   Split 38:  287 proteins
#   Split 39:  221 proteins
#   Split 40:  173 proteins
#   Split 41:  159 proteins
#   Split 42:  241 proteins
#   Split 43:  196 proteins
#   Split 44:  263 proteins
#   Split 45:  241 proteins
#   Split 46:  200 proteins
#   Split 47:  138 proteins
#   Split 48:  225 proteins
#   Split 49:  141 proteins
#   Split 50:  147 proteins
#
# 4. Overlap statistics across all splits
# ------------------------------------------------------------
#   Intersection (in ALL test sets): 0
#   Union (in ANY test set):         1057
#   Jaccard similarity:              0.000
#
# 5. Per-protein test frequency (how many splits each protein is in test)
# ------------------------------------------------------------
#   1 split(s): 90 proteins
#   7 split(s): 191 proteins
#   8 split(s): 121 proteins
#   10 split(s): 23 proteins
#   11 split(s): 215 proteins
#   12 split(s): 172 proteins
#   13 split(s): 87 proteins
#   14 split(s): 44 proteins
#   19 split(s): 28 proteins
#   22 split(s): 86 proteins
#
# 6. Per-group test frequency -- randomness check
# ------------------------------------------------------------
#   Total large groups:          23
#   Groups drawn to test/split:  5  (21.7%)
#   Expected test freq per group over 50 splits: 10.9
#   Binomial SD: 2.92   2 SD band: [5.0, 16.7]
#   With this many groups, roughly one falling outside the band by chance is expected.
#
#   Group                           AP size  Test count  Note
#   grp_0287                             90           1  !! outside 2 SD
#   grp_0288                             27           7  ok
#   grp_0302                             40           8  ok
#   grp_0320                             85           7  ok
#   grp_0335                             40          11  ok
#   grp_0456                             55           7  ok
#   grp_0639                             23          14  ok
#   grp_0684                             37          12  ok
#   grp_0688                             24           7  ok
#   grp_0756                             81          12  ok
#   grp_0757                             27          12  ok
#   grp_0849                             23          10  ok
#   grp_0879                             42          11  ok
#   grp_0886                             21          14  ok
#   grp_0942                             61          13  ok
#   grp_1114                            108          11  ok
#   grp_1261                             33           8  ok
#   grp_1325                             28          19  !! outside 2 SD
#   grp_1411                             26          13  ok
#   grp_1883                             48           8  ok
#   grp_2003                             86          22  !! outside 2 SD
#   grp_2161                             27          12  ok
#   grp_2721                             25          11  ok
#
#   Min test count: 1  Max: 22  Mean: 10.87  Std: 4.20
#   Groups outside the 2 SD band: 3 / 23  (~1 expected by chance)
#   Observed SD vs binomial SD: 4.20 vs 2.92  -- wider than a fair draw would give.
#
# ==========================================================================================
# 7. Drug target rate per group size  (analysis population only)
# ==========================================================================================
#   Analysis population = labelled (Drug_target/Non_target) + structured
#   Global drug target rate: 12.0%
#   n = 5122
#
#     group_size   n_groups    n_proteins    n_positive      pos_rate
#   --------------------------------------------------------------------
#              1       1451          1451           128          8.8%
#              2        286           572            52          9.1%
#              3        138           414            37          8.9%
#              4         67           268            37         13.8%
#              5         49           245            39         15.9%
#              6         21           126             7          5.6%
#              7         19           133             9          6.8%
#              8         21           168            21         12.5%
#              9          9            81            12         14.8%
#             10          8            80            12         15.0%
#             11          6            66             4          6.1%
#             12          8            96             6          6.2%
#             13          4            52             4          7.7%
#             14          4            56             4          7.1%
#             15          1            15             0          0.0%
#             16          5            80            10         12.5%
#             17          2            34             0          0.0%
#             18          5            90             2          2.2%
#             19          2            38             2          5.3%
#             21          1            21             8         38.1%
#             23          2            46             2          4.3%
#             24          1            24             0          0.0%
#             25          1            25             0          0.0%
#             26          1            26             6         23.1%
#             27          3            81             3          3.7%
#             28          1            28            16         57.1%
#             33          1            33             0          0.0%
#             37          1            37            15         40.5%
#             40          2            80             6          7.5%
#             42          1            42             0          0.0%
#             48          1            48             1          2.1%
#             55          1            55            12         21.8%
#             61          1            61             5          8.2%
#             81          1            81             0          0.0%
#             85          1            85             1          1.2%
#             86          1            86            36         41.9%
#             90          1            90            65         72.2%
#            108          1           108            55         50.9%
#
#   Saved: /Users/anitaapplegarth/github/dphil/protein_complexes/data/lookup_tables/corum/avg_chembl_by_group_size.csv
#
# ==========================================================================================
# 8. Large-bucket test drug target rate by split
# ==========================================================================================
#   Global drug target rate: 12.0%
#
#   Split   Groups in test   Test proteins  Bucket rate
#   ------------------------------------------------------
#       1                5             139        15.8%
#       2                5             138        21.7%
#       3                5             212        33.5%
#       4                5             228        32.0%
#       5                5             262        26.7%
#       6                5             180        11.7%
#       7                5             325        19.1%
#       8                5             228        22.4%
#       9                5             258        23.3%
#      10                5             289        19.4%
#      11                5             263        14.1%
#      12                5             312        22.8%
#      13                5             224        16.5%
#      14                5             227        12.8%
#      15                5             221        25.8%
#      16                5             168        12.5%
#      17                5             220         9.5%
#      18                5             214        17.8%
#      19                5             241        14.9%
#      20                5             134        19.4%
#      21                5             236        24.2%
#      22                5             190        32.6%
#      23                5             206        21.4%
#      24                5             205        29.3%
#      25                5             244        18.0%
#      26                5             188        21.8%
#      27                5             152        16.4%
#      28                5             303        20.5%
#      29                5             265        14.3%
#      30                5             332        20.5%
#      31                5             172        22.1%
#      32                5             309        25.2%
#      33                5             273        19.4%
#      34                5             315        13.7%
#      35                5             323        24.8%
#      36                5             198        12.6%
#      37                5             199        29.6%
#      38                5             287        22.3%
#      39                5             221        23.1%
#      40                5             173        20.2%
#      41                5             159        21.4%
#      42                5             241        22.8%
#      43                5             196        19.9%
#      44                5             263        22.8%
#      45                5             241        21.2%
#      46                5             200        33.0%
#      47                5             138        26.1%
#      48                5             225        32.0%
#      49                5             141        29.1%
#      50                5             147        19.7%
#
#   Saved: /Users/anitaapplegarth/github/dphil/protein_complexes/data/lookup_tables/corum/chembl_split_summary.txt
#
# Done!
