# %%
"""
Repeated random structural-group-level splits -- essentiality labels.

All logic lives in split_common.py; this file is configuration only.

LABELS: OGEE v3 + DepMap. Core -> Essential; Cancer and Non-essential ->
Non-essential; anything else -> dropped to Unknown and excluded from the
analysis population. This is the binarisation used throughout the paper.

NOTE: this is the RANDOM structural-group-atomic split. The complex-atomic
leak-free variant used for the supplementary robustness paragraph lives in
cp_complexatomic_ess_split.py and is a different scheme -- do not confuse the
output files.
"""

from split_common import run_splits

BASE = '/Users/anitaapplegarth/github/dphil/protein_complexes/data/lookup_tables'


def binarise_essentiality(raw):
    """Core -> Essential; Cancer & Non-essential -> Non-essential; else drop."""
    if raw == 'Core':
        return 'Essential'
    if raw in ('Cancer', 'Non-essential'):
        return 'Non-essential'
    return None


CONFIG = {
    'task_description': 'Essentiality Labels (OGEE v3 + DepMap)',

    # ---- Input files -------------------------------------------------------
    'group_mapping':      f'{BASE}/cp/mapping_struct.csv',
    'complex_membership': f'{BASE}/cp/stoich_protein.csv',
    'label_file':         f'{BASE}/lu_essentiality_protein.csv',

    # ---- Input column names ------------------------------------------------
    # NOTE: the essentiality table keys on 'Protein', not 'ProteinId' as the
    # drug-target tables do. This asymmetry is the reason the column names are
    # configurable rather than hardcoded.
    'col_group_protein':   'uniprot_id',
    'col_group_id':        'group_id',
    'col_complex_id':      'ComplexId',
    'col_complex_protein': 'ProteinId',
    'col_label_protein':   'Protein',
    'col_label_value':     'essential_category',

    # ---- Label scheme ------------------------------------------------------
    'label_scheme': {
        'positive': 'Essential',
        'negative': 'Non-essential',
        'noun':     'essential',
        'binarise': binarise_essentiality,
    },

    # ---- Output files ------------------------------------------------------
    'output_all_splits':   f'{BASE}/cp/ess_protein_splits.csv',
    'output_balance':      f'{BASE}/cp/ess_split_balance.csv',
    'output_summary':      f'{BASE}/cp/ess_split_summary.txt',
    'output_rate_by_size': f'{BASE}/cp/avg_essentiality_by_group_size.csv',

    # ---- Split parameters --------------------------------------------------
    'n_splits':    50,
    'train_ratio': 0.80,
    'test_ratio':  0.20,
    'base_seed':   42,

    'max_size_deviation': 5.0,   # pp -- acceptable range [15%, 25%]

    # Looser than the drug-target tasks (4.5pp vs 1.5pp) because the global
    # essential rate is far higher, so the same absolute pp tolerance is
    # proportionally much tighter. Renamed from 'max_ess_rate_deviation' to
    # match the shared engine.
    'max_label_rate_deviation': 4.5,

    'max_attempts': 25,

    # ---- Validation tuning -------------------------------------------------
    'validate_abs_tol':            0.15,
    'validate_min_groups':         3,
    'min_test_groups_per_bucket':  1,
    'strict_duplicate_check':      False,
    'require_full_n_splits':       True,

    # ---- Bucket ablation ---------------------------------------------------
    'stratify_by_bucket': True,
    'unstrat_suffix':     '_unstrat',
}


if __name__ == '__main__':
    run_splits(CONFIG)
# Out:
# ======================================================================
# Repeated Random group-Level Splitting -- Size-Stratified, N=50
# Essentiality Labels (OGEE v3 + DepMap)
# ======================================================================
#
# --- Loading data ---
#   Groups:    3388 rows, 958 unique groups
#   Complexes: 2220 complexes, 3394 unique proteins
#   Labels:    18392 rows from /Users/anitaapplegarth/github/dphil/protein_complexes/data/lookup_tables/lu_essentiality_protein.csv
#   Duplicate group assignments: none
#
#   Label distribution (3394 total complex proteins):
#     Essential      :   773
#     Non-essential  :  2538
#     Unknown        :    83  (no usable label -- excluded)
#     No-group       :     6  (no structural assignment -- excluded)
#   Analysis population (labelled + structured): 3306
#   Global essential rate (analysis population): 23.4%  (773 / 3306)
#
# --- Group size buckets (largest first) ---
#   large        (>20 proteins (merged large + very large)):   22 groups,   972 proteins -- 4 grps drawn to test each split
#   medium       (6-20                                    ):  105 groups,  1070 proteins -- 21 grps drawn to test each split
#   small        (2-5                                     ):  274 groups,   789 proteins -- 55 grps drawn to test each split
#   singleton    (1 protein                               ):  557 groups,   557 proteins -- 111 grps drawn to test each split
#   No-group proteins: 6
#
# --- Allocation mode: SIZE-STRATIFIED ---
# --- Generating 50 splits (tolerance +/-4.5pp label, +/-5.0pp size, max 25 attempts each) ---
#   Split  1 | train=2666 (78.5%) pos=24.4% | test=728 (21.4%) pos=19.6% | size_dev=1.4pp label_dev=3.8pp
#   Split  2 | train=2758 (81.3%) pos=24.1% | test=636 (18.7%) pos=20.1% | size_dev=1.3pp label_dev=3.2pp
#   Split  3 | train=2670 (78.7%) pos=22.4% | test=724 (21.3%) pos=26.8% | size_dev=1.3pp label_dev=3.5pp
#   Split  4 | train=2721 (80.2%) pos=23.5% | test=673 (19.8%) pos=22.8% | size_dev=0.2pp label_dev=0.6pp
#   Split  5 | train=2692 (79.3%) pos=23.1% | test=702 (20.7%) pos=24.4% | size_dev=0.7pp label_dev=1.0pp (accepted on attempt 3)
#   Split  6 | train=2836 (83.6%) pos=22.9% | test=558 (16.4%) pos=25.9% | size_dev=3.6pp label_dev=2.5pp
#   Split  7 | train=2727 (80.3%) pos=22.9% | test=667 (19.6%) pos=25.4% | size_dev=0.3pp label_dev=2.0pp
#   Split  8 | train=2699 (79.5%) pos=23.5% | test=695 (20.5%) pos=23.0% | size_dev=0.5pp label_dev=0.4pp
#   Split  9 | train=2753 (81.1%) pos=22.3% | test=641 (18.9%) pos=27.8% | size_dev=1.1pp label_dev=4.5pp (accepted on attempt 2)
#   Split 10 | train=2790 (82.2%) pos=22.9% | test=604 (17.8%) pos=25.6% | size_dev=2.2pp label_dev=2.2pp
#   Split 11 | train=2774 (81.7%) pos=23.6% | test=620 (18.3%) pos=22.4% | size_dev=1.7pp label_dev=1.0pp
#   Split 12 | train=2745 (80.9%) pos=23.7% | test=649 (19.1%) pos=22.1% | size_dev=0.9pp label_dev=1.3pp
#   Split 13 | train=2641 (77.8%) pos=24.2% | test=753 (22.2%) pos=20.5% | size_dev=2.2pp label_dev=2.9pp
#   Split 14 | train=2711 (79.9%) pos=23.1% | test=683 (20.1%) pos=24.5% | size_dev=0.1pp label_dev=1.1pp
#   Split 15 | train=2689 (79.2%) pos=22.3% | test=705 (20.8%) pos=27.5% | size_dev=0.8pp label_dev=4.1pp
#   Split 16 | train=2726 (80.3%) pos=22.6% | test=668 (19.7%) pos=26.6% | size_dev=0.3pp label_dev=3.2pp
#   Split 17 | train=2672 (78.7%) pos=22.9% | test=722 (21.3%) pos=25.2% | size_dev=1.3pp label_dev=1.8pp (accepted on attempt 2)
#   Split 18 | train=2733 (80.5%) pos=24.0% | test=661 (19.5%) pos=20.7% | size_dev=0.5pp label_dev=2.6pp
#   Split 19 | train=2630 (77.5%) pos=22.6% | test=764 (22.5%) pos=25.9% | size_dev=2.5pp label_dev=2.5pp
#   Split 20 | train=2677 (78.9%) pos=24.1% | test=717 (21.1%) pos=20.6% | size_dev=1.1pp label_dev=2.8pp
#   Split 21 | train=2763 (81.4%) pos=23.0% | test=631 (18.6%) pos=25.2% | size_dev=1.4pp label_dev=1.8pp
#   Split 22 | train=2688 (79.2%) pos=23.1% | test=706 (20.8%) pos=24.6% | size_dev=0.8pp label_dev=1.3pp
#   Split 23 | train=2801 (82.5%) pos=22.5% | test=593 (17.5%) pos=27.4% | size_dev=2.5pp label_dev=4.0pp (accepted on attempt 2)
#   Split 24 | train=2747 (80.9%) pos=24.0% | test=647 (19.1%) pos=20.9% | size_dev=0.9pp label_dev=2.5pp
#   Split 25 | train=2750 (81.0%) pos=24.1% | test=644 (19.0%) pos=20.3% | size_dev=1.0pp label_dev=3.1pp
#   Split 26 | train=2757 (81.2%) pos=22.8% | test=637 (18.8%) pos=26.0% | size_dev=1.2pp label_dev=2.7pp
#   Split 27 | train=2691 (79.3%) pos=24.3% | test=703 (20.7%) pos=19.9% | size_dev=0.7pp label_dev=3.4pp
#   Split 28 | train=2754 (81.1%) pos=23.8% | test=640 (18.9%) pos=21.6% | size_dev=1.1pp label_dev=1.8pp
#   Split 29 | train=2661 (78.4%) pos=24.2% | test=733 (21.6%) pos=20.5% | size_dev=1.6pp label_dev=2.9pp
#   Split 30 | train=2703 (79.6%) pos=22.6% | test=691 (20.4%) pos=26.4% | size_dev=0.4pp label_dev=3.0pp (accepted on attempt 2)
#   Split 31 | train=2761 (81.3%) pos=24.1% | test=633 (18.6%) pos=20.2% | size_dev=1.4pp label_dev=3.2pp (accepted on attempt 2)
#   Split 32 | train=2701 (79.6%) pos=23.5% | test=693 (20.4%) pos=23.0% | size_dev=0.4pp label_dev=0.4pp
#   Split 33 | train=2704 (79.7%) pos=23.2% | test=690 (20.3%) pos=24.2% | size_dev=0.3pp label_dev=0.8pp
#   Split 34 | train=2731 (80.5%) pos=22.4% | test=663 (19.5%) pos=27.4% | size_dev=0.5pp label_dev=4.0pp
#   Split 35 | train=2785 (82.1%) pos=22.7% | test=609 (17.9%) pos=26.3% | size_dev=2.1pp label_dev=2.9pp (accepted on attempt 4)
#   Split 36 | train=2644 (77.9%) pos=23.5% | test=750 (22.1%) pos=22.9% | size_dev=2.1pp label_dev=0.4pp (accepted on attempt 2)
#   Split 37 | train=2637 (77.7%) pos=23.3% | test=757 (22.3%) pos=23.6% | size_dev=2.3pp label_dev=0.2pp
#   Split 38 | train=2718 (80.1%) pos=22.9% | test=676 (19.9%) pos=25.2% | size_dev=0.1pp label_dev=1.9pp
#   Split 39 | train=2769 (81.6%) pos=22.7% | test=625 (18.4%) pos=26.4% | size_dev=1.6pp label_dev=3.1pp
#   Split 40 | train=2761 (81.3%) pos=22.9% | test=633 (18.6%) pos=25.2% | size_dev=1.4pp label_dev=1.9pp
#   Split 41 | train=2738 (80.7%) pos=23.0% | test=656 (19.3%) pos=25.0% | size_dev=0.7pp label_dev=1.6pp (accepted on attempt 3)
#   Split 42 | train=2778 (81.8%) pos=23.7% | test=616 (18.1%) pos=21.7% | size_dev=1.9pp label_dev=1.6pp (accepted on attempt 2)
#   Split 43 | train=2670 (78.7%) pos=23.4% | test=724 (21.3%) pos=23.4% | size_dev=1.3pp label_dev=0.0pp
#   Split 44 | train=2778 (81.8%) pos=22.9% | test=616 (18.1%) pos=25.3% | size_dev=1.9pp label_dev=1.9pp (accepted on attempt 2)
#   Split 45 | train=2736 (80.6%) pos=22.3% | test=658 (19.4%) pos=27.7% | size_dev=0.6pp label_dev=4.3pp
#   Split 46 | train=2737 (80.6%) pos=22.3% | test=657 (19.4%) pos=27.8% | size_dev=0.6pp label_dev=4.4pp
#   Split 47 | train=2794 (82.3%) pos=23.6% | test=600 (17.7%) pos=22.3% | size_dev=2.3pp label_dev=1.1pp
#   Split 48 | train=2780 (81.9%) pos=23.8% | test=614 (18.1%) pos=21.5% | size_dev=1.9pp label_dev=1.9pp
#   Split 49 | train=2673 (78.8%) pos=23.1% | test=721 (21.2%) pos=24.4% | size_dev=1.2pp label_dev=1.1pp
#   Split 50 | train=2690 (79.3%) pos=24.5% | test=704 (20.7%) pos=19.1% | size_dev=0.7pp label_dev=4.3pp
#
# group-size bucket distribution after split (groups counted):
# BUCKET           TRAIN   TEST  TOTAL TEST_FRAC
# large               18      4     22     0.182
# medium              84     21    105     0.200
# singleton          446    111    557     0.199
# small              219     55    274     0.201
#
# --- Integrity check ---
#   Splits emitted:            50 / 50
#   split_index contiguous:    True
#   Total leakage violations:  0
#   Splits failing validation: 0
#
# --- Saving outputs ---
#   Saved: /Users/anitaapplegarth/github/dphil/protein_complexes/data/lookup_tables/cp/ess_protein_splits.csv  (169,700 rows)
#   Saved: /Users/anitaapplegarth/github/dphil/protein_complexes/data/lookup_tables/cp/ess_split_balance.csv
#
# ==========================================================================================
# SPLIT SUMMARY -- Size-stratified repeated random group-level splits
# Essentiality Labels (OGEE v3 + DepMap)
# ==========================================================================================
# Total unique proteins:            3394
# Total complexes:                  2220
# Total groups:                     958
#   Large      (>20, merged):       22
#   Medium     (6-20):              105
#   Small      (2-5):               274
#   Singleton  (1 protein):         557
# Analysis population:              3306  (labelled + structured; excludes 83 Unknown, 6 no-group)
# Global essential rate:                23.4%  (773 / 3306)
# Allocation mode:                  size-stratified
# Number of splits:                 50
# Train/test ratio:                 80% / 20%
# Size tolerance:                   +/-5.0pp  (acceptable range: 15%-25%)
# Balance tolerance:                +/-4.5pp
# Max redraw attempts per split:    25
# Splits requiring redraw:          11 / 50
# Splits with size warnings:        0 / 50
# Splits with balance warnings:     0 / 50
# Splits with leakage violations:   0 / 50
# Splits emitted without full accept: 0 / 50
#
# Test positive COUNT across splits: min 125, median 158, max 196. On an imbalanced task the per-split positive count drives PR-AUC variance more than the rate does.
#
# Denominators above are the number of splits actually emitted, not the requested n_splits.
#
#  Split  Att   Train N  Train%  Train pos%   Test N  Test%  Test pos%  Test pos n   SzDev  LblDev  Flag
# ----------------------------------------------------------------------------------------------------
#      1    1      2666   78.5%       24.4%      728  21.4%      19.6%         136    1.4pp    3.8pp
#      2    1      2758   81.3%       24.1%      636  18.7%      20.1%         126    1.3pp    3.2pp
#      3    1      2670   78.7%       22.4%      724  21.3%      26.8%         191    1.3pp    3.5pp
#      4    1      2721   80.2%       23.5%      673  19.8%      22.8%         150    0.2pp    0.6pp
#      5    3      2692   79.3%       23.1%      702  20.7%      24.4%         164    0.7pp    1.0pp
#      6    1      2836   83.6%       22.9%      558  16.4%      25.9%         143    3.6pp    2.5pp
#      7    1      2727   80.3%       22.9%      667  19.6%      25.4%         165    0.3pp    2.0pp
#      8    1      2699   79.5%       23.5%      695  20.5%      23.0%         152    0.5pp    0.4pp
#      9    2      2753   81.1%       22.3%      641  18.9%      27.8%         174    1.1pp    4.5pp
#     10    1      2790   82.2%       22.9%      604  17.8%      25.6%         152    2.2pp    2.2pp
#     11    1      2774   81.7%       23.6%      620  18.3%      22.4%         136    1.7pp    1.0pp
#     12    1      2745   80.9%       23.7%      649  19.1%      22.1%         139    0.9pp    1.3pp
#     13    1      2641   77.8%       24.2%      753  22.2%      20.5%         147    2.2pp    2.9pp
#     14    1      2711   79.9%       23.1%      683  20.1%      24.5%         163    0.1pp    1.1pp
#     15    1      2689   79.2%       22.3%      705  20.8%      27.5%         192    0.8pp    4.1pp
#     16    1      2726   80.3%       22.6%      668  19.7%      26.6%         175    0.3pp    3.2pp
#     17    2      2672   78.7%       22.9%      722  21.3%      25.2%         175    1.3pp    1.8pp
#     18    1      2733   80.5%       24.0%      661  19.5%      20.7%         131    0.5pp    2.6pp
#     19    1      2630   77.5%       22.6%      764  22.5%      25.9%         196    2.5pp    2.5pp
#     20    1      2677   78.9%       24.1%      717  21.1%      20.6%         145    1.1pp    2.8pp
#     21    1      2763   81.4%       23.0%      631  18.6%      25.2%         157    1.4pp    1.8pp
#     22    1      2688   79.2%       23.1%      706  20.8%      24.6%         169    0.8pp    1.3pp
#     23    2      2801   82.5%       22.5%      593  17.5%      27.4%         158    2.5pp    4.0pp
#     24    1      2747   80.9%       24.0%      647  19.1%      20.9%         133    0.9pp    2.5pp
#     25    1      2750   81.0%       24.1%      644  19.0%      20.3%         129    1.0pp    3.1pp
#     26    1      2757   81.2%       22.8%      637  18.8%      26.0%         163    1.2pp    2.7pp
#     27    1      2691   79.3%       24.3%      703  20.7%      19.9%         138    0.7pp    3.4pp
#     28    1      2754   81.1%       23.8%      640  18.9%      21.6%         135    1.1pp    1.8pp
#   Split 24: grp_0091, grp_0318, grp_0681, grp_0842
#   Split 25: grp_0110, grp_0842, grp_0893, grp_1213
#   Split 26: grp_0033, grp_0072, grp_0963, grp_1213
#   Split 27: grp_0110, grp_0681, grp_1206, grp_1213
#   Split 28: grp_0065, grp_0524, grp_0842, grp_1206
#   Split 29: grp_0110, grp_0204, grp_0607, grp_1213
#   Split 30: grp_0000, grp_0072, grp_0113, grp_0748
#   Split 31: grp_0000, grp_0524, grp_0607, grp_0893
#   Split 32: grp_0065, grp_0681, grp_0963, grp_1206
#   Split 33: grp_0113, grp_0318, grp_0963, grp_1206
#   Split 34: grp_0033, grp_0091, grp_0101, grp_0826
#   Split 35: grp_0072, grp_0101, grp_0113, grp_0607
#   Split 36: grp_0000, grp_0204, grp_0748, grp_0842
#   Split 37: grp_0204, grp_0318, grp_0681, grp_1206
#   Split 38: grp_0101, grp_0110, grp_0826, grp_1206
#   Split 39: grp_0091, grp_0607, grp_0826, grp_1213
#   Split 40: grp_0091, grp_0113, grp_0748, grp_0963
#   Split 41: grp_0064, grp_0318, grp_0681, grp_0826
#   Split 42: grp_0065, grp_0101, grp_0607, grp_0893
#   Split 43: grp_0000, grp_0204, grp_0681, grp_0748
#   Split 44: grp_0000, grp_0018, grp_0072, grp_0842
#   Split 45: grp_0018, grp_0033, grp_0681, grp_0842
#   Split 46: grp_0000, grp_0018, grp_0033, grp_0748
#   Split 47: grp_0072, grp_0101, grp_0524, grp_0748
#   Split 48: grp_0101, grp_0524, grp_0681, grp_1213
#   Split 49: grp_0064, grp_0091, grp_0607, grp_1206
#   Split 50: grp_0000, grp_0064, grp_0318, grp_1213
#
# 2. All large groups and their sizes (analysis population proteins)
# ------------------------------------------------------------
#   grp_0000:   51 proteins  |  in test for splits [3, 16, 21, 30, 31, 36, 43, 44, 46, 50]
#   grp_0018:   48 proteins  |  in test for splits [2, 8, 14, 21, 44, 45, 46]
#   grp_0033:   32 proteins  |  in test for splits [6, 15, 23, 26, 34, 45, 46]
#   grp_0064:   88 proteins  |  in test for splits [12, 14, 16, 19, 20, 41, 49, 50]
#   grp_0065:   18 proteins  |  in test for splits [4, 12, 28, 32, 42]
#   grp_0072:   22 proteins  |  in test for splits [2, 6, 10, 16, 18, 26, 30, 35, 44, 47]
#   grp_0091:   34 proteins  |  in test for splits [4, 6, 7, 13, 16, 17, 24, 34, 39, 40, 49]
#   grp_0101:   40 proteins  |  in test for splits [2, 5, 15, 34, 35, 38, 42, 47, 48]
#   grp_0110:   45 proteins  |  in test for splits [9, 11, 25, 27, 29, 38]
#   grp_0113:   45 proteins  |  in test for splits [3, 5, 10, 12, 13, 14, 17, 30, 33, 35, 40]
#   grp_0204:   93 proteins  |  in test for splits [1, 5, 8, 13, 17, 18, 29, 36, 37, 43]
#   grp_0318:   24 proteins  |  in test for splits [7, 8, 18, 21, 23, 24, 33, 37, 41, 50]
#   grp_0524:   21 proteins  |  in test for splits [2, 9, 11, 12, 18, 28, 31, 47, 48]
#   grp_0607:   33 proteins  |  in test for splits [5, 9, 29, 31, 35, 39, 42, 49]
#   grp_0681:   29 proteins  |  in test for splits [4, 8, 17, 19, 21, 23, 24, 27, 32, 37, 41, 43, 45, 48]
#   grp_0748:   49 proteins  |  in test for splits [11, 19, 30, 36, 40, 43, 46, 47]
#   grp_0826:   37 proteins  |  in test for splits [1, 7, 9, 14, 15, 22, 34, 38, 39, 41]
#   grp_0842:   37 proteins  |  in test for splits [1, 10, 22, 23, 24, 25, 28, 36, 44, 45]
#   grp_0893:   22 proteins  |  in test for splits [6, 11, 20, 25, 31, 42]
#   grp_0963:   31 proteins  |  in test for splits [3, 10, 20, 22, 26, 32, 33, 40]
#   grp_1206:   90 proteins  |  in test for splits [3, 4, 7, 13, 15, 19, 20, 22, 27, 28, 32, 33, 37, 38, 49]
#   grp_1213:   45 proteins  |  in test for splits [1, 25, 26, 27, 29, 39, 48, 50]
#
# 3. Large test set size per split (all proteins)
# ------------------------------------------------------------
#   Split  1:  235 proteins
#   Split  2:  133 proteins
#   Split  3:  220 proteins
#   Split  4:  178 proteins
#   Split  5:  232 proteins
#   Split  6:  110 proteins
#   Split  7:  188 proteins
#   Split  8:  215 proteins
#   Split  9:  140 proteins
#   Split 10:  138 proteins
#   Split 11:  139 proteins
#   Split 12:  184 proteins
#   Split 13:  283 proteins
#   Split 14:  223 proteins
#   Split 15:  201 proteins
#   Split 16:  197 proteins
#   Split 17:  222 proteins
#   Split 18:  183 proteins
#   Split 19:  258 proteins
#   Split 20:  235 proteins
#   Split 21:  153 proteins
#   Split 22:  199 proteins
#   Split 23:  123 proteins
#   Split 24:  125 proteins
#   Split 25:  150 proteins
#   Split 26:  133 proteins
#   Split 27:  210 proteins
#   Split 28:  175 proteins
#   Split 29:  237 proteins
#   Split 30:  168 proteins
#   Split 31:  129 proteins
#   Split 32:  177 proteins
#   Split 33:  194 proteins
#   Split 34:  145 proteins
#   Split 35:  141 proteins
#   Split 36:  250 proteins
#   Split 37:  257 proteins
#   Split 38:  214 proteins
#   Split 39:  152 proteins
#   Split 40:  162 proteins
#   Split 41:  183 proteins
#   Split 42:  120 proteins
#   Split 43:  242 proteins
#   Split 44:  158 proteins
#   Split 45:  146 proteins
#   Split 46:  180 proteins
#   Split 47:  134 proteins
#   Split 48:  138 proteins
#   Split 49:  247 proteins
#   Split 50:  212 proteins
#
# 4. Overlap statistics across all splits
# ------------------------------------------------------------
#   Intersection (in ALL test sets): 0
#   Union (in ANY test set):         972
#   Jaccard similarity:              0.000
#
# 5. Per-protein test frequency (how many splits each protein is in test)
# ------------------------------------------------------------
#   5 split(s): 25 proteins
#   6 split(s): 67 proteins
#   7 split(s): 80 proteins
#   8 split(s): 251 proteins
#   9 split(s): 63 proteins
#   10 split(s): 287 proteins
#   11 split(s): 80 proteins
#   14 split(s): 29 proteins
#   15 split(s): 90 proteins
#
# 6. Per-group test frequency -- randomness check
# ------------------------------------------------------------
#   Total large groups:          22
#   Groups drawn to test/split:  4  (18.2%)
#   Expected test freq per group over 50 splits: 9.1
#   Binomial SD: 2.73   2 SD band: [3.6, 14.5]
#   With this many groups, roughly one falling outside the band by chance is expected.
#
#   Group                           AP size  Test count  Note
#   grp_0000                             51          10  ok
#   grp_0018                             48           7  ok
#   grp_0033                             32           7  ok
#   grp_0064                             88           8  ok
#   grp_0065                             18           5  ok
#   grp_0072                             22          10  ok
#   grp_0091                             34          11  ok
#   grp_0101                             40           9  ok
#   grp_0110                             45           6  ok
#   grp_0113                             45          11  ok
#   grp_0204                             93          10  ok
#   grp_0318                             24          10  ok
#   grp_0524                             21           9  ok
#   grp_0607                             33           8  ok
#   grp_0681                             29          14  ok
#   grp_0748                             49           8  ok
#   grp_0826                             37          10  ok
#   grp_0842                             37          10  ok
#   grp_0893                             22           6  ok
#   grp_0963                             31           8  ok
#   grp_1206                             90          15  !! outside 2 SD
#   grp_1213                             45           8  ok
#
#   Min test count: 5  Max: 15  Mean: 9.09  Std: 2.35
#   Groups outside the 2 SD band: 1 / 22  (~1 expected by chance)
#   Observed SD vs binomial SD: 2.35 vs 2.73  -- tighter than a fair draw would give.
#
# ==========================================================================================
# 7. Essential rate per group size  (analysis population only)
# ==========================================================================================
#   Analysis population = labelled (Essential/Non-essential) + structured
#   Global essential rate: 23.4%
#   n = 3306
#
#     group_size   n_groups    n_proteins    n_positive      pos_rate
#   --------------------------------------------------------------------
#              1        551           551           101         18.3%
#              2        134           268            63         23.5%
#              3         67           201            37         18.4%
#              4         44           176            36         20.5%
#              5         29           145            23         15.9%
#              6         21           126            26         20.6%
#              7         17           119            33         27.7%
#              8         11            88            26         29.5%
#              9          9            81            12         14.8%
#             10          7            70            18         25.7%
#             11          3            33             9         27.3%
#             12          4            48            19         39.6%
#             13          6            78            22         28.2%
#             14          7            98            11         11.2%
#             15          2            30             3         10.0%
#             16          5            80             3          3.8%
#             17          4            68            22         32.4%
#             18          4            72             8         11.1%
#             19          2            38             2          5.3%
#             20          1            20             6         30.0%
#             21          1            21             5         23.8%
#             22          2            44            11         25.0%
#             24          1            24             9         37.5%
#             29          1            29            23         79.3%
#             31          1            31             2          6.5%
#             32          1            32            28         87.5%
#             33          1            33            24         72.7%
#             34          1            34             7         20.6%
#             37          2            74            41         55.4%
#             40          1            40             0          0.0%
#             45          3           135            46         34.1%
#             48          1            48            14         29.2%
#             49          1            49            23         46.9%
#             51          1            51            21         41.2%
#             88          1            88             9         10.2%
#             90          1            90            29         32.2%
#             93          1            93             1          1.1%
#
#   Saved: /Users/anitaapplegarth/github/dphil/protein_complexes/data/lookup_tables/cp/avg_essentiality_by_group_size.csv
#
# ==========================================================================================
# 8. Large-bucket test essential rate by split
# ==========================================================================================
#   Global essential rate: 23.4%
#
#   Split   Groups in test   Test proteins  Bucket rate
#   ------------------------------------------------------
#       1                4             235        19.8%
#       2                4             133        22.1%
#       3                4             220        41.0%
#       4                4             178        34.5%
#       5                4             232        29.4%
#       6                4             110        41.8%
#       7                4             188        42.2%
#       8                4             215        24.2%
#       9                4             140        52.2%
#      10                4             138        42.2%
#      11                4             139        27.7%
#      12                4             184        29.7%
#      13                4             283        28.2%
#      14                4             223        42.7%
#      15                4             201        45.2%
#      16                4             197        24.1%
#      17                4             222        33.8%
#      18                4             183        15.6%
#      19                4             258        32.8%
#      20                4             235        17.7%
#      21                4             153        44.1%
#      22                4             199        36.9%
#      23                4             123        55.7%
#      24                4             125        37.9%
#      25                4             150        12.1%
#      26                4             133        30.8%
#      27                4             210        29.2%
#      28                4             175        25.3%
#      29                4             237        15.7%
#      30                4             168        54.5%
#      31                4             129        40.2%
#      32                4             177        32.1%
#      33                4             194        40.5%
#      34                4             145        47.6%
#      35                4             141        50.7%
#      36                4             250        23.0%
#      37                4             257        26.3%
#      38                4             214        33.5%
#      39                4             152        43.0%
#      40                4             162        43.4%
#      41                4             183        41.6%
#      42                4             120        22.1%
#      43                4             242        30.6%
#      44                4             158        33.5%
#      45                4             146        50.0%
#      46                4             180        47.8%
#      47                4             134        28.8%
#      48                4             138        20.7%
#      49                4             247        28.2%
#      50                4             212        18.8%
#
#   Saved: /Users/anitaapplegarth/github/dphil/protein_complexes/data/lookup_tables/cp/ess_split_summary.txt
#
# Done!
