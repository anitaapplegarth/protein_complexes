# %%
"""
Repeated random structural-group-level splits -- HPA drug-target labels.

All logic lives in split_common.py; this file is configuration only.

LABELS: Human Protein Atlas drug targets, kept strictly separate from the
ChEMBL set (Jaccard ~31%). Nothing is shared between the two label
derivations; they are independent prediction tasks.
"""

from split_common import run_splits

BASE = '/Users/anitaapplegarth/github/dphil/protein_complexes/data/lookup_tables'

CONFIG = {
    'task_description': 'Drug Target Labels (HPA)',

    # ---- Input files -------------------------------------------------------
    'group_mapping':      f'{BASE}/cp/mapping_struct.csv',
    'complex_membership': f'{BASE}/cp/stoich_protein.csv',
    'label_file':         f'{BASE}/cp_drug_target_hpa.csv',

    # ---- Input column names ------------------------------------------------
    'col_group_protein':   'uniprot_id',
    'col_group_id':        'group_id',
    'col_complex_id':      'ComplexId',
    'col_complex_protein': 'ProteinId',
    'col_label_protein':   'ProteinId',
    'col_label_value':     'target',

    # ---- Label scheme ------------------------------------------------------
    'label_scheme': {
        'positive': 'Drug_target',
        'negative': 'Non_target',
        'noun':     'drug target',
        'binarise': lambda v: 'Drug_target' if v == 1 else 'Non_target',
    },

    # ---- Output files ------------------------------------------------------
    'output_all_splits':   f'{BASE}/cp/hpa_protein_splits.csv',
    'output_balance':      f'{BASE}/cp/hpa_split_balance.csv',
    'output_summary':      f'{BASE}/cp/hpa_split_summary.txt',
    'output_rate_by_size': f'{BASE}/cp/avg_hpa_by_group_size.csv',

    # ---- Split parameters --------------------------------------------------
    'n_splits':    50,
    'train_ratio': 0.80,
    'test_ratio':  0.20,
    'base_seed':   42,

    'max_size_deviation': 5.0,   # pp -- acceptable range [15%, 25%]

    # Check the printed global rate on the first run. If HPA's positive rate
    # differs materially from ChEMBL's, 1.5pp is a different level of
    # strictness and should be retuned -- roughly a tenth of the global rate
    # is a reasonable starting point.
    'max_label_rate_deviation': 1.5,

    'max_attempts': 25,

    # ---- Validation tuning -------------------------------------------------
    'validate_abs_tol':            0.15,
    'validate_min_groups':         3,
    'min_test_groups_per_bucket':  1,
    'strict_duplicate_check':      False,
    'require_full_n_splits':       True,

    # ---- Bucket ablation ---------------------------------------------------
    'stratify_by_bucket': True,
    'unstrat_suffix':     '_unstrat',
}


if __name__ == '__main__':
    run_splits(CONFIG)
# Out:
# ======================================================================
# Repeated Random group-Level Splitting -- Size-Stratified, N=50
# Drug Target Labels (HPA)
# ======================================================================
#
# --- Loading data ---
#   Groups:    3388 rows, 958 unique groups
#   Complexes: 2220 complexes, 3394 unique proteins
#   Labels:    3394 rows from /Users/anitaapplegarth/github/dphil/protein_complexes/data/lookup_tables/cp_drug_target_hpa.csv
#   Duplicate group assignments: none
#
#   Label distribution (3394 total complex proteins):
#     Drug_target    :   272
#     Non_target     :  3122
#     Unknown        :     0  (no usable label -- excluded)
#     No-group       :     6  (no structural assignment -- excluded)
#   Analysis population (labelled + structured): 3388
#   Global drug target rate (analysis population): 8.0%  (272 / 3388)
#
# --- Group size buckets (largest first) ---
#   large        (>20 proteins (merged large + very large)):   22 groups,   972 proteins -- 4 grps drawn to test each split
#   medium       (6-20                                    ):  105 groups,  1070 proteins -- 21 grps drawn to test each split
#   small        (2-5                                     ):  274 groups,   789 proteins -- 55 grps drawn to test each split
#   singleton    (1 protein                               ):  557 groups,   557 proteins -- 111 grps drawn to test each split
#   No-group proteins: 6
#
# --- Allocation mode: SIZE-STRATIFIED ---
# --- Generating 50 splits (tolerance +/-1.5pp label, +/-5.0pp size, max 25 attempts each) ---
#   Split  1 | train=2706 (79.7%) pos=8.0% | test=688 (20.3%) pos=8.3% | size_dev=0.3pp label_dev=0.3pp (accepted on attempt 5)
#   Split  2 | train=2678 (78.9%) pos=7.7% | test=716 (21.1%) pos=9.2% | size_dev=1.1pp label_dev=1.2pp (accepted on attempt 9)
#   Split  3 | train=2670 (78.7%) pos=8.0% | test=724 (21.3%) pos=8.2% | size_dev=1.3pp label_dev=0.1pp
#   Split  4 | train=2754 (81.1%) pos=8.1% | test=640 (18.9%) pos=7.7% | size_dev=1.1pp label_dev=0.4pp (accepted on attempt 4)
#   Split  5 | train=2762 (81.4%) pos=8.2% | test=632 (18.6%) pos=7.5% | size_dev=1.4pp label_dev=0.6pp (accepted on attempt 4)
#   Split  6 | train=2687 (79.2%) pos=7.8% | test=707 (20.8%) pos=8.8% | size_dev=0.8pp label_dev=0.8pp (accepted on attempt 3)
#   Split  7 | train=2765 (81.5%) pos=8.1% | test=629 (18.5%) pos=7.6% | size_dev=1.5pp label_dev=0.4pp (accepted on attempt 3)
#   Split  8 | train=2769 (81.6%) pos=8.1% | test=625 (18.4%) pos=7.8% | size_dev=1.6pp label_dev=0.2pp (accepted on attempt 3)
#   Split  9 | train=2753 (81.1%) pos=8.4% | test=641 (18.9%) pos=6.6% | size_dev=1.1pp label_dev=1.5pp (accepted on attempt 2)
#   Split 10 | train=2701 (79.6%) pos=8.2% | test=693 (20.4%) pos=7.2% | size_dev=0.4pp label_dev=0.8pp (accepted on attempt 4)
#   Split 11 | train=2806 (82.7%) pos=8.0% | test=588 (17.3%) pos=8.2% | size_dev=2.7pp label_dev=0.1pp (accepted on attempt 3)
#   Split 12 | train=2745 (80.9%) pos=8.4% | test=649 (19.1%) pos=6.6% | size_dev=0.9pp label_dev=1.4pp
#   Split 13 | train=2641 (77.8%) pos=8.1% | test=753 (22.2%) pos=7.7% | size_dev=2.2pp label_dev=0.3pp
#   Split 14 | train=2711 (79.9%) pos=8.0% | test=683 (20.1%) pos=8.2% | size_dev=0.1pp label_dev=0.2pp
#   Split 15 | train=2689 (79.2%) pos=7.8% | test=705 (20.8%) pos=9.1% | size_dev=0.8pp label_dev=1.1pp
#   Split 16 | train=2678 (78.9%) pos=7.9% | test=716 (21.1%) pos=8.7% | size_dev=1.1pp label_dev=0.6pp (accepted on attempt 2)
#   Split 17 | train=2672 (78.7%) pos=8.2% | test=722 (21.3%) pos=7.5% | size_dev=1.3pp label_dev=0.5pp (accepted on attempt 2)
#   Split 18 | train=2733 (80.5%) pos=8.0% | test=661 (19.5%) pos=8.2% | size_dev=0.5pp label_dev=0.1pp
#   Split 19 | train=2796 (82.4%) pos=7.8% | test=598 (17.6%) pos=8.9% | size_dev=2.4pp label_dev=0.8pp (accepted on attempt 2)
#   Split 20 | train=2677 (78.9%) pos=7.8% | test=717 (21.1%) pos=8.9% | size_dev=1.1pp label_dev=0.9pp
#   Split 21 | train=2743 (80.8%) pos=8.0% | test=651 (19.2%) pos=8.3% | size_dev=0.8pp label_dev=0.3pp (accepted on attempt 2)
#   Split 22 | train=2688 (79.2%) pos=8.2% | test=706 (20.8%) pos=7.2% | size_dev=0.8pp label_dev=0.8pp
#   Split 23 | train=2694 (79.4%) pos=7.7% | test=700 (20.6%) pos=9.4% | size_dev=0.6pp label_dev=1.4pp (accepted on attempt 3)
#   Split 24 | train=2747 (80.9%) pos=7.8% | test=647 (19.1%) pos=8.8% | size_dev=0.9pp label_dev=0.8pp
#   Split 25 | train=2741 (80.8%) pos=8.2% | test=653 (19.2%) pos=7.4% | size_dev=0.8pp label_dev=0.7pp (accepted on attempt 2)
#   Split 26 | train=2748 (81.0%) pos=7.9% | test=646 (19.0%) pos=8.7% | size_dev=1.0pp label_dev=0.7pp (accepted on attempt 2)
#   Split 27 | train=2706 (79.7%) pos=7.8% | test=688 (20.3%) pos=8.7% | size_dev=0.3pp label_dev=0.7pp (accepted on attempt 3)
#   Split 28 | train=2756 (81.2%) pos=8.3% | test=638 (18.8%) pos=6.8% | size_dev=1.2pp label_dev=1.3pp (accepted on attempt 6)
#   Split 29 | train=2661 (78.4%) pos=7.7% | test=733 (21.6%) pos=9.2% | size_dev=1.6pp label_dev=1.1pp
#   Split 30 | train=2703 (79.6%) pos=7.8% | test=691 (20.4%) pos=8.8% | size_dev=0.4pp label_dev=0.8pp (accepted on attempt 2)
#   Split 31 | train=2761 (81.3%) pos=8.0% | test=633 (18.6%) pos=8.4% | size_dev=1.4pp label_dev=0.4pp (accepted on attempt 2)
#   Split 32 | train=2701 (79.6%) pos=7.9% | test=693 (20.4%) pos=8.5% | size_dev=0.4pp label_dev=0.5pp
#   Split 33 | train=2776 (81.8%) pos=8.0% | test=618 (18.2%) pos=8.1% | size_dev=1.8pp label_dev=0.1pp (accepted on attempt 2)
#   Split 34 | train=2731 (80.5%) pos=7.8% | test=663 (19.5%) pos=9.1% | size_dev=0.5pp label_dev=1.0pp
#   Split 35 | train=2752 (81.1%) pos=8.2% | test=642 (18.9%) pos=7.3% | size_dev=1.1pp label_dev=0.7pp
#   Split 36 | train=2740 (80.7%) pos=8.1% | test=654 (19.3%) pos=7.8% | size_dev=0.7pp label_dev=0.2pp
#   Split 37 | train=2768 (81.6%) pos=8.1% | test=626 (18.4%) pos=7.7% | size_dev=1.6pp label_dev=0.3pp (accepted on attempt 3)
#   Split 38 | train=2718 (80.1%) pos=8.3% | test=676 (19.9%) pos=7.1% | size_dev=0.1pp label_dev=0.9pp
#   Split 39 | train=2812 (82.8%) pos=7.8% | test=582 (17.1%) pos=9.3% | size_dev=2.9pp label_dev=1.3pp (accepted on attempt 2)
#   Split 40 | train=2761 (81.3%) pos=8.3% | test=633 (18.6%) pos=6.7% | size_dev=1.4pp label_dev=1.4pp
#   Split 41 | train=2738 (80.7%) pos=8.3% | test=656 (19.3%) pos=6.9% | size_dev=0.7pp label_dev=1.2pp (accepted on attempt 3)
#   Split 42 | train=2742 (80.8%) pos=7.8% | test=652 (19.2%) pos=9.2% | size_dev=0.8pp label_dev=1.2pp
#   Split 43 | train=2670 (78.7%) pos=7.8% | test=724 (21.3%) pos=8.7% | size_dev=1.3pp label_dev=0.7pp
#   Split 44 | train=2778 (81.8%) pos=7.8% | test=616 (18.1%) pos=8.9% | size_dev=1.9pp label_dev=0.9pp (accepted on attempt 2)
#   Split 45 | train=2734 (80.5%) pos=8.1% | test=660 (19.4%) pos=7.9% | size_dev=0.6pp label_dev=0.1pp (accepted on attempt 5)
#   Split 46 | train=2743 (80.8%) pos=8.1% | test=651 (19.2%) pos=7.5% | size_dev=0.8pp label_dev=0.5pp (accepted on attempt 4)
#   Split 47 | train=2603 (76.7%) pos=7.7% | test=791 (23.3%) pos=9.2% | size_dev=3.3pp label_dev=1.2pp (accepted on attempt 3)
#   Split 48 | train=2780 (81.9%) pos=7.8% | test=614 (18.1%) pos=9.3% | size_dev=1.9pp label_dev=1.3pp
#   Split 49 | train=2764 (81.4%) pos=8.1% | test=630 (18.6%) pos=7.8% | size_dev=1.4pp label_dev=0.2pp (accepted on attempt 3)
#   Split 50 | train=2807 (82.7%) pos=8.3% | test=587 (17.3%) pos=6.8% | size_dev=2.7pp label_dev=1.2pp (accepted on attempt 2)
#
# group-size bucket distribution after split (groups counted):
# BUCKET           TRAIN   TEST  TOTAL TEST_FRAC
# large               18      4     22     0.182
# medium              84     21    105     0.200
# singleton          446    111    557     0.199
# small              219     55    274     0.201
#
# --- Integrity check ---
#   Splits emitted:            50 / 50
#   split_index contiguous:    True
#   Total leakage violations:  0
#   Splits failing validation: 0
#
# --- Saving outputs ---
#   Saved: /Users/anitaapplegarth/github/dphil/protein_complexes/data/lookup_tables/cp/hpa_protein_splits.csv  (169,700 rows)
#   Saved: /Users/anitaapplegarth/github/dphil/protein_complexes/data/lookup_tables/cp/hpa_split_balance.csv
#
# ==========================================================================================
# SPLIT SUMMARY -- Size-stratified repeated random group-level splits
# Drug Target Labels (HPA)
# ==========================================================================================
# Total unique proteins:            3394
# Total complexes:                  2220
# Total groups:                     958
#   Large      (>20, merged):       22
#   Medium     (6-20):              105
#   Small      (2-5):               274
#   Singleton  (1 protein):         557
# Analysis population:              3388  (labelled + structured; excludes 0 Unknown, 6 no-group)
# Global drug target rate:              8.0%  (272 / 3388)
# Allocation mode:                  size-stratified
# Number of splits:                 50
# Train/test ratio:                 80% / 20%
# Size tolerance:                   +/-5.0pp  (acceptable range: 15%-25%)
# Balance tolerance:                +/-1.5pp
# Max redraw attempts per split:    25
# Splits requiring redraw:          31 / 50
# Splits with size warnings:        0 / 50
# Splits with balance warnings:     0 / 50
# Splits with leakage violations:   0 / 50
# Splits emitted without full accept: 0 / 50
#
# Test positive COUNT across splits: min 40, median 54, max 73. On an imbalanced task the per-split positive count drives PR-AUC variance more than the rate does.
#
# Denominators above are the number of splits actually emitted, not the requested n_splits.
#
#  Split  Att   Train N  Train%  Train pos%   Test N  Test%  Test pos%  Test pos n   SzDev  LblDev  Flag
# ----------------------------------------------------------------------------------------------------
#      1    5      2706   79.7%        8.0%      688  20.3%       8.3%          57    0.3pp    0.3pp
#      2    9      2678   78.9%        7.7%      716  21.1%       9.2%          66    1.1pp    1.2pp
#      3    1      2670   78.7%        8.0%      724  21.3%       8.2%          59    1.3pp    0.1pp
#      4    4      2754   81.1%        8.1%      640  18.9%       7.7%          49    1.1pp    0.4pp
#      5    4      2762   81.4%        8.2%      632  18.6%       7.5%          47    1.4pp    0.6pp
#      6    3      2687   79.2%        7.8%      707  20.8%       8.8%          62    0.8pp    0.8pp
#      7    3      2765   81.5%        8.1%      629  18.5%       7.6%          48    1.5pp    0.4pp
#      8    3      2769   81.6%        8.1%      625  18.4%       7.8%          49    1.6pp    0.2pp
#      9    2      2753   81.1%        8.4%      641  18.9%       6.6%          42    1.1pp    1.5pp
#     10    4      2701   79.6%        8.2%      693  20.4%       7.2%          50    0.4pp    0.8pp
#     11    3      2806   82.7%        8.0%      588  17.3%       8.2%          48    2.7pp    0.1pp
#     12    1      2745   80.9%        8.4%      649  19.1%       6.6%          43    0.9pp    1.4pp
#     13    1      2641   77.8%        8.1%      753  22.2%       7.7%          58    2.2pp    0.3pp
#     14    1      2711   79.9%        8.0%      683  20.1%       8.2%          56    0.1pp    0.2pp
#     15    1      2689   79.2%        7.8%      705  20.8%       9.1%          64    0.8pp    1.1pp
#     16    2      2678   78.9%        7.9%      716  21.1%       8.7%          62    1.1pp    0.6pp
#     17    2      2672   78.7%        8.2%      722  21.3%       7.5%          54    1.3pp    0.5pp
#     18    1      2733   80.5%        8.0%      661  19.5%       8.2%          54    0.5pp    0.1pp
#     19    2      2796   82.4%        7.8%      598  17.6%       8.9%          53    2.4pp    0.8pp
#     20    1      2677   78.9%        7.8%      717  21.1%       8.9%          64    1.1pp    0.9pp
#     21    2      2743   80.8%        8.0%      651  19.2%       8.3%          54    0.8pp    0.3pp
#     22    1      2688   79.2%        8.2%      706  20.8%       7.2%          51    0.8pp    0.8pp
#     23    3      2694   79.4%        7.7%      700  20.6%       9.4%          66    0.6pp    1.4pp
#     24    1      2747   80.9%        7.8%      647  19.1%       8.8%          57    0.9pp    0.8pp
#     25    2      2741   80.8%        8.2%      653  19.2%       7.4%          48    0.8pp    0.7pp
#     26    2      2748   81.0%        7.9%      646  19.0%       8.7%          56    1.0pp    0.7pp
#     27    3      2706   79.7%        7.8%      688  20.3%       8.7%          60    0.3pp    0.7pp
#     28    6      2756   81.2%        8.3%      638  18.8%       6.8%          43    1.2pp    1.3pp
#     29    1      2661   78.4%        7.7%      733  21.6%       9.2%          67    1.6pp    1.1pp
#     39       120 12.3%   9.2%        199 18.6%  12.6%       151 19.1%   4.0%           111 19.9%  10.8%
#     40       162 16.7%   5.6%        199 18.6%   9.5%       160 20.3%   2.5%           111 19.9%   9.0%
#     41       183 18.8%   0.0%        214 20.0%   8.9%       147 18.6%  10.9%           111 19.9%   9.0%
#     42       159 16.4%  10.1%        209 19.5%  10.5%       172 21.8%   6.4%           111 19.9%   9.9%
#     43       242 24.9%  13.2%        214 20.0%   6.1%       156 19.8%   4.5%           111 19.9%   9.9%
#     44       158 16.3%   7.0%        191 17.9%   9.4%       155 19.6%   7.1%           111 19.9%  13.5%
#     45       160 16.5%   6.9%        235 22.0%   8.5%       153 19.4%   6.5%           111 19.9%   9.9%
#     46       167 17.2%   1.8%        218 20.4%   8.7%       154 19.5%  10.4%           111 19.9%   9.9%
#     47       281 28.9%  11.7%        232 21.7%   3.9%       166 21.0%  10.8%           111 19.9%  11.7%
#     48       138 14.2%  17.4%        210 19.6%   7.6%       154 19.5%   2.6%           111 19.9%  11.7%
#     49       148 15.2%  14.2%        209 19.5%   3.3%       161 20.4%   8.1%           111 19.9%   7.2%
#     50       156 16.0%   1.9%        161 15.0%   8.7%       158 20.0%   7.6%           111 19.9%   9.9%
# ------------------------------------------------------------------------------------------
#   Mean     180.0 18.5%   8.4%      214.4 20.0%   8.4%     158.4 20.1%   6.3%         111.0 19.9%   9.4%
#    Std      40.2 4.13%  5.21%       21.3 1.99%  3.55%       6.3 0.81%  2.37%           0.0 0.00%  2.31%
#
#   N% = % of that bucket's proteins going to test.
#   Pos% = drug target rate among analysis-population test proteins in that bucket.
#
# ==========================================================================================
# LARGE-BUCKET PROFILE ANALYSIS
# ==========================================================================================
#
# 1. Which large groups are in TEST per split?
# ------------------------------------------------------------
#   Split  1: grp_0018, grp_0524, grp_0607, grp_1206
#   Split  2: grp_0065, grp_0113, grp_0204, grp_0826
#   Split  3: grp_0000, grp_0113, grp_0963, grp_1206
#   Split  4: grp_0064, grp_0065, grp_0524, grp_0607
#   Split  5: grp_0072, grp_0101, grp_0681, grp_1213
#   Split  6: grp_0000, grp_0018, grp_0065, grp_1206
#   Split  7: grp_0018, grp_0113, grp_0681, grp_0963
#   Split  8: grp_0072, grp_0091, grp_0110, grp_1213
#   Split  9: grp_0110, grp_0524, grp_0607, grp_0826
#   Split 10: grp_0101, grp_0110, grp_0113, grp_0826
#   Split 11: grp_0091, grp_0681, grp_0893, grp_0963
#   Split 12: grp_0064, grp_0065, grp_0113, grp_0524
#   Split 13: grp_0091, grp_0113, grp_0204, grp_1206
#   Split 14: grp_0018, grp_0064, grp_0113, grp_0826
#   Split 15: grp_0033, grp_0101, grp_0826, grp_1206
#   Split 16: grp_0000, grp_0065, grp_0204, grp_0893
#   Split 17: grp_0091, grp_0113, grp_0204, grp_0681
#   Split 18: grp_0072, grp_0204, grp_0318, grp_0524
#   Split 19: grp_0101, grp_0524, grp_0748, grp_0893
#   Split 20: grp_0064, grp_0893, grp_0963, grp_1206
#   Split 21: grp_0018, grp_0681, grp_0842, grp_1213
#   Split 22: grp_0826, grp_0842, grp_0963, grp_1206
#   Split 23: grp_0113, grp_0204, grp_0607, grp_1213
#   Split 24: grp_0091, grp_0318, grp_0681, grp_0842
#   Split 25: grp_0033, grp_0091, grp_0101, grp_1206
#   Split 26: grp_0064, grp_0065, grp_0101, grp_0826
#   Split 27: grp_0033, grp_0064, grp_0110, grp_0842
#   Split 28: grp_0018, grp_0072, grp_0681, grp_1206
#   Split 29: grp_0110, grp_0204, grp_0607, grp_1213
#   Split 30: grp_0000, grp_0072, grp_0113, grp_0748
#   Split 31: grp_0000, grp_0524, grp_0607, grp_0893
#   Split 32: grp_0065, grp_0681, grp_0963, grp_1206
#   Split 33: grp_0018, grp_0318, grp_0748, grp_0893
#   Split 34: grp_0033, grp_0091, grp_0101, grp_0826
#   Split 35: grp_0000, grp_0607, grp_0826, grp_0842
#   Split 36: grp_0033, grp_0113, grp_0607, grp_0842
#   Split 37: grp_0018, grp_0072, grp_0091, grp_0681
#   Split 38: grp_0101, grp_0110, grp_0826, grp_1206
#   Split 39: grp_0065, grp_0524, grp_0826, grp_0963
#   Split 40: grp_0091, grp_0113, grp_0748, grp_0963
#   Split 41: grp_0064, grp_0318, grp_0681, grp_0826
#   Split 42: grp_0018, grp_0033, grp_0113, grp_0607
#   Split 43: grp_0000, grp_0204, grp_0681, grp_0748
#   Split 44: grp_0000, grp_0018, grp_0072, grp_0842
#   Split 45: grp_0018, grp_0681, grp_0842, grp_1213
#   Split 46: grp_0000, grp_0065, grp_0110, grp_0113
#   Split 47: grp_0033, grp_0204, grp_1206, grp_1213
#   Split 48: grp_0101, grp_0524, grp_0681, grp_1213
#   Split 49: grp_0101, grp_0113, grp_0318, grp_0842
#   Split 50: grp_0072, grp_0748, grp_0826, grp_1213
#
# 2. All large groups and their sizes (analysis population proteins)
# ------------------------------------------------------------
#   grp_0000:   51 proteins  |  in test for splits [3, 6, 16, 30, 31, 35, 43, 44, 46]
#   grp_0018:   48 proteins  |  in test for splits [1, 6, 7, 14, 21, 28, 33, 37, 42, 44, 45]
#   grp_0033:   32 proteins  |  in test for splits [15, 25, 27, 34, 36, 42, 47]
#   grp_0064:   90 proteins  |  in test for splits [4, 12, 14, 20, 26, 27, 41]
#   grp_0065:   25 proteins  |  in test for splits [2, 4, 6, 12, 16, 26, 32, 39, 46]
#   grp_0072:   22 proteins  |  in test for splits [5, 8, 18, 28, 30, 37, 44, 50]
#   grp_0091:   34 proteins  |  in test for splits [8, 11, 13, 17, 24, 25, 34, 37, 40]
#   grp_0101:   40 proteins  |  in test for splits [5, 10, 15, 19, 25, 26, 34, 38, 48, 49]
#   grp_0110:   45 proteins  |  in test for splits [8, 9, 10, 27, 29, 38, 46]
#   grp_0113:   46 proteins  |  in test for splits [2, 3, 7, 10, 12, 13, 14, 17, 23, 30, 36, 40, 42, 46, 49]
#   grp_0204:  113 proteins  |  in test for splits [2, 13, 16, 17, 18, 23, 29, 43, 47]
#   grp_0318:   25 proteins  |  in test for splits [18, 24, 33, 41, 49]
#   grp_0524:   23 proteins  |  in test for splits [1, 4, 9, 12, 18, 19, 31, 39, 48]
#   grp_0607:   33 proteins  |  in test for splits [1, 4, 9, 23, 29, 31, 35, 36, 42]
#   grp_0681:   29 proteins  |  in test for splits [5, 7, 11, 17, 21, 24, 28, 32, 37, 41, 43, 45, 48]
#   grp_0748:   49 proteins  |  in test for splits [19, 30, 33, 40, 43, 50]
#   grp_0826:   39 proteins  |  in test for splits [2, 9, 10, 14, 15, 22, 26, 34, 35, 38, 39, 41, 50]
#   grp_0842:   37 proteins  |  in test for splits [21, 22, 24, 27, 35, 36, 44, 45, 49]
#   grp_0893:   22 proteins  |  in test for splits [11, 16, 19, 20, 31, 33]
#   grp_0963:   33 proteins  |  in test for splits [3, 7, 11, 20, 22, 32, 39, 40]
#   grp_1206:   90 proteins  |  in test for splits [1, 3, 6, 13, 15, 20, 22, 25, 28, 32, 38, 47]
#   grp_1213:   46 proteins  |  in test for splits [5, 8, 21, 23, 29, 45, 47, 48, 50]
#
# 3. Large test set size per split (all proteins)
# ------------------------------------------------------------
#   Split  1:  194 proteins
#   Split  2:  223 proteins
#   Split  3:  220 proteins
#   Split  4:  171 proteins
#   Split  5:  137 proteins
#   Split  6:  214 proteins
#   Split  7:  156 proteins
#   Split  8:  147 proteins
#   Split  9:  140 proteins
#   Split 10:  170 proteins
#   Split 11:  118 proteins
#   Split 12:  184 proteins
#   Split 13:  283 proteins
#   Split 14:  223 proteins
#   Split 15:  201 proteins
#   Split 16:  211 proteins
#   Split 17:  222 proteins
#   Split 18:  183 proteins
#   Split 19:  134 proteins
#   Split 20:  235 proteins
#   Split 21:  160 proteins
#   Split 22:  199 proteins
#   Split 23:  238 proteins
#   Split 24:  125 proteins
#   Split 25:  196 proteins
#   Split 26:  194 proteins
#   Split 27:  204 proteins
#   Split 28:  189 proteins
#   Split 29:  237 proteins
#   Split 30:  168 proteins
#   Split 31:  129 proteins
#   Split 32:  177 proteins
#   Split 33:  144 proteins
#   Split 34:  145 proteins
#   Split 35:  160 proteins
#   Split 36:  148 proteins
#   Split 37:  133 proteins
#   Split 38:  214 proteins
#   Split 39:  120 proteins
#   Split 40:  162 proteins
#   Split 41:  183 proteins
#   Split 42:  159 proteins
#   Split 43:  242 proteins
#   Split 44:  158 proteins
#   Split 45:  160 proteins
#   Split 46:  167 proteins
#   Split 47:  281 proteins
#   Split 48:  138 proteins
#   Split 49:  148 proteins
#   Split 50:  156 proteins
#
# 4. Overlap statistics across all splits
# ------------------------------------------------------------
#   Intersection (in ALL test sets): 0
#   Union (in ANY test set):         972
#   Jaccard similarity:              0.000
#
# 5. Per-protein test frequency (how many splits each protein is in test)
# ------------------------------------------------------------
#   5 split(s): 25 proteins
#   6 split(s): 71 proteins
#   7 split(s): 167 proteins
#   8 split(s): 55 proteins
#   9 split(s): 362 proteins
#   10 split(s): 40 proteins
#   11 split(s): 48 proteins
#   12 split(s): 90 proteins
#   13 split(s): 68 proteins
#   15 split(s): 46 proteins
#
# 6. Per-group test frequency -- randomness check
# ------------------------------------------------------------
#   Total large groups:          22
#   Groups drawn to test/split:  4  (18.2%)
#   Expected test freq per group over 50 splits: 9.1
#   Binomial SD: 2.73   2 SD band: [3.6, 14.5]
#   With this many groups, roughly one falling outside the band by chance is expected.
#
#   Group                           AP size  Test count  Note
#   grp_0000                             51           9  ok
#   grp_0018                             48          11  ok
#   grp_0033                             32           7  ok
#   grp_0064                             90           7  ok
#   grp_0065                             25           9  ok
#   grp_0072                             22           8  ok
#   grp_0091                             34           9  ok
#   grp_0101                             40          10  ok
#   grp_0110                             45           7  ok
#   grp_0113                             46          15  !! outside 2 SD
#   grp_0204                            113           9  ok
#   grp_0318                             25           5  ok
#   grp_0524                             23           9  ok
#   grp_0607                             33           9  ok
#   grp_0681                             29          13  ok
#   grp_0748                             49           6  ok
#   grp_0826                             39          13  ok
#   grp_0842                             37           9  ok
#   grp_0893                             22           6  ok
#   grp_0963                             33           8  ok
#   grp_1206                             90          12  ok
#   grp_1213                             46           9  ok
#
#   Min test count: 5  Max: 15  Mean: 9.09  Std: 2.43
#   Groups outside the 2 SD band: 1 / 22  (~1 expected by chance)
#   Observed SD vs binomial SD: 2.43 vs 2.73  -- tighter than a fair draw would give.
#
# ==========================================================================================
# 7. Drug target rate per group size  (analysis population only)
# ==========================================================================================
#   Analysis population = labelled (Drug_target/Non_target) + structured
#   Global drug target rate: 8.0%
#   n = 3388
#
#     group_size   n_groups    n_proteins    n_positive      pos_rate
#   --------------------------------------------------------------------
#              1        557           557            50          9.0%
#              2        135           270            11          4.1%
#              3         66           198            15          7.6%
#              4         44           176            11          6.2%
#              5         29           145            12          8.3%
#              6         19           114             6          5.3%
#              7         21           147             7          4.8%
#              8         12            96             2          2.1%
#              9          8            72             7          9.7%
#             10          6            60             5          8.3%
#             11          4            44             0          0.0%
#             12          4            48             6         12.5%
#             13          3            39             0          0.0%
#             14          8           112             4          3.6%
#             15          4            60            18         30.0%
#             16          5            80            23         28.7%
#             17          5            85             1          1.2%
#             18          3            54             7         13.0%
#             19          1            19             3         15.8%
#             20          2            40             2          5.0%
#             22          2            44             1          2.3%
#             23          1            23             2          8.7%
#             25          2            50             1          2.0%
#             29          1            29             0          0.0%
#             32          1            32             0          0.0%
#             33          2            66            14         21.2%
#             34          1            34             0          0.0%
#             37          1            37             0          0.0%
#             39          1            39             0          0.0%
#             40          1            40            20         50.0%
#             45          1            45             0          0.0%
#             46          2            92             3          3.3%
#             48          1            48             9         18.8%
#             49          1            49             0          0.0%
#             51          1            51             1          2.0%
#             90          2           180             0          0.0%
#            113          1           113            31         27.4%
#
#   Saved: /Users/anitaapplegarth/github/dphil/protein_complexes/data/lookup_tables/cp/avg_hpa_by_group_size.csv
#
# ==========================================================================================
# 8. Large-bucket test drug target rate by split
# ==========================================================================================
#   Global drug target rate: 8.0%
#
#   Split   Groups in test   Test proteins  Bucket rate
#   ------------------------------------------------------
#       1                4             194         8.8%
#       2                4             223        14.8%
#       3                4             220         4.5%
#       4                4             171         5.3%
#       5                4             137        16.8%
#       6                4             214         5.1%
#       7                4             156        11.5%
#       8                4             147         2.0%
#       9                4             140         5.7%
#      10                4             170        12.4%
#      11                4             118         6.8%
#      12                4             184         2.2%
#      13                4             283        11.3%
#      14                4             223         4.5%
#      15                4             201        10.0%
#      16                4             211        15.6%
#      17                4             222        14.4%
#      18                4             183        18.6%
#      19                4             134        16.4%
#      20                4             235         3.4%
#      21                4             160         6.9%
#      22                4             199         4.0%
#      23                4             238        16.8%
#      24                4             125         0.0%
#      25                4             196        10.2%
#      26                4             194        10.8%
#      27                4             204         0.0%
#      28                4             189         5.3%
#      29                4             237        16.5%
#      30                4             168         1.8%
#      31                4             129         7.0%
#      32                4             177         5.1%
#      33                4             144         6.2%
#      34                4             145        13.8%
#      35                4             160         4.4%
#      36                4             148         4.7%
#      37                4             133         7.5%
#      38                4             214         9.3%
#      39                4             120         9.2%
#      40                4             162         5.6%
#      41                4             183         0.0%
#      42                4             159        10.1%
#      43                4             242        13.2%
#      44                4             158         7.0%
#      45                4             160         6.9%
#      46                4             167         1.8%
#      47                4             281        11.7%
#      48                4             138        17.4%
#      49                4             148        14.2%
#      50                4             156         1.9%
#
#   Saved: /Users/anitaapplegarth/github/dphil/protein_complexes/data/lookup_tables/cp/hpa_split_summary.txt
#
# Done!
