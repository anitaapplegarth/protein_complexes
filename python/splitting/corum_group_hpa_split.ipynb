# %%
"""
Repeated random structural-group-level splits -- HPA drug-target labels.

All logic lives in split_common.py; this file is configuration only.

LABELS: Human Protein Atlas drug targets, kept strictly separate from the
ChEMBL set (Jaccard ~31%). Nothing is shared between the two label
derivations; they are independent prediction tasks.
"""

from split_common import run_splits

BASE = '/Users/anitaapplegarth/github/dphil/protein_complexes/data/lookup_tables'

CONFIG = {
    'task_description': 'Drug Target Labels (HPA)',

    # ---- Input files -------------------------------------------------------
    'group_mapping':      f'{BASE}/corum/mapping_struct.csv',
    'complex_membership': f'{BASE}/corum/stoich_protein.csv',
    'label_file':         f'{BASE}/corum_drug_target_hpa.csv',

    # ---- Input column names ------------------------------------------------
    'col_group_protein':   'uniprot_id',
    'col_group_id':        'group_id',
    'col_complex_id':      'ComplexId',
    'col_complex_protein': 'ProteinId',
    'col_label_protein':   'ProteinId',
    'col_label_value':     'target',

    # ---- Label scheme ------------------------------------------------------
    'label_scheme': {
        'positive': 'Drug_target',
        'negative': 'Non_target',
        'noun':     'drug target',
        'binarise': lambda v: 'Drug_target' if v == 1 else 'Non_target',
    },

    # ---- Output files ------------------------------------------------------
    'output_all_splits':   f'{BASE}/corum/hpa_protein_splits.csv',
    'output_balance':      f'{BASE}/corum/hpa_split_balance.csv',
    'output_summary':      f'{BASE}/corum/hpa_split_summary.txt',
    'output_rate_by_size': f'{BASE}/corum/avg_hpa_by_group_size.csv',

    # ---- Split parameters --------------------------------------------------
    'n_splits':    50,
    'train_ratio': 0.80,
    'test_ratio':  0.20,
    'base_seed':   42,

    'max_size_deviation': 5.0,   # pp -- acceptable range [15%, 25%]

    # Check the printed global rate on the first run. If HPA's positive rate
    # differs materially from ChEMBL's, 1.5pp is a different level of
    # strictness and should be retuned -- roughly a tenth of the global rate
    # is a reasonable starting point.
    'max_label_rate_deviation': 1.5,

    'max_attempts': 25,

    # ---- Validation tuning -------------------------------------------------
    'validate_abs_tol':            0.15,
    'validate_min_groups':         3,
    'min_test_groups_per_bucket':  1,
    'strict_duplicate_check':      False,
    'require_full_n_splits':       True,

    # ---- Bucket ablation ---------------------------------------------------
    'stratify_by_bucket': True,
    'unstrat_suffix':     '_unstrat',
}


if __name__ == '__main__':
    run_splits(CONFIG)
# Out:
# ======================================================================
# Repeated Random group-Level Splitting -- Size-Stratified, N=50
# Drug Target Labels (HPA)
# ======================================================================
#
# --- Loading data ---
#   Groups:    5122 rows, 2129 unique groups
#   Complexes: 5454 complexes, 5132 unique proteins
#   Labels:    5132 rows from /Users/anitaapplegarth/github/dphil/protein_complexes/data/lookup_tables/corum_drug_target_hpa.csv
#   Duplicate group assignments: none
#
#   Label distribution (5132 total complex proteins):
#     Drug_target    :   592
#     Non_target     :  4540
#     Unknown        :     0  (no usable label -- excluded)
#     No-group       :    10  (no structural assignment -- excluded)
#   Analysis population (labelled + structured): 5122
#   Global drug target rate (analysis population): 11.6%  (592 / 5122)
#
# --- Group size buckets (largest first) ---
#   large        (>20 proteins (merged large + very large)):   23 groups,  1057 proteins -- 5 grps drawn to test each split
#   medium       (6-20                                    ):  115 groups,  1115 proteins -- 23 grps drawn to test each split
#   small        (2-5                                     ):  540 groups,  1499 proteins -- 108 grps drawn to test each split
#   singleton    (1 protein                               ): 1451 groups,  1451 proteins -- 290 grps drawn to test each split
#   No-group proteins: 10
#
# --- Allocation mode: SIZE-STRATIFIED ---
# --- Generating 50 splits (tolerance +/-1.5pp label, +/-5.0pp size, max 25 attempts each) ---
#   Split  1 | train=4171 (81.3%) pos=11.6% | test=961 (18.7%) pos=11.5% | size_dev=1.3pp label_dev=0.1pp
#   Split  2 | train=4157 (81.0%) pos=11.5% | test=975 (19.0%) pos=11.9% | size_dev=1.0pp label_dev=0.4pp (accepted on attempt 3)
#   Split  3 | train=4095 (79.8%) pos=11.5% | test=1037 (20.2%) pos=11.9% | size_dev=0.2pp label_dev=0.3pp (accepted on attempt 2)
#   Split  4 | train=4135 (80.6%) pos=11.8% | test=997 (19.4%) pos=10.3% | size_dev=0.6pp label_dev=1.2pp
#   Split  5 | train=4128 (80.4%) pos=11.6% | test=1004 (19.6%) pos=11.4% | size_dev=0.4pp label_dev=0.2pp (accepted on attempt 3)
#   Split  6 | train=4140 (80.7%) pos=11.7% | test=992 (19.3%) pos=11.1% | size_dev=0.7pp label_dev=0.5pp (accepted on attempt 5)
#   Split  7 | train=4164 (81.1%) pos=11.6% | test=968 (18.9%) pos=11.3% | size_dev=1.1pp label_dev=0.3pp (accepted on attempt 2)
#   Split  8 | train=4105 (80.0%) pos=11.5% | test=1027 (20.0%) pos=11.8% | size_dev=0.0pp label_dev=0.2pp (accepted on attempt 2)
#   Split  9 | train=4114 (80.2%) pos=11.4% | test=1018 (19.8%) pos=12.3% | size_dev=0.2pp label_dev=0.7pp (accepted on attempt 5)
#   Split 10 | train=4116 (80.2%) pos=11.3% | test=1016 (19.8%) pos=12.4% | size_dev=0.2pp label_dev=0.9pp (accepted on attempt 2)
#   Split 11 | train=4063 (79.2%) pos=11.8% | test=1069 (20.8%) pos=10.8% | size_dev=0.8pp label_dev=0.8pp (accepted on attempt 3)
#   Split 12 | train=4068 (79.3%) pos=11.3% | test=1064 (20.7%) pos=12.3% | size_dev=0.7pp label_dev=0.8pp (accepted on attempt 3)
#   Split 13 | train=4130 (80.5%) pos=11.3% | test=1002 (19.5%) pos=12.6% | size_dev=0.5pp label_dev=1.0pp (accepted on attempt 2)
#   Split 14 | train=4114 (80.2%) pos=11.6% | test=1018 (19.8%) pos=11.4% | size_dev=0.2pp label_dev=0.1pp
#   Split 15 | train=4073 (79.4%) pos=11.5% | test=1059 (20.6%) pos=11.6% | size_dev=0.6pp label_dev=0.1pp
#   Split 16 | train=4093 (79.8%) pos=11.8% | test=1039 (20.2%) pos=10.4% | size_dev=0.2pp label_dev=1.1pp (accepted on attempt 4)
#   Split 17 | train=4087 (79.6%) pos=11.6% | test=1045 (20.4%) pos=11.4% | size_dev=0.4pp label_dev=0.1pp (accepted on attempt 2)
#   Split 18 | train=4094 (79.8%) pos=11.5% | test=1038 (20.2%) pos=11.7% | size_dev=0.2pp label_dev=0.1pp
#   Split 19 | train=3929 (76.6%) pos=11.5% | test=1203 (23.4%) pos=11.8% | size_dev=3.4pp label_dev=0.3pp
#   Split 20 | train=4060 (79.1%) pos=11.5% | test=1072 (20.9%) pos=11.8% | size_dev=0.9pp label_dev=0.2pp
#   Split 21 | train=4105 (80.0%) pos=11.8% | test=1027 (20.0%) pos=10.5% | size_dev=0.0pp label_dev=1.0pp (accepted on attempt 2)
#   Split 22 | train=4156 (81.0%) pos=11.5% | test=976 (19.0%) pos=11.7% | size_dev=1.0pp label_dev=0.1pp
#   Split 23 | train=4080 (79.5%) pos=11.7% | test=1052 (20.5%) pos=11.1% | size_dev=0.5pp label_dev=0.4pp
#   Split 24 | train=4155 (81.0%) pos=11.3% | test=977 (19.0%) pos=12.7% | size_dev=1.0pp label_dev=1.2pp (accepted on attempt 5)
#   Split 25 | train=4077 (79.4%) pos=11.6% | test=1055 (20.6%) pos=11.3% | size_dev=0.6pp label_dev=0.3pp
#   Split 26 | train=4100 (79.9%) pos=11.6% | test=1032 (20.1%) pos=11.6% | size_dev=0.1pp label_dev=0.0pp (accepted on attempt 4)
#   Split 27 | train=4164 (81.1%) pos=11.3% | test=968 (18.9%) pos=12.5% | size_dev=1.1pp label_dev=1.0pp
#   Split 28 | train=4018 (78.3%) pos=11.9% | test=1114 (21.7%) pos=10.3% | size_dev=1.7pp label_dev=1.2pp (accepted on attempt 3)
#   Split 29 | train=4088 (79.7%) pos=11.8% | test=1044 (20.3%) pos=10.6% | size_dev=0.3pp label_dev=1.0pp (accepted on attempt 3)
#   Split 30 | train=3984 (77.6%) pos=11.6% | test=1148 (22.4%) pos=11.5% | size_dev=2.4pp label_dev=0.0pp
#   Split 31 | train=4052 (79.0%) pos=11.2% | test=1080 (21.0%) pos=12.8% | size_dev=1.0pp label_dev=1.2pp (accepted on attempt 2)
#   Split 32 | train=3998 (77.9%) pos=11.7% | test=1134 (22.1%) pos=11.1% | size_dev=2.1pp label_dev=0.4pp (accepted on attempt 3)
#   Split 33 | train=4058 (79.1%) pos=11.3% | test=1074 (20.9%) pos=12.7% | size_dev=0.9pp label_dev=1.1pp
#   Split 34 | train=4073 (79.4%) pos=11.8% | test=1059 (20.6%) pos=10.6% | size_dev=0.6pp label_dev=1.0pp (accepted on attempt 4)
#   Split 35 | train=3993 (77.8%) pos=11.2% | test=1139 (22.2%) pos=12.9% | size_dev=2.2pp label_dev=1.4pp (accepted on attempt 2)
#   Split 36 | train=4111 (80.1%) pos=11.8% | test=1021 (19.9%) pos=10.6% | size_dev=0.1pp label_dev=1.0pp
#   Split 37 | train=4110 (80.1%) pos=11.7% | test=1022 (19.9%) pos=11.0% | size_dev=0.1pp label_dev=0.6pp
#   Split 38 | train=4093 (79.8%) pos=11.7% | test=1039 (20.2%) pos=11.0% | size_dev=0.2pp label_dev=0.6pp (accepted on attempt 2)
#   Split 39 | train=4134 (80.5%) pos=11.2% | test=998 (19.4%) pos=12.8% | size_dev=0.6pp label_dev=1.3pp (accepted on attempt 2)
#   Split 40 | train=4044 (78.8%) pos=11.5% | test=1088 (21.2%) pos=11.9% | size_dev=1.2pp label_dev=0.3pp (accepted on attempt 4)
#   Split 41 | train=4165 (81.2%) pos=11.3% | test=967 (18.8%) pos=12.6% | size_dev=1.2pp label_dev=1.1pp
#   Split 42 | train=4116 (80.2%) pos=11.6% | test=1016 (19.8%) pos=11.5% | size_dev=0.2pp label_dev=0.0pp
#   Split 43 | train=4144 (80.8%) pos=11.3% | test=988 (19.2%) pos=12.6% | size_dev=0.8pp label_dev=1.0pp (accepted on attempt 2)
#   Split 44 | train=4066 (79.2%) pos=11.8% | test=1066 (20.8%) pos=10.5% | size_dev=0.8pp label_dev=1.0pp
#   Split 45 | train=4068 (79.3%) pos=11.6% | test=1064 (20.7%) pos=11.3% | size_dev=0.7pp label_dev=0.3pp (accepted on attempt 7)
#   Split 46 | train=4140 (80.7%) pos=11.2% | test=992 (19.3%) pos=12.8% | size_dev=0.7pp label_dev=1.3pp (accepted on attempt 2)
#   Split 47 | train=4201 (81.9%) pos=11.3% | test=931 (18.1%) pos=12.6% | size_dev=1.9pp label_dev=1.0pp (accepted on attempt 8)
#   Split 48 | train=4122 (80.3%) pos=11.7% | test=1010 (19.7%) pos=11.1% | size_dev=0.3pp label_dev=0.5pp (accepted on attempt 2)
#   Split 49 | train=4166 (81.2%) pos=11.3% | test=966 (18.8%) pos=12.8% | size_dev=1.2pp label_dev=1.2pp (accepted on attempt 2)
#   Split 50 | train=4108 (80.0%) pos=11.3% | test=1024 (19.9%) pos=12.4% | size_dev=0.1pp label_dev=0.9pp (accepted on attempt 2)
#
# group-size bucket distribution after split (groups counted):
# BUCKET           TRAIN   TEST  TOTAL TEST_FRAC
# large               18      5     23     0.217
# medium              92     23    115     0.200
# singleton         1161    290   1451     0.200
# small              432    108    540     0.200
#
# --- Integrity check ---
#   Splits emitted:            50 / 50
#   split_index contiguous:    True
#   Total leakage violations:  0
#   Splits failing validation: 0
#
# --- Saving outputs ---
#   Saved: /Users/anitaapplegarth/github/dphil/protein_complexes/data/lookup_tables/corum/hpa_protein_splits.csv  (256,600 rows)
#   Saved: /Users/anitaapplegarth/github/dphil/protein_complexes/data/lookup_tables/corum/hpa_split_balance.csv
#
# ==========================================================================================
# SPLIT SUMMARY -- Size-stratified repeated random group-level splits
# Drug Target Labels (HPA)
# ==========================================================================================
# Total unique proteins:            5132
# Total complexes:                  5454
# Total groups:                     2129
#   Large      (>20, merged):       23
#   Medium     (6-20):              115
#   Small      (2-5):               540
#   Singleton  (1 protein):         1451
# Analysis population:              5122  (labelled + structured; excludes 0 Unknown, 10 no-group)
# Global drug target rate:              11.6%  (592 / 5122)
# Allocation mode:                  size-stratified
# Number of splits:                 50
# Train/test ratio:                 80% / 20%
# Size tolerance:                   +/-5.0pp  (acceptable range: 15%-25%)
# Balance tolerance:                +/
#   grp_1325:   28 proteins  |  in test for splits [1, 2, 3, 9, 11, 14, 17, 22, 24, 26, 32, 35, 41, 42, 46, 47, 49, 50]
#   grp_1411:   26 proteins  |  in test for splits [1, 7, 14, 20, 22, 23, 24, 25, 28, 34, 36, 37, 39, 47, 48, 49]
#   grp_1883:   48 proteins  |  in test for splits [6, 10, 11, 12, 20, 28, 30, 31, 39, 41, 45]
#   grp_2003:   86 proteins  |  in test for splits [8, 11, 12, 13, 15, 18, 19, 20, 21, 22, 23, 24, 25, 29, 33, 34, 37, 39, 43, 45, 46]
#   grp_2161:   27 proteins  |  in test for splits [4, 8, 11, 12, 13, 22, 23, 25, 27, 33, 43, 45, 49]
#   grp_2721:   25 proteins  |  in test for splits [1, 2, 3, 7, 13, 15, 21, 27, 34, 38, 44, 45, 46, 50]
#
# 3. Large test set size per split (all proteins)
# ------------------------------------------------------------
#   Split  1:  139 proteins
#   Split  2:  138 proteins
#   Split  3:  212 proteins
#   Split  4:  174 proteins
#   Split  5:  206 proteins
#   Split  6:  180 proteins
#   Split  7:  151 proteins
#   Split  8:  228 proteins
#   Split  9:  189 proteins
#   Split 10:  225 proteins
#   Split 11:  212 proteins
#   Split 12:  219 proteins
#   Split 13:  214 proteins
#   Split 14:  227 proteins
#   Split 15:  221 proteins
#   Split 16:  218 proteins
#   Split 17:  220 proteins
#   Split 18:  214 proteins
#   Split 19:  393 proteins
#   Split 20:  272 proteins
#   Split 21:  236 proteins
#   Split 22:  190 proteins
#   Split 23:  206 proteins
#   Split 24:  205 proteins
#   Split 25:  244 proteins
#   Split 26:  188 proteins
#   Split 27:  152 proteins
#   Split 28:  303 proteins
#   Split 29:  189 proteins
#   Split 30:  332 proteins
#   Split 31:  262 proteins
#   Split 32:  309 proteins
#   Split 33:  273 proteins
#   Split 34:  231 proteins
#   Split 35:  323 proteins
#   Split 36:  205 proteins
#   Split 37:  199 proteins
#   Split 38:  210 proteins
#   Split 39:  221 proteins
#   Split 40:  277 proteins
#   Split 41:  159 proteins
#   Split 42:  183 proteins
#   Split 43:  196 proteins
#   Split 44:  263 proteins
#   Split 45:  241 proteins
#   Split 46:  200 proteins
#   Split 47:  138 proteins
#   Split 48:  207 proteins
#   Split 49:  141 proteins
#   Split 50:  172 proteins
#
# 4. Overlap statistics across all splits
# ------------------------------------------------------------
#   Intersection (in ALL test sets): 0
#   Union (in ANY test set):         1057
#   Jaccard similarity:              0.000
#
# 5. Per-protein test frequency (how many splits each protein is in test)
# ------------------------------------------------------------
#   2 split(s): 90 proteins
#   4 split(s): 24 proteins
#   7 split(s): 85 proteins
#   8 split(s): 270 proteins
#   9 split(s): 114 proteins
#   10 split(s): 23 proteins
#   11 split(s): 113 proteins
#   12 split(s): 27 proteins
#   13 split(s): 88 proteins
#   14 split(s): 62 proteins
#   15 split(s): 21 proteins
#   16 split(s): 26 proteins
#   18 split(s): 28 proteins
#   21 split(s): 86 proteins
#
# 6. Per-group test frequency -- randomness check
# ------------------------------------------------------------
#   Total large groups:          23
#   Groups drawn to test/split:  5  (21.7%)
#   Expected test freq per group over 50 splits: 10.9
#   Binomial SD: 2.92   2 SD band: [5.0, 16.7]
#   With this many groups, roughly one falling outside the band by chance is expected.
#
#   Group                           AP size  Test count  Note
#   grp_0287                             90           2  !! outside 2 SD
#   grp_0288                             27           8  ok
#   grp_0302                             40           8  ok
#   grp_0320                             85           7  ok
#   grp_0335                             40           8  ok
#   grp_0456                             55           8  ok
#   grp_0639                             23          11  ok
#   grp_0684                             37          14  ok
#   grp_0688                             24           4  !! outside 2 SD
#   grp_0756                             81           9  ok
#   grp_0757                             27          12  ok
#   grp_0849                             23          10  ok
#   grp_0879                             42          11  ok
#   grp_0886                             21          15  ok
#   grp_0942                             61          13  ok
#   grp_1114                            108           8  ok
#   grp_1261                             33           9  ok
#   grp_1325                             28          18  !! outside 2 SD
#   grp_1411                             26          16  ok
#   grp_1883                             48          11  ok
#   grp_2003                             86          21  !! outside 2 SD
#   grp_2161                             27          13  ok
#   grp_2721                             25          14  ok
#
#   Min test count: 2  Max: 21  Mean: 10.87  Std: 4.26
#   Groups outside the 2 SD band: 4 / 23  (~1 expected by chance)
#   Observed SD vs binomial SD: 4.26 vs 2.92  -- wider than a fair draw would give.
#
# ==========================================================================================
# 7. Drug target rate per group size  (analysis population only)
# ==========================================================================================
#   Analysis population = labelled (Drug_target/Non_target) + structured
#   Global drug target rate: 11.6%
#   n = 5122
#
#     group_size   n_groups    n_proteins    n_positive      pos_rate
#   --------------------------------------------------------------------
#              1       1451          1451           115          7.9%
#              2        286           572            58         10.1%
#              3        138           414            45         10.9%
#              4         67           268            32         11.9%
#              5         49           245            41         16.7%
#              6         21           126             4          3.2%
#              7         19           133            12          9.0%
#              8         21           168            15          8.9%
#              9          9            81             9         11.1%
#             10          8            80            12         15.0%
#             11          6            66             8         12.1%
#             12          8            96             1          1.0%
#             13          4            52             6         11.5%
#             14          4            56            10         17.9%
#             15          1            15             0          0.0%
#             16          5            80             7          8.8%
#             17          2            34             1          2.9%
#             18          5            90            17         18.9%
#             19          2            38             2          5.3%
#             21          1            21             8         38.1%
#             23          2            46             1          2.2%
#             24          1            24             0          0.0%
#             25          1            25             0          0.0%
#             26          1            26             4         15.4%
#             27          3            81             2          2.5%
#             28          1            28            19         67.9%
#             33          1            33             1          3.0%
#             37          1            37            17         45.9%
#             40          2            80             6          7.5%
#             42          1            42             1          2.4%
#             48          1            48             1          2.1%
#             55          1            55            15         27.3%
#             61          1            61             4          6.6%
#             81          1            81             0          0.0%
#             85          1            85             2          2.4%
#             86          1            86            28         32.6%
#             90          1            90            53         58.9%
#            108          1           108            35         32.4%
#
#   Saved: /Users/anitaapplegarth/github/dphil/protein_complexes/data/lookup_tables/corum/avg_hpa_by_group_size.csv
#
# ==========================================================================================
# 8. Large-bucket test drug target rate by split
# ==========================================================================================
#   Global drug target rate: 11.6%
#
#   Split   Groups in test   Test proteins  Bucket rate
#   ------------------------------------------------------
#       1                5             139        18.0%
#       2                5             138        23.9%
#       3                5             212        25.9%
#       4                5             174         3.4%
#       5                5             206        12.6%
#       6                5             180        13.9%
#       7                5             151        18.5%
#       8                5             228        18.4%
#       9                5             189        28.0%
#      10                5             225        24.9%
#      11                5             212        23.6%
#      12                5             219        25.1%
#      13                5             214        24.3%
#      14                5             227        12.8%
#      15                5             221        23.5%
#      16                5             218         9.6%
#      17                5             220        10.9%
#      18                5             214        14.0%
#      19                5             393        16.8%
#      20                5             272        13.2%
#      21                5             236        20.8%
#      22                5             190        27.9%
#      23                5             206        16.5%
#      24                5             205        25.9%
#      25                5             244        13.5%
#      26                5             188        24.5%
#      27                5             152        17.8%
#      28                5             303        13.2%
#      29                5             189        15.9%
#      30                5             332        15.4%
#      31                5             262        25.6%
#      32                5             309        19.4%
#      33                5             273        17.2%
#      34                5             231        16.0%
#      35                5             323        19.8%
#      36                5             205        17.1%
#      37                5             199        25.6%
#      38                5             210         9.5%
#      39                5             221        18.6%
#      40                5             277        18.4%
#      41                5             159        23.9%
#      42                5             183        16.4%
#      43                5             196        15.3%
#      44                5             263        15.6%
#      45                5             241        18.7%
#      46                5             200        30.5%
#      47                5             138        26.8%
#      48                5             207        11.6%
#      49                5             141        29.8%
#      50                5             172        21.5%
#
#   Saved: /Users/anitaapplegarth/github/dphil/protein_complexes/data/lookup_tables/corum/hpa_split_summary.txt
#
# Done!
