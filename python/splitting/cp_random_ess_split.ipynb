# %%
"""
Repeated random structural-group-level splits -- essentiality labels.

All logic lives in split_common.py; this file is configuration only.

LABELS: OGEE v3 + DepMap. Core -> Essential; Cancer and Non-essential ->
Non-essential; anything else -> dropped to Unknown and excluded from the
analysis population. This is the binarisation used throughout the paper.

NOTE: this is the RANDOM structural-group-atomic split. The complex-atomic
leak-free variant used for the supplementary robustness paragraph lives in
cp_complexatomic_ess_split.py and is a different scheme -- do not confuse the
output files.
"""

from split_common import run_splits

BASE = '/Users/anitaapplegarth/github/dphil/protein_complexes/data/lookup_tables'


def binarise_essentiality(raw):
    """Core -> Essential; Cancer & Non-essential -> Non-essential; else drop."""
    if raw == 'Core':
        return 'Essential'
    if raw in ('Cancer', 'Non-essential'):
        return 'Non-essential'
    return None


CONFIG = {
    'task_description': 'Essentiality Labels (OGEE v3 + DepMap)',

    # ---- Input files -------------------------------------------------------
    'group_mapping':      f'{BASE}/cp/mapping_struct.csv',
    'complex_membership': f'{BASE}/cp/stoich_protein.csv',
    'label_file':         f'{BASE}/lu_essentiality_protein.csv',

    # ---- Input column names ------------------------------------------------
    # NOTE: the essentiality table keys on 'Protein', not 'ProteinId' as the
    # drug-target tables do. This asymmetry is the reason the column names are
    # configurable rather than hardcoded.
    'col_group_protein':   'uniprot_id',
    'col_group_id':        'group_id',
    'col_complex_id':      'ComplexId',
    'col_complex_protein': 'ProteinId',
    'col_label_protein':   'Protein',
    'col_label_value':     'essential_category',

    # ---- Label scheme ------------------------------------------------------
    'label_scheme': {
        'positive': 'Essential',
        'negative': 'Non-essential',
        'noun':     'essential',
        'binarise': binarise_essentiality,
    },

    # ---- Output files ------------------------------------------------------
    'output_all_splits':   f'{BASE}/cp/ess_protein_splits.csv',
    'output_balance':      f'{BASE}/cp/ess_split_balance.csv',
    'output_summary':      f'{BASE}/cp/ess_split_summary.txt',
    'output_rate_by_size': f'{BASE}/cp/avg_essentiality_by_group_size.csv',

    # ---- Split parameters --------------------------------------------------
    'n_splits':    50,
    'train_ratio': 0.80,
    'test_ratio':  0.20,
    'base_seed':   42,

    'max_size_deviation': 5.0,   # pp -- acceptable range [15%, 25%]

    # Looser than the drug-target tasks (4.5pp vs 1.5pp) because the global
    # essential rate is far higher, so the same absolute pp tolerance is
    # proportionally much tighter. Renamed from 'max_ess_rate_deviation' to
    # match the shared engine.
    'max_label_rate_deviation': 4.5,

    'max_attempts': 25,

    # ---- Validation tuning -------------------------------------------------
    'validate_abs_tol':            0.15,
    'validate_min_groups':         3,
    'min_test_groups_per_bucket':  1,
    'strict_duplicate_check':      False,
    'require_full_n_splits':       True,

    # ---- Bucket ablation ---------------------------------------------------
    'stratify_by_bucket': True,
    'unstrat_suffix':     '_unstrat',
}


if __name__ == '__main__':
    run_splits(CONFIG)
# Out:
# ======================================================================
# Repeated Random group-Level Splitting -- Size-Stratified, N=50
# Essentiality Labels (OGEE v3 + DepMap)
# ======================================================================
#
# --- Loading data ---
#   Groups:    3388 rows, 955 unique groups
#   Complexes: 2220 complexes, 3394 unique proteins
#   Labels:    18392 rows from /Users/anitaapplegarth/github/dphil/protein_complexes/data/lookup_tables/lu_essentiality_protein.csv
#   Duplicate group assignments: none
#
#   Label distribution (3394 total complex proteins):
#     Essential      :   773
#     Non-essential  :  2538
#     Unknown        :    83  (no usable label -- excluded)
#     No-group       :     6  (no structural assignment -- excluded)
#   Analysis population (labelled + structured): 3306
#   Global essential rate (analysis population): 23.4%  (773 / 3306)
#
# --- Group size buckets (largest first) ---
#   large        (>20 proteins (merged large + very large)):   22 groups,   970 proteins -- 4 grps drawn to test each split
#   medium       (6-20                                    ):  106 groups,  1075 proteins -- 21 grps drawn to test each split
#   small        (2-5                                     ):  277 groups,   793 proteins -- 55 grps drawn to test each split
#   singleton    (1 protein                               ):  550 groups,   550 proteins -- 110 grps drawn to test each split
#   No-group proteins: 6
#
# --- Allocation mode: SIZE-STRATIFIED ---
# --- Generating 50 splits (tolerance +/-4.5pp label, +/-5.0pp size, max 25 attempts each) ---
#   Split  1 | train=2709 (79.8%) pos=24.0% | test=685 (20.2%) pos=20.8% | size_dev=0.2pp label_dev=2.6pp
#   Split  2 | train=2771 (81.6%) pos=23.0% | test=623 (18.4%) pos=25.0% | size_dev=1.6pp label_dev=1.6pp
#   Split  3 | train=2691 (79.3%) pos=23.2% | test=703 (20.7%) pos=24.1% | size_dev=0.7pp label_dev=0.8pp
#   Split  4 | train=2811 (82.8%) pos=23.9% | test=583 (17.2%) pos=20.6% | size_dev=2.8pp label_dev=2.8pp
#   Split  5 | train=2604 (76.7%) pos=24.2% | test=790 (23.3%) pos=20.7% | size_dev=3.3pp label_dev=2.7pp
#   Split  6 | train=2714 (80.0%) pos=24.3% | test=680 (20.0%) pos=19.8% | size_dev=0.0pp label_dev=3.6pp (accepted on attempt 2)
#   Split  7 | train=2757 (81.2%) pos=22.9% | test=637 (18.8%) pos=25.4% | size_dev=1.2pp label_dev=2.0pp (accepted on attempt 2)
#   Split  8 | train=2726 (80.3%) pos=24.3% | test=668 (19.7%) pos=19.6% | size_dev=0.3pp label_dev=3.8pp
#   Split  9 | train=2721 (80.2%) pos=23.2% | test=673 (19.8%) pos=24.1% | size_dev=0.2pp label_dev=0.7pp (accepted on attempt 2)
#   Split 10 | train=2717 (80.0%) pos=22.9% | test=677 (19.9%) pos=25.2% | size_dev=0.1pp label_dev=1.8pp
#   Split 11 | train=2749 (81.0%) pos=22.7% | test=645 (19.0%) pos=26.3% | size_dev=1.0pp label_dev=3.0pp (accepted on attempt 3)
#   Split 12 | train=2738 (80.7%) pos=22.9% | test=656 (19.3%) pos=25.6% | size_dev=0.7pp label_dev=2.2pp
#   Split 13 | train=2675 (78.8%) pos=24.1% | test=719 (21.2%) pos=20.9% | size_dev=1.2pp label_dev=2.5pp
#   Split 14 | train=2718 (80.1%) pos=23.9% | test=676 (19.9%) pos=21.2% | size_dev=0.1pp label_dev=2.2pp
#   Split 15 | train=2770 (81.6%) pos=24.0% | test=624 (18.4%) pos=20.6% | size_dev=1.6pp label_dev=2.8pp
#   Split 16 | train=2715 (80.0%) pos=24.1% | test=679 (20.0%) pos=20.5% | size_dev=0.0pp label_dev=2.8pp
#   Split 17 | train=2707 (79.8%) pos=23.7% | test=687 (20.2%) pos=22.0% | size_dev=0.2pp label_dev=1.4pp (accepted on attempt 2)
#   Split 18 | train=2698 (79.5%) pos=23.8% | test=696 (20.5%) pos=21.6% | size_dev=0.5pp label_dev=1.8pp
#   Split 19 | train=2705 (79.7%) pos=24.2% | test=689 (20.3%) pos=20.3% | size_dev=0.3pp label_dev=3.1pp
#   Split 20 | train=2642 (77.8%) pos=23.9% | test=752 (22.2%) pos=21.5% | size_dev=2.2pp label_dev=1.9pp
#   Split 21 | train=2763 (81.4%) pos=22.9% | test=631 (18.6%) pos=25.3% | size_dev=1.4pp label_dev=1.9pp
#   Split 22 | train=2706 (79.7%) pos=23.7% | test=688 (20.3%) pos=22.0% | size_dev=0.3pp label_dev=1.4pp
#   Split 23 | train=2814 (82.9%) pos=22.6% | test=580 (17.1%) pos=27.0% | size_dev=2.9pp label_dev=3.6pp (accepted on attempt 2)
#   Split 24 | train=2810 (82.8%) pos=23.9% | test=584 (17.2%) pos=21.1% | size_dev=2.8pp label_dev=2.3pp
#   Split 25 | train=2767 (81.5%) pos=23.9% | test=627 (18.5%) pos=20.9% | size_dev=1.5pp label_dev=2.5pp
#   Split 26 | train=2681 (79.0%) pos=23.2% | test=713 (21.0%) pos=23.9% | size_dev=1.0pp label_dev=0.5pp (accepted on attempt 3)
#   Split 27 | train=2785 (82.1%) pos=23.9% | test=609 (17.9%) pos=21.3% | size_dev=2.1pp label_dev=2.1pp
#   Split 28 | train=2786 (82.1%) pos=23.9% | test=608 (17.9%) pos=21.0% | size_dev=2.1pp label_dev=2.3pp
#   Split 29 | train=2657 (78.3%) pos=23.8% | test=737 (21.7%) pos=21.8% | size_dev=1.7pp label_dev=1.6pp
#   Split 30 | train=2778 (81.8%) pos=23.4% | test=616 (18.1%) pos=23.1% | size_dev=1.9pp label_dev=0.2pp (accepted on attempt 3)
#   Split 31 | train=2753 (81.1%) pos=22.7% | test=641 (18.9%) pos=26.1% | size_dev=1.1pp label_dev=2.7pp (accepted on attempt 2)
#   Split 32 | train=2752 (81.1%) pos=24.0% | test=642 (18.9%) pos=20.6% | size_dev=1.1pp label_dev=2.8pp
#   Split 33 | train=2710 (79.8%) pos=23.8% | test=684 (20.1%) pos=21.6% | size_dev=0.1pp label_dev=1.7pp
#   Split 34 | train=2758 (81.3%) pos=23.7% | test=636 (18.7%) pos=22.2% | size_dev=1.3pp label_dev=1.2pp
#   Split 35 | train=2779 (81.9%) pos=23.6% | test=615 (18.1%) pos=22.5% | size_dev=1.9pp label_dev=0.8pp
#   Split 36 | train=2694 (79.4%) pos=23.7% | test=700 (20.6%) pos=22.2% | size_dev=0.6pp label_dev=1.2pp (accepted on attempt 2)
#   Split 37 | train=2798 (82.4%) pos=22.7% | test=596 (17.6%) pos=26.6% | size_dev=2.4pp label_dev=3.2pp (accepted on attempt 2)
#   Split 38 | train=2755 (81.2%) pos=24.2% | test=639 (18.8%) pos=19.7% | size_dev=1.2pp label_dev=3.7pp
#   Split 39 | train=2761 (81.3%) pos=24.4% | test=633 (18.6%) pos=19.2% | size_dev=1.4pp label_dev=4.2pp
#   Split 40 | train=2687 (79.2%) pos=23.8% | test=707 (20.8%) pos=21.9% | size_dev=0.8pp label_dev=1.5pp (accepted on attempt 2)
#   Split 41 | train=2658 (78.3%) pos=24.4% | test=736 (21.7%) pos=19.8% | size_dev=1.7pp label_dev=3.6pp (accepted on attempt 2)
#   Split 42 | train=2794 (82.3%) pos=24.0% | test=600 (17.7%) pos=20.3% | size_dev=2.3pp label_dev=3.1pp (accepted on attempt 2)
#   Split 43 | train=2681 (79.0%) pos=23.5% | test=713 (21.0%) pos=22.9% | size_dev=1.0pp label_dev=0.4pp
#   Split 44 | train=2715 (80.0%) pos=23.0% | test=679 (20.0%) pos=25.1% | size_dev=0.0pp label_dev=1.7pp
#   Split 45 | train=2806 (82.7%) pos=22.8% | test=588 (17.3%) pos=26.3% | size_dev=2.7pp label_dev=2.9pp
#   Split 46 | train=2729 (80.4%) pos=24.0% | test=665 (19.6%) pos=20.8% | size_dev=0.4pp label_dev=2.6pp (accepted on attempt 3)
#   Split 47 | train=2822 (83.2%) pos=23.6% | test=572 (16.9%) pos=22.5% | size_dev=3.1pp label_dev=0.9pp (accepted on attempt 2)
#   Split 48 | train=2784 (82.0%) pos=23.4% | test=610 (18.0%) pos=23.1% | size_dev=2.0pp label_dev=0.2pp (accepted on attempt 2)
#   Split 49 | train=2765 (81.5%) pos=23.4% | test=629 (18.5%) pos=23.3% | size_dev=1.5pp label_dev=0.0pp (accepted on attempt 3)
#   Split 50 | train=2690 (79.3%) pos=24.1% | test=704 (20.7%) pos=20.5% | size_dev=0.7pp label_dev=2.9pp
#
# group-size bucket distribution after split (groups counted):
# BUCKET           TRAIN   TEST  TOTAL TEST_FRAC
# large               18      4     22     0.182
# medium              85     21    106     0.198
# singleton          440    110    550     0.200
# small              222     55    277     0.199
#
# --- Integrity check ---
#   Splits emitted:            50 / 50
#   split_index contiguous:    True
#   Total leakage violations:  0
#   Splits failing validation: 0
#
# --- Saving outputs ---
#   Saved: /Users/anitaapplegarth/github/dphil/protein_complexes/data/lookup_tables/cp/ess_protein_splits.csv  (169,700 rows)
#   Saved: /Users/anitaapplegarth/github/dphil/protein_complexes/data/lookup_tables/cp/ess_split_balance.csv
#
# ==========================================================================================
# SPLIT SUMMARY -- Size-stratified repeated random group-level splits
# Essentiality Labels (OGEE v3 + DepMap)
# ==========================================================================================
# Total unique proteins:            3394
# Total complexes:                  2220
# Total groups:                     955
#   Large      (>20, merged):       22
#   Medium     (6-20):              106
#   Small      (2-5):               277
#   Singleton  (1 protein):         550
# Analysis population:              3306  (labelled + structured; excludes 83 Unknown, 6 no-group)
# Global essential rate:                23.4%  (773 / 3306)
# Allocation mode:                  size-stratified
# Number of splits:                 50
# Train/test ratio:                 80% / 20%
# Size tolerance:                   +/-5.0pp  (acceptable range: 15%-25%)
# Balance tolerance:                +/-4.5pp
# Max redraw attempts per split:    25
# Splits requiring redraw:          18 / 50
# Splits with size warnings:        0 / 50
# Splits with balance warnings:     0 / 50
# Splits with leakage violations:   0 / 50
# Splits emitted without full accept: 0 / 50
#
# Test positive COUNT across splits: min 116, median 143, max 169. On an imbalanced task the per-split positive count drives PR-AUC variance more than the rate does.
#
# Denominators above are the number of splits actually emitted, not the requested n_splits.
#
#  Split  Att   Train N  Train%  Train pos%   Test N  Test%  Test pos%  Test pos n   SzDev  LblDev  Flag
# ----------------------------------------------------------------------------------------------------
#      1    1      2709   79.8%       24.0%      685  20.2%      20.8%         135    0.2pp    2.6pp
#      2    1      2771   81.6%       23.0%      623  18.4%      25.0%         153    1.6pp    1.6pp
#      3    1      2691   79.3%       23.2%      703  20.7%      24.1%         167    0.7pp    0.8pp
#      4    1      2811   82.8%       23.9%      583  17.2%      20.6%         116    2.8pp    2.8pp
#      5    1      2604   76.7%       24.2%      790  23.3%      20.7%         157    3.3pp    2.7pp
#      6    2      2714   80.0%       24.3%      680  20.0%      19.8%         132    0.0pp    3.6pp
#      7    2      2757   81.2%       22.9%      637  18.8%      25.4%         159    1.2pp    2.0pp
#      8    1      2726   80.3%       24.3%      668  19.7%      19.6%         125    0.3pp    3.8pp
#      9    2      2721   80.2%       23.2%      673  19.8%      24.1%         158    0.2pp    0.7pp
#     10    1      2717   80.0%       22.9%      677  19.9%      25.2%         169    0.1pp    1.8pp
#     11    3      2749   81.0%       22.7%      645  19.0%      26.3%         168    1.0pp    3.0pp
#     12    1      2738   80.7%       22.9%      656  19.3%      25.6%         163    0.7pp    2.2pp
#     13    1      2675   78.8%       24.1%      719  21.2%      20.9%         143    1.2pp    2.5pp
#     14    1      2718   80.1%       23.9%      676  19.9%      21.2%         139    0.1pp    2.2pp
#     15    1      2770   81.6%       24.0%      624  18.4%      20.6%         126    1.6pp    2.8pp
#     16    1      2715   80.0%       24.1%      679  20.0%      20.5%         137    0.0pp    2.8pp
#     17    2      2707   79.8%       23.7%      687  20.2%      22.0%         143    0.2pp    1.4pp
#     18    1      2698   79.5%       23.8%      696  20.5%      21.6%         144    0.5pp    1.8pp
#     19    1      2705   79.7%       24.2%      689  20.3%      20.3%         138    0.3pp    3.1pp
#     20    1      2642   77.8%       23.9%      752  22.2%      21.5%         159    2.2pp    1.9pp
#     21    1      2763   81.4%       22.9%      631  18.6%      25.3%         157    1.4pp    1.9pp
#     22    1      2706   79.7%       23.7%      688  20.3%      22.0%         148    0.3pp    1.4pp
#     23    2      2814   82.9%       22.6%      580  17.1%      27.0%         153    2.9pp    3.6pp
#     24    1      2810   82.8%       23.9%      584  17.2%      21.1%         120    2.8pp    2.3pp
#     25    1      2767   81.5%       23.9%      627  18.5%      20.9%         128    1.5pp    2.5pp
#     26    3      2681   79.0%       23.2%      713  21.0%      23.9%         168    1.0pp    0.5pp
#     27    1      2785   82.1%       23.9%      609  17.9%      21.3%         127    2.1pp    2.1pp
#     28    1      2786   82.1%       23.9%      608  17.9%      21.0%         125    2.1pp    2.3pp
#     29    1      2657   78.3%       23.8%      737  21.7%      21.8%         153    1.7pp    1.6pp
#     30    3      2778   81.8%       23.4%      616  18.1%      23.1%         139    1.9pp    0.2pp
#     31    2      2753   81.1%       22.7%      641  18.9%      26.1%         164    1.1pp    2.7pp
#     32    1      2752   81.1%       24.0%      642  18.9%      20.6%         128    1.1pp    2.8pp
#     33    1      2710   79.8%       23.8%      684  20.1%      21.6%         144    0.1pp    1.7pp
#     34    1      2758   81.3%       23.7%      636  18.7%      22.2%         139    1.3pp    1.2pp
#     35    1      2779   81.9%       23.6%      615  18.1%      22.5%         137    1.9pp    0.8pp
#     36    2      2694   79.4%       23.7%      700  20.6%      22.2%         150    0.6pp    1.2pp
#     37    2      2798   82.4%       22.7%      596  17.6%      26.6%         155    2.4pp    3.2pp
#     38    1      2755   81.2%       24.2%      639  18.8%      19.7%         122    1.2pp    3.7pp
#     39    1      2761   81.3%       24.4%      633  18.6%      19.2%         118    1.4pp    4.2pp
#     40    2      2687   79.2%       23.8%      707  20.8%      21.9%         151    0.8pp    1.5pp
#     41    2      2658   78.3%       24.4%      736  21.7%      19.8%         140    1.7pp    3.6pp
#     42    2      2794   82.3%       24.0%      600  17.7%      20.3%         119    2.3pp    3.1pp
#     43    1      2681   79.0%       23.5%      713  21.0%      22.9%         157    1.0pp    0.4pp
#     44    1      2715   80.0%       23.0%      679  20.0%      25.1%         163    0.0pp    1.7pp
#     45    1      2806   82.7%       22.8%      588  17.3%      26.3%         152    2.7pp    2.9pp
#     46    3      2729   80.4%       24.0%      665  19.6%      20.8%         136    0.4pp    2.6pp
#     47    2      2822   83.2%       23.6%      572  16.9%      22.5%         126    3.1pp    0.9pp
#     48    2      2784   82.0%       23.4%      610  18.0%      23.1%         140    2.0pp    0.2pp
#     49    3      2765   81.5%       23.4%      629  18.5%      23.3%         144    1.5pp    0.0pp
#     50    1      2690   79.3%       24.1%      704  20.7%      20.5%         140    0.7pp    2.9pp
# ----------------------------------------------------------------------------------------------------
#   Mean                  80.6%       23.6%           19.4%      22.4%       143.5    1.3pp
#    Std                  1.46%       0.52%           1.46%      2.17%       14.96   0.92pp
#    Min                  76.7%       22.6%           16.9%      19.2%         116    0.0pp
#    Max                  83.2%       24.4%           23.3%      27.0%         169    3.3pp
#
# Leakage guarantee: all structural groups are atomic -- no group spans train and test. Complexes are NOT atomic by design; see the split_common module docstring.
# Flag key: Sz = size out of range, Lb = label imbalance, Lk = leakage, Vd = failed validation
#
# Bucket distribution (final split):
# group-size bucket distribution after split (groups counted):
# BUCKET           TRAIN   TEST  TOTAL TEST_FRAC
# large               18      4     22     0.182
# medium              85     21    106     0.198
# singleton          440    110    550     0.200
# small              222     55    277     0.199
#
# ==========================================================================================
# TEST SET BREAKDOWN BY STRUCTURAL GROUP SIZE BUCKET (proteins in test)
# ==========================================================================================
#  Split   Large N    L%   Pos%   Medium N    M%   Pos%   Small N    S%   Pos%   Singleton N   Sg%   Pos%
# ------------------------------------------------------------------------------------------
#      1       213 22.0%  13.6%        201 18.7%  24.1%       160 20.2%  23.8%           110 20.0%  23.1%
#      2       149 15.4%  38.8%        217 20.2%  23.6%       146 18.4%  15.9%           110 20.0%  21.3%
#      3       233 24.0%  37.7%        196 18.2%  16.4%       163 20.6%  17.9%           110 20.0%  18.2%
#      4       129 13.3%  10.1%        183 17.0%  25.7%       160 20.2%  21.4%           110 20.0%  22.6%
#      5       298 30.7%  25.9%        216 20.1%  18.3%       165 20.8%  15.9%           110 20.0%  19.4%
#      6       169 17.4%  21.9%        231 21.5%  21.1%       169 21.3%  18.1%           110 20.0%  16.7%
#      7       156 16.1%  35.9%        209 19.4%  28.2%       161 20.3%  18.1%           110 20.0%  15.7%
#      8       209 21.5%  15.6%        195 18.1%  25.4%       153 19.3%  21.9%           110 20.0%  12.8%
#      9       157 16.2%  34.0%        241 22.4%  19.1%       164 20.7%  23.9%           110 20.0%  21.2%
#     10       178 18.4%  43.5%        241 22.4%  20.3%       147 18.5%  14.3%           110 20.0%  21.1%
#     11       175 18.0%  37.0%        207 19.3%  25.2%       152 19.2%  21.1%           110 20.0%  18.7%
#     12       200 20.6%  42.0%        189 17.6%  21.5%       156 19.7%  18.8%           110 20.0%  13.6%
#     13       240 24.7%  20.6%        216 20.1%  26.0%       152 19.2%  17.3%           110 20.0%  16.4%
#     14       218 22.5%  29.6%        189 17.6%  14.4%       158 19.9%  19.9%           110 20.0%  17.6%
#     15       153 15.8%  20.7%        202 18.8%  26.0%       158 19.9%  10.9%           110 20.0%  24.5%
#     16       197 20.3%  24.1%        212 19.7%  21.1%       159 20.1%  16.7%           110 20.0%  18.7%
#     17       216 22.3%  25.9%        197 18.3%  22.6%       163 20.6%  16.0%           110 20.0%  22.9%
#     18       199 20.5%  30.1%        220 20.5%  25.0%       166 20.9%  12.7%           110 20.0%  14.5%
#     19       193 19.9%  20.2%        227 21.1%  25.3%       158 19.9%  17.7%           110 20.0%  13.6%
#     20       255 26.3%  24.2%        224 20.8%  22.0%       162 20.4%  20.5%           110 20.0%  15.7%
#     21       147 15.2%  34.0%        217 20.2%  19.3%       156 19.7%  26.6%           110 20.0%  23.6%
#     22       191 19.7%  17.6%        235 21.9%  32.5%       151 19.0%  16.4%           110 20.0%  14.8%
#     23       101 10.4%  43.9%        209 19.4%  27.7%       159 20.1%  21.0%           110 20.0%  19.3%
#     24       103 10.6%  22.0%        221 20.6%  21.1%       149 18.8%  23.6%           110 20.0%  16.7%
#     25       140 14.4%  38.6%        219 20.4%  12.9%       157 19.8%  19.9%           110 20.0%  15.0%
#     26       207 21.3%  30.0%        236 22.0%  17.0%       159 20.1%  26.6%           110 20.0%  22.9%
#     27       160 16.5%  22.3%        187 17.4%  20.9%       151 19.0%  20.7%           110 20.0%  21.3%
#     28       132 13.6%  27.9%        198 18.4%  25.1%       167 21.1%  15.0%           110 20.0%  15.5%
#     29       242 24.9%  17.1%        223 20.7%  22.8%       161 20.3%  26.2%           110 20.0%  22.6%
#     30       132 13.6%  15.2%        205 19.1%  28.5%       168 21.2%  21.0%           110 20.0%  25.7%
#     31       158 16.3%  53.8%        205 19.1%  15.9%       167 21.1%  10.9%           110 20.0%  28.3%
#     32       184 19.0%  19.5%        190 17.7%  18.3%       157 19.8%  24.2%           110 20.0%  20.8%
#     33       207 21.3%  36.8%        198 18.4%   9.7%       168 21.2%  20.4%           110 20.0%  15.7%
#     34       140 14.4%  27.5%        226 21.0%  22.2%       159 20.1%  20.1%           110 20.0%  18.3%
#     35       145 14.9%  22.4%        185 17.2%  26.6%       174 21.9%  21.4%           110 20.0%  17.6%
#     36       218 22.5%  23.7%        212 19.7%  24.3%       159 20.1%  19.5%           110 20.0%  19.3%
#     37       130 13.4%  44.5%        202 18.8%  30.4%       153 19.3%  14.7%           110 20.0%  15.5%
#     38       166 17.1%   7.4%        207 19.3%  29.1%       155 19.5%  24.2%           110 20.0%  15.0%
#     39       152 15.7%  25.3%        218 20.3%  15.2%       152 19.2%  20.7%           110 20.0%  16.0%
#     40       210 21.6%  26.6%        240 22.3%  17.7%       146 18.4%  26.2%           110 20.0%  15.9%
#     41       257 26.5%  17.9%        212 19.7%  21.9%       156 19.7%  17.9%           110 20.0%  22.2%
#     42       133 13.7%  23.8%        199 18.5%  20.4%       157 19.8%  19.2%           110 20.0%  17.6%
#     43       220 22.7%  25.8%        230 21.4%  22.5%       152 19.2%  22.0%           110 20.0%  20.2%
#     44       225 23.2%  25.9%        181 16.8%  33.1%       162 20.4%  20.5%           110 20.0%  17.6%
#     45       124 12.8%  39.3%        191 17.8%  33.5%       162 20.4%  14.3%           110 20.0%  17.3%
#     46       207 21.3%  22.4%        199 18.5%  23.8%       148 18.7%  14.2%           110 20.0%  21.1%
#     47       135 13.9%  20.3%        176 16.4%  20.0%       150 18.9%  30.7%           110 20.0%  17.6%
#     48       129 13.3%  40.3%        213 19.8%  19.5%       157 19.8%  17.8%           110 20.0%  17.4%
#     49       132 13.6%  36.2%        222 20.7%  22.5%       164 20.7%  14.2%           110 20.0%  23.4%
#     50       211 21.8%  28.8%        228 21.2%  16.0%       154 19.4%  15.9%           110 20.0%  19.8%
# ------------------------------------------------------------------------------------------
#   Mean     179.5 18.5%  27.8%      209.9 19.5%  22.4%     158.0 19.9%  19.4%         110.0 20.0%  18.8%
#    Std      44.1 4.55%  9.85%       16.8 1.56%  5.10%       6.5 0.82%  4.25%           0.0 0.00%  3.47%
#
#   N% = % of that bucket's proteins going to test.
#   Pos% = essential rate among analysis-population test proteins in that bucket.
#
# ==========================================================================================
# LARGE-BUCKET PROFILE ANALYSIS
# ==========================================================================================
#
# 1. Which large groups are in TEST per split?
# ------------------------------------------------------------
#   Split  1: grp_0222, grp_0916, grp_1004, grp_1341
#   Split  2: grp_0018, grp_0072, grp_0101, grp_0644
#   Split  3: grp_0000, grp_0113, grp_1179, grp_1186
#   Split  4: grp_0065, grp_0091, grp_0738, grp_1186
#   Split  5: grp_0000, grp_0222, grp_1179, grp_1341
#   Split  6: grp_0101, grp_0110, grp_0673, grp_1341
#   Split  7: grp_0033, grp_0101, grp_0673, grp_1341
#   Split  8: grp_0018, grp_0222, grp_0336, grp_0738
#   Split  9: grp_0110, grp_0644, grp_0673, grp_0916
#   Split 10: grp_0072, grp_0113, grp_1004, grp_1179
#   Split 11: grp_0091, grp_0738, grp_1091, grp_1179
#   Split 12: grp_0064, grp_0065, grp_0113, grp_0644
#   Split 13: grp_0091, grp_0113, grp_0222, grp_1186
#   Split 14: grp_0018, grp_0064, grp_0113, grp_0916
#   Split 15: grp_0033, grp_0101, grp_0916, grp_1186
#   Split 16: grp_0000, grp_0064, grp_0072, grp_0091
#   Split 17: grp_0091, grp_0113, grp_0222, grp_0738
#   Split 18: grp_0072, grp_0222, grp_0336, grp_0644
#   Split 19: grp_0064, grp_0738, grp_0821, grp_1186
#   Split 20: grp_0064, grp_1091, grp_1179, grp_1186
#   Split 21: grp_0000, grp_0018, grp_0336, grp_0738
#   Split 22: grp_0916, grp_1004, grp_1179, grp_1186
#   Split 23: grp_0033, grp_0336, grp_0738, grp_1004
#   Split 24: grp_0091, grp_0336, grp_0738, grp_1004
#   Split 25: grp_0110, grp_1004, grp_1091, grp_1341
#   Split 26: grp_0101, grp_0110, grp_0821, grp_1179
#   Split 27: grp_0110, grp_0738, grp_1186, grp_1341
#   Split 28: grp_0065, grp_0644, grp_1004, grp_1186
#   Split 29: grp_0110, grp_0222, grp_0673, grp_1341
#   Split 30: grp_0065, grp_0072, grp_0101, grp_0110
#   Split 31: grp_0000, grp_0644, grp_0673, grp_1091
#   Split 32: grp_0065, grp_0738, grp_1179, grp_1186
#   Split 33: grp_0113, grp_0336, grp_1179, grp_1186
#   Split 34: grp_0033, grp_0091, grp_0101, grp_0916
#   Split 35: grp_0000, grp_0673, grp_0916, grp_1004
#   Split 36: grp_0000, grp_0222, grp_0821, grp_1004
#   Split 37: grp_0072, grp_0916, grp_1091, grp_1341
#   Split 38: grp_0101, grp_0110, grp_0916, grp_1186
#   Split 39: grp_0091, grp_0673, grp_0916, grp_1341
#   Split 40: grp_0000, grp_0738, grp_1179, grp_1186
#   Split 41: grp_0064, grp_0222, grp_0336, grp_1091
#   Split 42: grp_0065, grp_0101, grp_0673, grp_1091
#   Split 43: grp_0000, grp_0222, grp_0738, grp_0821
#   Split 44: grp_0091, grp_0222, grp_0821, grp_1341
#   Split 45: grp_0018, grp_0033, grp_0738, grp_1004
#   Split 46: grp_0018, grp_0064, grp_0101, grp_1091
#   Split 47: grp_0000, grp_0101, grp_0738, grp_1004
#   Split 48: grp_0091, grp_1004, grp_1091, grp_1341
#   Split 49: grp_0101, grp_0113, grp_0336, grp_1004
#   Split 50: grp_0000, grp_0064, grp_0336, grp_1341
#
# 2. All large groups and their sizes (analysis population proteins)
# ------------------------------------------------------------
#   grp_0000:   51 proteins  |  in test for splits [3, 5, 16, 21, 31, 35, 36, 40, 43, 47, 50]
#   grp_0018:   48 proteins  |  in test for splits [2, 8, 14, 21, 45, 46]
#   grp_0033:   32 proteins  |  in test for splits [7, 15, 23, 34, 45]
#   grp_0064:   88 proteins  |  in test for splits [12, 14, 16, 19, 20, 41, 46, 50]
#   grp_0065:   18 proteins  |  in test for splits [4, 12, 28, 30, 32, 42]
#   grp_0072:   22 proteins  |  in test for splits [2, 10, 16, 18, 30, 37]
#   grp_0091:   34 proteins  |  in test for splits [4, 11, 13, 16, 17, 24, 34, 39, 44, 48]
#   grp_0101:   40 proteins  |  in test for splits [2, 6, 7, 15, 26, 30, 34, 38, 42, 46, 47, 49]
#   grp_0110:   45 proteins  |  in test for splits [6, 9, 25, 26, 27, 29, 30, 38]
#   grp_0113:   45 proteins  |  in test for splits [3, 10, 12, 13, 14, 17, 33, 49]
#   grp_0222:   93 proteins  |  in test for splits [1, 5, 8, 13, 17, 18, 29, 36, 41, 43, 44]
#   grp_0336:   24 proteins  |  in test for splits [8, 18, 21, 23, 24, 33, 41, 49, 50]
#   grp_0644:   37 proteins  |  in test for splits [2, 9, 12, 18, 28, 31]
#   grp_0673:   39 proteins  |  in test for splits [6, 7, 9, 29, 31, 35, 39, 42]
#   grp_0738:   21 proteins  |  in test for splits [4, 8, 11, 17, 19, 21, 23, 24, 27, 32, 40, 43, 45, 47]
#   grp_0821:   33 proteins  |  in test for splits [19, 26, 36, 43, 44]
#   grp_0916:   32 proteins  |  in test for splits [1, 9, 14, 15, 22, 34, 35, 37, 38, 39]
#   grp_1004:   21 proteins  |  in test for splits [1, 10, 22, 23, 24, 25, 28, 35, 36, 45, 47, 48, 49]
#   grp_1091:   29 proteins  |  in test for splits [11, 20, 25, 31, 37, 41, 42, 46, 48]
#   grp_1179:   89 proteins  |  in test for splits [3, 5, 10, 11, 20, 22, 26, 32, 33, 40]
#   grp_1186:   46 proteins  |  in test for splits [3, 4, 13, 15, 19, 20, 22, 27, 28, 32, 33, 38, 40]
#   grp_1341:   45 proteins  |  in test for splits [1, 5, 6, 7, 25, 27, 29, 37, 39, 44, 48, 50]
#
# 3. Large test set size per split (all proteins)
# ------------------------------------------------------------
#   Split  1:  213 proteins
#   Split  2:  149 proteins
#   Split  3:  233 proteins
#   Split  4:  129 proteins
#   Split  5:  298 proteins
#   Split  6:  169 proteins
#   Split  7:  156 proteins
#   Split  8:  209 proteins
#   Split  9:  157 proteins
#   Split 10:  178 proteins
#   Split 11:  175 proteins
#   Split 12:  200 proteins
#   Split 13:  240 proteins
#   Split 14:  218 proteins
#   Split 15:  153 proteins
#   Split 16:  197 proteins
#   Split 17:  216 proteins
#   Split 18:  199 proteins
#   Split 19:  193 proteins
#   Split 20:  255 proteins
#   Split 21:  147 proteins
#   Split 22:  191 proteins
#   Split 23:  101 proteins
#   Split 24:  103 proteins
#   Split 25:  140 proteins
#   Split 26:  207 proteins
#   Split 27:  160 proteins
#   Split 28:  132 proteins
#   Split 29:  242 proteins
#   Split 30:  132 proteins
#   Split 31:  158 proteins
#   Split 32:  184 proteins
#   Split 33:  207 proteins
#   Split 34:  140 proteins
#   Split 35:  145 proteins
#   Split 36:  218 proteins
#   Split 37:  130 proteins
#   Split 38:  166 proteins
#   Split 39:  152 proteins
#   Split 40:  210 proteins
#   Split 41:  257 proteins
#   Split 42:  133 proteins
#   Split 43:  220 proteins
#   Split 44:  225 proteins
#   Split 45:  124 proteins
#   Split 46:  207 proteins
#   Split 47:  135 proteins
#   Split 48:  129 proteins
#   Split 49:  132 proteins
#   Split 50:  211 proteins
#
# 4. Overlap statistics across all splits
# ------------------------------------------------------------
#   Intersection (in ALL test sets): 0
#   Union (in ANY test set):         970
#   Jaccard similarity:              0.000
#
# 5. Per-protein test frequency (how many splits each protein is in test)
# ------------------------------------------------------------
#   5 split(s): 65 proteins
#   6 split(s): 134 proteins
#   8 split(s): 220 proteins
#   9 split(s): 54 proteins
#   10 split(s): 157 proteins
#   11 split(s): 164 proteins
#   12 split(s): 85 proteins
#   13 split(s): 68 proteins
#   14 split(s): 23 proteins
#
# 6. Per-group test frequency -- randomness check
# ------------------------------------------------------------
#   Total large groups:          22
#   Groups drawn to test/split:  4  (18.2%)
#   Expected test freq per group over 50 splits: 9.1
#   Binomial SD: 2.73   2 SD band: [3.6, 14.5]
#   With this many groups, roughly one falling outside the band by chance is expected.
#
#   Group                           AP size  Test count  Note
#   grp_0000                             51          11  ok
#   grp_0018                             48           6  ok
#   grp_0033                             32           5  ok
#   grp_0064                             88           8  ok
#   grp_0065                             18           6  ok
#   grp_0072                             22           6  ok
#   grp_0091                             34          10  ok
#   grp_0101                             40          12  ok
#   grp_0110                             45           8  ok
#   grp_0113                             45           8  ok
#   grp_0222                             93          11  ok
#   grp_0336                             24           9  ok
#   grp_0644                             37           6  ok
#   grp_0673                             39           8  ok
#   grp_0738                             21          14  ok
#   grp_0821                             33           5  ok
#   grp_0916                             32          10  ok
#   grp_1004                             21          13  ok
#   grp_1091                             29           9  ok
#   grp_1179                             89          10  ok
#   grp_1186                             46          13  ok
#   grp_1341                             45          12  ok
#
#   Min test count: 5  Max: 14  Mean: 9.09  Std: 2.68
#   Groups outside the 2 SD band: 0 / 22  (~1 expected by chance)
#   Observed SD vs binomial SD: 2.68 vs 2.73  -- tighter than a fair draw would give.
#
# ==========================================================================================
# 7. Essential rate per group size  (analysis population only)
# ==========================================================================================
#   Analysis population = labelled (Essential/Non-essential) + structured
#   Global essential rate: 23.4%
#   n = 3306
#
#     group_size   n_groups    n_proteins    n_positive      pos_rate
#   --------------------------------------------------------------------
#              1        545           545           103         18.9%
#              2        134           268            61         22.8%
#              3         72           216            38         17.6%
#              4         45           180            33         18.3%
#              5         26           130            20         15.4%
#              6         24           144            29         20.1%
#              7         14            98            23         23.5%
#              8         13           104            28         26.9%
#              9         10            90            22         24.4%
#             10          4            40            14         35.0%
#             11          2            22             9         40.9%
#             12          6            72            26         36.1%
#             13          6            78            22         28.2%
#             14          6            84            11         13.1%
#             15          3            45             4          8.9%
#             16          5            80             1          1.2%
#             17          4            68            22         32.4%
#             18          5            90            11         12.2%
#             19          2            38             5         13.2%
#             21          2            42             6         14.3%
#             22          1            22            10         45.5%
#             24          1            24             9         37.5%
#             29          1            29            23         79.3%
#             32          2            64            31         48.4%
#             33          1            33            24         72.7%
#             34          1            34             7         20.6%
#             37          1            37            33         89.2%
#             39          1            39             7         17.9%
#             40          1            40             0          0.0%
#             45          3           135            67         49.6%
#             46          1            46             0          0.0%
#             48          1            48            14         29.2%
#             51          1            51            21         41.2%
#             88          1            88             9         10.2%
#             89          1            89            29         32.6%
#             93          1            93             1          1.1%
#
#   Saved: /Users/anitaapplegarth/github/dphil/protein_complexes/data/lookup_tables/cp/avg_essentiality_by_group_size.csv
#
# ==========================================================================================
# 8. Large-bucket test essential rate by split
# ==========================================================================================
#   Global essential rate: 23.4%
#
#   Split   Groups in test   Test proteins  Bucket rate
#   ------------------------------------------------------
#       1                4             213        13.6%
#       2                4             149        38.8%
#       3                4             233        37.7%
#       4                4             129        10.1%
#       5                4             298        25.9%
#       6                4             169        21.9%
#       7                4             156        35.9%
#       8                4             209        15.6%
#       9                4             157        34.0%
#      10                4             178        43.5%
#      11                4             175        37.0%
#      12                4             200        42.0%
#      13                4             240        20.6%
#      14                4             218        29.6%
#      15                4             153        20.7%
#      16                4             197        24.1%
#      17                4             216        25.9%
#      18                4             199        30.1%
#      19                4             193        20.2%
#      20                4             255        24.2%
#      21                4             147        34.0%
#      22                4             191        17.6%
#      23                4             101        43.9%
#      24                4             103        22.0%
#      25                4             140        38.6%
#      26                4             207        30.0%
#      27                4             160        22.3%
#      28                4             132        27.9%
#      29                4             242        17.1%
#      30                4             132        15.2%
#      31                4             158        53.8%
#      32                4             184        19.5%
#      33                4             207        36.8%
#      34                4             140        27.5%
#      35                4             145        22.4%
#      36                4             218        23.7%
#      37                4             130        44.5%
#      38                4             166         7.4%
#      39                4             152        25.3%
#      40                4             210        26.6%
#      41                4             257        17.9%
#      42                4             133        23.8%
#      43                4             220        25.8%
#      44                4             225        25.9%
#      45                4             124        39.3%
#      46                4             207        22.4%
#      47                4             135        20.3%
#      48                4             129        40.3%
#      49                4             132        36.2%
#      50                4             211        28.8%
#
#   Saved: /Users/anitaapplegarth/github/dphil/protein_complexes/data/lookup_tables/cp/ess_split_summary.txt
#
# Done!
